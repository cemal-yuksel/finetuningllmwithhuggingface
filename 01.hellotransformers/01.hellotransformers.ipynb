# %% [markdown]
# # 🚀 Transformers ve Hugging Face'e Merhaba!
#
# <div style="background: linear-gradient(135deg, #E8F5E9 0%, #F3E5F5 100%); padding: 25px; border-radius: 15px; border-left: 5px solid #81C784; margin: 20px 0;">
#     <h2 style="color: #2E7D32; margin-top: 0;">📚 Ders Hedefi</h2>
#     <p style="font-size: 16px; line-height: 1.8; color: #424242;">
#         Bu derste, <strong>transformatör tabanlı büyük dil modelleriyle</strong> çalışmaya başlamadan önce, bu modellerin pratikte nasıl erişilebilir hale geldiğini ve neden günümüz yapay zeka ekosisteminin merkezinde yer aldığını anlayacağız.
#     </p>
#     <p style="font-size: 16px; line-height: 1.8; color: #424242;">
#         🎯 Amacımız doğrudan kod yazmak değil, <strong>kullanılan araçların mantığını ve rolünü doğru konumlandırmaktır.</strong>
#     </p>
# </div>
#
# <div style="background: linear-gradient(135deg, #FFF9C4 0%, #FFE0B2 100%); padding: 20px; border-radius: 15px; margin: 20px 0; box-shadow: 0 4px 6px rgba(0,0,0,0.1);">
#     <h3 style="color: #F57C00; margin-top: 0;">💡 YBS Perspektifi</h3>
#     <p style="font-size: 15px; line-height: 1.6; color: #424242;">
#         <strong>Yönetim Bilişim Sistemleri</strong> perspektifinde teknoloji, önce <em>"neden"</em> ve <em>"nasıl"</em> sorularıyla anlaşılır, sonra uygulamaya geçilir.
#     </p>
# </div>
#
# ---

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 🤗 Hugging Face Ekosistemi Nedir?
#
# <div style="background: linear-gradient(135deg, #E1F5FE 0%, #F3E5F5 100%); padding: 30px; border-radius: 20px; margin: 25px 0; box-shadow: 0 6px 12px rgba(0,0,0,0.08);">
#     <h3 style="color: #0277BD; margin-top: 0;">🌟 Tanım</h3>
#     <p style="font-size: 17px; line-height: 1.9; color: #263238;">
#         <strong>Hugging Face</strong>, transformatör tabanlı modelleri <span style="background-color: #FFEB3B; padding: 3px 8px; border-radius: 5px; font-weight: bold;">herkes için erişilebilir</span> hale getiren bir <strong>açık kaynak platformudur</strong>.
#     </p>
# </div>
#
# ### 📈 Hugging Face'in Evrimi
#
# <div style="display: flex; gap: 15px; margin: 20px 0; flex-wrap: wrap;">
#
# <div style="flex: 1; min-width: 250px; background: linear-gradient(135deg, #FFECB3 0%, #FFE0B2 100%); padding: 20px; border-radius: 15px; border-top: 4px solid #FF9800;">
#     <h4 style="color: #E65100; margin-top: 0;">🏁 Başlangıç</h4>
#     <p style="color: #424242; line-height: 1.6;">
#         Sadece <strong>Doğal Dil İşleme (NLP)</strong> modelleriyle yola çıktı
#     </p>
# </div>
#
# <div style="flex: 1; min-width: 250px; background: linear-gradient(135deg, #C8E6C9 0%, #DCEDC8 100%); padding: 20px; border-radius: 15px; border-top: 4px solid #4CAF50;">
#     <h4 style="color: #1B5E20; margin-top: 0;">🚀 Bugün</h4>
#     <p style="color: #424242; line-height: 1.6;">
#         <strong>Metin, Görüntü, Ses</strong> ve <strong>Çok Modlu</strong> yapay zeka uygulamalarını kapsıyor
#     </p>
# </div>
#
# </div>
#
# <div style="background: linear-gradient(135deg, #F8BBD0 0%, #E1BEE7 100%); padding: 25px; border-radius: 15px; margin: 25px 0; border-left: 5px solid #C2185B;">
#     <h3 style="color: #880E4F; margin-top: 0;">🏪 Yapay Zeka Pazaryeri</h3>
#     <p style="font-size: 16px; line-height: 1.8; color: #424242;">
#         Bugün Hugging Face, <strong>binlerce hazır modelin</strong> bulunduğu bir <em>"yapay zeka pazaryeri"</em> gibi düşünülebilir. İhtiyacınız olan modeli bulup hemen kullanabilirsiniz! 🛍️
#     </p>
# </div>
#
# ### 🎨 Hugging Face'te Bulunan Model Türleri
#
# | 🔤 Kategori | 📝 Açıklama | 🌟 Örnek Kullanım |
# |------------|-------------|------------------|
# | **Metin** | Dil modelleri, metin işleme | Sohbet botları, çeviri, özetleme |
# | **Görüntü** | Görüntü tanıma ve üretim | Nesne tespiti, görsel sınıflandırma |
# | **Ses** | Ses tanıma ve sentezleme | Konuşma tanıma, metin-konuşma |
# | **Çok Modlu** | Birden fazla veri tipi | Görsel soru yanıtlama |
#
# ---

# %% [markdown]
# ## 🎯 Neden Hugging Face Kullanıyoruz?
#
# <div style="background: linear-gradient(135deg, #E8EAF6 0%, #C5CAE9 100%); padding: 30px; border-radius: 20px; margin: 25px 0; box-shadow: 0 8px 16px rgba(0,0,0,0.1);">
#     <h3 style="color: #283593; margin-top: 0;">🔑 Temel Unsur</h3>
#     <p style="font-size: 17px; line-height: 1.9; color: #1A237E; font-weight: 500;">
#         Hugging Face'i önemli yapan temel unsur, <span style="background-color: #FFEB3B; padding: 4px 10px; border-radius: 5px; font-weight: bold; color: #000;">karmaşık yapay zeka modellerini sıfırdan inşa etmeyi zorunlu kılmamasıdır</span> ❌🏗️
#     </p>
# </div>
#
# ### 💡 Sıfırdan Eğitim vs. Hazır Model
#
# <div style="display: grid; grid-template-columns: 1fr 1fr; gap: 20px; margin: 25px 0;">
#
# <div style="background: linear-gradient(135deg, #FFCDD2 0%, #F8BBD0 100%); padding: 25px; border-radius: 15px; border: 3px solid #E91E63;">
#     <h4 style="color: #C2185B; margin-top: 0; text-align: center;">❌ Geleneksel Yöntem</h4>
#     <ul style="color: #424242; line-height: 2; font-size: 15px;">
#         <li>⏰ Aylarca süren eğitim</li>
#         <li>💰 Yüksek maliyet</li>
#         <li>👥 Büyük ekip gereksinimi</li>
#         <li>🖥️ Güçlü donanım ihtiyacı</li>
#     </ul>
# </div>
#
# <div style="background: linear-gradient(135deg, #C8E6C9 0%, #A5D6A7 100%); padding: 25px; border-radius: 15px; border: 3px solid #4CAF50;">
#     <h4 style="color: #1B5E20; margin-top: 0; text-align: center;">✅ Hugging Face Yöntemi</h4>
#     <ul style="color: #424242; line-height: 2; font-size: 15px;">
#         <li>⚡ Hazır model kullanımı</li>
#         <li>💸 Düşük maliyet</li>
#         <li>👤 Minimal ekip</li>
#         <li>🔧 Hızlı uyarlama</li>
#     </ul>
# </div>
#
# </div>
#
# <div style="background: linear-gradient(135deg, #FFF9C4 0%, #FFF59D 100%); padding: 25px; border-radius: 15px; margin: 25px 0; border-left: 6px solid #F9A825;">
#     <h3 style="color: #F57F17; margin-top: 0;">📊 İş Dünyası Avantajları</h3>
#     <table style="width: 100%; border-collapse: collapse; margin-top: 15px;">
#         <tr style="background-color: #FFECB3;">
#             <th style="padding: 12px; text-align: left; border: 1px solid #FDD835; color: #E65100;">Kaynak</th>
#             <th style="padding: 12px; text-align: left; border: 1px solid #FDD835; color: #E65100;">Kazanım</th>
#         </tr>
#         <tr>
#             <td style="padding: 12px; border: 1px solid #FDD835;">⏱️ <strong>Zaman</strong></td>
#             <td style="padding: 12px; border: 1px solid #FDD835;">Aylardan günlere/haftalara</td>
#         </tr>
#         <tr>
#             <td style="padding: 12px; border: 1px solid #FDD835;">💵 <strong>Maliyet</strong></td>
#             <td style="padding: 12px; border: 1px solid #FDD835;">%80-90 azalma</td>
#         </tr>
#         <tr>
#             <td style="padding: 12px; border: 1px solid #FDD835;">👨‍💼 <strong>İnsan Kaynağı</strong></td>
#             <td style="padding: 12px; border: 1px solid #FDD835;">Uzman ekip → Küçük geliştirici ekibi</td>
#         </tr>
#     </table>
# </div>
#
# <div style="background: linear-gradient(135deg, #D1C4E9 0%, #B39DDB 100%); padding: 30px; border-radius: 20px; margin: 30px 0; box-shadow: 0 6px 12px rgba(0,0,0,0.1);">
#     <h3 style="color: #4527A0; margin-top: 0;">🎓 YBS Öğrencileri İçin Kritik Nokta</h3>
#     <p style="font-size: 18px; line-height: 2; color: #311B92; font-weight: 500;">
#         Burada asıl değer <span style="background-color: #FFEB3B; padding: 4px 10px; border-radius: 5px; font-weight: bold; color: #000;">kod yazma becerisinden çok</span>
#         <br><br>
#         <span style="font-size: 20px;">🎯 "Doğru teknolojiyi doğru iş problemine eşleştirebilme yeteneğidir" 🎯</span>
#     </p>
# </div>
#
# ---

# %% [markdown]
# ## 🔄 İki Aşamalı Model Eğitim Süreci
#
# <div style="background: linear-gradient(135deg, #FCE4EC 0%, #F3E5F5 100%); padding: 30px; border-radius: 20px; margin: 25px 0; box-shadow: 0 8px 16px rgba(0,0,0,0.1);">
#     <h3 style="color: #C2185B; margin-top: 0;">📚 Öğrenme Süreci Analojisi</h3>
#     <p style="font-size: 16px; line-height: 1.8; color: #424242;">
#         Hugging Face ekosisteminde karşılaşacağınız modeller <strong>temelde iki aşamalı bir mantıkla</strong> çalışır. Bu süreci bir öğrencinin dil öğrenme sürecine benzetebiliriz! 🎓
#     </p>
# </div>
#
# ### 1️⃣ Birinci Aşama: Ön Eğitim (Pre-training)
#
# <div style="background: linear-gradient(135deg, #B3E5FC 0%, #81D4FA 100%); padding: 30px; border-radius: 20px; margin: 25px 0; border: 4px solid #0277BD;">
#     <h4 style="color: #01579B; margin-top: 0; font-size: 20px;">📖 Ön Eğitim Nedir?</h4>
#     <p style="font-size: 16px; line-height: 1.9; color: #263238;">
#         Model, <span style="background-color: #FFEB3B; padding: 3px 8px; border-radius: 5px; font-weight: bold;">çok büyük ve genellikle etiketlenmemiş veriler</span> üzerinde <strong>dilin genel yapısını öğrenir</strong>.
#     </p>
#
# <div style="background-color: rgba(255,255,255,0.8); padding: 20px; border-radius: 10px; margin-top: 15px;">
#     <h5 style="color: #0277BD; margin-top: 0;">🔍 Ne Öğrenilir?</h5>
#     <ul style="line-height: 2; color: #424242; font-size: 15px;">
#         <li>📝 Kelimelerin anlamları</li>
#         <li>🔗 Cümlelerin yapısı</li>
#         <li>💬 Bağlamsal ilişkiler</li>
#         <li>🌍 Genel dil kuralları</li>
#     </ul>
# </div>
# </div>
#
# <div style="background: linear-gradient(135deg, #FFF9C4 0%, #FFF59D 100%); padding: 25px; border-radius: 15px; margin: 25px 0; border-left: 6px solid #F9A825;">
#     <h4 style="color: #F57F17; margin-top: 0;">🎯 Önemli Kavram: Denetimsiz Öğrenme</h4>
#     <p style="font-size: 16px; line-height: 1.8; color: #424242;">
#         Bu süreç <strong>"denetimsiz öğrenme"</strong> olarak adlandırılır. Model, doğru cevap verilmeden kendi kendine öğrenir!
#     </p>
#     <div style="background-color: rgba(255,255,255,0.7); padding: 15px; border-radius: 8px; margin-top: 15px;">
#         <p style="margin: 0; font-size: 15px; color: #424242;">
#             <strong>💡 Analoji:</strong> Bir öğrencinin kitap okuyarak ve çevresindeki konuşmaları dinleyerek <em>doğal olarak</em> bir dili öğrenmesi gibi...
#         </p>
#     </div>
# </div>
#
# ### 📊 Ön Eğitim Süreci Görselleştirme
#
# <div style="display: flex; align-items: center; justify-content: space-around; margin: 30px 0; flex-wrap: wrap; gap: 20px;">
#
# <div style="flex: 1; min-width: 200px; background: linear-gradient(135deg, #E3F2FD 0%, #BBDEFB 100%); padding: 25px; border-radius: 15px; text-align: center; box-shadow: 0 4px 8px rgba(0,0,0,0.1);">
#     <div style="font-size: 40px; margin-bottom: 10px;">📚</div>
#     <h5 style="color: #0D47A1; margin: 10px 0;">Milyarlarca Kelime</h5>
#     <p style="color: #424242; margin: 0; font-size: 14px;">Etiketlenmemiş veri</p>
# </div>
#
# <div style="font-size: 40px; color: #4CAF50;">➡️</div>
#
# <div style="flex: 1; min-width: 200px; background: linear-gradient(135deg, #F3E5F5 0%, #E1BEE7 100%); padding: 25px; border-radius: 15px; text-align: center; box-shadow: 0 4px 8px rgba(0,0,0,0.1);">
#     <div style="font-size: 40px; margin-bottom: 10px;">🧠</div>
#     <h5 style="color: #6A1B9A; margin: 10px 0;">Dil Modeli</h5>
#     <p style="color: #424242; margin: 0; font-size: 14px;">Genel dil bilgisi</p>
# </div>
#
# <div style="font-size: 40px; color: #4CAF50;">➡️</div>
#
# <div style="flex: 1; min-width: 200px; background: linear-gradient(135deg, #C8E6C9 0%, #A5D6A7 100%); padding: 25px; border-radius: 15px; text-align: center; box-shadow: 0 4px 8px rgba(0,0,0,0.1);">
#     <div style="font-size: 40px; margin-bottom: 10px;">✅</div>
#     <h5 style="color: #2E7D32; margin: 10px 0;">Temel Model</h5>
#     <p style="color: #424242; margin: 0; font-size: 14px;">Hazır kullanım</p>
# </div>
#
# </div>
#
# ---

# %% [markdown]
# ### 2️⃣ İkinci Aşama: İnce Ayar (Fine-tuning)
#
# <div style="background: linear-gradient(135deg, #FFF3E0 0%, #FFE0B2 100%); padding: 30px; border-radius: 20px; margin: 25px 0; border: 4px solid #EF6C00;">
#     <h4 style="color: #E65100; margin-top: 0; font-size: 20px;">⚙️ Fine-Tuning Nedir?</h4>
#     <p style="font-size: 16px; line-height: 1.9; color: #424242;">
#         Model, <span style="background-color: #FFEB3B; padding: 3px 8px; border-radius: 5px; font-weight: bold;">belirli bir görev için özel olarak eğitilir</span>.
#     </p>
#
# <div style="background-color: rgba(255,255,255,0.8); padding: 20px; border-radius: 10px; margin-top: 15px;">
#     <h5 style="color: #EF6C00; margin-top: 0;">🎯 Örnek Görevler</h5>
#     <div style="display: grid; grid-template-columns: repeat(auto-fit, minmax(200px, 1fr)); gap: 10px; margin-top: 10px;">
#         <div style="background: linear-gradient(135deg, #E1F5FE 0%, #B3E5FC 100%); padding: 15px; border-radius: 10px; text-align: center;">
#             📊 <strong>Metin Sınıflandırma</strong>
#         </div>
#         <div style="background: linear-gradient(135deg, #F3E5F5 0%, #E1BEE7 100%); padding: 15px; border-radius: 10px; text-align: center;">
#             😊 <strong>Duygu Analizi</strong>
#         </div>
#         <div style="background: linear-gradient(135deg, #FFF9C4 0%, #FFF59D 100%); padding: 15px; border-radius: 10px; text-align: center;">
#             ❓ <strong>Soru Yanıtlama</strong>
#         </div>
#         <div style="background: linear-gradient(135deg, #C8E6C9 0%, #A5D6A7 100%); padding: 15px; border-radius: 10px; text-align: center;">
#             🏷️ <strong>NER (Varlık Tanıma)</strong>
#         </div>
#     </div>
# </div>
# </div>
#
# <div style="background: linear-gradient(135deg, #E8EAF6 0%, #C5CAE9 100%); padding: 25px; border-radius: 15px; margin: 25px 0; border-left: 6px solid #3F51B5;">
#     <h4 style="color: #283593; margin-top: 0;">🎓 Önemli Kavram: Denetimli Öğrenme</h4>
#     <p style="font-size: 16px; line-height: 1.8; color: #424242;">
#         Bu süreç <strong>"denetimli öğrenme"</strong> ile gerçekleştirilir. Model, <em>doğru cevapları bilinen örnekler</em> üzerinden yönlendirilir.
#     </p>
#     <div style="background-color: rgba(255,255,255,0.7); padding: 15px; border-radius: 8px; margin-top: 15px;">
#         <p style="margin: 0; font-size: 15px; color: #424242;">
#             <strong>💡 Analoji:</strong> Bir öğrencinin sınav soruları çözerek ve öğretmeninden düzeltme alarak <em>spesifik bir konuda uzmanlaşması</em> gibi...
#         </p>
#     </div>
# </div>
#
# ### 🔄 Fine-Tuning Süreci
#
# <div style="background: linear-gradient(135deg, #E8F5E9 0%, #C8E6C9 100%); padding: 30px; border-radius: 20px; margin: 25px 0; box-shadow: 0 6px 12px rgba(0,0,0,0.1);">
#     <h4 style="color: #1B5E20; margin-top: 0; text-align: center; font-size: 22px;">📌 Fine-Tuning'in Özü</h4>
#     <p style="font-size: 18px; line-height: 2; color: #2E7D32; text-align: center; font-weight: 500; margin: 20px 0;">
#         Modeli <span style="background-color: #FFEB3B; padding: 5px 12px; border-radius: 5px; font-weight: bold; color: #000;">genel bir bilgi havuzundan</span> alıp,<br>
#         <span style="background-color: #81C784; padding: 5px 12px; border-radius: 5px; font-weight: bold; color: #FFF;">spesifik bir iş problemine</span> uyarlama sürecidir! 🎯
#     </p>
# </div>
#
# ### 📊 Karşılaştırmalı Tablo
#
# <table style="width: 100%; border-collapse: collapse; margin: 25px 0; box-shadow: 0 4px 8px rgba(0,0,0,0.1);">
#     <thead>
#         <tr style="background: linear-gradient(135deg, #5C6BC0 0%, #3F51B5 100%); color: white;">
#             <th style="padding: 15px; text-align: left; border: 2px solid #3F51B5;">Özellik</th>
#             <th style="padding: 15px; text-align: center; border: 2px solid #3F51B5;">Ön Eğitim (Pre-training)</th>
#             <th style="padding: 15px; text-align: center; border: 2px solid #3F51B5;">İnce Ayar (Fine-tuning)</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr style="background-color: #E8EAF6;">
#             <td style="padding: 12px; border: 1px solid #9FA8DA; font-weight: bold;">📚 Veri Tipi</td>
#             <td style="padding: 12px; border: 1px solid #9FA8DA; text-align: center;">Etiketlenmemiş, büyük veri</td>
#             <td style="padding: 12px; border: 1px solid #9FA8DA; text-align: center;">Etiketlenmiş, küçük veri</td>
#         </tr>
#         <tr style="background-color: #F3E5F5;">
#             <td style="padding: 12px; border: 1px solid #CE93D8; font-weight: bold;">🎯 Öğrenme Türü</td>
#             <td style="padding: 12px; border: 1px solid #CE93D8; text-align: center;">Denetimsiz öğrenme</td>
#             <td style="padding: 12px; border: 1px solid #CE93D8; text-align: center;">Denetimli öğrenme</td>
#         </tr>
#         <tr style="background-color: #E8F5E9;">
#             <td style="padding: 12px; border: 1px solid #A5D6A7; font-weight: bold;">🎓 Hedef</td>
#             <td style="padding: 12px; border: 1px solid #A5D6A7; text-align: center;">Genel dil yapısı</td>
#             <td style="padding: 12px; border: 1px solid #A5D6A7; text-align: center;">Spesifik görev</td>
#         </tr>
#         <tr style="background-color: #FFF9C4;">
#             <td style="padding: 12px; border: 1px solid #FFF59D; font-weight: bold;">⏱️ Süre</td>
#             <td style="padding: 12px; border: 1px solid #FFF59D; text-align: center;">Haftalar/Aylar</td>
#             <td style="padding: 12px; border: 1px solid #FFF59D; text-align: center;">Saatler/Günler</td>
#         </tr>
#         <tr style="background-color: #FFECB3;">
#             <td style="padding: 12px; border: 1px solid #FFD54F; font-weight: bold;">💰 Maliyet</td>
#             <td style="padding: 12px; border: 1px solid #FFD54F; text-align: center;">Çok yüksek</td>
#             <td style="padding: 12px; border: 1px solid #FFD54F; text-align: center;">Düşük</td>
#         </tr>
#     </tbody>
# </table>
#
# ---

# %% [markdown]
# ## 🎯 Bu Repo'da Neler Öğreneceğiz?
#
# <div style="background: linear-gradient(135deg, #FCE4EC 0%, #F8BBD0 100%); padding: 30px; border-radius: 20px; margin: 25px 0; box-shadow: 0 8px 16px rgba(0,0,0,0.1);">
#     <h3 style="color: #C2185B; margin-top: 0;">🎓 Ana Odak Noktamız</h3>
#     <p style="font-size: 17px; line-height: 1.9; color: #424242; font-weight: 500;">
#         Bu repo kapsamında <span style="background-color: #FFEB3B; padding: 4px 10px; border-radius: 5px; font-weight: bold;">tam olarak bu noktaya odaklanacağız</span>:
#     </p>
#     <p style="font-size: 18px; line-height: 2; color: #880E4F; text-align: center; margin: 20px 0; font-weight: 600;">
#         "Hazır bir büyük dil modelini alıp, onu doğal dil işleme görevleri için nasıl ince ayar yapabileceğimizi adım adım ele alacağız" 🚀
#     </p>
# </div>
#
# ### 📝 Doğal Dil İşleme (NLP) Görevleri
#
# <div style="display: grid; grid-template-columns: repeat(auto-fit, minmax(250px, 1fr)); gap: 20px; margin: 25px 0;">
#
# <div style="background: linear-gradient(135deg, #E3F2FD 0%, #BBDEFB 100%); padding: 25px; border-radius: 15px; border-top: 5px solid #1976D2; box-shadow: 0 4px 8px rgba(0,0,0,0.1);">
#     <h4 style="color: #0D47A1; margin-top: 0; font-size: 18px;">📊 Metin Sınıflandırma</h4>
#     <p style="color: #424242; line-height: 1.6; font-size: 14px;">
#         Metinleri kategorilere ayırma
#     </p>
#     <div style="background-color: rgba(255,255,255,0.6); padding: 10px; border-radius: 8px; margin-top: 10px; font-size: 13px;">
#         <strong>Örnek:</strong> E-postaları spam/değil olarak ayırma
#     </div>
# </div>
#
# <div style="background: linear-gradient(135deg, #F3E5F5 0%, #E1BEE7 100%); padding: 25px; border-radius: 15px; border-top: 5px solid #7B1FA2; box-shadow: 0 4px 8px rgba(0,0,0,0.1);">
#     <h4 style="color: #4A148C; margin-top: 0; font-size: 18px;">📄 Özetleme</h4>
#     <p style="color: #424242; line-height: 1.6; font-size: 14px;">
#         Uzun metinleri kısaltma
#     </p>
#     <div style="background-color: rgba(255,255,255,0.6); padding: 10px; border-radius: 8px; margin-top: 10px; font-size: 13px;">
#         <strong>Örnek:</strong> Haber makalelerinden özet çıkarma
#     </div>
# </div>
#
# <div style="background: linear-gradient(135deg, #E8F5E9 0%, #C8E6C9 100%); padding: 25px; border-radius: 15px; border-top: 5px solid #388E3C; box-shadow: 0 4px 8px rgba(0,0,0,0.1);">
#     <h4 style="color: #1B5E20; margin-top: 0; font-size: 18px;">🌐 Çeviri</h4>
#     <p style="color: #424242; line-height: 1.6; font-size: 14px;">
#         Diller arası çeviri yapma
#     </p>
#     <div style="background-color: rgba(255,255,255,0.6); padding: 10px; border-radius: 8px; margin-top: 10px; font-size: 13px;">
#         <strong>Örnek:</strong> İngilizce → Türkçe çeviri
#     </div>
# </div>
#
# <div style="background: linear-gradient(135deg, #FFF9C4 0%, #FFF59D 100%); padding: 25px; border-radius: 15px; border-top: 5px solid #F57F17; box-shadow: 0 4px 8px rgba(0,0,0,0.1);">
#     <h4 style="color: #E65100; margin-top: 0; font-size: 18px;">❓ Soru Yanıtlama</h4>
#     <p style="color: #424242; line-height: 1.6; font-size: 14px;">
#         Sorulara otomatik cevap üretme
#     </p>
#     <div style="background-color: rgba(255,255,255,0.6); padding: 10px; border-radius: 8px; margin-top: 10px; font-size: 13px;">
#         <strong>Örnek:</strong> Chatbot uygulamaları
#     </div>
# </div>
#
# <div style="background: linear-gradient(135deg, #FFECB3 0%, #FFE082 100%); padding: 25px; border-radius: 15px; border-top: 5px solid #FF6F00; box-shadow: 0 4px 8px rgba(0,0,0,0.1);">
#     <h4 style="color: #E65100; margin-top: 0; font-size: 18px;">✍️ Metin Üretimi</h4>
#     <p style="color: #424242; line-height: 1.6; font-size: 14px;">
#         Yeni içerik oluşturma
#     </p>
#     <div style="background-color: rgba(255,255,255,0.6); padding: 10px; border-radius: 8px; margin-top: 10px; font-size: 13px;">
#         <strong>Örnek:</strong> Ürün açıklamaları yazma
#     </div>
# </div>
#
# </div>
#
# ### 🔮 İlerleyen Aşamalar
#
# <div style="background: linear-gradient(135deg, #E1F5FE 0%, #B3E5FC 100%); padding: 25px; border-radius: 15px; margin: 25px 0; border-left: 6px solid #0288D1;">
#     <h4 style="color: #01579B; margin-top: 0;">🖼️ Görüntü ve Çok Modlu Uygulamalar</h4>
#     <p style="font-size: 15px; line-height: 1.8; color: #424242;">
#         İlerleyen aşamalarda şu konulara da değinilecektir:
#     </p>
#     <ul style="line-height: 2; color: #424242; font-size: 15px;">
#         <li>📷 <strong>Görüntü Sınıflandırma</strong> - Resimleri kategorilere ayırma</li>
#         <li>🔀 <strong>Çok Modlu Uygulamalar</strong> - Metin + görüntü birlikte çalışma</li>
#     </ul>
# </div>
#
# <div style="background: linear-gradient(135deg, #C8E6C9 0%, #A5D6A7 100%); padding: 30px; border-radius: 20px; margin: 30px 0; box-shadow: 0 6px 12px rgba(0,0,0,0.1); border: 3px solid #4CAF50;">
#     <h3 style="color: #1B5E20; margin-top: 0; text-align: center;">🎯 Temel Omurgamız</h3>
#     <p style="font-size: 20px; line-height: 2; color: #2E7D32; text-align: center; font-weight: 600; margin: 0;">
#         📝 Metin Verisi + 🧠 NLP (Doğal Dil İşleme)
#     </p>
# </div>
#
# ---

# %% [markdown]
# ## 🛠️ Hugging Face'in Teknik Altyapısı
#
# <div style="background: linear-gradient(135deg, #E8EAF6 0%, #C5CAE9 100%); padding: 30px; border-radius: 20px; margin: 25px 0; box-shadow: 0 8px 16px rgba(0,0,0,0.1);">
#     <h3 style="color: #283593; margin-top: 0;">🔧 Arka Planda Neler Var?</h3>
#     <p style="font-size: 17px; line-height: 1.9; color: #424242;">
#         Hugging Face'in bir diğer önemli avantajı, arka planda <span style="background-color: #FFEB3B; padding: 3px 8px; border-radius: 5px; font-weight: bold;">popüler derin öğrenme kütüphanelerini kullanmasıdır</span> 🚀
#     </p>
# </div>
#
# ### 📚 Desteklenen Kütüphaneler
#
# <div style="display: grid; grid-template-columns: repeat(auto-fit, minmax(300px, 1fr)); gap: 20px; margin: 25px 0;">
#
# <div style="background: linear-gradient(135deg, #FFEBEE 0%, #FFCDD2 100%); padding: 30px; border-radius: 15px; text-align: center; box-shadow: 0 6px 12px rgba(0,0,0,0.1); border: 3px solid #E53935;">
#     <div style="font-size: 50px; margin-bottom: 15px;">🔥</div>
#     <h4 style="color: #B71C1C; margin: 10px 0; font-size: 22px;">PyTorch</h4>
#     <p style="color: #424242; font-size: 14px; line-height: 1.6;">
#         Facebook (Meta) tarafından geliştirilen popüler derin öğrenme framework'ü
#     </p>
# </div>
#
# <div style="background: linear-gradient(135deg, #FFF3E0 0%, #FFE0B2 100%); padding: 30px; border-radius: 15px; text-align: center; box-shadow: 0 6px 12px rgba(0,0,0,0.1); border: 3px solid #FB8C00;">
#     <div style="font-size: 50px; margin-bottom: 15px;">⚡</div>
#     <h4 style="color: #E65100; margin: 10px 0; font-size: 22px;">TensorFlow</h4>
#     <p style="color: #424242; font-size: 14px; line-height: 1.6;">
#         Google tarafından geliştirilen endüstri standardı derin öğrenme kütüphanesi
#     </p>
# </div>
#
# </div>
#
# <div style="background: linear-gradient(135deg, #C8E6C9 0%, #A5D6A7 100%); padding: 30px; border-radius: 20px; margin: 30px 0; border-left: 6px solid #4CAF50; box-shadow: 0 6px 12px rgba(0,0,0,0.1);">
#     <h3 style="color: #1B5E20; margin-top: 0;">✅ İyi Haber!</h3>
#     <p style="font-size: 18px; line-height: 2; color: #2E7D32; font-weight: 500;">
#         Bu kütüphaneleri <span style="background-color: #FFEB3B; padding: 4px 10px; border-radius: 5px; font-weight: bold; color: #000;">ileri düzeyde bilmek zorunlu değildir</span>! 🎉
#     </p>
#     <p style="font-size: 16px; line-height: 1.8; color: #424242; margin-top: 15px;">
#         <strong>Python'a temel düzeyde hakim olmak</strong>, bu ekosistemi verimli şekilde kullanmak için yeterlidir.
#     </p>
# </div>
#
# ### 🎓 YBS Öğrencileri İçin Avantajlar
#
# <div style="background: linear-gradient(135deg, #F3E5F5 0%, #E1BEE7 100%); padding: 30px; border-radius: 20px; margin: 25px 0; box-shadow: 0 8px 16px rgba(0,0,0,0.1);">
#     <h4 style="color: #6A1B9A; margin-top: 0; font-size: 20px;">📉 Düşük Öğrenme Eşiği</h4>
#
# <table style="width: 100%; border-collapse: collapse; margin: 20px 0;">
#     <tr style="background: linear-gradient(135deg, #CE93D8 0%, #BA68C8 100%); color: white;">
#         <th style="padding: 15px; text-align: left; border-radius: 8px 0 0 0;">Gerekli</th>
#         <th style="padding: 15px; text-align: left; border-radius: 0 8px 0 0;">Gerekli Değil</th>
#     </tr>
#     <tr style="background-color: rgba(255,255,255,0.9);">
#         <td style="padding: 15px; border: 2px solid #CE93D8;">
#             <ul style="margin: 0; padding-left: 20px; color: #424242; line-height: 2;">
#                 <li>🐍 Temel Python bilgisi</li>
#                 <li>📊 Temel programlama mantığı</li>
#                 <li>💡 Problem çözme becerisi</li>
#             </ul>
#         </td>
#         <td style="padding: 15px; border: 2px solid #CE93D8;">
#             <ul style="margin: 0; padding-left: 20px; color: #424242; line-height: 2;">
#                 <li>❌ İleri düzey PyTorch</li>
#                 <li>❌ İleri düzey TensorFlow</li>
#                 <li>❌ Derin matematik bilgisi</li>
#             </ul>
#         </td>
#     </tr>
# </table>
#
# <div style="background-color: rgba(255,255,255,0.7); padding: 20px; border-radius: 10px; margin-top: 20px;">
#     <p style="font-size: 16px; line-height: 1.8; color: #4A148C; margin: 0; font-weight: 500;">
#         🎯 Bu da YBS öğrencileri için <strong>öğrenme eşiğini ciddi biçimde düşürür</strong> ve yapay zeka projelerine daha hızlı başlamanızı sağlar!
#     </p>
# </div>
#
# </div>
#
# ### 🔄 Soyutlama Katmanı
#
# <div style="display: flex; align-items: center; justify-content: space-around; margin: 30px 0; flex-wrap: wrap; gap: 15px;">
#
# <div style="flex: 1; min-width: 180px; background: linear-gradient(135deg, #FFCDD2 0%, #EF9A9A 100%); padding: 20px; border-radius: 15px; text-align: center; box-shadow: 0 4px 8px rgba(0,0,0,0.1);">
#     <div style="font-size: 35px; margin-bottom: 10px;">⚙️</div>
#     <h5 style="color: #C62828; margin: 10px 0;">Düşük Seviye</h5>
#     <p style="color: #424242; margin: 0; font-size: 13px;">PyTorch / TensorFlow</p>
# </div>
#
# <div style="font-size: 35px; color: #4CAF50;">⬆️</div>
#
# <div style="flex: 1; min-width: 180px; background: linear-gradient(135deg, #FFE082 0%, #FFD54F 100%); padding: 20px; border-radius: 15px; text-align: center; box-shadow: 0 4px 8px rgba(0,0,0,0.1);">
#     <div style="font-size: 35px; margin-bottom: 10px;">🤗</div>
#     <h5 style="color: #F57F17; margin: 10px 0;">Hugging Face</h5>
#     <p style="color: #424242; margin: 0; font-size: 13px;">Soyutlama Katmanı</p>
# </div>
#
# <div style="font-size: 35px; color: #4CAF50;">⬆️</div>
#
# <div style="flex: 1; min-width: 180px; background: linear-gradient(135deg, #A5D6A7 0%, #81C784 100%); padding: 20px; border-radius: 15px; text-align: center; box-shadow: 0 4px 8px rgba(0,0,0,0.1);">
#     <div style="font-size: 35px; margin-bottom: 10px;">👨‍💻</div>
#     <h5 style="color: #2E7D32; margin: 10px 0;">YBS Öğrencisi</h5>
#     <p style="color: #424242; margin: 0; font-size: 13px;">Kolay Kullanım</p>
# </div>
#
# </div>
#
# ---

# %% [markdown]
# ## 📊 YBS Perspektifinden Hugging Face
#
# <div style="background: linear-gradient(135deg, #FCE4EC 0%, #F8BBD0 100%); padding: 35px; border-radius: 20px; margin: 30px 0; box-shadow: 0 10px 20px rgba(0,0,0,0.12); border: 4px solid #E91E63;">
#     <h3 style="color: #C2185B; margin-top: 0; font-size: 24px; text-align: center;">🎯 Stratejik Yaklaşım</h3>
#     <p style="font-size: 18px; line-height: 2; color: #424242; text-align: center; font-weight: 500;">
#         Bu ders serisinde, Hugging Face'i bir <span style="background-color: #FFCDD2; padding: 5px 12px; border-radius: 5px; font-weight: bold; text-decoration: line-through;">"kod deposu"</span> olarak <strong>DEĞİL</strong>,
#     </p>
#     <p style="font-size: 20px; line-height: 2; color: #880E4F; text-align: center; font-weight: 700; margin-top: 15px;">
#         bir <span style="background-color: #FFEB3B; padding: 6px 15px; border-radius: 8px; color: #000;">"Stratejik Yapay Zeka Altyapısı"</span> olarak ele alacağız! 🏗️
#     </p>
# </div>
#
# ### 🎓 YBS Mezunu Yetkinlikleri
#
# <div style="background: linear-gradient(135deg, #E3F2FD 0%, #BBDEFB 100%); padding: 30px; border-radius: 20px; margin: 25px 0; box-shadow: 0 6px 12px rgba(0,0,0,0.1);">
#     <h4 style="color: #0D47A1; margin-top: 0; font-size: 20px;">🎯 Ders Serisinin Amacı</h4>
#     <p style="font-size: 17px; line-height: 2; color: #424242;">
#         Bir YBS mezununun <strong>mezuniyet sonrası bir projede veya iş ortamında</strong> aşağıdaki soruları bilinçli şekilde cevaplayabilecek düzeye gelmesini sağlamak:
#     </p>
# </div>
#
# <div style="display: grid; grid-template-columns: repeat(auto-fit, minmax(220px, 1fr)); gap: 20px; margin: 30px 0;">
#
# <div style="background: linear-gradient(135deg, #FFF9C4 0%, #FFF59D 100%); padding: 25px; border-radius: 15px; text-align: center; box-shadow: 0 6px 12px rgba(0,0,0,0.1); border-top: 5px solid #F9A825;">
#     <div style="font-size: 45px; margin-bottom: 15px;">❓</div>
#     <h5 style="color: #F57F17; margin: 10px 0; font-size: 18px;">HANGİ MODEL?</h5>
#     <p style="color: #424242; font-size: 14px; line-height: 1.6;">
#         İhtiyacıma uygun doğru modeli nasıl seçerim?
#     </p>
# </div>
#
# <div style="background: linear-gradient(135deg, #E1BEE7 0%, #CE93D8 100%); padding: 25px; border-radius: 15px; text-align: center; box-shadow: 0 6px 12px rgba(0,0,0,0.1); border-top: 5px solid #8E24AA;">
#     <div style="font-size: 45px; margin-bottom: 15px;">📍</div>
#     <h5 style="color: #6A1B9A; margin: 10px 0; font-size: 18px;">NEREDE?</h5>
#     <p style="color: #424242; font-size: 14px; line-height: 1.6;">
#         Bu modeli hangi senaryoda kullanmalıyım?
#     </p>
# </div>
#
# <div style="background: linear-gradient(135deg, #FFCCBC 0%, #FFAB91 100%); padding: 25px; border-radius: 15px; text-align: center; box-shadow: 0 6px 12px rgba(0,0,0,0.1); border-top: 5px solid #E64A19;">
#     <div style="font-size: 45px; margin-bottom: 15px;">🤔</div>
#     <h5 style="color: #BF360C; margin: 10px 0; font-size: 18px;">NEDEN?</h5>
#     <p style="color: #424242; font-size: 14px; line-height: 1.6;">
#         Bu modeli seçmemin iş mantığı nedir?
#     </p>
# </div>
#
# <div style="background: linear-gradient(135deg, #C8E6C9 0%, #A5D6A7 100%); padding: 25px; border-radius: 15px; text-align: center; box-shadow: 0 6px 12px rgba(0,0,0,0.1); border-top: 5px solid #43A047;">
#     <div style="font-size: 45px; margin-bottom: 15px;">⚙️</div>
#     <h5 style="color: #2E7D32; margin: 10px 0; font-size: 18px;">NASIL?</h5>
#     <p style="color: #424242; font-size: 14px; line-height: 1.6;">
#         Bu modeli nasıl entegre edip kullanırım?
#     </p>
# </div>
#
# </div>
#
# ### 💼 İş Dünyasında YBS Profesyonelinin Rolü
#
# <div style="background: linear-gradient(135deg, #E8EAF6 0%, #C5CAE9 100%); padding: 30px; border-radius: 20px; margin: 30px 0; border-left: 6px solid #3F51B5;">
#     <table style="width: 100%; border-collapse: collapse;">
#         <tr style="background: linear-gradient(135deg, #5C6BC0 0%, #3F51B5 100%); color: white;">
#             <th style="padding: 15px; text-align: left; border-radius: 8px 0 0 0; font-size: 16px;">👨‍💻 Geleneksel Yazılımcı</th>
#             <th style="padding: 15px; text-align: left; border-radius: 0 8px 0 0; font-size: 16px;">🎯 YBS Profesyoneli</th>
#         </tr>
#         <tr style="background-color: rgba(255,255,255,0.9);">
#             <td style="padding: 20px; border: 2px solid #9FA8DA; vertical-align: top;">
#                 <ul style="margin: 0; padding-left: 20px; color: #424242; line-height: 2;">
#                     <li>Kod yazmaya odaklı</li>
#                     <li>Teknik detaylara yoğunlaşır</li>
#                     <li>Uygulama geliştirme</li>
#                 </ul>
#             </td>
#             <td style="padding: 20px; border: 2px solid #9FA8DA; vertical-align: top;">
#                 <ul style="margin: 0; padding-left: 20px; color: #424242; line-height: 2;">
#                     <li><strong>İş problemini analiz eder</strong></li>
#                     <li><strong>Doğru teknolojiyi seçer</strong></li>
#                     <li><strong>Stratejik karar verir</strong></li>
#                     <li><strong>Maliyet-fayda analizi yapar</strong></li>
#                 </ul>
#             </td>
#         </tr>
#     </table>
# </div>
#
# ### 🚀 Öğrenme Yolculuğumuz
#
# <div style="background: linear-gradient(135deg, #DCEDC8 0%, #C5E1A5 100%); padding: 30px; border-radius: 20px; margin: 30px 0; box-shadow: 0 8px 16px rgba(0,0,0,0.1); border: 3px solid #7CB342;">
#     <h4 style="color: #33691E; margin-top: 0; font-size: 20px;">📚 Bu Serinin Kapsamı</h4>
#     <div style="display: grid; grid-template-columns: repeat(auto-fit, minmax(200px, 1fr)); gap: 15px; margin-top: 20px;">
#         <div style="background-color: rgba(255,255,255,0.8); padding: 15px; border-radius: 10px; border-left: 4px solid #7CB342;">
#             <strong style="color: #33691E;">📝 Metin İşleme</strong>
#             <p style="margin: 5px 0 0 0; font-size: 14px; color: #424242;">Sınıflandırma, özetleme</p>
#         </div>
#         <div style="background-color: rgba(255,255,255,0.8); padding: 15px; border-radius: 10px; border-left: 4px solid #7CB342;">
#             <strong style="color: #33691E;">🌐 Dil Çevirisi</strong>
#             <p style="margin: 5px 0 0 0; font-size: 14px; color: #424242;">Çok dilli uygulamalar</p>
#         </div>
#         <div style="background-color: rgba(255,255,255,0.8); padding: 15px; border-radius: 10px; border-left: 4px solid #7CB342;">
#             <strong style="color: #33691E;">❓ Soru Yanıtlama</strong>
#             <p style="margin: 5px 0 0 0; font-size: 14px; color: #424242;">Chatbot sistemleri</p>
#         </div>
#         <div style="background-color: rgba(255,255,255,0.8); padding: 15px; border-radius: 10px; border-left: 4px solid #7CB342;">
#             <strong style="color: #33691E;">✍️ Metin Üretimi</strong>
#             <p style="margin: 5px 0 0 0; font-size: 14px; color: #424242;">İçerik otomasyonu</p>
#         </div>
#         <div style="background-color: rgba(255,255,255,0.8); padding: 15px; border-radius: 10px; border-left: 4px solid #7CB342;">
#             <strong style="color: #33691E;">🖼️ Görüntü İşleme</strong>
#             <p style="margin: 5px 0 0 0; font-size: 14px; color: #424242;">Görsel sınıflandırma</p>
#         </div>
#         <div style="background-color: rgba(255,255,255,0.8); padding: 15px; border-radius: 10px; border-left: 4px solid #7CB342;">
#             <strong style="color: #33691E;">🔀 Çok Modlu</strong>
#             <p style="margin: 5px 0 0 0; font-size: 14px; color: #424242;">Hibrit sistemler</p>
#         </div>
#     </div>
# </div>
#
# ---

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 🔄 Pipeline: Transformatör Modellerini Kullanmanın En Kolay Yolu
#
# <div style="background: linear-gradient(135deg, #E1F5FE 0%, #B3E5FC 100%); padding: 35px; border-radius: 20px; margin: 30px 0; box-shadow: 0 10px 20px rgba(0,0,0,0.12); border: 4px solid #0288D1;">
#     <h3 style="color: #01579B; margin-top: 0; font-size: 24px;">🎯 Pipeline Nedir?</h3>
#     <p style="font-size: 18px; line-height: 2; color: #263238; font-weight: 500;">
#         Pipeline, bir transformatör modelini <span style="background-color: #FFEB3B; padding: 5px 12px; border-radius: 5px; font-weight: bold; color: #000;">"çıkarım" (inference)</span> yani <strong>tahmin üretme</strong> aşamasında kullanmanın <em>en hızlı ve en pratik</em> yoludur! 🚀
#     </p>
# </div>
#
# ### 💼 YBS Perspektifi: Pipeline = Otomatik İş Akışı
#
# <div style="background: linear-gradient(135deg, #F3E5F5 0%, #E1BEE7 100%); padding: 30px; border-radius: 20px; margin: 25px 0; border-left: 6px solid #8E24AA;">
#     <h4 style="color: #6A1B9A; margin-top: 0; font-size: 20px;">🏭 İş Süreci Benzetmesi</h4>
#     <p style="font-size: 16px; line-height: 1.9; color: #424242;">
#         Pipeline, karmaşık bir yapay zeka sürecini <span style="background-color: #FFEB3B; padding: 3px 8px; border-radius: 5px; font-weight: bold;">uçtan uca otomatik çalışan bir iş akışına</span> dönüştürür.
#     </p>
#     <div style="background-color: rgba(255,255,255,0.7); padding: 20px; border-radius: 10px; margin-top: 15px;">
#         <p style="font-size: 16px; color: #424242; margin: 0; line-height: 1.8;">
#             <strong>💡 Analoji:</strong> Bir ERP sisteminde kullanıcı sipariş girişi yapar, sistem arka planda <em>otomatik olarak</em> stok kontrolü, fiyatlandırma, onay süreçlerini yönetir. Kullanıcı <span style="background-color: #CE93D8; padding: 2px 6px; border-radius: 4px; color: white; font-weight: bold;">süreci değil, sonucu yönetir</span>! ✅
#         </p>
#     </div>
# </div>
#
# ---

# %% [markdown]
# ### ⚙️ Pipeline'da Arka Planda Ne Oluyor?
#
# <div style="background: linear-gradient(135deg, #FFF9C4 0%, #FFF59D 100%); padding: 30px; border-radius: 20px; margin: 25px 0; box-shadow: 0 6px 12px rgba(0,0,0,0.1);">
#     <h4 style="color: #F57F17; margin-top: 0; font-size: 20px;">🔍 Üç Temel İşlem (Otomatik)</h4>
#     <p style="font-size: 16px; line-height: 1.8; color: #424242; margin-bottom: 20px;">
#         Kullanıcı pipeline'ı çağırdığında, arka planda <strong>üç temel işlem otomatik olarak gerçekleşir</strong>:
#     </p>
# </div>
#
# <div style="display: flex; align-items: center; justify-content: space-around; margin: 35px 0; flex-wrap: wrap; gap: 15px;">
#
# <div style="flex: 1; min-width: 220px; background: linear-gradient(135deg, #E3F2FD 0%, #BBDEFB 100%); padding: 30px; border-radius: 20px; text-align: center; box-shadow: 0 6px 12px rgba(0,0,0,0.1); border: 3px solid #1976D2;">
#     <div style="background-color: #1976D2; color: white; width: 50px; height: 50px; border-radius: 50%; display: flex; align-items: center; justify-content: center; margin: 0 auto 15px; font-size: 24px; font-weight: bold;">1</div>
#     <h5 style="color: #0D47A1; margin: 15px 0; font-size: 18px;">📥 Ön İşleme</h5>
#     <p style="color: #424242; font-size: 14px; line-height: 1.6;">
#         Girdi verisi modelin anlayabileceği <strong>sayısal forma</strong> dönüştürülür
#     </p>
#     <div style="background-color: rgba(255,255,255,0.6); padding: 10px; border-radius: 8px; margin-top: 10px; font-size: 13px; color: #01579B;">
#         <strong>Tokenizasyon</strong>
#     </div>
# </div>
#
# <div style="font-size: 40px; color: #4CAF50;">➡️</div>
#
# <div style="flex: 1; min-width: 220px; background: linear-gradient(135deg, #F3E5F5 0%, #E1BEE7 100%); padding: 30px; border-radius: 20px; text-align: center; box-shadow: 0 6px 12px rgba(0,0,0,0.1); border: 3px solid #7B1FA2;">
#     <div style="background-color: #7B1FA2; color: white; width: 50px; height: 50px; border-radius: 50%; display: flex; align-items: center; justify-content: center; margin: 0 auto 15px; font-size: 24px; font-weight: bold;">2</div>
#     <h5 style="color: #6A1B9A; margin: 15px 0; font-size: 18px;">🧠 Model Çalıştırma</h5>
#     <p style="color: #424242; font-size: 14px; line-height: 1.6;">
#         İlgili transformatör modeli <strong>yüklenir ve çalıştırılır</strong>
#     </p>
#     <div style="background-color: rgba(255,255,255,0.6); padding: 10px; border-radius: 8px; margin-top: 10px; font-size: 13px; color: #6A1B9A;">
#         <strong>Inference</strong>
#     </div>
# </div>
#
# <div style="font-size: 40px; color: #4CAF50;">➡️</div>
#
# <div style="flex: 1; min-width: 220px; background: linear-gradient(135deg, #C8E6C9 0%, #A5D6A7 100%); padding: 30px; border-radius: 20px; text-align: center; box-shadow: 0 6px 12px rgba(0,0,0,0.1); border: 3px solid #388E3C;">
#     <div style="background-color: #388E3C; color: white; width: 50px; height: 50px; border-radius: 50%; display: flex; align-items: center; justify-content: center; margin: 0 auto 15px; font-size: 24px; font-weight: bold;">3</div>
#     <h5 style="color: #2E7D32; margin: 15px 0; font-size: 18px;">📤 Son İşleme</h5>
#     <p style="color: #424242; font-size: 14px; line-height: 1.6;">
#         Model çıktısı <strong>okunabilir sonuca</strong> dönüştürülür
#     </p>
#     <div style="background-color: rgba(255,255,255,0.6); padding: 10px; border-radius: 8px; margin-top: 10px; font-size: 13px; color: #2E7D32;">
#         <strong>Post-processing</strong>
#     </div>
# </div>
#
# </div>
#
# <div style="background: linear-gradient(135deg, #FFECB3 0%, #FFE082 100%); padding: 25px; border-radius: 15px; margin: 25px 0; border-left: 6px solid #FF6F00;">
#     <h4 style="color: #E65100; margin-top: 0;">✨ Pipeline'ın Gücü</h4>
#     <p style="font-size: 17px; line-height: 1.9; color: #424242; font-weight: 500;">
#         Bu üç adımın <span style="background-color: #FFEB3B; padding: 3px 8px; border-radius: 5px; font-weight: bold;">tamamı tek bir komutla çalışır</span>! 🚀
#     </p>
#     <p style="font-size: 15px; line-height: 1.7; color: #424242; margin-top: 10px;">
#         Pipeline olmadan bu işlemleri manuel olarak yönetmek gerekir. Pipeline ile sistem <em>otomasyonu</em> elde ederiz.
#     </p>
# </div>
#
# ---

# %% [markdown]
# ### 🎯 Görev Bazlı Pipeline Kullanımı
#
# <div style="background: linear-gradient(135deg, #E8EAF6 0%, #C5CAE9 100%); padding: 30px; border-radius: 20px; margin: 25px 0; box-shadow: 0 6px 12px rgba(0,0,0,0.1);">
#     <h4 style="color: #283593; margin-top: 0; font-size: 20px;">📋 İlk Adım: Görevi Tanımlamak</h4>
#     <p style="font-size: 16px; line-height: 1.8; color: #424242;">
#         Pipeline kullanırken yapılması gereken ilk şey, <span style="background-color: #FFEB3B; padding: 3px 8px; border-radius: 5px; font-weight: bold;">hangi görevi yapmak istediğimizi tanımlamaktır</span>.
#     </p>
#     <p style="font-size: 15px; line-height: 1.7; color: #424242; margin-top: 10px;">
#         Çünkü <strong>her görev farklı türde bir girdi ve çıktı üretir</strong>. Pipeline otomatik olarak buna göre uyum sağlar.
#     </p>
# </div>
#
# ### 📊 Popüler Pipeline Görevleri
#
# <div style="display: grid; grid-template-columns: repeat(auto-fit, minmax(280px, 1fr)); gap: 20px; margin: 25px 0;">
#
# <div style="background: linear-gradient(135deg, #E1F5FE 0%, #B3E5FC 100%); padding: 25px; border-radius: 15px; box-shadow: 0 4px 8px rgba(0,0,0,0.1); border-top: 5px solid #0288D1;">
#     <h5 style="color: #01579B; margin-top: 0; font-size: 18px;">❓ Soru-Cevap</h5>
#     <div style="background-color: rgba(255,255,255,0.7); padding: 15px; border-radius: 10px; margin: 10px 0;">
#         <p style="margin: 0; color: #424242; font-size: 14px;"><strong>Girdi:</strong> Bağlam + Soru</p>
#         <p style="margin: 5px 0 0 0; color: #424242; font-size: 14px;"><strong>Çıktı:</strong> Anlamlı cevap</p>
#     </div>
#     <div style="background-color: #B3E5FC; padding: 10px; border-radius: 8px; margin-top: 10px; font-size: 13px; color: #01579B;">
#         <strong>Örnek:</strong> "Türkiye'nin başkenti nedir?" → "Ankara"
#     </div>
# </div>
#
# <div style="background: linear-gradient(135deg, #F3E5F5 0%, #E1BEE7 100%); padding: 25px; border-radius: 15px; box-shadow: 0 4px 8px rgba(0,0,0,0.1); border-top: 5px solid #8E24AA;">
#     <h5 style="color: #6A1B9A; margin-top: 0; font-size: 18px;">😊 Duygu Analizi</h5>
#     <div style="background-color: rgba(255,255,255,0.7); padding: 15px; border-radius: 10px; margin: 10px 0;">
#         <p style="margin: 0; color: #424242; font-size: 14px;"><strong>Girdi:</strong> Düz metin</p>
#         <p style="margin: 5px 0 0 0; color: #424242; font-size: 14px;"><strong>Çıktı:</strong> Duygu etiketi (pozitif/negatif)</p>
#     </div>
#     <div style="background-color: #E1BEE7; padding: 10px; border-radius: 8px; margin-top: 10px; font-size: 13px; color: #6A1B9A;">
#         <strong>Örnek:</strong> "Bu ürün harika!" → Pozitif (%98)
#     </div>
# </div>
#
# <div style="background: linear-gradient(135deg, #C8E6C9 0%, #A5D6A7 100%); padding: 25px; border-radius: 15px; box-shadow: 0 4px 8px rgba(0,0,0,0.1); border-top: 5px solid #43A047;">
#     <h5 style="color: #2E7D32; margin-top: 0; font-size: 18px;">📊 Metin Sınıflandırma</h5>
#     <div style="background-color: rgba(255,255,255,0.7); padding: 15px; border-radius: 10px; margin: 10px 0;">
#         <p style="margin: 0; color: #424242; font-size: 14px;"><strong>Girdi:</strong> Düz metin</p>
#         <p style="margin: 5px 0 0 0; color: #424242; font-size: 14px;"><strong>Çıktı:</strong> Kategori etiketi</p>
#     </div>
#     <div style="background-color: #C8E6C9; padding: 10px; border-radius: 8px; margin-top: 10px; font-size: 13px; color: #2E7D32;">
#         <strong>Örnek:</strong> E-posta → Spam/Değil
#     </div>
# </div>
#
# <div style="background: linear-gradient(135deg, #FFF9C4 0%, #FFF59D 100%); padding: 25px; border-radius: 15px; box-shadow: 0 4px 8px rgba(0,0,0,0.1); border-top: 5px solid #F9A825;">
#     <h5 style="color: #F57F17; margin-top: 0; font-size: 18px;">🎭 Maske Doldurma</h5>
#     <div style="background-color: rgba(255,255,255,0.7); padding: 15px; border-radius: 10px; margin: 10px 0;">
#         <p style="margin: 0; color: #424242; font-size: 14px;"><strong>Girdi:</strong> Eksik kelimeli metin</p>
#         <p style="margin: 5px 0 0 0; color: #424242; font-size: 14px;"><strong>Çıktı:</strong> Tahmin edilen kelimeler</p>
#     </div>
#     <div style="background-color: #FFF9C4; padding: 10px; border-radius: 8px; margin-top: 10px; font-size: 13px; color: #F57F17;">
#         <strong>Örnek:</strong> "Bugün hava çok [MASK]" → "güzel"
#     </div>
# </div>
#
# <div style="background: linear-gradient(135deg, #FFECB3 0%, #FFE082 100%); padding: 25px; border-radius: 15px; box-shadow: 0 4px 8px rgba(0,0,0,0.1); border-top: 5px solid #FF6F00;">
#     <h5 style="color: #E65100; margin-top: 0; font-size: 18px;">📄 Özetleme</h5>
#     <div style="background-color: rgba(255,255,255,0.7); padding: 15px; border-radius: 10px; margin: 10px 0;">
#         <p style="margin: 0; color: #424242; font-size: 14px;"><strong>Girdi:</strong> Uzun metin</p>
#         <p style="margin: 5px 0 0 0; color: #424242; font-size: 14px;"><strong>Çıktı:</strong> Kısa özet</p>
#     </div>
#     <div style="background-color: #FFECB3; padding: 10px; border-radius: 8px; margin-top: 10px; font-size: 13px; color: #E65100;">
#         <strong>Örnek:</strong> Makale → 3 cümlelik özet
#     </div>
# </div>
#
# <div style="background: linear-gradient(135deg, #FFCCBC 0%, #FFAB91 100%); padding: 25px; border-radius: 15px; box-shadow: 0 4px 8px rgba(0,0,0,0.1); border-top: 5px solid #E64A19;">
#     <h5 style="color: #BF360C; margin-top: 0; font-size: 18px;">✍️ Metin Üretimi</h5>
#     <div style="background-color: rgba(255,255,255,0.7); padding: 15px; border-radius: 10px; margin: 10px 0;">
#         <p style="margin: 0; color: #424242; font-size: 14px;"><strong>Girdi:</strong> Başlangıç metni</p>
#         <p style="margin: 5px 0 0 0; color: #424242; font-size: 14px;"><strong>Çıktı:</strong> Devam eden metin</p>
#     </div>
#     <div style="background-color: #FFCCBC; padding: 10px; border-radius: 8px; margin-top: 10px; font-size: 13px; color: #BF360C;">
#         <strong>Örnek:</strong> "Bir varmış bir yokmuş" → Hikaye devamı
#     </div>
# </div>
#
# </div>
#
# <div style="background: linear-gradient(135deg, #FCE4EC 0%, #F8BBD0 100%); padding: 25px; border-radius: 15px; margin: 25px 0; border-left: 6px solid #C2185B;">
#     <h4 style="color: #880E4F; margin-top: 0;">🔄 Otomatik Uyum</h4>
#     <p style="font-size: 16px; line-height: 1.8; color: #424242;">
#         <strong>Görev değiştikçe</strong> pipeline'ın çalışma biçimi <span style="background-color: #FFEB3B; padding: 3px 8px; border-radius: 5px; font-weight: bold;">otomatik olarak buna göre uyum sağlar</span>! 🎯
#     </p>
# </div>
#
# ---

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 🎓 İnce Ayarlı Transformatörler ve Aşağı Akış Görevleri
#
# <div style="background: linear-gradient(135deg, #E8F5E9 0%, #C8E6C9 100%); padding: 30px; border-radius: 20px; margin: 25px 0; box-shadow: 0 8px 16px rgba(0,0,0,0.1); border: 4px solid #4CAF50;">
#     <h4 style="color: #1B5E20; margin-top: 0; font-size: 20px;">🔧 Fine-Tuned Transformers</h4>
#     <p style="font-size: 17px; line-height: 1.9; color: #424242;">
#         Pipeline'lar genellikle <span style="background-color: #FFEB3B; padding: 4px 10px; border-radius: 5px; font-weight: bold;">belirli bir göreve göre eğitilmiş</span> ya da <strong>ince ayar yapılmış modellerle</strong> kullanılır.
#     </p>
# </div>
#
# <div style="background: linear-gradient(135deg, #E1F5FE 0%, #B3E5FC 100%); padding: 25px; border-radius: 15px; margin: 25px 0; border-left: 6px solid #0288D1;">
#     <h4 style="color: #01579B; margin-top: 0;">📉 Aşağı Akış Görevleri (Downstream Tasks)</h4>
#     <p style="font-size: 16px; line-height: 1.8; color: #424242;">
#         Ön eğitimli bir modelin <em>spesifik görevlere uyarlanması</em> sonucu ortaya çıkan görevlere <strong>"aşağı akış görevleri"</strong> denir.
#     </p>
#
# <div style="display: flex; flex-wrap: wrap; gap: 10px; margin-top: 15px;">
#     <span style="background-color: #81D4FA; color: #01579B; padding: 8px 15px; border-radius: 20px; font-size: 14px; font-weight: 500;">😊 Duygu Analizi</span>
#     <span style="background-color: #CE93D8; color: #6A1B9A; padding: 8px 15px; border-radius: 20px; font-size: 14px; font-weight: 500;">❓ Soru Cevaplama</span>
#     <span style="background-color: #A5D6A7; color: #2E7D32; padding: 8px 15px; border-radius: 20px; font-size: 14px; font-weight: 500;">📄 Özetleme</span>
#     <span style="background-color: #FFF59D; color: #F57F17; padding: 8px 15px; border-radius: 20px; font-size: 14px; font-weight: 500;">🎭 Maske Doldurma</span>
#     <span style="background-color: #FFAB91; color: #BF360C; padding: 8px 15px; border-radius: 20px; font-size: 14px; font-weight: 500;">✍️ Metin Üretimi</span>
#     <span style="background-color: #B39DDB; color: #4A148C; padding: 8px 15px; border-radius: 20px; font-size: 14px; font-weight: 500;">🏷️ NER</span>
# </div>
# </div>
#
# <div style="background: linear-gradient(135deg, #D1C4E9 0%, #B39DDB 100%); padding: 25px; border-radius: 15px; margin: 25px 0; border-left: 6px solid #7B1FA2;">
#     <h4 style="color: #4A148C; margin-top: 0;">🚀 Pipeline Sayesinde</h4>
#     <p style="font-size: 16px; line-height: 1.8; color: #424242; font-weight: 500;">
#         Bu görevlerin <span style="background-color: #FFEB3B; padding: 3px 8px; border-radius: 5px; font-weight: bold;">her biri neredeyse aynı mantıkla</span> çalıştırılabilir! 🎯
#     </p>
# </div>
#
# ---

# %% [markdown]
# ### 🏗️ Pipeline'ın İç Yapısı: Üç Temel Bileşen
#
# <div style="background: linear-gradient(135deg, #FFF3E0 0%, #FFE0B2 100%); padding: 30px; border-radius: 20px; margin: 25px 0; box-shadow: 0 6px 12px rgba(0,0,0,0.1);">
#     <h4 style="color: #E65100; margin-top: 0; font-size: 20px;">🔍 Pipeline'ın Anatomisi</h4>
#     <p style="font-size: 16px; line-height: 1.8; color: #424242;">
#         Pipeline'ın iç yapısına biraz daha yakından bakıldığında, <strong>üç temel bileşen</strong> görülür:
#     </p>
# </div>
#
# <div style="display: grid; grid-template-columns: repeat(auto-fit, minmax(280px, 1fr)); gap: 20px; margin: 30px 0;">
#
# <div style="background: linear-gradient(135deg, #E3F2FD 0%, #BBDEFB 100%); padding: 30px; border-radius: 15px; box-shadow: 0 6px 12px rgba(0,0,0,0.1); border-left: 6px solid #1976D2;">
#     <div style="text-align: center; font-size: 50px; margin-bottom: 15px;">🔤</div>
#     <h5 style="color: #0D47A1; margin: 10px 0; font-size: 20px; text-align: center;">1. Tokenizer</h5>
#     <div style="background-color: rgba(255,255,255,0.7); padding: 15px; border-radius: 10px; margin-top: 15px;">
#         <p style="margin: 0; color: #424242; font-size: 15px; line-height: 1.7;">
#             Metni modelin anlayabileceği <strong>sayısal parçalara (token)</strong> ayırır
#         </p>
#     </div>
#     <div style="background-color: #B3E5FC; padding: 12px; border-radius: 8px; margin-top: 12px; font-size: 14px; color: #01579B; text-align: center;">
#         <strong>Metin → Sayılar</strong>
#     </div>
# </div>
#
# <div style="background: linear-gradient(135deg, #F3E5F5 0%, #E1BEE7 100%); padding: 30px; border-radius: 15px; box-shadow: 0 6px 12px rgba(0,0,0,0.1); border-left: 6px solid #7B1FA2;">
#     <div style="text-align: center; font-size: 50px; margin-bottom: 15px;">🧠</div>
#     <h5 style="color: #6A1B9A; margin: 10px 0; font-size: 20px; text-align: center;">2. Model Yükleyici</h5>
#     <div style="background-color: rgba(255,255,255,0.7); padding: 15px; border-radius: 10px; margin-top: 15px;">
#         <p style="margin: 0; color: #424242; font-size: 15px; line-height: 1.7;">
#             İlgili transformatör modelini <strong>belleğe alır</strong> ve hazır hale getirir
#         </p>
#     </div>
#     <div style="background-color: #E1BEE7; padding: 12px; border-radius: 8px; margin-top: 12px; font-size: 14px; color: #6A1B9A; text-align: center;">
#         <strong>Model → RAM</strong>
#     </div>
# </div>
#
# <div style="background: linear-gradient(135deg, #C8E6C9 0%, #A5D6A7 100%); padding: 30px; border-radius: 15px; box-shadow: 0 6px 12px rgba(0,0,0,0.1); border-left: 6px solid #388E3C;">
#     <div style="text-align: center; font-size: 50px; margin-bottom: 15px;">✨</div>
#     <h5 style="color: #2E7D32; margin: 10px 0; font-size: 20px; text-align: center;">3. Çıktı Üretici</h5>
#     <div style="background-color: rgba(255,255,255,0.7); padding: 15px; border-radius: 10px; margin-top: 15px;">
#         <p style="margin: 0; color: #424242; font-size: 15px; line-height: 1.7;">
#             Model çıktısını <strong>kullanıcıya anlamlı sonuç</strong> olarak sunar
#         </p>
#     </div>
#     <div style="background-color: #C8E6C9; padding: 12px; border-radius: 8px; margin-top: 12px; font-size: 14px; color: #2E7D32; text-align: center;">
#         <strong>Sayılar → Sonuç</strong>
#     </div>
# </div>
#
# </div>
#
# <div style="background: linear-gradient(135deg, #FFF9C4 0%, #FFF59D 100%); padding: 30px; border-radius: 20px; margin: 30px 0; box-shadow: 0 8px 16px rgba(0,0,0,0.1); border: 3px solid #F9A825;">
#     <h4 style="color: #F57F17; margin-top: 0; text-align: center;">🎭 Kullanıcı Deneyimi</h4>
#     <p style="font-size: 18px; line-height: 2; color: #424242; text-align: center; font-weight: 500;">
#         Kullanıcı pipeline'ı kullandığında <span style="background-color: #FFEB3B; padding: 4px 10px; border-radius: 5px; font-weight: bold;">bu üç adımın varlığını hissetmez</span>! 🪄
#     </p>
#     <p style="font-size: 16px; line-height: 1.8; color: #424242; text-align: center; margin-top: 15px;">
#         Ancak sistem <strong>arka planda otomatik olarak bu sırayı izler</strong>. ⚡
#     </p>
# </div>
#
# ---

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 📍 Checkpoint: Modelin Kayıtlı Hali
#
# <div style="background: linear-gradient(135deg, #FCE4EC 0%, #F8BBD0 100%); padding: 35px; border-radius: 20px; margin: 30px 0; box-shadow: 0 10px 20px rgba(0,0,0,0.12); border: 4px solid #E91E63;">
#     <h3 style="color: #C2185B; margin-top: 0; font-size: 24px;">🎯 Checkpoint Nedir?</h3>
#     <p style="font-size: 18px; line-height: 2; color: #424242; font-weight: 500;">
#         Bir transformatör modeli ne zaman <strong>ön eğitimden</strong> veya <strong>ince ayardan</strong> geçirilirse, ortaya çıkan bu model bir <span style="background-color: #FFEB3B; padding: 5px 12px; border-radius: 5px; font-weight: bold; color: #000;">kontrol noktası (checkpoint)</span> olarak kaydedilir.
#     </p>
# </div>
#
# ### 🗂️ Checkpoint Mantığı
#
# <div style="background: linear-gradient(135deg, #E8EAF6 0%, #C5CAE9 100%); padding: 30px; border-radius: 20px; margin: 25px 0; box-shadow: 0 6px 12px rgba(0,0,0,0.1);">
#     <h4 style="color: #283593; margin-top: 0; font-size: 20px;">💾 Kayıt ve Sürüm Yönetimi</h4>
#     <p style="font-size: 16px; line-height: 1.9; color: #424242;">
#         Checkpoint, bir modelin <strong>belirli bir eğitim anındaki durumunun kaydedilmiş halidir</strong>. Tıpkı bir oyundaki kayıt noktası gibi! 🎮
#     </p>
#
# <div style="display: flex; align-items: center; justify-content: space-around; margin: 25px 0; flex-wrap: wrap; gap: 15px;">
#
# <div style="flex: 1; min-width: 200px; background: linear-gradient(135deg, #FFECB3 0%, #FFE082 100%); padding: 25px; border-radius: 15px; text-align: center; box-shadow: 0 4px 8px rgba(0,0,0,0.1);">
#     <div style="font-size: 40px; margin-bottom: 10px;">📚</div>
#     <h5 style="color: #F57F17; margin: 10px 0;">Eğitim Başlangıcı</h5>
#     <p style="color: #424242; margin: 0; font-size: 13px;">İlk checkpoint</p>
# </div>
#
# <div style="font-size: 30px; color: #4CAF50;">→</div>
#
# <div style="flex: 1; min-width: 200px; background: linear-gradient(135deg, #FFE0B2 0%, #FFCC80 100%); padding: 25px; border-radius: 15px; text-align: center; box-shadow: 0 4px 8px rgba(0,0,0,0.1);">
#     <div style="font-size: 40px; margin-bottom: 10px;">⚙️</div>
#     <h5 style="color: #EF6C00; margin: 10px 0;">Eğitim Devam Ediyor</h5>
#     <p style="color: #424242; margin: 0; font-size: 13px;">Ara checkpointler</p>
# </div>
#
# <div style="font-size: 30px; color: #4CAF50;">→</div>
#
# <div style="flex: 1; min-width: 200px; background: linear-gradient(135deg, #C8E6C9 0%, #A5D6A7 100%); padding: 25px; border-radius: 15px; text-align: center; box-shadow: 0 4px 8px rgba(0,0,0,0.1);">
#     <div style="font-size: 40px; margin-bottom: 10px;">✅</div>
#     <h5 style="color: #2E7D32; margin: 10px 0;">Son Checkpoint</h5>
#     <p style="color: #424242; margin: 0; font-size: 13px;">Kullanıma hazır model</p>
# </div>
#
# </div>
# </div>
#
# ### 🎯 Doğru Checkpoint Seçimi
#
# <div style="background: linear-gradient(135deg, #FFCDD2 0%, #EF9A9A 100%); padding: 30px; border-radius: 20px; margin: 25px 0; border-left: 6px solid #E53935; box-shadow: 0 6px 12px rgba(0,0,0,0.1);">
#     <h4 style="color: #C62828; margin-top: 0;">⚠️ Önemli Uyarı</h4>
#     <p style="font-size: 17px; line-height: 1.9; color: #424242; font-weight: 500;">
#         Hugging Face üzerinde <span style="background-color: #FFEB3B; padding: 4px 10px; border-radius: 5px; font-weight: bold; color: #000;">binlerce farklı checkpoint</span> bulunmaktadır.
#     </p>
#     <p style="font-size: 16px; line-height: 1.8; color: #424242; margin-top: 15px;">
#         Ancak <strong>her kontrol noktası her görev için uygun değildir</strong>! ❌
#     </p>
# </div>
#
# <div style="background: linear-gradient(135deg, #FFF9C4 0%, #FFF59D 100%); padding: 25px; border-radius: 15px; margin: 25px 0;">
#     <h4 style="color: #F57F17; margin-top: 0;">📊 Örnek Senaryolar</h4>
#
# <table style="width: 100%; border-collapse: collapse; margin-top: 15px; box-shadow: 0 4px 8px rgba(0,0,0,0.1);">
#     <thead>
#         <tr style="background: linear-gradient(135deg, #FFD54F 0%, #FDD835 100%); color: #000;">
#             <th style="padding: 15px; text-align: left; border: 2px solid #FDD835; font-size: 15px;">✅ Uygun Kullanım</th>
#             <th style="padding: 15px; text-align: left; border: 2px solid #FDD835; font-size: 15px;">❌ Uygun Olmayan Kullanım</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr style="background-color: rgba(255,255,255,0.9);">
#             <td style="padding: 15px; border: 1px solid #FFE082; vertical-align: top;">
#                 <p style="margin: 0; color: #2E7D32; font-weight: 600;">✍️ Metin Üretimi Modeli</p>
#                 <p style="margin: 5px 0 0 0; color: #424242; font-size: 14px;">→ Hikaye yazma, içerik üretme</p>
#             </td>
#             <td style="padding: 15px; border: 1px solid #FFE082; vertical-align: top;">
#                 <p style="margin: 0; color: #C62828; font-weight: 600;">✍️ Metin Üretimi Modeli</p>
#                 <p style="margin: 5px 0 0 0; color: #424242; font-size: 14px;">→ Duygu analizi ❌</p>
#             </td>
#         </tr>
#         <tr style="background-color: rgba(255,255,255,0.7);">
#             <td style="padding: 15px; border: 1px solid #FFE082; vertical-align: top;">
#                 <p style="margin: 0; color: #2E7D32; font-weight: 600;">😊 Duygu Analizi Modeli</p>
#                 <p style="margin: 5px 0 0 0; color: #424242; font-size: 14px;">→ Müşteri yorumlarını analiz etme</p>
#             </td>
#             <td style="padding: 15px; border: 1px solid #FFE082; vertical-align: top;">
#                 <p style="margin: 0; color: #C62828; font-weight: 600;">😊 Duygu Analizi Modeli</p>
#                 <p style="margin: 5px 0 0 0; color: #424242; font-size: 14px;">→ Metin çevirisi ❌</p>
#             </td>
#         </tr>
#     </tbody>
# </table>
# </div>
#
# <div style="background: linear-gradient(135deg, #E1F5FE 0%, #B3E5FC 100%); padding: 30px; border-radius: 20px; margin: 30px 0; box-shadow: 0 8px 16px rgba(0,0,0,0.1); border: 3px solid #0288D1;">
#     <h4 style="color: #01579B; margin-top: 0; text-align: center; font-size: 20px;">🎯 Kritik Nokta</h4>
#     <p style="font-size: 18px; line-height: 2; color: #263238; text-align: center; font-weight: 600; margin: 0;">
#         Doğru görev için <span style="background-color: #FFEB3B; padding: 5px 12px; border-radius: 5px; font-weight: bold; color: #000;">doğru checkpoint'in seçilmesi</span> kritik öneme sahiptir! 🎯
#     </p>
# </div>
#
# ---

# %% [markdown]
# ### 🏷️ Checkpoint İsimlendirme Yapısı
#
# <div style="background: linear-gradient(135deg, #F3E5F5 0%, #E1BEE7 100%); padding: 30px; border-radius: 20px; margin: 25px 0; box-shadow: 0 6px 12px rgba(0,0,0,0.1);">
#     <h4 style="color: #6A1B9A; margin-top: 0; font-size: 20px;">📝 İki Farklı Adlandırma Yöntemi</h4>
#     <p style="font-size: 16px; line-height: 1.8; color: #424242;">
#         Checkpoint'ler genellikle <strong>iki şekilde adlandırılır</strong>:
#     </p>
# </div>
#
# <div style="display: grid; grid-template-columns: repeat(auto-fit, minmax(300px, 1fr)); gap: 25px; margin: 30px 0;">
#
# <div style="background: linear-gradient(135deg, #E3F2FD 0%, #BBDEFB 100%); padding: 30px; border-radius: 15px; box-shadow: 0 6px 12px rgba(0,0,0,0.1); border: 4px solid #1976D2;">
#     <div style="text-align: center; font-size: 50px; margin-bottom: 15px;">👤</div>
#     <h5 style="color: #0D47A1; margin: 15px 0; font-size: 20px; text-align: center;">1. Kullanıcı Adı + Model Adı</h5>
#     <div style="background-color: rgba(255,255,255,0.8); padding: 20px; border-radius: 10px; margin-top: 15px;">
#         <p style="margin: 0; color: #424242; font-size: 15px; line-height: 1.7; text-align: center;">
#             Modeli yükleyen kullanıcının adı ve model isminin <strong>birlikte kullanılması</strong>
#         </p>
#         <div style="background-color: #B3E5FC; padding: 15px; border-radius: 8px; margin-top: 15px; font-family: 'Courier New', monospace; font-size: 14px; color: #01579B; text-align: center; font-weight: bold;">
#             microsoft/deberta-base
#         </div>
#         <div style="background-color: #81D4FA; padding: 15px; border-radius: 8px; margin-top: 10px; font-family: 'Courier New', monospace; font-size: 14px; color: #01579B; text-align: center; font-weight: bold;">
#             google/bert-base-uncased
#         </div>
#     </div>
# </div>
#
# <div style="background: linear-gradient(135deg, #C8E6C9 0%, #A5D6A7 100%); padding: 30px; border-radius: 15px; box-shadow: 0 6px 12px rgba(0,0,0,0.1); border: 4px solid #388E3C;">
#     <div style="text-align: center; font-size: 50px; margin-bottom: 15px;">🏢</div>
#     <h5 style="color: #2E7D32; margin: 15px 0; font-size: 20px; text-align: center;">2. Varsayılan Model Adı</h5>
#     <div style="background-color: rgba(255,255,255,0.8); padding: 20px; border-radius: 10px; margin-top: 15px;">
#         <p style="margin: 0; color: #424242; font-size: 15px; line-height: 1.7; text-align: center;">
#             Genellikle ilgili modeli <strong>ilk yayımlayan büyük kurumların</strong> sürümleri
#         </p>
#         <div style="background-color: #C8E6C9; padding: 15px; border-radius: 8px; margin-top: 15px; font-family: 'Courier New', monospace; font-size: 14px; color: #2E7D32; text-align: center; font-weight: bold;">
#             bert-base-uncased
#         </div>
#         <div style="background-color: #A5D6A7; padding: 15px; border-radius: 8px; margin-top: 10px; font-family: 'Courier New', monospace; font-size: 14px; color: #2E7D32; text-align: center; font-weight: bold;">
#             gpt2
#         </div>
#     </div>
# </div>
#
# </div>
#
# <div style="background: linear-gradient(135deg, #FFF3E0 0%, #FFE0B2 100%); padding: 30px; border-radius: 20px; margin: 30px 0; border-left: 6px solid #FF6F00;">
#     <h4 style="color: #E65100; margin-top: 0;">🎓 YBS Öğrencileri İçin Ders</h4>
#     <p style="font-size: 17px; line-height: 2; color: #424242; font-weight: 500;">
#         Bu yapı şunu öğretir:
#     </p>
#     <div style="background-color: rgba(255,255,255,0.7); padding: 20px; border-radius: 10px; margin-top: 15px;">
#         <p style="font-size: 18px; line-height: 2; color: #BF360C; text-align: center; margin: 0; font-weight: 600;">
#             "Teknolojide yalnızca <span style="background-color: #FFEB3B; padding: 4px 10px; border-radius: 5px; color: #000;">aracı değil</span>, <span style="background-color: #FF6F00; padding: 4px 10px; border-radius: 5px; color: #FFF;">kaynağı da</span> doğru seçmek gerekir" 🎯
#         </p>
#     </div>
# </div>
#
# ---

# %% [markdown]
# ## 🌐 Hugging Face Hub: Merkezi Ekosistem
#
# <div style="background: linear-gradient(135deg, #E8F5E9 0%, #C8E6C9 100%); padding: 40px; border-radius: 20px; margin: 30px 0; box-shadow: 0 12px 24px rgba(0,0,0,0.15); border: 5px solid #4CAF50;">
#     <div style="text-align: center; font-size: 60px; margin-bottom: 20px;">🏪</div>
#     <h3 style="color: #1B5E20; margin-top: 0; font-size: 26px; text-align: center;">Hugging Face Hub</h3>
#     <p style="font-size: 18px; line-height: 2; color: #2E7D32; text-align: center; font-weight: 500;">
#         Checkpoint'lerin keşfedildiği, modellerin ve veri setlerinin <span style="background-color: #FFEB3B; padding: 5px 12px; border-radius: 5px; font-weight: bold; color: #000;">merkezi olarak bulunduğu yer</span>! 🌟
#     </p>
# </div>
#
# ### 📊 Hub İstatistikleri
#
# <div style="display: grid; grid-template-columns: repeat(auto-fit, minmax(250px, 1fr)); gap: 20px; margin: 30px 0;">
#
# <div style="background: linear-gradient(135deg, #E1F5FE 0%, #B3E5FC 100%); padding: 30px; border-radius: 20px; text-align: center; box-shadow: 0 8px 16px rgba(0,0,0,0.1); border: 4px solid #0288D1;">
#     <div style="font-size: 55px; margin-bottom: 15px;">🤖</div>
#     <h4 style="color: #01579B; margin: 15px 0; font-size: 22px;">Yüz Binlerce</h4>
#     <p style="color: #424242; font-size: 18px; font-weight: 600;">Eğitilmiş Model</p>
#     <div style="background-color: rgba(255,255,255,0.7); padding: 12px; border-radius: 8px; margin-top: 15px; font-size: 14px; color: #01579B;">
#         Doğrudan kullanıma hazır
#     </div>
# </div>
#
# <div style="background: linear-gradient(135deg, #F3E5F5 0%, #E1BEE7 100%); padding: 30px; border-radius: 20px; text-align: center; box-shadow: 0 8px 16px rgba(0,0,0,0.1); border: 4px solid #8E24AA;">
#     <div style="font-size: 55px; margin-bottom: 15px;">📊</div>
#     <h4 style="color: #6A1B9A; margin: 15px 0; font-size: 22px;">Binlerce</h4>
#     <p style="color: #424242; font-size: 18px; font-weight: 600;">Veri Seti</p>
#     <div style="background-color: rgba(255,255,255,0.7); padding: 12px; border-radius: 8px; margin-top: 15px; font-size: 14px; color: #6A1B9A;">
#         Fine-tuning için hazır
#     </div>
# </div>
#
# <div style="background: linear-gradient(135deg, #FFF9C4 0%, #FFF59D 100%); padding: 30px; border-radius: 20px; text-align: center; box-shadow: 0 8px 16px rgba(0,0,0,0.1); border: 4px solid #F9A825;">
#     <div style="font-size: 55px; margin-bottom: 15px;">🚀</div>
#     <h4 style="color: #F57F17; margin: 15px 0; font-size: 22px;">Spaces (Alanlar)</h4>
#     <p style="color: #424242; font-size: 18px; font-weight: 600;">Canlı Uygulamalar</p>
#     <div style="background-color: rgba(255,255,255,0.7); padding: 12px; border-radius: 8px; margin-top: 15px; font-size: 14px; color: #F57F17;">
#         Demo ve test ortamları
#     </div>
# </div>
#
# </div>
#
# <div style="background: linear-gradient(135deg, #E8EAF6 0%, #C5CAE9 100%); padding: 30px; border-radius: 20px; margin: 30px 0; box-shadow: 0 6px 12px rgba(0,0,0,0.1);">
#     <h4 style="color: #283593; margin-top: 0; font-size: 20px;">🔍 Hub Özellikleri</h4>
#     <p style="font-size: 16px; line-height: 1.9; color: #424242;">
#         Hugging Face Hub, <span style="background-color: #FFEB3B; padding: 3px 8px; border-radius: 5px; font-weight: bold;">açık bir ekosistemdir</span>. Kullanıcılar burada:
#     </p>
#
# <ul style="line-height: 2.2; color: #424242; font-size: 16px; margin-top: 20px;">
#     <li>📄 <strong>Model kartlarını</strong> inceleyebilir</li>
#     <li>📊 Hangi <strong>veriyle eğitildiğini</strong> görebilir</li>
#     <li>🧪 Modeli <strong>doğrudan tarayıcı üzerinden</strong> test edebilir</li>
#     <li>⬇️ Modeli <strong>indirip projelerinde</strong> kullanabilir</li>
#     <li>⬆️ Kendi modellerini <strong>topluluğa paylaşabilir</strong></li>
# </ul>
# </div>
#
# ---

# %% [markdown]
# ### 🔍 Hub'da Filtreleme ve Arama
#
# <div style="background: linear-gradient(135deg, #FCE4EC 0%, #F8BBD0 100%); padding: 30px; border-radius: 20px; margin: 25px 0; box-shadow: 0 6px 12px rgba(0,0,0,0.1);">
#     <h4 style="color: #C2185B; margin-top: 0; font-size: 20px;">🎯 Görev Bazlı Filtreleme</h4>
#     <p style="font-size: 16px; line-height: 1.8; color: #424242;">
#         Hub üzerinde modeller <span style="background-color: #FFEB3B; padding: 3px 8px; border-radius: 5px; font-weight: bold;">görev türüne göre filtrelenebilir</span>. Bu sayede ihtiyacınız olan modeli kolayca bulabilirsiniz! 🔎
#     </p>
# </div>
#
# <div style="display: grid; grid-template-columns: repeat(auto-fit, minmax(250px, 1fr)); gap: 15px; margin: 25px 0;">
#
# <div style="background: linear-gradient(135deg, #E3F2FD 0%, #BBDEFB 100%); padding: 20px; border-radius: 12px; border-left: 5px solid #1976D2;">
#     <h5 style="color: #0D47A1; margin: 0 0 10px 0; font-size: 16px;">📊 Metin Sınıflandırma</h5>
#     <p style="margin: 0; color: #424242; font-size: 13px;">Sadece sınıflandırma modelleri</p>
# </div>
#
# <div style="background: linear-gradient(135deg, #F3E5F5 0%, #E1BEE7 100%); padding: 20px; border-radius: 12px; border-left: 5px solid #8E24AA;">
#     <h5 style="color: #6A1B9A; margin: 0 0 10px 0; font-size: 16px;">❓ Soru Cevaplama</h5>
#     <p style="margin: 0; color: #424242; font-size: 13px;">QA için özel modeller</p>
# </div>
#
# <div style="background: linear-gradient(135deg, #C8E6C9 0%, #A5D6A7 100%); padding: 20px; border-radius: 12px; border-left: 5px solid #388E3C;">
#     <h5 style="color: #2E7D32; margin: 0 0 10px 0; font-size: 16px;">🌐 Çeviri</h5>
#     <p style="margin: 0; color: #424242; font-size: 13px;">Diller arası çeviri modelleri</p>
# </div>
#
# <div style="background: linear-gradient(135deg, #FFF9C4 0%, #FFF59D 100%); padding: 20px; border-radius: 12px; border-left: 5px solid #F9A825;">
#     <h5 style="color: #F57F17; margin: 0 0 10px 0; font-size: 16px;">📄 Özetleme</h5>
#     <p style="margin: 0; color: #424242; font-size: 13px;">Metin özetleme modelleri</p>
# </div>
#
# <div style="background: linear-gradient(135deg, #FFECB3 0%, #FFE082 100%); padding: 20px; border-radius: 12px; border-left: 5px solid #FF6F00;">
#     <h5 style="color: #E65100; margin: 0 0 10px 0; font-size: 16px;">✍️ Metin Üretimi</h5>
#     <p style="margin: 0; color: #424242; font-size: 13px;">GPT benzeri generative modeller</p>
# </div>
#
# <div style="background: linear-gradient(135deg, #FFCCBC 0%, #FFAB91 100%); padding: 20px; border-radius: 12px; border-left: 5px solid #E64A19;">
#     <h5 style="color: #BF360C; margin: 0 0 10px 0; font-size: 16px;">🖼️ Görüntü İşleme</h5>
#     <p style="margin: 0; color: #424242; font-size: 13px;">Vision modelleri</p>
# </div>
#
# </div>
#
# ### 📦 Veri Setleri ve Fine-Tuning
#
# <div style="background: linear-gradient(135deg, #E1BEE7 0%, #CE93D8 100%); padding: 30px; border-radius: 20px; margin: 25px 0; border-left: 6px solid #8E24AA;">
#     <h4 style="color: #6A1B9A; margin-top: 0;">📊 Veri Seti Filtreleme</h4>
#     <p style="font-size: 16px; line-height: 1.8; color: #424242;">
#         Aynı şekilde <strong>veri setleri de filtrelenebilir</strong>. Eğer bir modeli ince ayar yapmak istiyorsanız, Hub üzerinden ilgili veri setini bulup kullanabilirsiniz.
#     </p>
#
# <div style="background-color: rgba(255,255,255,0.7); padding: 20px; border-radius: 10px; margin-top: 15px;">
#     <p style="font-size: 16px; color: #424242; margin: 0; line-height: 1.8;">
#         <strong>💡 Örnek:</strong> Türkçe duygu analizi için bir model ince ayar yapmak istiyorsunuz → Hub'da "sentiment analysis Turkish dataset" araması yapabilirsiniz! 🔍
#     </p>
# </div>
# </div>
#
# <div style="background: linear-gradient(135deg, #FFF3E0 0%, #FFE0B2 100%); padding: 30px; border-radius: 20px; margin: 30px 0; box-shadow: 0 8px 16px rgba(0,0,0,0.1); border: 3px solid #FF6F00;">
#     <h4 style="color: #E65100; margin-top: 0; text-align: center;">🎓 YBS Perspektifi</h4>
#     <p style="font-size: 18px; line-height: 2; color: #424242; text-align: center; font-weight: 500;">
#         Bu yapı, YBS açısından bakıldığında<br>
#         <span style="background-color: #FFEB3B; padding: 5px 15px; border-radius: 8px; font-weight: bold; color: #000; display: inline-block; margin-top: 10px;">
#             "Açık Veri ve Açık Model Ekonomisinin"
#         </span><br>
#         <strong style="font-size: 20px; margin-top: 10px; display: inline-block;">somut bir örneğidir! 🌍</strong>
#     </p>
# </div>
#
# ---

# %% [markdown]
# ### 🚀 Spaces: Modelden Ürüne Giden Yol
#
# <div style="background: linear-gradient(135deg, #E8F5E9 0%, #C8E6C9 100%); padding: 35px; border-radius: 20px; margin: 30px 0; box-shadow: 0 10px 20px rgba(0,0,0,0.12); border: 4px solid #4CAF50;">
#     <h4 style="color: #1B5E20; margin-top: 0; font-size: 22px;">🎨 Spaces Nedir?</h4>
#     <p style="font-size: 17px; line-height: 2; color: #2E7D32; font-weight: 500;">
#         <strong>Spaces</strong>, eğitilmiş bir modelin <span style="background-color: #FFEB3B; padding: 4px 10px; border-radius: 5px; font-weight: bold; color: #000;">canlı olarak çalıştırıldığı</span> ve <strong>son kullanıcıya sunulduğu</strong> uygulama alanlarıdır! 🌟
#     </p>
# </div>
#
# <div style="display: flex; align-items: center; justify-content: space-around; margin: 35px 0; flex-wrap: wrap; gap: 20px;">
#
# <div style="flex: 1; min-width: 220px; background: linear-gradient(135deg, #FFECB3 0%, #FFE082 100%); padding: 30px; border-radius: 20px; text-align: center; box-shadow: 0 6px 12px rgba(0,0,0,0.1); border: 3px solid #FDD835;">
#     <div style="font-size: 50px; margin-bottom: 15px;">🤖</div>
#     <h5 style="color: #F57F17; margin: 15px 0; font-size: 18px;">Sadece Kod</h5>
#     <p style="color: #424242; font-size: 14px; line-height: 1.6;">
#         Model dosyaları ve<br>Python kodları
#     </p>
# </div>
#
# <div style="font-size: 50px; color: #4CAF50;">→</div>
#
# <div style="flex: 1; min-width: 220px; background: linear-gradient(135deg, #C8E6C9 0%, #A5D6A7 100%); padding: 30px; border-radius: 20px; text-align: center; box-shadow: 0 6px 12px rgba(0,0,0,0.1); border: 3px solid #4CAF50;">
#     <div style="font-size: 50px; margin-bottom: 15px;">🌐</div>
#     <h5 style="color: #2E7D32; margin: 15px 0; font-size: 18px;">Spaces ile</h5>
#     <p style="color: #424242; font-size: 14px; line-height: 1.6;">
#         Çalışan web uygulaması!<br>Herkes kullanabilir
#     </p>
# </div>
#
# </div>
#
# <div style="background: linear-gradient(135deg, #E1F5FE 0%, #B3E5FC 100%); padding: 30px; border-radius: 20px; margin: 25px 0; box-shadow: 0 6px 12px rgba(0,0,0,0.1);">
#     <h4 style="color: #01579B; margin-top: 0; font-size: 20px;">✨ Spaces'in Özellikleri</h4>
#
# <table style="width: 100%; border-collapse: collapse; margin-top: 15px;">
#     <tr style="background: linear-gradient(135deg, #81D4FA 0%, #4FC3F7 100%); color: white;">
#         <th style="padding: 15px; text-align: left; border-radius: 8px 0 0 0; font-size: 15px;">Özellik</th>
#         <th style="padding: 15px; text-align: left; border-radius: 0 8px 0 0; font-size: 15px;">Açıklama</th>
#     </tr>
#     <tr style="background-color: rgba(255,255,255,0.9);">
#         <td style="padding: 15px; border: 2px solid #B3E5FC; font-weight: bold; color: #01579B;">🎨 Görsel Arayüz</td>
#         <td style="padding: 15px; border: 2px solid #B3E5FC; color: #424242;">Kullanıcı dostu web arayüzü</td>
#     </tr>
#     <tr style="background-color: rgba(255,255,255,0.7);">
#         <td style="padding: 15px; border: 2px solid #B3E5FC; font-weight: bold; color: #01579B;">🧪 Canlı Test</td>
#         <td style="padding: 15px; border: 2px solid #B3E5FC; color: #424242;">Tarayıcıdan direkt test edebilme</td>
#     </tr>
#     <tr style="background-color: rgba(255,255,255,0.9);">
#         <td style="padding: 15px; border: 2px solid #B3E5FC; font-weight: bold; color: #01579B;">📱 Paylaşılabilir</td>
#         <td style="padding: 15px; border: 2px solid #B3E5FC; color: #424242;">Link ile kolayca paylaşım</td>
#     </tr>
#     <tr style="background-color: rgba(255,255,255,0.7);">
#         <td style="padding: 15px; border: 2px solid #B3E5FC; font-weight: bold; color: #01579B;">🔗 API Desteği</td>
#         <td style="padding: 15px; border: 2px solid #B3E5FC; color: #424242;">Programatik erişim imkanı</td>
#     </tr>
# </table>
# </div>
#
# <div style="background: linear-gradient(135deg, #FCE4EC 0%, #F8BBD0 100%); padding: 30px; border-radius: 20px; margin: 30px 0; border-left: 6px solid #C2185B;">
#     <h4 style="color: #880E4F; margin-top: 0;">🎯 Spaces Kullanım Senaryoları</h4>
#
# <div style="display: grid; gap: 15px; margin-top: 20px;">
#
# <div style="background-color: rgba(255,255,255,0.8); padding: 20px; border-radius: 10px; border-left: 4px solid #E91E63;">
#     <h5 style="color: #C2185B; margin: 0 0 10px 0;">🧪 Demo ve Prototype</h5>
#     <p style="margin: 0; color: #424242; font-size: 14px; line-height: 1.6;">
#         Geliştirdiğiniz modeli müşteriye veya ekibe göstermek için
#     </p>
# </div>
#
# <div style="background-color: rgba(255,255,255,0.8); padding: 20px; border-radius: 10px; border-left: 4px solid #E91E63;">
#     <h5 style="color: #C2185B; margin: 0 0 10px 0;">📊 A/B Testi</h5>
#     <p style="margin: 0; color: #424242; font-size: 14px; line-height: 1.6;">
#         Farklı modelleri karşılaştırma ve performans değerlendirme
#     </p>
# </div>
#
# <div style="background-color: rgba(255,255,255,0.8); padding: 20px; border-radius: 10px; border-left: 4px solid #E91E63;">
#     <h5 style="color: #C2185B; margin: 0 0 10px 0;">🎓 Eğitim ve Sunum</h5>
#     <p style="margin: 0; color: #424242; font-size: 14px; line-height: 1.6;">
#         Öğrencilere veya paydaşlara interaktif gösterim
#     </p>
# </div>
#
# <div style="background-color: rgba(255,255,255,0.8); padding: 20px; border-radius: 10px; border-left: 4px solid #E91E63;">
#     <h5 style="color: #C2185B; margin: 0 0 10px 0;">🚀 MVP Geliştirme</h5>
#     <p style="margin: 0; color: #424242; font-size: 14px; line-height: 1.6;">
#         Minimum uygulanabilir ürün (MVP) oluşturma
#     </p>
# </div>
#
# </div>
# </div>
#
# <div style="background: linear-gradient(135deg, #D1C4E9 0%, #B39DDB 100%); padding: 35px; border-radius: 20px; margin: 30px 0; box-shadow: 0 10px 20px rgba(0,0,0,0.12); border: 4px solid #7B1FA2;">
#     <h4 style="color: #4A148C; margin-top: 0; text-align: center; font-size: 22px;">🎓 YBS Öğrencileri İçin</h4>
#     <p style="font-size: 18px; line-height: 2; color: #424242; text-align: center; font-weight: 500;">
#         Spaces, bir modelin <em>sadece kod olarak değil</em>,<br>
#         <span style="background-color: #FFEB3B; padding: 5px 15px; border-radius: 8px; font-weight: bold; color: #000; display: inline-block; margin-top: 10px;">
#             "Çalışan bir ürün olarak nasıl sunulduğunu"
#         </span><br>
#         <strong style="font-size: 20px; margin-top: 10px; display: inline-block;">gözlemleyebileceğiniz en somut örneklerden biridir! 🌟</strong>
#     </p>
#     <p style="font-size: 16px; line-height: 1.8; color: #6A1B9A; text-align: center; margin-top: 20px; font-weight: 500;">
#         "Modelden Ürüne Giden Yol" 🛤️
#     </p>
# </div>
#
# ---

# %% [markdown]
# ## 📌 Özet: Üç Temel Unsur
#
# <div style="background: linear-gradient(135deg, #FFF9C4 0%, #FFECB3 100%); padding: 40px; border-radius: 20px; margin: 30px 0; box-shadow: 0 12px 24px rgba(0,0,0,0.15); border: 5px solid #FDD835;">
#     <h3 style="color: #F57F17; margin-top: 0; text-align: center; font-size: 26px;">🎯 Bu Derste Öğrendiklerimiz</h3>
#     <p style="font-size: 17px; line-height: 1.9; color: #424242; text-align: center; margin-bottom: 30px;">
#         Hugging Face ekosisteminin <strong>üç temel unsurunu</strong> tanıttık:
#     </p>
#
# <div style="display: grid; grid-template-columns: repeat(auto-fit, minmax(280px, 1fr)); gap: 25px; margin-top: 30px;">
#
# <div style="background: linear-gradient(135deg, #E1F5FE 0%, #B3E5FC 100%); padding: 30px; border-radius: 20px; box-shadow: 0 8px 16px rgba(0,0,0,0.1); border: 4px solid #0288D1;">
#     <div style="text-align: center; font-size: 60px; margin-bottom: 15px;">🔄</div>
#     <h4 style="color: #01579B; margin: 15px 0; font-size: 22px; text-align: center;">1. Pipeline</h4>
#     <div style="background-color: rgba(255,255,255,0.8); padding: 20px; border-radius: 12px; margin-top: 15px;">
#         <p style="margin: 0; color: #424242; font-size: 15px; line-height: 1.8;">
#             Modeli <strong>kolayca kullanmamızı</strong> sağlar. Tokenizasyon, model çalıştırma ve çıktı üretimi <span style="background-color: #FFEB3B; padding: 2px 6px; border-radius: 4px; font-weight: bold;">tek bir yapı içinde</span> gizlenmiştir.
#         </p>
#         <div style="background-color: #B3E5FC; padding: 12px; border-radius: 8px; margin-top: 12px; text-align: center; font-weight: bold; color: #01579B;">
#             Uçtan Uca Otomatik İş Akışı ⚡
#         </div>
#     </div>
# </div>
#
# <div style="background: linear-gradient(135deg, #F3E5F5 0%, #E1BEE7 100%); padding: 30px; border-radius: 20px; box-shadow: 0 8px 16px rgba(0,0,0,0.1); border: 4px solid #8E24AA;">
#     <div style="text-align: center; font-size: 60px; margin-bottom: 15px;">📍</div>
#     <h4 style="color: #6A1B9A; margin: 15px 0; font-size: 22px; text-align: center;">2. Checkpoint</h4>
#     <div style="background-color: rgba(255,255,255,0.8); padding: 20px; border-radius: 12px; margin-top: 15px;">
#         <p style="margin: 0; color: #424242; font-size: 15px; line-height: 1.8;">
#             Modelin <strong>belirli bir eğitim anındaki</strong> kayıtlı halidir. Her görev için <span style="background-color: #FFEB3B; padding: 2px 6px; border-radius: 4px; font-weight: bold;">doğru checkpoint</span> seçilmelidir.
#         </p>
#         <div style="background-color: #E1BEE7; padding: 12px; border-radius: 8px; margin-top: 12px; text-align: center; font-weight: bold; color: #6A1B9A;">
#             Model Sürüm Yönetimi 💾
#         </div>
#     </div>
# </div>
#
# <div style="background: linear-gradient(135deg, #C8E6C9 0%, #A5D6A7 100%); padding: 30px; border-radius: 20px; box-shadow: 0 8px 16px rgba(0,0,0,0.1); border: 4px solid #4CAF50;">
#     <div style="text-align: center; font-size: 60px; margin-bottom: 15px;">🌐</div>
#     <h4 style="color: #2E7D32; margin: 15px 0; font-size: 22px; text-align: center;">3. Hub</h4>
#     <div style="background-color: rgba(255,255,255,0.8); padding: 20px; border-radius: 12px; margin-top: 15px;">
#         <p style="margin: 0; color: #424242; font-size: 15px; line-height: 1.8;">
#             Model ve veri ekosisteminin <strong>merkezidir</strong>. Yüz binlerce model, veri seti ve <span style="background-color: #FFEB3B; padding: 2px 6px; border-radius: 4px; font-weight: bold;">Spaces</span> uygulamaları içerir.
#         </p>
#         <div style="background-color: #C8E6C9; padding: 12px; border-radius: 8px; margin-top: 12px; text-align: center; font-weight: bold; color: #2E7D32;">
#             Açık Model Ekonomisi 🌍
#         </div>
#     </div>
# </div>
#
# </div>
# </div>
#
# ### 🎯 Önemli Kavramlar Flashcard'ları
#
# <div style="display: grid; grid-template-columns: repeat(auto-fit, minmax(300px, 1fr)); gap: 20px; margin: 30px 0;">
#
# <div style="background: linear-gradient(135deg, #FFECB3 0%, #FFE082 100%); padding: 25px; border-radius: 15px; box-shadow: 0 6px 12px rgba(0,0,0,0.1); border: 3px solid #FDD835;">
#     <h5 style="color: #F57F17; margin: 0 0 15px 0; font-size: 18px; text-align: center;">🔤 Tokenizer</h5>
#     <p style="margin: 0; color: #424242; font-size: 14px; line-height: 1.7; text-align: center;">
#         Metni modelin anlayabileceği sayısal parçalara (token) ayıran bileşen
#     </p>
# </div>
#
# <div style="background: linear-gradient(135deg, #FFE0B2 0%, #FFCC80 100%); padding: 25px; border-radius: 15px; box-shadow: 0 6px 12px rgba(0,0,0,0.1); border: 3px solid #FF9800;">
#     <h5 style="color: #E65100; margin: 0 0 15px 0; font-size: 18px; text-align: center;">📉 Downstream Tasks</h5>
#     <p style="margin: 0; color: #424242; font-size: 14px; line-height: 1.7; text-align: center;">
#         Ön eğitimli modelin spesifik görevlere uyarlanması sonucu ortaya çıkan görevler
#     </p>
# </div>
#
# <div style="background: linear-gradient(135deg, #E1BEE7 0%, #CE93D8 100%); padding: 25px; border-radius: 15px; box-shadow: 0 6px 12px rgba(0,0,0,0.1); border: 3px solid #AB47BC;">
#     <h5 style="color: #6A1B9A; margin: 0 0 15px 0; font-size: 18px; text-align: center;">🧪 Inference</h5>
#     <p style="margin: 0; color: #424242; font-size: 14px; line-height: 1.7; text-align: center;">
#         Eğitilmiş modelin tahmin üretme (çıkarım) aşaması
#     </p>
# </div>
#
# <div style="background: linear-gradient(135deg, #B3E5FC 0%, #81D4FA 100%); padding: 25px; border-radius: 15px; box-shadow: 0 6px 12px rgba(0,0,0,0.1); border: 3px solid #29B6F6;">
#     <h5 style="color: #01579B; margin: 0 0 15px 0; font-size: 18px; text-align: center;">🎨 Model Card</h5>
#     <p style="margin: 0; color: #424242; font-size: 14px; line-height: 1.7; text-align: center;">
#         Modelin ne için eğitildiği, hangi veriyle çalıştığı gibi bilgileri içeren dokümantasyon
#     </p>
# </div>
#
# <div style="background: linear-gradient(135deg, #C8E6C9 0%, #A5D6A7 100%); padding: 25px; border-radius: 15px; box-shadow: 0 6px 12px rgba(0,0,0,0.1); border: 3px solid #66BB6A;">
#     <h5 style="color: #2E7D32; margin: 0 0 15px 0; font-size: 18px; text-align: center;">🚀 Spaces</h5>
#     <p style="margin: 0; color: #424242; font-size: 14px; line-height: 1.7; text-align: center;">
#         Eğitilmiş modellerin canlı web uygulaması olarak sunulduğu platformlar
#     </p>
# </div>
#
# <div style="background: linear-gradient(135deg, #FFCCBC 0%, #FFAB91 100%); padding: 25px; border-radius: 15px; box-shadow: 0 6px 12px rgba(0,0,0,0.1); border: 3px solid #FF7043;">
#     <h5 style="color: #BF360C; margin: 0 0 15px 0; font-size: 18px; text-align: center;">🔄 Pipeline API</h5>
#     <p style="margin: 0; color: #424242; font-size: 14px; line-height: 1.7; text-align: center;">
#         Modeli tek satır kodla kullanmamızı sağlayan yüksek seviye arayüz
#     </p>
# </div>
#
# </div>
#
# ---
#
# <div style="background: linear-gradient(135deg, #E8F5E9 0%, #C8E6C9 100%); padding: 35px; border-radius: 20px; margin: 30px 0; text-align: center; box-shadow: 0 10px 20px rgba(0,0,0,0.12); border: 4px solid #4CAF50;">
#     <h3 style="color: #1B5E20; margin-top: 0; font-size: 26px;">🎉 Tebrikler!</h3>
#     <p style="font-size: 18px; line-height: 2; color: #2E7D32; margin: 20px 0; font-weight: 500;">
#         Hugging Face ekosisteminin temel kavramlarını öğrendiniz! 🎓
#     </p>
#     <p style="font-size: 16px; line-height: 1.8; color: #424242; margin: 20px 0;">
#         Artık <strong>Pipeline, Checkpoint ve Hub</strong> kavramlarını anlıyorsunuz.<br>
#         Bir sonraki derste bu kavramları <em>pratik olarak</em> kullanmaya başlayacağız! 💻
#     </p>
#     <div style="margin-top: 30px; font-size: 20px; color: #1B5E20; font-weight: 700;">
#         Hazır mısınız? Hadi kodlamaya başlayalım! 🚀✨
#     </div>
# </div>

# %% [markdown]
# ## 🤖 Auto Classes: Otomatik Sınıf Seçimi
#
# <div style="background: linear-gradient(135deg, #E8EAF6 0%, #C5CAE9 100%); padding: 40px; border-radius: 20px; margin: 30px 0; box-shadow: 0 12px 24px rgba(0,0,0,0.15); border: 5px solid #5C6BC0;">
#     <h3 style="color: #283593; margin-top: 0; font-size: 26px; text-align: center;">🎯 Auto Classes Nedir?</h3>
#     <p style="font-size: 18px; line-height: 2; color: #424242; font-weight: 500;">
#         Auto Classes, modellerle çalışırken <span style="background-color: #FFEB3B; padding: 5px 12px; border-radius: 5px; font-weight: bold; color: #000;">"doğru sınıfı elle seçme" zorunluluğunu</span> büyük ölçüde ortadan kaldıran <strong>pratik bir yaklaşımdır</strong>! 🚀
#     </p>
# </div>
#
# ### 🔄 Geleneksel Yöntem vs. Auto Classes
#
# <div style="display: grid; grid-template-columns: repeat(auto-fit, minmax(320px, 1fr)); gap: 25px; margin: 30px 0;">
#
# <div style="background: linear-gradient(135deg, #FFCDD2 0%, #EF9A9A 100%); padding: 30px; border-radius: 20px; box-shadow: 0 8px 16px rgba(0,0,0,0.1); border: 4px solid #E53935;">
#     <div style="text-align: center; font-size: 55px; margin-bottom: 15px;">❌</div>
#     <h4 style="color: #C62828; margin: 15px 0; font-size: 20px; text-align: center;">Geleneksel Yöntem</h4>
#     <div style="background-color: rgba(255,255,255,0.8); padding: 20px; border-radius: 12px; margin-top: 15px;">
#         <p style="margin: 0 0 15px 0; color: #424242; font-size: 15px; line-height: 1.8;">
#             <strong>Elle Seçim Gerekir:</strong>
#         </p>
#         <ul style="margin: 0; padding-left: 20px; color: #424242; line-height: 2; font-size: 14px;">
#             <li>Doğru tokenizer sınıfını bilmek</li>
#             <li>Doğru model sınıfını bilmek</li>
#             <li>Mimari ayrıntılarını hatırlamak</li>
#             <li>Her model için farklı import</li>
#         </ul>
#     </div>
#     <div style="background-color: #FFCDD2; padding: 15px; border-radius: 8px; margin-top: 15px; font-family: 'Courier New', monospace; font-size: 13px; color: #C62828; font-weight: bold;">
#         from transformers import BertTokenizer<br>
#         tokenizer = BertTokenizer.from_pretrained(...)
#     </div>
# </div>
#
# <div style="background: linear-gradient(135deg, #C8E6C9 0%, #A5D6A7 100%); padding: 30px; border-radius: 20px; box-shadow: 0 8px 16px rgba(0,0,0,0.1); border: 4px solid #4CAF50;">
#     <div style="text-align: center; font-size: 55px; margin-bottom: 15px;">✅</div>
#     <h4 style="color: #2E7D32; margin: 15px 0; font-size: 20px; text-align: center;">Auto Classes Yöntemi</h4>
#     <div style="background-color: rgba(255,255,255,0.8); padding: 20px; border-radius: 12px; margin-top: 15px;">
#         <p style="margin: 0 0 15px 0; color: #424242; font-size: 15px; line-height: 1.8;">
#             <strong>Otomatik Seçim:</strong>
#         </p>
#         <ul style="margin: 0; padding-left: 20px; color: #424242; line-height: 2; font-size: 14px;">
#             <li>Sadece checkpoint adı verin</li>
#             <li>Mimari otomatik tanınır</li>
#             <li>Uygun sınıf otomatik yüklenir</li>
#             <li>Tek bir standart arayüz</li>
#         </ul>
#     </div>
#     <div style="background-color: #C8E6C9; padding: 15px; border-radius: 8px; margin-top: 15px; font-family: 'Courier New', monospace; font-size: 13px; color: #2E7D32; font-weight: bold;">
#         from transformers import AutoTokenizer<br>
#         tokenizer = AutoTokenizer.from_pretrained(...)
#     </div>
# </div>
#
# </div>
#
# <div style="background: linear-gradient(135deg, #FFF9C4 0%, #FFF59D 100%); padding: 30px; border-radius: 20px; margin: 30px 0; border-left: 6px solid #F9A825;">
#     <h4 style="color: #F57F17; margin-top: 0;">💼 YBS Perspektifi</h4>
#     <p style="font-size: 17px; line-height: 2; color: #424242; font-weight: 500;">
#         Bu yaklaşım, karmaşık teknik seçimleri bir <span style="background-color: #FFEB3B; padding: 3px 8px; border-radius: 5px; font-weight: bold;">"standartlaştırılmış arayüz"</span> ile sadeleştirir.
#     </p>
#     <div style="background-color: rgba(255,255,255,0.7); padding: 20px; border-radius: 10px; margin-top: 15px;">
#         <h5 style="color: #E65100; margin-top: 0;">🎯 Faydaları:</h5>
#         <ul style="margin: 0; padding-left: 20px; line-height: 2; color: #424242; font-size: 15px;">
#             <li>📉 <strong>Zihinsel yük azalır</strong></li>
#             <li>❌ <strong>Hata olasılığı düşer</strong></li>
#             <li>📈 <strong>Süreç ölçeklenebilir hale gelir</strong></li>
#         </ul>
#     </div>
# </div>
#
# ---

# %% [markdown]
# ### 🔤 AutoTokenizer: En Sık Kullanılan Bileşen
#
# <div style="background: linear-gradient(135deg, #E1F5FE 0%, #B3E5FC 100%); padding: 30px; border-radius: 20px; margin: 25px 0; box-shadow: 0 6px 12px rgba(0,0,0,0.1);">
#     <h4 style="color: #01579B; margin-top: 0; font-size: 20px;">🎯 AutoTokenizer Mantığı</h4>
#     <p style="font-size: 16px; line-height: 1.9; color: #424242;">
#         Elinizde bir checkpoint vardır ve siz <span style="background-color: #FFEB3B; padding: 3px 8px; border-radius: 5px; font-weight: bold;">"bu checkpoint için doğru tokenizer hangisi"</span> sorusunu kütüphaneye bırakırsınız.
#     </p>
# </div>
#
# <div style="display: flex; align-items: center; justify-content: space-around; margin: 30px 0; flex-wrap: wrap; gap: 15px;">
#
# <div style="flex: 1; min-width: 200px; background: linear-gradient(135deg, #FFECB3 0%, #FFE082 100%); padding: 25px; border-radius: 15px; text-align: center; box-shadow: 0 4px 8px rgba(0,0,0,0.1);">
#     <div style="font-size: 40px; margin-bottom: 10px;">📝</div>
#     <h5 style="color: #F57F17; margin: 10px 0;">Checkpoint Adı</h5>
#     <div style="background-color: rgba(255,255,255,0.8); padding: 12px; border-radius: 8px; margin-top: 10px; font-family: 'Courier New', monospace; font-size: 13px; color: #E65100;">
#         bert-base-uncased
#     </div>
# </div>
#
# <div style="font-size: 40px; color: #4CAF50;">➡️</div>
#
# <div style="flex: 1; min-width: 200px; background: linear-gradient(135deg, #F3E5F5 0%, #E1BEE7 100%); padding: 25px; border-radius: 15px; text-align: center; box-shadow: 0 4px 8px rgba(0,0,0,0.1);">
#     <div style="font-size: 40px; margin-bottom: 10px;">🤖</div>
#     <h5 style="color: #6A1B9A; margin: 10px 0;">Auto Algılama</h5>
#     <p style="color: #424242; margin: 0; font-size: 13px;">Sistem BERT ailesini tanır</p>
# </div>
#
# <div style="font-size: 40px; color: #4CAF50;">➡️</div>
#
# <div style="flex: 1; min-width: 200px; background: linear-gradient(135deg, #C8E6C9 0%, #A5D6A7 100%); padding: 25px; border-radius: 15px; text-align: center; box-shadow: 0 4px 8px rgba(0,0,0,0.1);">
#     <div style="font-size: 40px; margin-bottom: 10px;">✅</div>
#     <h5 style="color: #2E7D32; margin: 10px 0;">Doğru Tokenizer</h5>
#     <p style="color: #424242; margin: 0; font-size: 13px;">BERT uyumlu tokenizer</p>
# </div>
#
# </div>
#
# ### 🧠 AutoModel: Görev Odaklı Yaklaşım
#
# <div style="background: linear-gradient(135deg, #FCE4EC 0%, #F8BBD0 100%); padding: 30px; border-radius: 20px; margin: 25px 0; box-shadow: 0 6px 12px rgba(0,0,0,0.1);">
#     <h4 style="color: #C2185B; margin-top: 0; font-size: 20px;">⚠️ Kritik Ayrım</h4>
#     <p style="font-size: 17px; line-height: 1.9; color: #424242; font-weight: 500;">
#         Modeli <span style="background-color: #FFEB3B; padding: 4px 10px; border-radius: 5px; font-weight: bold; color: #000;">"hangi görev"</span> için yüklediğiniz <strong>önemlidir</strong>!
#     </p>
#     <p style="font-size: 15px; line-height: 1.7; color: #424242; margin-top: 10px;">
#         Bu nedenle <strong>görev odaklı otomatik sınıflar</strong> kullanılır:
#     </p>
# </div>
#
# <div style="display: grid; grid-template-columns: repeat(auto-fit, minmax(280px, 1fr)); gap: 20px; margin: 30px 0;">
#
# <div style="background: linear-gradient(135deg, #E3F2FD 0%, #BBDEFB 100%); padding: 25px; border-radius: 15px; box-shadow: 0 4px 8px rgba(0,0,0,0.1); border-top: 5px solid #1976D2;">
#     <h5 style="color: #0D47A1; margin-top: 0; font-size: 18px;">📊 Dizi Sınıflandırma</h5>
#     <div style="background-color: rgba(255,255,255,0.7); padding: 15px; border-radius: 10px; margin: 10px 0;">
#         <div style="font-family: 'Courier New', monospace; font-size: 12px; color: #01579B; font-weight: bold; word-break: break-all;">
#             AutoModelForSequenceClassification
#         </div>
#     </div>
#     <div style="background-color: #B3E5FC; padding: 10px; border-radius: 8px; margin-top: 10px; font-size: 13px; color: #01579B;">
#         <strong>Kullanım:</strong> Metin sınıflandırma, duygu analizi
#     </div>
# </div>
#
# <div style="background: linear-gradient(135deg, #F3E5F5 0%, #E1BEE7 100%); padding: 25px; border-radius: 15px; box-shadow: 0 4px 8px rgba(0,0,0,0.1); border-top: 5px solid #8E24AA;">
#     <h5 style="color: #6A1B9A; margin-top: 0; font-size: 18px;">🏷️ Token Sınıflandırma</h5>
#     <div style="background-color: rgba(255,255,255,0.7); padding: 15px; border-radius: 10px; margin: 10px 0;">
#         <div style="font-family: 'Courier New', monospace; font-size: 12px; color: #6A1B9A; font-weight: bold; word-break: break-all;">
#             AutoModelForTokenClassification
#         </div>
#     </div>
#     <div style="background-color: #E1BEE7; padding: 10px; border-radius: 8px; margin-top: 10px; font-size: 13px; color: #6A1B9A;">
#         <strong>Kullanım:</strong> NER (Named Entity Recognition)
#     </div>
# </div>
#
# <div style="background: linear-gradient(135deg, #C8E6C9 0%, #A5D6A7 100%); padding: 25px; border-radius: 15px; box-shadow: 0 4px 8px rgba(0,0,0,0.1); border-top: 5px solid #43A047;">
#     <h5 style="color: #2E7D32; margin-top: 0; font-size: 18px;">❓ Soru Yanıtlama</h5>
#     <div style="background-color: rgba(255,255,255,0.7); padding: 15px; border-radius: 10px; margin: 10px 0;">
#         <div style="font-family: 'Courier New', monospace; font-size: 12px; color: #2E7D32; font-weight: bold; word-break: break-all;">
#             AutoModelForQuestionAnswering
#         </div>
#     </div>
#     <div style="background-color: #C8E6C9; padding: 10px; border-radius: 8px; margin-top: 10px; font-size: 13px; color: #2E7D32;">
#         <strong>Kullanım:</strong> QA sistemleri
#     </div>
# </div>
#
# <div style="background: linear-gradient(135deg, #FFF9C4 0%, #FFF59D 100%); padding: 25px; border-radius: 15px; box-shadow: 0 4px 8px rgba(0,0,0,0.1); border-top: 5px solid #F9A825;">
#     <h5 style="color: #F57F17; margin-top: 0; font-size: 18px;">✍️ Nedensel Dil Modeli</h5>
#     <div style="background-color: rgba(255,255,255,0.7); padding: 15px; border-radius: 10px; margin: 10px 0;">
#         <div style="font-family: 'Courier New', monospace; font-size: 12px; color: #F57F17; font-weight: bold; word-break: break-all;">
#             AutoModelForCausalLM
#         </div>
#     </div>
#     <div style="background-color: #FFF9C4; padding: 10px; border-radius: 8px; margin-top: 10px; font-size: 13px; color: #F57F17;">
#         <strong>Kullanım:</strong> Metin üretimi (GPT benzeri)
#     </div>
# </div>
#
# <div style="background: linear-gradient(135deg, #FFECB3 0%, #FFE082 100%); padding: 25px; border-radius: 15px; box-shadow: 0 4px 8px rgba(0,0,0,0.1); border-top: 5px solid #FF6F00;">
#     <h5 style="color: #E65100; margin-top: 0; font-size: 18px;">🎭 Maskeli Dil Modeli</h5>
#     <div style="background-color: rgba(255,255,255,0.7); padding: 15px; border-radius: 10px; margin: 10px 0;">
#         <div style="font-family: 'Courier New', monospace; font-size: 12px; color: #E65100; font-weight: bold; word-break: break-all;">
#             AutoModelForMaskedLM
#         </div>
#     </div>
#     <div style="background-color: #FFECB3; padding: 10px; border-radius: 8px; margin-top: 10px; font-size: 13px; color: #E65100;">
#         <strong>Kullanım:</strong> Maske doldurma (BERT benzeri)
#     </div>
# </div>
#
# <div style="background: linear-gradient(135deg, #FFCCBC 0%, #FFAB91 100%); padding: 25px; border-radius: 15px; box-shadow: 0 4px 8px rgba(0,0,0,0.1); border-top: 5px solid #E64A19;">
#     <h5 style="color: #BF360C; margin-top: 0; font-size: 18px;">📝 Seq2Seq</h5>
#     <div style="background-color: rgba(255,255,255,0.7); padding: 15px; border-radius: 10px; margin: 10px 0;">
#         <div style="font-family: 'Courier New', monospace; font-size: 12px; color: #BF360C; font-weight: bold; word-break: break-all;">
#             AutoModelForSeq2SeqLM
#         </div>
#     </div>
#     <div style="background-color: #FFCCBC; padding: 10px; border-radius: 8px; margin-top: 10px; font-size: 13px; color: #BF360C;">
#         <strong>Kullanım:</strong> Çeviri, özetleme
#     </div>
# </div>
#
# </div>
#
# ---

# %% [markdown]
# ### 🏗️ Gövde ve Başlık Kavramı
#
# <div style="background: linear-gradient(135deg, #E8EAF6 0%, #C5CAE9 100%); padding: 35px; border-radius: 20px; margin: 30px 0; box-shadow: 0 10px 20px rgba(0,0,0,0.12); border: 4px solid #5C6BC0;">
#     <h4 style="color: #283593; margin-top: 0; font-size: 22px; text-align: center;">🎯 Önemli Kavram</h4>
#     <p style="font-size: 17px; line-height: 2; color: #424242; text-align: center; font-weight: 500;">
#         Checkpoint adı <span style="background-color: #FFEB3B; padding: 4px 10px; border-radius: 5px; font-weight: bold; color: #000;">aynı kalsa bile</span>, seçilen model başlığı (head) <strong>göreve göre farklılaşır</strong>! 🔄
#     </p>
# </div>
#
# <div style="display: grid; grid-template-columns: repeat(auto-fit, minmax(280px, 1fr)); gap: 25px; margin: 30px 0;">
#
# <div style="background: linear-gradient(135deg, #E3F2FD 0%, #BBDEFB 100%); padding: 30px; border-radius: 20px; box-shadow: 0 8px 16px rgba(0,0,0,0.1); border: 4px solid #1976D2;">
#     <div style="text-align: center; font-size: 55px; margin-bottom: 15px;">🏛️</div>
#     <h5 style="color: #0D47A1; margin: 15px 0; font-size: 20px; text-align: center;">Gövde (Body)</h5>
#     <div style="background-color: rgba(255,255,255,0.8); padding: 20px; border-radius: 12px; margin-top: 15px;">
#         <p style="margin: 0; color: #424242; font-size: 15px; line-height: 1.8;">
#             Temel transformatör katmanları. <strong>Genel özellik çıkarımı</strong> yapar.
#         </p>
#         <div style="background-color: #B3E5FC; padding: 12px; border-radius: 8px; margin-top: 12px; text-align: center; font-weight: bold; color: #01579B;">
#             ✅ Çoğu zaman aynı kalır
#         </div>
#     </div>
# </div>
#
# <div style="background: linear-gradient(135deg, #F3E5F5 0%, #E1BEE7 100%); padding: 30px; border-radius: 20px; box-shadow: 0 8px 16px rgba(0,0,0,0.1); border: 4px solid #8E24AA;">
#     <div style="text-align: center; font-size: 55px; margin-bottom: 15px;">👑</div>
#     <h5 style="color: #6A1B9A; margin: 15px 0; font-size: 20px; text-align: center;">Başlık (Head)</h5>
#     <div style="background-color: rgba(255,255,255,0.8); padding: 20px; border-radius: 12px; margin-top: 15px;">
#         <p style="margin: 0; color: #424242; font-size: 15px; line-height: 1.8;">
#             Göreve özel çıktı katmanı. <strong>Spesifik görev</strong> için uyarlanır.
#         </p>
#         <div style="background-color: #E1BEE7; padding: 12px; border-radius: 8px; margin-top: 12px; text-align: center; font-weight: bold; color: #6A1B9A;">
#             🔄 Göreve göre değişir
#         </div>
#     </div>
# </div>
#
# </div>
#
# <div style="background: linear-gradient(135deg, #FFF3E0 0%, #FFE0B2 100%); padding: 30px; border-radius: 20px; margin: 25px 0; border-left: 6px solid #FF6F00;">
#     <h4 style="color: #E65100; margin-top: 0;">📚 Örnek Senaryo</h4>
#     <div style="background-color: rgba(255,255,255,0.7); padding: 20px; border-radius: 10px; margin-top: 15px;">
#         <p style="margin: 0 0 10px 0; color: #424242; font-size: 15px; line-height: 1.7;">
#             <strong>Durum:</strong> İki sınıflı duygu analizi için eğitilmiş bir başlık var.
#         </p>
#         <p style="margin: 10px 0; color: #424242; font-size: 15px; line-height: 1.7;">
#             <strong>Problem:</strong> Üç sınıflı bir probleme uygulamak istiyorsunuz.
#         </p>
#         <p style="margin: 10px 0; color: #2E7D32; font-size: 15px; line-height: 1.7; font-weight: 600;">
#             <strong>Çözüm:</strong> 🏛️ Gövdeyi koru + 👑 Başlığı değiştir + ⚙️ Fine-tuning yap!
#         </p>
#     </div>
# </div>
#
# ### 🖼️ Çok Modlu Auto Classes
#
# <div style="background: linear-gradient(135deg, #E1F5FE 0%, #B3E5FC 100%); padding: 30px; border-radius: 20px; margin: 25px 0; box-shadow: 0 6px 12px rgba(0,0,0,0.1);">
#     <h4 style="color: #01579B; margin-top: 0; font-size: 20px;">🌐 Sadece Metin Değil!</h4>
#     <p style="font-size: 16px; line-height: 1.9; color: #424242;">
#         Auto Classes yalnızca metin dünyasıyla <strong>sınırlı değildir</strong>. Farklı veri tipleri için de otomatik bileşenler mevcuttur:
#     </p>
# </div>
#
# <div style="display: grid; grid-template-columns: repeat(auto-fit, minmax(260px, 1fr)); gap: 20px; margin: 25px 0;">
#
# <div style="background: linear-gradient(135deg, #C8E6C9 0%, #A5D6A7 100%); padding: 25px; border-radius: 15px; box-shadow: 0 4px 8px rgba(0,0,0,0.1); border-left: 5px solid #388E3C;">
#     <h5 style="color: #2E7D32; margin: 0 0 15px 0; font-size: 18px;">🖼️ AutoImageProcessor</h5>
#     <p style="margin: 0; color: #424242; font-size: 14px; line-height: 1.6;">
#         Görüntü verisi için <strong>ön işleme</strong> otomasyonu
#     </p>
# </div>
#
# <div style="background: linear-gradient(135deg, #FFF9C4 0%, #FFF59D 100%); padding: 25px; border-radius: 15px; box-shadow: 0 4px 8px rgba(0,0,0,0.1); border-left: 5px solid #F9A825;">
#     <h5 style="color: #F57F17; margin: 0 0 15px 0; font-size: 18px;">🎵 AutoFeatureExtractor</h5>
#     <p style="margin: 0; color: #424242; font-size: 14px; line-height: 1.6;">
#         Ses veya diğer veri tipleri için <strong>özellik çıkarımı</strong>
#     </p>
# </div>
#
# <div style="background: linear-gradient(135deg, #FFECB3 0%, #FFE082 100%); padding: 25px; border-radius: 15px; box-shadow: 0 4px 8px rgba(0,0,0,0.1); border-left: 5px solid #FF6F00;">
#     <h5 style="color: #E65100; margin: 0 0 15px 0; font-size: 18px;">🔀 AutoProcessor</h5>
#     <p style="margin: 0; color: #424242; font-size: 14px; line-height: 1.6;">
#         Çok modlu modeller için <strong>birleşik ön işleme</strong>
#     </p>
# </div>
#
# </div>
#
# <div style="background: linear-gradient(135deg, #D1C4E9 0%, #B39DDB 100%); padding: 30px; border-radius: 20px; margin: 30px 0; box-shadow: 0 8px 16px rgba(0,0,0,0.1); border: 3px solid #7B1FA2;">
#     <h4 style="color: #4A148C; margin-top: 0; text-align: center;">🔌 Otomatik Adaptör Benzetmesi</h4>
#     <p style="font-size: 17px; line-height: 2; color: #424242; text-align: center; font-weight: 500;">
#         Auto Classes ailesini bir <span style="background-color: #FFEB3B; padding: 4px 10px; border-radius: 5px; font-weight: bold; color: #000;">"otomatik adaptör"</span> gibi düşünebilirsiniz.
#     </p>
#     <div style="background-color: rgba(255,255,255,0.7); padding: 20px; border-radius: 10px; margin-top: 20px;">
#         <p style="margin: 0; color: #424242; font-size: 16px; line-height: 1.8; text-align: center;">
#             Siz <strong>hedef görevi</strong> ve <strong>checkpoint'i</strong> söylersiniz.<br>
#             Sistem, <em>veri tipine uygun dönüştürmeyi</em> ve <em>doğru model bileşenini</em> devreye alır! ⚡
#         </p>
#     </div>
# </div>
#
# <div style="background: linear-gradient(135deg, #FCE4EC 0%, #F8BBD0 100%); padding: 30px; border-radius: 20px; margin: 30px 0; border-left: 6px solid #C2185B;">
#     <h4 style="color: #880E4F; margin-top: 0;">🎓 Bu Repo'da Neden Sık Kullanacağız?</h4>
#     <p style="font-size: 17px; line-height: 2; color: #424242; font-weight: 500;">
#         Auto Classes'ı sık kullanmamızın nedeni:
#     </p>
#     <div style="background-color: rgba(255,255,255,0.7); padding: 20px; border-radius: 10px; margin-top: 15px;">
#         <p style="font-size: 18px; line-height: 2; color: #C2185B; text-align: center; margin: 0; font-weight: 600;">
#             "Öğrenciler, <span style="background-color: #FFEB3B; padding: 4px 10px; border-radius: 5px; color: #000;">mimari ayrıntılarda boğulmadan</span>,<br>
#             <strong>iş problemine ve veri mantığına odaklanabilir</strong>" 🎯
#         </p>
#     </div>
# </div>
#
# ---

# %% [markdown]
# ## 🔄 Transfer Öğrenimi (Transfer Learning)
#
# <div style="background: linear-gradient(135deg, #E8F5E9 0%, #C8E6C9 100%); padding: 40px; border-radius: 20px; margin: 30px 0; box-shadow: 0 12px 24px rgba(0,0,0,0.15); border: 5px solid #4CAF50;">
#     <h3 style="color: #1B5E20; margin-top: 0; font-size: 26px; text-align: center;">🎯 Transfer Öğrenimi Nedir?</h3>
#     <p style="font-size: 18px; line-height: 2; color: #2E7D32; text-align: center; font-weight: 500;">
#         YBS öğrencilerinin <span style="background-color: #FFEB3B; padding: 5px 12px; border-radius: 5px; font-weight: bold; color: #000;">"Sıfırdan geliştirmek mi yoksa hazırı uyarlamak mı?"</span> ikilemini doğru okumaları için <strong>merkezi bir kavramdır</strong>! 🔑
#     </p>
# </div>
#
# ### ⚖️ İki Yaklaşım: Karşılaştırma
#
# <div style="display: grid; grid-template-columns: repeat(auto-fit, minmax(320px, 1fr)); gap: 25px; margin: 30px 0;">
#
# <div style="background: linear-gradient(135deg, #FFCDD2 0%, #EF9A9A 100%); padding: 30px; border-radius: 20px; box-shadow: 0 8px 16px rgba(0,0,0,0.1); border: 4px solid #E53935;">
#     <div style="text-align: center; font-size: 55px; margin-bottom: 15px;">❌</div>
#     <h4 style="color: #C62828; margin: 15px 0; font-size: 20px; text-align: center;">Transfer Öğrenimi OLMADAN</h4>
#     <div style="background-color: rgba(255,255,255,0.8); padding: 20px; border-radius: 12px; margin-top: 15px;">
#         <ul style="margin: 0; padding-left: 20px; color: #424242; line-height: 2.2; font-size: 15px;">
#             <li>🔄 Her problem için <strong>sıfırdan başlama</strong></li>
#             <li>🎲 Rastgele ağırlıklarla eğitim</li>
#             <li>⏰ Çok uzun eğitim süresi</li>
#             <li>📊 Büyük veri seti gereksinimi</li>
#             <li>💰 Yüksek hesaplama maliyeti</li>
#             <li>⚠️ Daha yüksek hata riski</li>
#         </ul>
#     </div>
# </div>
#
# <div style="background: linear-gradient(135deg, #C8E6C9 0%, #A5D6A7 100%); padding: 30px; border-radius: 20px; box-shadow: 0 8px 16px rgba(0,0,0,0.1); border: 4px solid #4CAF50;">
#     <div style="text-align: center; font-size: 55px; margin-bottom: 15px;">✅</div>
#     <h4 style="color: #2E7D32; margin: 15px 0; font-size: 20px; text-align: center;">Transfer Öğrenimi İLE</h4>
#     <div style="background-color: rgba(255,255,255,0.8); padding: 20px; border-radius: 12px; margin-top: 15px;">
#         <ul style="margin: 0; padding-left: 20px; color: #424242; line-height: 2.2; font-size: 15px;">
#             <li>🚀 Hazır bilgi ile <strong>başlama</strong></li>
#             <li>🧠 Ön eğitimli ağırlıklarla eğitim</li>
#             <li>⚡ Daha hızlı yakınsama</li>
#             <li>📉 Daha az veri yeterli</li>
#             <li>💸 Düşük maliyet</li>
#             <li>✅ Daha iyi genelleme</li>
#         </ul>
#     </div>
# </div>
#
# </div>
#
# <div style="background: linear-gradient(135deg, #E1F5FE 0%, #B3E5FC 100%); padding: 30px; border-radius: 20px; margin: 30px 0; box-shadow: 0 6px 12px rgba(0,0,0,0.1);">
#     <h4 style="color: #01579B; margin-top: 0; font-size: 20px;">🔄 Transfer Öğrenimi Süreci</h4>
#     <p style="font-size: 16px; line-height: 1.9; color: #424242;">
#         Büyük bir <strong>kaynak görev</strong> veya <strong>genel veri</strong> üzerinde eğitilmiş bir modelin öğrendiği <span style="background-color: #FFEB3B; padding: 3px 8px; border-radius: 5px; font-weight: bold;">temsil gücünü alır</span>, bunu <strong>hedef göreve</strong> adapte edersiniz.
#     </p>
# </div>
#
# ### 🔀 Transfer Öğrenimi Akışı
#
# <div style="display: flex; align-items: center; justify-content: space-around; margin: 35px 0; flex-wrap: wrap; gap: 15px;">
#
# <div style="flex: 1; min-width: 220px; background: linear-gradient(135deg, #FFECB3 0%, #FFE082 100%); padding: 30px; border-radius: 20px; text-align: center; box-shadow: 0 6px 12px rgba(0,0,0,0.1); border: 3px solid #FDD835;">
#     <div style="font-size: 50px; margin-bottom: 15px;">📚</div>
#     <h5 style="color: #F57F17; margin: 15px 0; font-size: 18px;">1. Kaynak Görev</h5>
#     <p style="color: #424242; font-size: 14px; line-height: 1.6;">
#         Büyük veri seti<br>Genel bilgi öğrenme
#     </p>
# </div>
#
# <div style="font-size: 40px; color: #4CAF50;">→</div>
#
# <div style="flex: 1; min-width: 220px; background: linear-gradient(135deg, #E1BEE7 0%, #CE93D8 100%); padding: 30px; border-radius: 20px; text-align: center; box-shadow: 0 6px 12px rgba(0,0,0,0.1); border: 3px solid #AB47BC;">
#     <div style="font-size: 50px; margin-bottom: 15px;">🧠</div>
#     <h5 style="color: #6A1B9A; margin: 15px 0; font-size: 18px;">2. Ön Eğitimli Model</h5>
#     <p style="color: #424242; font-size: 14px; line-height: 1.6;">
#         Genel temsil gücü<br>Transfer edilebilir bilgi
#     </p>
# </div>
#
# <div style="font-size: 40px; color: #4CAF50;">→</div>
#
# <div style="flex: 1; min-width: 220px; background: linear-gradient(135deg, #B3E5FC 0%, #81D4FA 100%); padding: 30px; border-radius: 20px; text-align: center; box-shadow: 0 6px 12px rgba(0,0,0,0.1); border: 3px solid #29B6F6;">
#     <div style="font-size: 50px; margin-bottom: 15px;">⚙️</div>
#     <h5 style="color: #01579B; margin: 15px 0; font-size: 18px;">3. Fine-Tuning</h5>
#     <p style="color: #424242; font-size: 14px; line-height: 1.6;">
#         Hedef göreve adaptasyon<br>Küçük veri seti
#     </p>
# </div>
#
# <div style="font-size: 40px; color: #4CAF50;">→</div>
#
# <div style="flex: 1; min-width: 220px; background: linear-gradient(135deg, #C8E6C9 0%, #A5D6A7 100%); padding: 30px; border-radius: 20px; text-align: center; box-shadow: 0 6px 12px rgba(0,0,0,0.1); border: 3px solid #66BB6A;">
#     <div style="font-size: 50px; margin-bottom: 15px;">✅</div>
#     <h5 style="color: #2E7D32; margin: 15px 0; font-size: 18px;">4. Özel Model</h5>
#     <p style="color: #424242; font-size: 14px; line-height: 1.6;">
#         Göreve özel uzmanlık<br>Kullanıma hazır
#     </p>
# </div>
#
# </div>
#
# ---

# %% [markdown]
# ### 🏗️ Model Anatomisi: Gövde + Başlık
#
# <div style="background: linear-gradient(135deg, #F3E5F5 0%, #E1BEE7 100%); padding: 30px; border-radius: 20px; margin: 25px 0; box-shadow: 0 6px 12px rgba(0,0,0,0.1);">
#     <h4 style="color: #6A1B9A; margin-top: 0; font-size: 20px;">🔍 İki Parçalı Yapı</h4>
#     <p style="font-size: 16px; line-height: 1.9; color: #424242;">
#         Pratikte modeli <strong>iki parçasını ayırt ederek</strong> düşünmek faydalıdır:
#     </p>
# </div>
#
# <div style="display: grid; grid-template-columns: repeat(auto-fit, minmax(300px, 1fr)); gap: 25px; margin: 30px 0;">
#
# <div style="background: linear-gradient(135deg, #E3F2FD 0%, #BBDEFB 100%); padding: 35px; border-radius: 20px; box-shadow: 0 8px 16px rgba(0,0,0,0.1); border: 5px solid #1976D2;">
#     <div style="text-align: center; font-size: 60px; margin-bottom: 20px;">🏛️</div>
#     <h5 style="color: #0D47A1; margin: 15px 0; font-size: 22px; text-align: center;">Gövde (Body)</h5>
#     <div style="background-color: rgba(255,255,255,0.8); padding: 20px; border-radius: 12px; margin-top: 15px;">
#         <p style="margin: 0; color: #424242; font-size: 15px; line-height: 1.8; text-align: center;">
#             <strong>Genel özellik çıkaran</strong><br>temel transformatör katmanları
#         </p>
#         <div style="background-color: #B3E5FC; padding: 15px; border-radius: 8px; margin-top: 15px; text-align: center; font-size: 14px; color: #01579B; font-weight: 600;">
#             📦 Genellikle <span style="background-color: #FFEB3B; padding: 2px 6px; border-radius: 4px; color: #000;">KORUNUR</span>
#         </div>
#     </div>
# </div>
#
# <div style="background: linear-gradient(135deg, #FFF9C4 0%, #FFF59D 100%); padding: 35px; border-radius: 20px; box-shadow: 0 8px 16px rgba(0,0,0,0.1); border: 5px solid #F9A825;">
#     <div style="text-align: center; font-size: 60px; margin-bottom: 20px;">👑</div>
#     <h5 style="color: #F57F17; margin: 15px 0; font-size: 22px; text-align: center;">Başlık (Head)</h5>
#     <div style="background-color: rgba(255,255,255,0.8); padding: 20px; border-radius: 12px; margin-top: 15px;">
#         <p style="margin: 0; color: #424242; font-size: 15px; line-height: 1.8; text-align: center;">
#             <strong>Göreve özel</strong><br>çıktı katmanı
#         </p>
#         <div style="background-color: #FFF9C4; padding: 15px; border-radius: 8px; margin-top: 15px; text-align: center; font-size: 14px; color: #F57F17; font-weight: 600;">
#             🔄 Göreve göre <span style="background-color: #FF6F00; padding: 2px 6px; border-radius: 4px; color: #FFF;">DEĞİŞTİRİLİR</span>
#         </div>
#     </div>
# </div>
#
# </div>
#
# ### 🔧 Pratik Uygulama Senaryosu
#
# <div style="background: linear-gradient(135deg, #FFF3E0 0%, #FFE0B2 100%); padding: 30px; border-radius: 20px; margin: 25px 0; box-shadow: 0 6px 12px rgba(0,0,0,0.1);">
#     <h4 style="color: #E65100; margin-top: 0; font-size: 20px;">📋 Örnek Durum</h4>
#     <div style="background-color: rgba(255,255,255,0.7); padding: 25px; border-radius: 12px; margin-top: 15px;">
#         <div style="margin-bottom: 20px;">
#             <p style="margin: 0 0 10px 0; color: #BF360C; font-size: 16px; font-weight: 600;">❌ Mevcut Model:</p>
#             <p style="margin: 0; color: #424242; font-size: 15px; line-height: 1.7;">
#                 2 sınıflı duygu analizi için eğitilmiş (Pozitif / Negatif)
#             </p>
#         </div>
#         <div style="margin-bottom: 20px;">
#             <p style="margin: 0 0 10px 0; color: #1976D2; font-size: 16px; font-weight: 600;">🎯 Yeni İhtiyaç:</p>
#             <p style="margin: 0; color: #424242; font-size: 15px; line-height: 1.7;">
#                 3 sınıflı problem (Pozitif / Nötr / Negatif)
#             </p>
#         </div>
#         <div style="background-color: #C8E6C9; padding: 20px; border-radius: 10px;">
#             <p style="margin: 0 0 10px 0; color: #2E7D32; font-size: 16px; font-weight: 600;">✅ Çözüm Adımları:</p>
#             <ol style="margin: 0; padding-left: 20px; line-height: 2; color: #424242; font-size: 14px;">
#                 <li>🏛️ <strong>Gövdeyi koru</strong> (genel dil bilgisi)</li>
#                 <li>👑 <strong>Başlığı değiştir</strong> (2 sınıf → 3 sınıf)</li>
#                 <li>⚙️ <strong>Fine-tuning yap</strong> (yeni veri seti ile)</li>
#             </ol>
#         </div>
#     </div>
# </div>
#
# ### 📊 Transfer Öğreniminin Kazanımları
#
# <div style="background: linear-gradient(135deg, #E8F5E9 0%, #C8E6C9 100%); padding: 30px; border-radius: 20px; margin: 30px 0; box-shadow: 0 8px 16px rgba(0,0,0,0.1); border: 4px solid #4CAF50;">
#     <h4 style="color: #1B5E20; margin-top: 0; font-size: 20px;">🎯 Tipik Kazanımlar</h4>
#
# <table style="width: 100%; border-collapse: collapse; margin-top: 20px; box-shadow: 0 4px 8px rgba(0,0,0,0.1);">
#     <thead>
#         <tr style="background: linear-gradient(135deg, #66BB6A 0%, #4CAF50 100%); color: white;">
#             <th style="padding: 15px; text-align: left; border: 2px solid #4CAF50; font-size: 15px;">Metrik</th>
#             <th style="padding: 15px; text-align: center; border: 2px solid #4CAF50; font-size: 15px;">Sıfırdan Eğitim</th>
#             <th style="padding: 15px; text-align: center; border: 2px solid #4CAF50; font-size: 15px;">Transfer Öğrenimi</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr style="background-color: rgba(255,255,255,0.9);">
#             <td style="padding: 15px; border: 1px solid #C8E6C9; font-weight: bold; color: #2E7D32;">📊 Veri Gereksinimi</td>
#             <td style="padding: 15px; border: 1px solid #C8E6C9; text-align: center; color: #C62828;">Yüksek (1M+ örnek)</td>
#             <td style="padding: 15px; border: 1px solid #C8E6C9; text-align: center; color: #2E7D32;">Düşük (10K örnek)</td>
#         </tr>
#         <tr style="background-color: rgba(200,230,201,0.3);">
#             <td style="padding: 15px; border: 1px solid #C8E6C9; font-weight: bold; color: #2E7D32;">⏱️ Eğitim Süresi</td>
#             <td style="padding: 15px; border: 1px solid #C8E6C9; text-align: center; color: #C62828;">Hafta/Ay</td>
#             <td style="padding: 15px; border: 1px solid #C8E6C9; text-align: center; color: #2E7D32;">Saat/Gün</td>
#         </tr>
#         <tr style="background-color: rgba(255,255,255,0.9);">
#             <td style="padding: 15px; border: 1px solid #C8E6C9; font-weight: bold; color: #2E7D32;">💰 Maliyet</td>
#             <td style="padding: 15px; border: 1px solid #C8E6C9; text-align: center; color: #C62828;">Çok Yüksek</td>
#             <td style="padding: 15px; border: 1px solid #C8E6C9; text-align: center; color: #2E7D32;">Düşük</td>
#         </tr>
#         <tr style="background-color: rgba(200,230,201,0.3);">
#             <td style="padding: 15px; border: 1px solid #C8E6C9; font-weight: bold; color: #2E7D32;">📈 Performans</td>
#             <td style="padding: 15px; border: 1px solid #C8E6C9; text-align: center; color: #F57F17;">Değişken</td>
#             <td style="padding: 15px; border: 1px solid #C8E6C9; text-align: center; color: #2E7D32;">Genellikle Daha İyi</td>
#         </tr>
#         <tr style="background-color: rgba(255,255,255,0.9);">
#             <td style="padding: 15px; border: 1px solid #C8E6C9; font-weight: bold; color: #2E7D32;">🎯 Genelleme</td>
#             <td style="padding: 15px; border: 1px solid #C8E6C9; text-align: center; color: #F57F17;">Orta</td>
#             <td style="padding: 15px; border: 1px solid #C8E6C9; text-align: center; color: #2E7D32;">Yüksek</td>
#         </tr>
#     </tbody>
# </table>
# </div>
#
# <div style="background: linear-gradient(135deg, #E1F5FE 0%, #B3E5FC 100%); padding: 30px; border-radius: 20px; margin: 30px 0; border-left: 6px solid #0288D1;">
#     <h4 style="color: #01579B; margin-top: 0;">📚 Kaynak</h4>
#     <p style="margin: 0; color: #424242; font-size: 14px; line-height: 1.7; font-style: italic;">
#         Pan, S. J., & Yang, Q. (2010). A survey on transfer learning. IEEE Transactions on knowledge and data engineering, 22(10), 1345-1359.
#     </p>
# </div>
#
# ---

# %% [markdown]
# ## 🚀 Transformers Neden Bu Kadar Güçlü?
#
# <div style="background: linear-gradient(135deg, #FCE4EC 0%, #F8BBD0 100%); padding: 40px; border-radius: 20px; margin: 30px 0; box-shadow: 0 8px 16px rgba(0,0,0,0.15);">
#     <h3 style="color: #880E4F; margin-top: 0; font-size: 24px; text-align: center;">🤖 Mimarinin Devrim Yaratan Farkı</h3>
#     <p style="font-size: 17px; line-height: 1.9; color: #424242; text-align: center; margin-bottom: 0;">
#         Transformers, önceki nesil <strong>RNN (Recurrent Neural Networks)</strong> mimarilerine kıyasla <strong>iki kritik avantaj</strong> sunar:
#     </p>
# </div>
#
# ### 📊 RNN vs Transformers Karşılaştırması
#
# <div style="display: grid; grid-template-columns: repeat(auto-fit, minmax(350px, 1fr)); gap: 30px; margin: 30px 0;">
#
# <div style="background: linear-gradient(135deg, #FFEBEE 0%, #FFCDD2 100%); padding: 35px; border-radius: 20px; box-shadow: 0 8px 16px rgba(0,0,0,0.1); border: 4px solid #E57373;">
#     <div style="text-align: center; font-size: 60px; margin-bottom: 20px;">🐢</div>
#     <h4 style="color: #C62828; margin: 15px 0; font-size: 22px; text-align: center;">RNN Yaklaşımı</h4>
#     <div style="background-color: rgba(255,255,255,0.8); padding: 25px; border-radius: 12px; margin-top: 15px;">
#         <div style="margin-bottom: 20px;">
#             <p style="margin: 0 0 8px 0; color: #B71C1C; font-size: 15px; font-weight: 600;">⚠️ Sınırlama 1: Sıralı İşlem</p>
#             <p style="margin: 0; color: #424242; font-size: 14px; line-height: 1.7;">
#                 Her kelime bir öncekine <strong>bağımlı</strong> olarak işlenir → Paralelizasyon imkansız
#             </p>
#         </div>
#         <div>
#             <p style="margin: 0 0 8px 0; color: #B71C1C; font-size: 15px; font-weight: 600;">⚠️ Sınırlama 2: Bellek Sorunu</p>
#             <p style="margin: 0; color: #424242; font-size: 14px; line-height: 1.7;">
#                 Uzun metinlerde <strong>erken bilgiler unutulur</strong> (vanishing gradient)
#             </p>
#         </div>
#     </div>
# </div>
#
# <div style="background: linear-gradient(135deg, #E8F5E9 0%, #C8E6C9 100%); padding: 35px; border-radius: 20px; box-shadow: 0 8px 16px rgba(0,0,0,0.1); border: 4px solid #66BB6A;">
#     <div style="text-align: center; font-size: 60px; margin-bottom: 20px;">⚡</div>
#     <h4 style="color: #2E7D32; margin: 15px 0; font-size: 22px; text-align: center;">Transformers Mimarisi</h4>
#     <div style="background-color: rgba(255,255,255,0.8); padding: 25px; border-radius: 12px; margin-top: 15px;">
#         <div style="margin-bottom: 20px;">
#             <p style="margin: 0 0 8px 0; color: #1B5E20; font-size: 15px; font-weight: 600;">✅ Avantaj 1: Paralel İşlem</p>
#             <p style="margin: 0; color: #424242; font-size: 14px; line-height: 1.7;">
#                 <strong>Tüm kelimeler aynı anda</strong> işlenir → GPU'yu tam kapasite kullanır
#             </p>
#         </div>
#         <div>
#             <p style="margin: 0 0 8px 0; color: #1B5E20; font-size: 15px; font-weight: 600;">✅ Avantaj 2: Uzun Bağlam</p>
#             <p style="margin: 0; color: #424242; font-size: 14px; line-height: 1.7;">
#                 <strong>Self-Attention</strong> sayesinde metinin <strong>herhangi iki noktası arasında</strong> doğrudan ilişki
#             </p>
#         </div>
#     </div>
# </div>
#
# </div>
#
# ### 🔍 Self-Attention Mekanizması
#
# <div style="background: linear-gradient(135deg, #F3E5F5 0%, #E1BEE7 100%); padding: 30px; border-radius: 20px; margin: 25px 0; box-shadow: 0 6px 12px rgba(0,0,0,0.1);">
#     <h4 style="color: #6A1B9A; margin-top: 0; font-size: 20px;">💡 Anahtar Konsept</h4>
#     <p style="font-size: 16px; line-height: 1.9; color: #424242; margin-bottom: 20px;">
#         Transformers'ın gücünün arkasındaki temel mekanizma <strong>"Self-Attention"</strong> (Öz-Dikkat) katmanıdır.
#     </p>
#     <div style="background-color: rgba(255,255,255,0.7); padding: 25px; border-radius: 12px;">
#         <p style="margin: 0 0 15px 0; color: #4A148C; font-size: 16px; font-weight: 600;">🎯 Ne Yapar?</p>
#         <p style="margin: 0; color: #424242; font-size: 15px; line-height: 1.8;">
#             Her kelime, <strong>cümledeki diğer tüm kelimelerle</strong> ilişkisini hesaplar ve <strong>en ilgili olanlardan</strong> bilgi toplar.
#         </p>
#     </div>
# </div>
#
# <div style="background: linear-gradient(135deg, #FFF9C4 0%, #FFF59D 100%); padding: 30px; border-radius: 20px; margin: 30px 0; border-left: 6px solid #F9A825;">
#     <h4 style="color: #F57F17; margin-top: 0;">💼 YBS Perspektifi: İş Dünyasındaki Etki</h4>
#     <div style="background-color: rgba(255,255,255,0.7); padding: 25px; border-radius: 12px; margin-top: 15px;">
#         <p style="margin: 0 0 15px 0; color: #424242; font-size: 15px; line-height: 1.8;">
#             <strong>RNN'lerin sınırlamaları</strong> gerçek dünya uygulamalarında ciddi problemler yaratıyordu:
#         </p>
#         <ul style="margin: 0; padding-left: 20px; line-height: 2; color: #424242; font-size: 14px;">
#             <li>📄 <strong>Uzun dökümanlar</strong> (sözleşmeler, raporlar) etkili analiz edilemiyordu</li>
#             <li>⏱️ <strong>Eğitim süreleri</strong> aylar alabiliyor, inovasyon yavaşlıyordu</li>
#             <li>💰 <strong>Maliyetler</strong> yüksekti (GPU süreleri)</li>
#         </ul>
#         <div style="background-color: #C8E6C9; padding: 20px; border-radius: 10px; margin-top: 20px;">
#             <p style="margin: 0; color: #1B5E20; font-size: 15px; line-height: 1.8;">
#                 <strong>Transformers bu engelleri aşarak:</strong> ChatGPT, Google Bard, GitHub Copilot gibi milyarlarca kullanıcıya ulaşan ürünlerin mümkün olmasını sağladı. 🚀
#             </p>
#         </div>
#     </div>
# </div>
#
# ### 📚 Orijinal Makale
#
# <div style="background: linear-gradient(135deg, #E1F5FE 0%, #B3E5FC 100%); padding: 30px; border-radius: 20px; margin: 30px 0; border-left: 6px solid #0288D1;">
#     <h4 style="color: #01579B; margin-top: 0;">🏆 Tarihsel Kaynak</h4>
#     <p style="margin: 0 0 15px 0; color: #424242; font-size: 15px; line-height: 1.7;">
#         Transformers mimarisi, Google'ın 2017 tarihli "Attention is All You Need" makalesinde tanıtılmıştır.
#     </p>
#     <div style="background-color: rgba(255,255,255,0.8); padding: 20px; border-radius: 10px;">
#         <p style="margin: 0; color: #424242; font-size: 14px; line-height: 1.7; font-style: italic;">
#             Vaswani, A., Shazeer, N., Parmar, N., Uszkoreit, J., Jones, L., Gomez, A. N., ... & Polosukhin, I. (2017). Attention is all you need. In Advances in neural information processing systems (pp. 5998-6008).
#         </p>
#         <div style="margin-top: 15px; text-align: center;">
#             <span style="background-color: #FFF9C4; padding: 8px 16px; border-radius: 8px; color: #F57F17; font-weight: 600; font-size: 14px;">
#                 📊 60,000+ alıntı | NLP'nin paradigmasını değiştiren çalışma
#             </span>
#         </div>
#     </div>
# </div>
#
# ---

# %% [markdown]
# ## 🎓 Kapanış: Bu Derste Neler Öğrendik?
#
# <div style="background: linear-gradient(135deg, #E8F5E9 0%, #C8E6C9 50%, #A5D6A7 100%); padding: 40px; border-radius: 20px; margin: 30px 0; box-shadow: 0 10px 20px rgba(0,0,0,0.15); border: 5px solid #4CAF50;">
#     <h3 style="color: #1B5E20; margin-top: 0; font-size: 26px; text-align: center;">🌟 Temel Kavramlar Özeti</h3>
#     <p style="font-size: 17px; line-height: 1.9; color: #424242; text-align: center; margin-bottom: 30px;">
#         Modern <strong>NLP</strong> ve <strong>Fine-Tuning</strong> yolculuğunun temel taşlarını öğrendik!
#     </p>
# </div>
#
# ### 🧩 Kavramsal Bağlantılar
#
# <div style="background: linear-gradient(135deg, #F3E5F5 0%, #E1BEE7 100%); padding: 30px; border-radius: 20px; margin: 30px 0; box-shadow: 0 6px 12px rgba(0,0,0,0.1);">
#     <div style="display: flex; flex-wrap: wrap; justify-content: center; gap: 20px; margin: 25px 0;">
#
# <div style="background-color: #BBDEFB; padding: 20px; border-radius: 15px; flex: 1; min-width: 200px; text-align: center; box-shadow: 0 4px 8px rgba(0,0,0,0.1);">
#     <div style="font-size: 40px; margin-bottom: 10px;">🤗</div>
#     <p style="margin: 0; color: #01579B; font-weight: 600; font-size: 16px;">Hugging Face</p>
#     <p style="margin: 5px 0 0 0; color: #424242; font-size: 13px;">Platform Ekosistemi</p>
# </div>
#
# <div style="background-color: #C5CAE9; padding: 20px; border-radius: 15px; flex: 1; min-width: 200px; text-align: center; box-shadow: 0 4px 8px rgba(0,0,0,0.1);">
#     <div style="font-size: 40px; margin-bottom: 10px;">⚙️</div>
#     <p style="margin: 0; color: #311B92; font-weight: 600; font-size: 16px;">Pipeline</p>
#     <p style="margin: 5px 0 0 0; color: #424242; font-size: 13px;">3 Aşamalı İş Akışı</p>
# </div>
#
# <div style="background-color: #FFCCBC; padding: 20px; border-radius: 15px; flex: 1; min-width: 200px; text-align: center; box-shadow: 0 4px 8px rgba(0,0,0,0.1);">
#     <div style="font-size: 40px; margin-bottom: 10px;">📍</div>
#     <p style="margin: 0; color: #BF360C; font-weight: 600; font-size: 16px;">Checkpoint</p>
#     <p style="margin: 5px 0 0 0; color: #424242; font-size: 13px;">Model Versiyonları</p>
# </div>
#
# <div style="background-color: #FFF9C4; padding: 20px; border-radius: 15px; flex: 1; min-width: 200px; text-align: center; box-shadow: 0 4px 8px rgba(0,0,0,0.1);">
#     <div style="font-size: 40px; margin-bottom: 10px;">🌐</div>
#     <p style="margin: 0; color: #F57F17; font-weight: 600; font-size: 16px;">Hub</p>
#     <p style="margin: 5px 0 0 0; color: #424242; font-size: 13px;">Model Deposu</p>
# </div>
#
# <div style="background-color: #B2DFDB; padding: 20px; border-radius: 15px; flex: 1; min-width: 200px; text-align: center; box-shadow: 0 4px 8px rgba(0,0,0,0.1);">
#     <div style="font-size: 40px; margin-bottom: 10px;">🤖</div>
#     <p style="margin: 0; color: #004D40; font-weight: 600; font-size: 16px;">Auto Classes</p>
#     <p style="margin: 5px 0 0 0; color: #424242; font-size: 13px;">Otomatik Model Seçimi</p>
# </div>
#
# <div style="background-color: #F8BBD0; padding: 20px; border-radius: 15px; flex: 1; min-width: 200px; text-align: center; box-shadow: 0 4px 8px rgba(0,0,0,0.1);">
#     <div style="font-size: 40px; margin-bottom: 10px;">🔄</div>
#     <p style="margin: 0; color: #880E4F; font-weight: 600; font-size: 16px;">Transfer Learning</p>
#     <p style="margin: 5px 0 0 0; color: #424242; font-size: 13px;">Bilgiyi Yeniden Kullanma</p>
# </div>
#
# <div style="background-color: #C8E6C9; padding: 20px; border-radius: 15px; flex: 1; min-width: 200px; text-align: center; box-shadow: 0 4px 8px rgba(0,0,0,0.1);">
#     <div style="font-size: 40px; margin-bottom: 10px;">⚡</div>
#     <p style="margin: 0; color: #2E7D32; font-weight: 600; font-size: 16px;">Transformers</p>
#     <p style="margin: 5px 0 0 0; color: #424242; font-size: 13px;">Modern Mimari</p>
# </div>
#
# </div>
# </div>
#
# ### 📋 Kavramsal Akış Şeması
#
# <div style="background: linear-gradient(135deg, #FFF3E0 0%, #FFE0B2 100%); padding: 35px; border-radius: 20px; margin: 30px 0; box-shadow: 0 8px 16px rgba(0,0,0,0.1);">
#     <div style="display: flex; flex-direction: column; gap: 20px;">
#
# <div style="background-color: rgba(255,255,255,0.8); padding: 25px; border-radius: 15px; border-left: 6px solid #1976D2;">
#     <p style="margin: 0; color: #01579B; font-size: 18px; font-weight: 600;">1️⃣ Platform Temeli</p>
#     <p style="margin: 8px 0 0 0; color: #424242; font-size: 14px; line-height: 1.7;">
#         <strong>Hugging Face Hub</strong> üzerinde <strong>700K+ model</strong> ve <strong>200K+ veri seti</strong> bulunur
#     </p>
# </div>
#
# <div style="text-align: center; font-size: 30px; color: #F57F17;">⬇️</div>
#
# <div style="background-color: rgba(255,255,255,0.8); padding: 25px; border-radius: 15px; border-left: 6px solid #7B1FA2;">
#     <p style="margin: 0; color: #6A1B9A; font-size: 18px; font-weight: 600;">2️⃣ Model Seçimi</p>
#     <p style="margin: 8px 0 0 0; color: #424242; font-size: 14px; line-height: 1.7;">
#         <strong>Auto Classes</strong> kullanarak checkpoint'ten <strong>otomatik model yüklemesi</strong> yaparız
#     </p>
# </div>
#
# <div style="text-align: center; font-size: 30px; color: #F57F17;">⬇️</div>
#
# <div style="background-color: rgba(255,255,255,0.8); padding: 25px; border-radius: 15px; border-left: 6px solid #F57F17;">
#     <p style="margin: 0; color: #E65100; font-size: 18px; font-weight: 600;">3️⃣ Transfer Öğrenimi</p>
#     <p style="margin: 8px 0 0 0; color: #424242; font-size: 14px; line-height: 1.7;">
#         <strong>Gövde</strong> korunur, <strong>başlık</strong> yeni göreve göre değiştirilir (fine-tuning)
#     </p>
# </div>
#
# <div style="text-align: center; font-size: 30px; color: #F57F17;">⬇️</div>
#
# <div style="background-color: rgba(255,255,255,0.8); padding: 25px; border-radius: 15px; border-left: 6px solid #388E3C;">
#     <p style="margin: 0; color: #2E7D32; font-size: 18px; font-weight: 600;">4️⃣ Üretim Kullanımı</p>
#     <p style="margin: 8px 0 0 0; color: #424242; font-size: 14px; line-height: 1.7;">
#         <strong>Pipeline API</strong> ile <strong>3 aşamalı akış</strong> (preprocessing → inference → postprocessing) gerçekleştirilir
#     </p>
# </div>
#
# </div>
# </div>
#
# ### 💡 YBS Bakış Açısı: Büyük Resim
#
# <div style="background: linear-gradient(135deg, #FCE4EC 0%, #F8BBD0 100%); padding: 35px; border-radius: 20px; margin: 30px 0; box-shadow: 0 8px 16px rgba(0,0,0,0.1); border: 5px solid #E91E63;">
#     <h4 style="color: #880E4F; margin-top: 0; font-size: 20px;">🏢 İş Dünyası Perspektifi</h4>
#     <div style="background-color: rgba(255,255,255,0.8); padding: 30px; border-radius: 12px; margin-top: 15px;">
#         <p style="margin: 0 0 20px 0; color: #424242; font-size: 16px; line-height: 1.9;">
#             <strong>Bir YBS profesyoneli</strong> olarak, bu teknolojileri sadece <strong>"nasıl çalışır"</strong> değil, <strong>"nasıl değer yaratır"</strong> perspektifinden anlamalısınız:
#         </p>
#         <div style="display: grid; grid-template-columns: repeat(auto-fit, minmax(250px, 1fr)); gap: 20px; margin-top: 20px;">
#
# <div style="background: linear-gradient(135deg, #E3F2FD 0%, #BBDEFB 100%); padding: 20px; border-radius: 12px; box-shadow: 0 4px 8px rgba(0,0,0,0.1);">
#     <p style="margin: 0 0 10px 0; color: #0D47A1; font-size: 16px; font-weight: 600;">💰 Maliyet Optimizasyonu</p>
#     <p style="margin: 0; color: #424242; font-size: 13px; line-height: 1.7;">
#         Transfer learning ile <strong>%90 daha az veri</strong> ve <strong>%80 daha az eğitim süresi</strong>
#     </p>
# </div>
#
# <div style="background: linear-gradient(135deg, #F3E5F5 0%, #E1BEE7 100%); padding: 20px; border-radius: 12px; box-shadow: 0 4px 8px rgba(0,0,0,0.1);">
#     <p style="margin: 0 0 10px 0; color: #6A1B9A; font-size: 16px; font-weight: 600;">⏱️ Hızlı Prototipleme</p>
#     <p style="margin: 0; color: #424242; font-size: 13px; line-height: 1.7;">
#         Pipeline API ile <strong>5 satır kodda</strong> çalışan bir NLP uygulaması
#     </p>
# </div>
#
# <div style="background: linear-gradient(135deg, #FFF9C4 0%, #FFF59D 100%); padding: 20px; border-radius: 12px; box-shadow: 0 4px 8px rgba(0,0,0,0.1);">
#     <p style="margin: 0 0 10px 0; color: #F57F17; font-size: 16px; font-weight: 600;">🌍 Açık Kaynak Ekosistemi</p>
#     <p style="margin: 0; color: #424242; font-size: 13px; line-height: 1.7;">
#         Hub üzerinde <strong>hazır çözümler</strong>, community bilgisi, sürekli güncel teknoloji
#     </p>
# </div>
#
# <div style="background: linear-gradient(135deg, #E8F5E9 0%, #C8E6C9 100%); padding: 20px; border-radius: 12px; box-shadow: 0 4px 8px rgba(0,0,0,0.1);">
#     <p style="margin: 0 0 10px 0; color: #2E7D32; font-size: 16px; font-weight: 600;">🎯 Ürün Odaklı Düşünce</p>
#     <p style="margin: 0; color: #424242; font-size: 13px; line-height: 1.7;">
#         Teknik detaylar yerine <strong>"hangi problemi çözüyor?"</strong> sorusuna odaklanma
#     </p>
# </div>
#
# </div>
#     </div>
# </div>
#
# ### 🚀 Sıradaki Adım
#
# <div style="background: linear-gradient(135deg, #C8E6C9 0%, #A5D6A7 50%, #81C784 100%); padding: 40px; border-radius: 20px; margin: 30px 0; box-shadow: 0 10px 20px rgba(0,0,0,0.15); border: 5px solid #4CAF50; text-align: center;">
#     <div style="font-size: 60px; margin-bottom: 20px;">🎯</div>
#     <h3 style="color: #1B5E20; margin: 0 0 20px 0; font-size: 24px;">Bir Sonraki Derste...</h3>
#     <div style="background-color: rgba(255,255,255,0.9); padding: 30px; border-radius: 15px; box-shadow: 0 4px 8px rgba(0,0,0,0.1);">
#         <p style="margin: 0 0 15px 0; color: #424242; font-size: 18px; line-height: 1.9; font-weight: 500;">
#             Bu temel kavramları <strong>pratiğe dökecek</strong>, ilk <strong>fine-tuning deneyimizi</strong> gerçekleştireceğiz!
#         </p>
#         <div style="margin-top: 25px;">
#             <span style="background-color: #FFF9C4; padding: 12px 24px; border-radius: 12px; color: #F57F17; font-weight: 600; font-size: 16px; display: inline-block;">
#                 📚 Hazırlanın: Kodlamaya başlıyoruz! 💻
#             </span>
#         </div>
#     </div>
# </div>
#
# <div style="background: linear-gradient(135deg, #E1F5FE 0%, #B3E5FC 100%); padding: 30px; border-radius: 20px; margin: 30px 0; border-left: 6px solid #0288D1; text-align: center;">
#     <p style="margin: 0; color: #01579B; font-size: 18px; font-weight: 600; line-height: 1.8;">
#         🌟 İyi çalışmalar! Transformers dünyasına hoş geldiniz! 🤗
#     </p>
# </div>

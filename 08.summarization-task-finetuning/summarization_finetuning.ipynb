# %% [markdown]
# # 🎓 Fine-Tuning Guide for Text Summarization
# ## From Zero to Hero - YBS Öğrencileri İçin Kapsamlı Rehber
#
# ---
#
# <div style='background: linear-gradient(135deg, #667eea 0%, #764ba2 100%); padding: 30px; border-radius: 15px; color: white; text-align: center;'>
#     <h2>🚀 8 Farklı Model ile Profesyonel Özetleme Sistemi</h2>
#     <p style='font-size: 18px;'><b>T5 • BART • Pegasus • DistilBART • FLAN-T5 • LED • BigBird-Pegasus • mT5</b></p>
# </div>
#
# ---
#
# **👨‍💼 Hazırlayan:** Cemal YÜKSEL
# **📅 Tarih:** 23 Ocak 2026
# **🎯 Hedef Kitle:** Yönetim Bilişim Sistemleri (YBS) Öğrencileri

# %% [markdown]
# ---
#
# # 📋 ADIM 1: Giriş ve Temel Kavramlar
#
# <div style='background-color: #FFF5E6; padding: 20px; border-left: 5px solid #FF9800; border-radius: 10px;'>
#     <h3>🎯 Bu Adımda Öğrenecekleriniz:</h3>
#     <ul style='font-size: 16px;'>
#         <li>✅ Text Summarization'ın temel prensipleri</li>
#         <li>✅ Extractive vs Abstractive özetleme farkları</li>
#         <li>✅ Fine-tuning kavramı ve Transfer Learning</li>
#         <li>✅ YBS perspektifinden iş dünyası uygulamaları</li>
#         <li>✅ Modern NLP pipeline'ının anatomisi</li>
#     </ul>
# </div>

# %% [markdown]
# ---
#
# ## 🤔 Text Summarization Nedir?
#
# <div style='background: linear-gradient(135deg, #E3F2FD 0%, #BBDEFB 100%); padding: 25px; border-radius: 15px; margin: 20px 0;'>
#     <h3 style='color: #1565C0;'>📝 Tanım</h3>
#     <p style='font-size: 17px; line-height: 1.8;'>
#         <b>Text Summarization</b> (Metin Özetleme), uzun bir metni veya dokümanı,
#         <span style='background-color: #FFEB3B; padding: 3px 8px; border-radius: 5px;'><b>ana fikirlerini koruyarak</b></span>
#         daha kısa ve anlaşılır bir forma dönüştürme işlemidir.
#     </p>
# </div>
#
# ### 🏢 YBS Perspektifinden İş Dünyası Örnekleri:
#
# | 🎯 Senaryo | 📊 Kullanım Alanı | 💡 Değer Yaratımı |
# |:-----------|:------------------|:------------------|
# | **Müşteri Raporları** | 100+ sayfalık yıllık raporu 2 sayfaya indirgeme | ⏱️ %95 zaman tasarrufu |
# | **E-posta Yönetimi** | Günlük 200+ e-postayı özetleme | 📈 %80 verimlilik artışı |
# | **Toplantı Notları** | 2 saatlik meeting'i 5 dakikaya çevirme | 🎯 Hızlı karar alma |
# | **Müşteri Yorumları** | Binlerce feedback'i trend analizine dönüştürme | 💰 Stratejik içgörüler |
# | **Haber Takibi** | Sektör haberlerini günlük özet bulletin | 🌍 Rekabet avantajı |

# %% [markdown]
# ---
#
# ## 🔄 Extractive vs Abstractive Summarization
#
# <table style='width: 100%; border-collapse: collapse; margin: 20px 0;'>
#     <tr>
#         <th style='background-color: #FFE5E5; padding: 15px; border: 2px solid #FFCCCB; text-align: center; width: 50%;'>
#             <h3>📋 EXTRACTIVE</h3>
#         </th>
#         <th style='background-color: #E5F5FF; padding: 15px; border: 2px solid #CCE5FF; text-align: center; width: 50%;'>
#             <h3>✨ ABSTRACTIVE</h3>
#         </th>
#     </tr>
#     <tr>
#         <td style='background-color: #FFF5F5; padding: 20px; border: 2px solid #FFCCCB; vertical-align: top;'>
#             <p><b>🎯 Yöntem:</b> Metinden <span style='background-color: #FFEB3B; padding: 2px 6px;'>önemli cümleleri seçip</span> aynen kopyalar</p>
#             <hr style='border: 1px dashed #FFCCCB;'>
#             <p><b>⚙️ Teknik:</b> Cümle skorlama, TF-IDF, TextRank</p>
#             <hr style='border: 1px dashed #FFCCCB;'>
#             <p><b>✅ Avantajlar:</b></p>
#             <ul>
#                 <li>Grammatik hata riski yok</li>
#                 <li>Hızlı işlem</li>
#                 <li>Doğruluğu garanti</li>
#             </ul>
#             <hr style='border: 1px dashed #FFCCCB;'>
#             <p><b>❌ Dezavantajlar:</b></p>
#             <ul>
#                 <li>Yeni cümle üretemez</li>
#                 <li>Sınırlı esneklik</li>
#                 <li>Bazen kopuk cümleler</li>
#             </ul>
#         </td>
#         <td style='background-color: #F5FAFF; padding: 20px; border: 2px solid #CCE5FF; vertical-align: top;'>
#             <p><b>🎯 Yöntem:</b> Metni anlayıp <span style='background-color: #C8E6C9; padding: 2px 6px;'>yeni cümleler oluşturur</span></p>
#             <hr style='border: 1px dashed #CCE5FF;'>
#             <p><b>⚙️ Teknik:</b> Transformer Models (T5, BART, Pegasus)</p>
#             <hr style='border: 1px dashed #CCE5FF;'>
#             <p><b>✅ Avantajlar:</b></p>
#             <ul>
#                 <li>İnsan gibi doğal özet</li>
#                 <li>Paraphrase yapabilir</li>
#                 <li>Daha akıcı metin</li>
#             </ul>
#             <hr style='border: 1px dashed #CCE5FF;'>
#             <p><b>❌ Dezavantajlar:</b></p>
#             <ul>
#                 <li>Yüksek hesaplama gücü</li>
#                 <li>Hallucination riski</li>
#                 <li>Eğitim gerektirir</li>
#             </ul>
#         </td>
#     </tr>
# </table>
#
# <div style='background-color: #E8F5E9; padding: 15px; border-radius: 10px; margin-top: 20px;'>
#     <p style='font-size: 16px; margin: 0;'>
#         <b>💡 Bu Notebook'ta Odak:</b> <span style='background-color: #FFD54F; padding: 5px 10px; border-radius: 5px; font-weight: bold;'>ABSTRACTIVE SUMMARIZATION</span> ile 8 farklı transformer modelini fine-tune edeceğiz!
#     </p>
# </div>

# %% [markdown]
# ---
#
# ## 💼 Gerçek Dünya Örneği: YBS Şirket Raporu Senaryosu
#
# <div style='background: linear-gradient(135deg, #FFF9C4 0%, #FFE082 100%); padding: 25px; border-radius: 15px; border: 3px solid #FFD54F;'>
#     <h3 style='color: #F57F17;'>📊 Senaryo: Çeyreklik Finansal Rapor Özetleme</h3>
#
# **🏢 Şirket:** TechCorp International
# **📋 Görev:** CEO'ya sunulacak özet hazırlama
# **⏱️ Süre Kısıtı:** 2 saat içinde teslim
#
# </div>

# %% [markdown]
# <div style='background: linear-gradient(135deg, #F3E5F5 0%, #E1BEE7 100%); padding: 25px; border-radius: 15px; margin: 20px 0;'>
#     <h3 style='color: #6A1B9A;'>🔬 Transfer Learning Analojisi</h3>
#
# Düşünün ki bir tıp fakültesi mezunusunuz (pre-trained model). Genel tıp bilgisine sahipsiniz.
#
# **🎓 Pre-training:** 6 yıl tıp eğitimi (genel bilgi)
#
# **🎯 Fine-tuning:** 3 yıl kardiyoloji uzmanlığı (spesifik alan)
#
# **💡 Sonuç:** 9 yıl yerine genel bilgi + özel alan uzmanlığı!
#
# </div>
#
# ### 📊 Fine-Tuning Avantajları:
#
# <table style='width: 100%; border-collapse: collapse; margin: 20px 0;'>
#     <thead>
#         <tr style='background: linear-gradient(135deg, #667eea 0%, #764ba2 100%); color: white;'>
#             <th style='padding: 15px; text-align: left;'>Özellik</th>
#             <th style='padding: 15px; text-align: center;'>Sıfırdan Eğitim</th>
#             <th style='padding: 15px; text-align: center;'>Fine-Tuning</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr style='background-color: #FFF9C4;'>
#             <td style='padding: 12px; border: 1px solid #ddd;'><b>⏱️ Eğitim Süresi</b></td>
#             <td style='padding: 12px; border: 1px solid #ddd; text-align: center;'>Haftalar/Aylar</td>
#             <td style='padding: 12px; border: 1px solid #ddd; text-align: center; background-color: #C8E6C9;'><b>Saatler</b> ✅</td>
#         </tr>
#         <tr style='background-color: #FFE5E5;'>
#             <td style='padding: 12px; border: 1px solid #ddd;'><b>💰 Maliyet</b></td>
#             <td style='padding: 12px; border: 1px solid #ddd; text-align: center;'>$10,000+</td>
#             <td style='padding: 12px; border: 1px solid #ddd; text-align: center; background-color: #C8E6C9;'><b>$50-100</b> ✅</td>
#         </tr>
#         <tr style='background-color: #E3F2FD;'>
#             <td style='padding: 12px; border: 1px solid #ddd;'><b>📊 Veri İhtiyacı</b></td>
#             <td style='padding: 12px; border: 1px solid #ddd; text-align: center;'>Milyonlarca örnek</td>
#             <td style='padding: 12px; border: 1px solid #ddd; text-align: center; background-color: #C8E6C9;'><b>Binlerce örnek</b> ✅</td>
#         </tr>
#         <tr style='background-color: #F3E5F5;'>
#             <td style='padding: 12px; border: 1px solid #ddd;'><b>🎯 Performans</b></td>
#             <td style='padding: 12px; border: 1px solid #ddd; text-align: center;'>Belirsiz</td>
#             <td style='padding: 12px; border: 1px solid #ddd; text-align: center; background-color: #C8E6C9;'><b>Yüksek başlangıç</b> ✅</td>
#         </tr>
#     </tbody>
# </table>

# %% [markdown]
# ---
#
# ## 🎴 FLASHCARDS: Temel Kavramları Pekiştirin!
#
# <div style='display: flex; flex-wrap: wrap; gap: 20px; margin: 20px 0;'>
#
# <div style='flex: 1; min-width: 300px; background: linear-gradient(135deg, #FFE5E5 0%, #FFCDD2 100%); padding: 20px; border-radius: 15px; border: 3px solid #FF6B6B;'>
#     <h4 style='color: #C62828; margin-top: 0;'>📚 Card 1: Summarization</h4>
#     <p><b>Soru:</b> Text Summarization'ın iki ana türü nedir?</p>
#     <details>
#         <summary style='cursor: pointer; color: #D32F2F; font-weight: bold;'>💡 Cevabı Göster</summary>
#         <p style='background-color: white; padding: 15px; border-radius: 10px; margin-top: 10px;'>
#             <b>1. Extractive:</b> Metinden cümleleri aynen kopyalar<br/>
#             <b>2. Abstractive:</b> Metni anlayıp yeni cümleler oluşturur
#         </p>
#     </details>
# </div>
#
# <div style='flex: 1; min-width: 300px; background: linear-gradient(135deg, #E3F2FD 0%, #BBDEFB 100%); padding: 20px; border-radius: 15px; border: 3px solid #42A5F5;'>
#     <h4 style='color: #1565C0; margin-top: 0;'>🧠 Card 2: Transfer Learning</h4>
#     <p><b>Soru:</b> Pre-trained model neden avantajlıdır?</p>
#     <details>
#         <summary style='cursor: pointer; color: #1976D2; font-weight: bold;'>💡 Cevabı Göster</summary>
#         <p style='background-color: white; padding: 15px; border-radius: 10px; margin-top: 10px;'>
#             <b>✅ Daha az veri gerektirir</b><br/>
#             <b>✅ Eğitim süresi kısa</b><br/>
#             <b>✅ Maliyeti düşük</b><br/>
#             <b>✅ Yüksek performans</b>
#         </p>
#     </details>
# </div>
#
# </div>
#
# <div style='display: flex; flex-wrap: wrap; gap: 20px; margin: 20px 0;'>
#
# <div style='flex: 1; min-width: 300px; background: linear-gradient(135deg, #F3E5F5 0%, #E1BEE7 100%); padding: 20px; border-radius: 15px; border: 3px solid #AB47BC;'>
#     <h4 style='color: #6A1B9A; margin-top: 0;'>🎯 Card 3: Fine-tuning</h4>
#     <p><b>Soru:</b> Fine-tuning sürecinde ne yapılır?</p>
#     <details>
#         <summary style='cursor: pointer; color: #7B1FA2; font-weight: bold;'>💡 Cevabı Göster</summary>
#         <p style='background-color: white; padding: 15px; border-radius: 10px; margin-top: 10px;'>
#             Pre-trained bir model alınır ve <b>spesifik bir task</b> (örn: business report özetleme) için <b>domain-specific data</b> ile tekrar eğitilir. Model ağırlıkları güncellenir ama sıfırdan başlanmaz!
#         </p>
#     </details>
# </div>
#
# <div style='flex: 1; min-width: 300px; background: linear-gradient(135deg, #FFF9C4 0%, #FFE082 100%); padding: 20px; border-radius: 15px; border: 3px solid #FBC02D;'>
#     <h4 style='color: #F57F17; margin-top: 0;'>💼 Card 4: YBS Uygulaması</h4>
#     <p><b>Soru:</b> Özetleme'nin 3 iş dünyası kullanımı?</p>
#     <details>
#         <summary style='cursor: pointer; color: #F9A825; font-weight: bold;'>💡 Cevabı Göster</summary>
#         <p style='background-color: white; padding: 15px; border-radius: 10px; margin-top: 10px;'>
#             <b>1. Rapor Özetleme:</b> 100+ sayfa → 2 sayfa<br/>
#             <b>2. E-posta Yönetimi:</b> Günlük özet bulletinler<br/>
#             <b>3. Müşteri Analizi:</b> Feedback özetleri
#         </p>
#     </details>
# </div>
#
# </div>

# %% [markdown]
# ---
#
# # ⚙️ ADIM 2: Çalışma Ortamının Hazırlanması ve Model Tanıtımları
#
# <div style='background: linear-gradient(135deg, #FFE0B2 0%, #FFCC80 100%); padding: 25px; border-radius: 15px; border: 3px solid #FB8C00;'>
#     <h3 style='color: #E65100; margin-top: 0;'>🛠️ Bu Adımda Yapacaklarımız:</h3>
#     <ul style='font-size: 16px;'>
#         <li>✅ Gerekli Python kütüphanelerini kurma</li>
#         <li>✅ GPU/CPU kontrolü ve optimizasyon</li>
#         <li>✅ 8 farklı özetleme modelini detaylı tanıma</li>
#         <li>✅ Her modelin güçlü/zayıf yönlerini öğrenme</li>
#         <li>✅ YBS perspektifinden model seçim stratejileri</li>
#     </ul>
# </div>

# %% [markdown]
# ---
#
# ## 📦 Kütüphane Kurulumları
#
# <div style='background-color: #E3F2FD; padding: 20px; border-left: 5px solid #2196F3; border-radius: 10px;'>
#     <h4 style='color: #1565C0; margin-top: 0;'>💡 Neden Bu Kütüphaneler?</h4>
#     <p style='font-size: 16px;'>
#         Modern NLP çalışmaları için <b>HuggingFace ekosistemi</b> endüstri standardı haline gelmiştir.
#         Bu kütüphaneler bize <span style='background-color: #FFEB3B; padding: 3px 8px; border-radius: 5px;'><b>pre-trained modellere kolay erişim</b></span> sağlar.
#     </p>
# </div>

# %% [markdown]
# ---
#
# ## 🚀 Google Colab GPU Ayarları
#
# <div style='background: linear-gradient(135deg, #FF9800 0%, #F57C00 100%); padding: 25px; border-radius: 15px; color: white; margin: 20px 0;'>
#     <h3 style='margin-top: 0;'>⚡ ÖNEMLI: Google Colab'da Çalışıyorsanız!</h3>
#     <p style='font-size: 16px; line-height: 1.8;'>
#         Bu notebook'u Google Colab'da çalıştıracaksanız, <b>mutlaka GPU runtime</b> seçmelisiniz!<br/>
#         <b>📍 Yol:</b> Runtime → Change runtime type → Hardware accelerator → <b>GPU (T4 veya A100)</b>
#     </p>
# </div>
#
# ### 🎯 GPU Seçim Rehberi (Google Colab)
#
# <table style='width: 100%; border-collapse: collapse; margin: 20px 0;'>
#     <thead>
#         <tr style='background: linear-gradient(135deg, #667eea 0%, #764ba2 100%); color: white;'>
#             <th style='padding: 15px; text-align: left;'>GPU Tipi</th>
#             <th style='padding: 15px; text-align: center;'>Bellek</th>
#             <th style='padding: 15px; text-align: center;'>Ücret</th>
#             <th style='padding: 15px; text-align: center;'>Önerilen Modeller</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr style='background-color: #E8F5E9;'>
#             <td style='padding: 12px;'><b>🆓 T4 (Free)</b></td>
#             <td style='padding: 12px; text-align: center;'>15 GB</td>
#             <td style='padding: 12px; text-align: center;'>Ücretsiz</td>
#             <td style='padding: 12px;'>T5-small, DistilBART, FLAN-T5-small</td>
#         </tr>
#         <tr style='background-color: #FFF9C4;'>
#             <td style='padding: 12px;'><b>💎 A100 (Colab Pro)</b></td>
#             <td style='padding: 12px; text-align: center;'>40 GB</td>
#             <td style='padding: 12px; text-align: center;'>$9.99/ay</td>
#             <td style='padding: 12px;'>Tüm modeller (LED, BigBird, mT5-large)</td>
#         </tr>
#         <tr style='background-color: #E3F2FD;'>
#             <td style='padding: 12px;'><b>⚙️ CPU (Not Recommended)</b></td>
#             <td style='padding: 12px; text-align: center;'>12 GB RAM</td>
#             <td style='padding: 12px; text-align: center;'>Ücretsiz</td>
#             <td style='padding: 12px;'>Sadece test için (çok yavaş)</td>
#         </tr>
#     </tbody>
# </table>
#
# <div style='background-color: #FFEBEE; padding: 20px; border-left: 5px solid #F44336; border-radius: 10px; margin-top: 20px;'>
#     <h4 style='color: #C62828; margin-top: 0;'>⚠️ Önemli Uyarılar:</h4>
#     <ul style='font-size: 15px; line-height: 1.8;'>
#         <li><b>Free T4 sınırlaması:</b> Günde ~12 saat kullanım hakkı var</li>
#         <li><b>Session disconnect:</b> 90 dakika idle kalırsanız session kapanır</li>
#         <li><b>Model boyutu:</b> T4 ile large modeller (LED, mT5-large) OOM (Out of Memory) verebilir</li>
#         <li><b>Checkpoint kaydetme:</b> Mutlaka Google Drive'a kaydedin!</li>
#     </ul>
# </div>

# %%
# 📦 ADIM 2.1: Temel Kütüphanelerin Kurulumu
# Bu cell'i çalıştırarak tüm gerekli paketleri yükleyelim

# transformers: HuggingFace'in ana kütüphanesi - modellere erişim için
# datasets: Hazır veri setlerine erişim ve veri işleme için
# evaluate: Model performans metriklerini hesaplamak için (ROUGE, BLEU, etc.)
# accelerate: GPU/CPU optimizasyonu ve distributed training için
# sentencepiece: Tokenization için (özellikle T5 ve mT5 için gerekli)
# protobuf: Model serileştirme için
# py7zr: Bazı dataset'lerin sıkıştırılmış formatlarını açmak için

# !pip install transformers datasets evaluate accelerate sentencepiece protobuf py7zr -q

# rouge-score: ROUGE metriklerini hesaplamak için özel paket
# !pip install rouge-score nltk -q

print("✅ Tüm kütüphaneler başarıyla yüklendi!")
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 8.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.4/71.4 kB 7.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 494.2/494.2 kB 43.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.6/100.6 kB 11.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.5/51.5 kB 5.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.3/144.3 kB 17.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
# ✅ Tüm kütüphaneler başarıyla yüklendi!

# %%
# 🔧 ADIM 2.2: Temel Kütüphaneleri İmport Edelim
# Her kütüphanenin rolünü anlayalım

import torch  # PyTorch - deep learning framework'ü
import numpy as np  # Numerik hesaplamalar için
import pandas as pd  # Veri analizi ve görselleştirme için
import matplotlib.pyplot as plt  # Grafikler için
import seaborn as sns  # İleri seviye görselleştirme
from IPython.display import HTML, display  # Zengin görsel içerik için
import warnings  # Uyarıları filtrelemek için
warnings.filterwarnings('ignore')  # Gereksiz uyarıları gizle

# HuggingFace kütüphaneleri
import transformers  # Transformers kütüphanesi
from transformers import (
    AutoTokenizer,  # Tokenizer'ları otomatik yükleme
    AutoModelForSeq2SeqLM,  # Sequence-to-Sequence modelleri için
    Seq2SeqTrainingArguments,  # Training parametreleri
    Seq2SeqTrainer,  # Trainer sınıfı
    DataCollatorForSeq2Seq,  # Batch oluşturma
    pipeline  # Kolay inference için
)

# Dataset ve metrik yükleme - SADECE load_dataset kullanıyoruz
from datasets import load_dataset  # Dataset yükleme için
import evaluate  # Metrik hesaplama için (ROUGE, BLEU, BERTScore)
# NOT: load_metric artık kullanılmıyor! evaluate.load() kullanacağız

# Görselleştirme ayarları - pastel renkler
sns.set_palette("pastel")
plt.style.use('seaborn-v0_8-pastel')

print("✅ Tüm importlar başarılı!")
print(f"🔥 PyTorch versiyonu: {torch.__version__}")
print(f"🤗 Transformers versiyonu: {transformers.__version__}")
print(f"📊 Datasets kütüphanesi hazır")
print(f"📈 Evaluate kütüphanesi hazır - ROUGE, BLEU metrikleri kullanılabilir")
# Out:
# ✅ Tüm importlar başarılı!
# 🔥 PyTorch versiyonu: 2.9.0+cu126
# 🤗 Transformers versiyonu: 4.57.6
# 📊 Datasets kütüphanesi hazır
# 📈 Evaluate kütüphanesi hazır - ROUGE, BLEU metrikleri kullanılabilir

# %% [markdown]
# ---
#
# ## 🖥️ GPU/CPU Kontrolü ve Optimizasyon
#
# <div style='background: linear-gradient(135deg, #F3E5F5 0%, #E1BEE7 100%); padding: 20px; border-radius: 15px; border: 3px solid #AB47BC;'>
#     <h4 style='color: #6A1B9A; margin-top: 0;'>⚡ Performans Optimizasyonu</h4>
#     <p style='font-size: 16px;'>
#         GPU varsa eğitim süresi <b>10-50x</b> daha hızlı olur! CPU'da da çalışabilir ama
#         <span style='background-color: #FFEB3B; padding: 3px 8px; border-radius: 5px;'><b>küçük modeller</b></span> tercih edilmelidir.
#     </p>
# </div>

# %%
# 🖥️ ADIM 2.3: Sistem Kontrolü ve Cihaz Seçimi
# Hangi donanımda çalıştığımızı tespit edelim

# GPU mevcut mu kontrol et
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"🎯 Kullanılacak Cihaz: {device}")

if torch.cuda.is_available():
    # GPU varsa detaylı bilgi göster
    print(f"\n✅ GPU Bulundu!")
    print(f"📊 GPU Adı: {torch.cuda.get_device_name(0)}")
    print(f"💾 GPU Belleği: {torch.cuda.get_device_properties(0).total_memory / 1e9:.2f} GB")
    print(f"🔥 CUDA Versiyonu: {torch.version.cuda}")
    print(f"\n💡 Tavsiye: Tüm 8 modeli rahatça çalıştırabilirsiniz!")

    # Mixed precision training için kontrol
    if torch.cuda.get_device_capability()[0] >= 7:
        print(f"⚡ Mixed Precision Training (FP16) destekleniyor - %2x hız artışı!")

else:
    # CPU kullanılıyorsa
    print(f"\n⚠️ GPU bulunamadı, CPU kullanılıyor")
    print(f"💻 CPU: {torch.get_num_threads()} thread")
    print(f"\n💡 Tavsiye: Küçük modeller kullanın (t5-small, distilbart)")
    print(f"   veya Google Colab'de ücretsiz GPU kullanın!")

# Bellek optimizasyonu
print(f"\n🔧 Bellek Optimizasyonu Ayarları:")
print(f"   • Gradient Accumulation: Önerilir")
print(f"   • Batch Size: {'8-16 (GPU)' if torch.cuda.is_available() else '2-4 (CPU)'}")
print(f"   • Mixed Precision: {'✅ Aktif' if torch.cuda.is_available() else '❌ Sadece GPU'}")
# Out:
# 🎯 Kullanılacak Cihaz: cuda
#
# ✅ GPU Bulundu!
# 📊 GPU Adı: NVIDIA A100-SXM4-80GB
# 💾 GPU Belleği: 85.17 GB
# 🔥 CUDA Versiyonu: 12.6
#
# 💡 Tavsiye: Tüm 8 modeli rahatça çalıştırabilirsiniz!
# ⚡ Mixed Precision Training (FP16) destekleniyor - %2x hız artışı!
#
# 🔧 Bellek Optimizasyonu Ayarları:
#    • Gradient Accumulation: Önerilir
#    • Batch Size: 8-16 (GPU)
#    • Mixed Precision: ✅ Aktif

# %% [markdown]
# ---
#
# # 🤖 8 Özetleme Modeli: Detaylı Tanıtım ve Karşılaştırma
#
# <div style='background: linear-gradient(135deg, #667eea 0%, #764ba2 100%); padding: 30px; border-radius: 15px; color: white; text-align: center; margin: 30px 0;'>
#     <h2 style='margin-top: 0;'>🌟 Model Seçim Rehberi</h2>
#     <p style='font-size: 18px;'>
#         Her modelin kendine özgü güçlü yönleri var. YBS perspektifinden
#         <b>iş ihtiyacınıza göre</b> doğru modeli seçmek kritik!
#     </p>
# </div>
#
# ```mermaid
# graph TD
#     A[📊 İş İhtiyacınız Ne?] --> B{Doküman Uzunluğu?}
#     B -->|Kısa<br/>512 token| C[T5/BART/Pegasus]
#     B -->|Orta<br/>1024 token| D[FLAN-T5/DistilBART]
#     B -->|Uzun<br/>16K+ token| E[LED/BigBird-Pegasus]
#
#     A --> F{Çoklu Dil?}
#     F -->|Evet| G[mT5]
#     F -->|Hayır| C
#
#     A --> H{Hız Önceliği?}
#     H -->|Hızlı| I[DistilBART/T5-small]
#     H -->|Kaliteli| J[Pegasus/FLAN-T5]
#
#     style A fill:#FFE5E5,stroke:#FF6B6B,stroke-width:3px
#     style C fill:#E3F2FD,stroke:#42A5F5,stroke-width:2px
#     style D fill:#FFF9C4,stroke:#FBC02D,stroke-width:2px
#     style E fill:#F3E5F5,stroke:#AB47BC,stroke-width:2px
#     style G fill:#E8F5E9,stroke:#66BB6A,stroke-width:2px
#     style I fill:#FFE0B2,stroke:#FB8C00,stroke-width:2px
#     style J fill:#C5E1A5,stroke:#9CCC65,stroke-width:2px
# ```

# %% [markdown]
# ---
#
# ## 🥇 MODEL 1: T5 (Text-to-Text Transfer Transformer)
#
# <div style='background: linear-gradient(135deg, #FFE5E5 0%, #FFCDD2 100%); padding: 25px; border-radius: 15px; border: 3px solid #EF5350; margin: 20px 0;'>
#     <h3 style='color: #C62828; margin-top: 0;'>🎯 T5 - Her Şey Text-to-Text!</h3>
#
# <table style='width: 100%; background-color: white; border-radius: 10px; overflow: hidden; margin-top: 15px;'>
#     <tr style='background-color: #FFCDD2;'>
#         <td style='padding: 15px; width: 30%;'><b>🏢 Geliştirici</b></td>
#         <td style='padding: 15px;'>Google Research</td>
#     </tr>
#     <tr>
#         <td style='padding: 15px;'><b>📅 Yıl</b></td>
#         <td style='padding: 15px;'>2019</td>
#     </tr>
#     <tr style='background-color: #FFEBEE;'>
#         <td style='padding: 15px;'><b>📊 Parametre</b></td>
#         <td style='padding: 15px;'>60M (small), 220M (base), 770M (large), 3B (3b), 11B (11b)</td>
#     </tr>
#     <tr>
#         <td style='padding: 15px;'><b>🎯 Özellik</b></td>
#         <td style='padding: 15px;'>Unified text-to-text framework</td>
#     </tr>
#     <tr style='background-color: #FFEBEE;'>
#         <td style='padding: 15px;'><b>💡 YBS Kullanımı</b></td>
#         <td style='padding: 15px;'>Genel amaçlı raporlar, e-posta özetleme</td>
#     </tr>
# </table>
#
# </div>
#
# ### 🔍 T5'in Benzersiz Yaklaşımı:
#
# <div style='display: flex; gap: 20px; margin: 20px 0;'>
#
# <div style='flex: 1; background-color: #FFF3E0; padding: 20px; border-radius: 10px; border-left: 5px solid #FF9800;'>
#     <h4 style='color: #E65100; margin-top: 0;'>📝 Text-to-Text Paradigması</h4>
#     <p style='line-height: 1.8;'>
#         T5, <b>her NLP görevini</b> text-to-text formatına dönüştürür:<br/><br/>
#         <code style='background-color: #FFE0B2; padding: 5px 10px; border-radius: 5px; display: block; margin: 10px 0;'>
#         Input: "summarize: [DOCUMENT]"<br/>
#         Output: "[SUMMARY]"
#         </code>
#     </p>
# </div>
#
# <div style='flex: 1; background-color: #E8F5E9; padding: 20px; border-radius: 10px; border-left: 5px solid #66BB6A;'>
#     <h4 style='color: #2E7D32; margin-top: 0;'>⚡ Avantajlar</h4>
#     <ul style='line-height: 1.8;'>
#         <li>✅ Çok yönlü (multi-task)</li>
#         <li>✅ Fine-tune kolay</li>
#         <li>✅ Geniş pre-training</li>
#         <li>✅ Farklı boyutlarda mevcut</li>
#     </ul>
# </div>
#
# </div>
#
# ### 💼 YBS Senaryosu: T5 ile Günlük E-posta Özeti
#
# <div style='background-color: #FFF9C4; padding: 20px; border-radius: 10px; border: 2px dashed #FBC02D; margin: 20px 0;'>
#
# **📧 Problem:** Bir YBS müdürü günde 150+ e-posta alıyor
# **🎯 Çözüm:** T5 ile otomatik e-posta kategorilendirme ve özetleme
# **📊 Sonuç:** %80 zaman tasarrufu, kritik mesajlara hızlı yanıt
#
# <div style='background-color: white; padding: 15px; border-radius: 8px; margin-top: 15px;'>
#
# **Örnek Input:**
# ```text
# summarize: Dear Team, Following up on yesterday's quarterly review meeting,
# I wanted to highlight several key action items that require immediate attention.
# First, the customer satisfaction metrics showed a 15% decline in Q4, primarily
# due to delayed response times in technical support. Second, we need to finalize
# the budget allocation for the new CRM implementation project by next Friday.
# Third, HR has requested updated headcount projections for Q2 2026. Please
# review the attached presentation and share your feedback by Wednesday EOD.
# ```
#
# **T5 Output:**
# ```text
# Quarterly review follow-up: Customer satisfaction declined 15% in Q4 due to
# support delays. CRM budget needs approval by Friday. Q2 headcount projections
# due to HR. Feedback requested by Wednesday.
# ```
#
# </div>
#
# </div>
#
# ### 🎴 Flashcard: T5
#
# <div style='background: linear-gradient(135deg, #FFCDD2 0%, #EF9A9A 100%); padding: 20px; border-radius: 15px; border: 3px solid #EF5350; margin: 20px 0;'>
#     <h4 style='color: #C62828; margin-top: 0;'>🎓 T5 Özet Kartı</h4>
#     <details>
#         <summary style='cursor: pointer; font-size: 18px; font-weight: bold; color: #B71C1C;'>
#             ❓ T5'in ana felsefesi nedir?
#         </summary>
#         <div style='background-color: white; padding: 20px; border-radius: 10px; margin-top: 15px;'>
#             <p style='font-size: 16px; line-height: 1.8;'>
#                 <b>"Everything is text-to-text"</b><br/><br/>
#                 T5, translation, summarization, classification gibi <b>tüm NLP görevlerini</b>
#                 aynı formatta (input text → output text) ele alır. Bu sayede tek bir model
#                 mimarisi ile birçok görevi çözebilir!<br/><br/>
#                 <span style='background-color: #FFD54F; padding: 5px 10px; border-radius: 5px;'>
#                     <b>YBS Değeri:</b> Tek model, çoklu kullanım - maliyet etkin!
#                 </span>
#             </p>
#         </div>
#     </details>
# </div>

# %% [markdown]
# ---
#
# ## 🥈 MODEL 2: BART (Bidirectional and Auto-Regressive Transformers)
#
# <div style='background: linear-gradient(135deg, #E3F2FD 0%, #BBDEFB 100%); padding: 25px; border-radius: 15px; border: 3px solid #42A5F5; margin: 20px 0;'>
#     <h3 style='color: #1565C0; margin-top: 0;'>🎯 BART - Denoising Champion!</h3>
#
# <table style='width: 100%; background-color: white; border-radius: 10px; overflow: hidden; margin-top: 15px;'>
#     <tr style='background-color: #BBDEFB;'>
#         <td style='padding: 15px; width: 30%;'><b>🏢 Geliştirici</b></td>
#         <td style='padding: 15px;'>Facebook AI (Meta)</td>
#     </tr>
#     <tr>
#         <td style='padding: 15px;'><b>📅 Yıl</b></td>
#         <td style='padding: 15px;'>2019</td>
#     </tr>
#     <tr style='background-color: #E3F2FD;'>
#         <td style='padding: 15px;'><b>📊 Parametre</b></td>
#         <td style='padding: 15px;'>139M (base), 406M (large)</td>
#     </tr>
#     <tr>
#         <td style='padding: 15px;'><b>🎯 Özellik</b></td>
#         <td style='padding: 15px;'>Denoising autoencoder + seq2seq</td>
#     </tr>
#     <tr style='background-color: #E3F2FD;'>
#         <td style='padding: 15px;'><b>💡 YBS Kullanımı</b></td>
#         <td style='padding: 15px;'>Haber özetleme, gürültülü metin temizleme</td>
#     </tr>
# </table>
#
# </div>
#
# ### 🔍 BART'ın Denoising Yaklaşımı:
#
# <div style='background-color: #E1F5FE; padding: 20px; border-radius: 10px; border: 2px solid #0277BD; margin: 20px 0;'>
#     <h4 style='color: #01579B; margin-top: 0;'>🧠 Pre-training Stratejisi</h4>
#     <p style='font-size: 16px; line-height: 1.8;'>
#         BART, eğitim sırasında metni <b>bozup sonra restore etmeyi</b> öğrenir:
#     </p>
#
# <div style='display: flex; gap: 15px; margin-top: 20px;'>
#     <div style='flex: 1; background-color: #FFEBEE; padding: 15px; border-radius: 8px;'>
#         <h5 style='color: #C62828; margin-top: 0;'>❌ Bozulmuş Metin</h5>
#         <code style='background-color: white; padding: 10px; display: block; border-radius: 5px;'>
#         The company [MASK] revenue<br/>
#         by [MASK] % last quarter
#         </code>
#     </div>
#     <div style='flex: 0; display: flex; align-items: center; font-size: 30px;'>
#         ➡️
#     </div>
#     <div style='flex: 1; background-color: #E8F5E9; padding: 15px; border-radius: 8px;'>
#         <h5 style='color: #2E7D32; margin-top: 0;'>✅ Restore Edilmiş</h5>
#         <code style='background-color: white; padding: 10px; display: block; border-radius: 5px;'>
#         The company increased revenue<br/>
#         by 23% last quarter
#         </code>
#     </div>
# </div>
#
# <p style='margin-top: 20px; padding: 15px; background-color: #FFF9C4; border-radius: 8px;'>
#     <b>💡 YBS Değeri:</b> Bu özellik sayesinde BART, eksik veya gürültülü metinleri
#     (incomplete emails, noisy customer feedback) çok iyi özetleyebilir!
# </p>
#
# </div>
#
# ### 💼 YBS Senaryosu: BART ile Müşteri Feedback Analizi
#
# <div style='background-color: #E8F5E9; padding: 20px; border-radius: 10px; border: 2px dashed #66BB6A; margin: 20px 0;'>
#
# **📊 Problem:** E-ticaret firması aylık 50,000+ müşteri yorumu alıyor
# **🎯 Çözüm:** BART ile otomatik sentiment + özet extraction
# **📈 Sonuç:** Trend analizi süresi 2 haftadan 2 saate düştü
#
# <div style='background-color: white; padding: 15px; border-radius: 8px; margin-top: 15px;'>
#
# **Örnek Input (Noisy Customer Review):**
# ```text
# omg!!! this product is sooo good 😍 i mean like seriously... delivery was fast
# maybe 2-3 days? idk exactly but the packaging could be better tbh 📦 the quality
# is AMAZING tho!!! would definitely recommend 10/10 but fix the box lol also
# customer service replied quick when i had questions so thats a plus 👍
# ```
#
# **BART Output (Clean Summary):**
# ```text
# Customer highly satisfied with product quality and fast delivery (2-3 days).
# Customer service was responsive. Suggestion: Improve packaging quality.
# ```
#
# **🎯 Analiz:**
# - ✅ Emoji ve informal dili temizledi
# - ✅ Ana noktaları yapılandırdı
# - ✅ Constructive feedback'i vurguladı
#
# </div>
#
# </div>
#
# ### 📊 T5 vs BART Karşılaştırması
#
# <table style='width: 100%; border-collapse: collapse; margin: 20px 0;'>
#     <thead>
#         <tr style='background: linear-gradient(135deg, #667eea 0%, #764ba2 100%); color: white;'>
#             <th style='padding: 15px; text-align: left;'>Özellik</th>
#             <th style='padding: 15px; text-align: center;'>T5</th>
#             <th style='padding: 15px; text-align: center;'>BART</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr style='background-color: #FFEBEE;'>
#             <td style='padding: 12px; border: 1px solid #ddd;'><b>🎯 Yaklaşım</b></td>
#             <td style='padding: 12px; border: 1px solid #ddd; text-align: center;'>Text-to-text unified</td>
#             <td style='padding: 12px; border: 1px solid #ddd; text-align: center;'>Denoising autoencoder</td>
#         </tr>
#         <tr style='background-color: #E3F2FD;'>
#             <td style='padding: 12px; border: 1px solid #ddd;'><b>💪 Güçlü Yön</b></td>
#             <td style='padding: 12px; border: 1px solid #ddd; text-align: center;'>Multi-task versatility</td>
#             <td style='padding: 12px; border: 1px solid #ddd; text-align: center;'>Noisy text handling</td>
#         </tr>
#         <tr style='background-color: #F3E5F5;'>
#             <td style='padding: 12px; border: 1px solid #ddd;'><b>📏 Input Length</b></td>
#             <td style='padding: 12px; border: 1px solid #ddd; text-align: center;'>512 tokens</td>
#             <td style='padding: 12px; border: 1px solid #ddd; text-align: center;'>1024 tokens</td>
#         </tr>
#         <tr style='background-color: #FFF9C4;'>
#             <td style='padding: 12px; border: 1px solid #ddd;'><b>⚡ Hız</b></td>
#             <td style='padding: 12px; border: 1px solid #ddd; text-align: center;'>Hızlı (small variantlar)</td>
#             <td style='padding: 12px; border: 1px solid #ddd; text-align: center;'>Orta</td>
#         </tr>
#         <tr style='background-color: #C8E6C9;'>
#             <td style='padding: 12px; border: 1px solid #ddd;'><b>💼 YBS Case</b></td>
#             <td style='padding: 12px; border: 1px solid #ddd; text-align: center;'>Genel raporlar</td>
#             <td style='padding: 12px; border: 1px solid #ddd; text-align: center;'>Social media, reviews</td>
#         </tr>
#     </tbody>
# </table>
#
# ### 🎴 Flashcard: BART
#
# <div style='background: linear-gradient(135deg, #BBDEFB 0%, #90CAF9 100%); padding: 20px; border-radius: 15px; border: 3px solid #42A5F5; margin: 20px 0;'>
#     <h4 style='color: #1565C0; margin-top: 0;'>🎓 BART Özet Kartı</h4>
#     <details>
#         <summary style='cursor: pointer; font-size: 18px; font-weight: bold; color: #0D47A1;'>
#             ❓ BART'ı hangi senaryolarda tercih etmeliyiz?
#         </summary>
#         <div style='background-color: white; padding: 20px; border-radius: 10px; margin-top: 15px;'>
#             <p style='font-size: 16px; line-height: 1.8;'>
#                 <b>BART'ın Süper Gücü: Gürültülü/Eksik Metinler!</b><br/><br/>
#                 ✅ <b>Social media içeriği</b> (emoji, slang, typo)<br/>
#                 ✅ <b>Customer reviews</b> (informal dil)<br/>
#                 ✅ <b>Transcript'ler</b> (speech-to-text hataları)<br/>
#                 ✅ <b>Uzun haberler</b> (1024 token desteği)<br/><br/>
#                 <span style='background-color: #FFD54F; padding: 5px 10px; border-radius: 5px;'>
#                     <b>Karar:</b> Temiz metin → T5, Gürültülü metin → BART
#                 </span>
#             </p>
#         </div>
#     </details>
# </div>

# %% [markdown]
# ---
#
# ## 🥉 MODEL 3: Pegasus (Pre-training with Extracted Gap-sentences)
#
# <div style='background: linear-gradient(135deg, #F3E5F5 0%, #E1BEE7 100%); padding: 25px; border-radius: 15px; border: 3px solid #AB47BC; margin: 20px 0;'>
#     <h3 style='color: #6A1B9A; margin-top: 0;'>🎯 Pegasus - Özetleme için Doğdu!</h3>
#
# <table style='width: 100%; background-color: white; border-radius: 10px; overflow: hidden; margin-top: 15px;'>
#     <tr style='background-color: #E1BEE7;'>
#         <td style='padding: 15px; width: 30%;'><b>🏢 Geliştirici</b></td>
#         <td style='padding: 15px;'>Google Research</td>
#     </tr>
#     <tr>
#         <td style='padding: 15px;'><b>📅 Yıl</b></td>
#         <td style='padding: 15px;'>2020</td>
#     </tr>
#     <tr style='background-color: #F3E5F5;'>
#         <td style='padding: 15px;'><b>📊 Parametre</b></td>
#         <td style='padding: 15px;'>223M (base), 568M (large)</td>
#     </tr>
#     <tr>
#         <td style='padding: 15px;'><b>🎯 Özellik</b></td>
#         <td style='padding: 15px;'>Gap Sentence Generation (GSG) pre-training</td>
#     </tr>
#     <tr style='background-color: #F3E5F5;'>
#         <td style='padding: 15px;'><b>💡 YBS Kullanımı</b></td>
#         <td style='padding: 15px;'>Akademik makaleler, teknik raporlar, haberler</td>
#     </tr>
# </table>
#
# </div>
#
# ### 🔬 Pegasus'un Devrim Niteliğindeki GSG Yaklaşımı:
#
# <div style='background-color: #F3E5F5; padding: 20px; border-radius: 10px; border: 2px solid #8E24AA; margin: 20px 0;'>
#     <h4 style='color: #6A1B9A; margin-top: 0;'>🧪 Gap Sentence Generation Nedir?</h4>
#
# <div style='background-color: white; padding: 20px; border-radius: 10px; margin: 15px 0;'>
#     <p style='font-size: 16px; line-height: 1.8;'>
#         Pegasus, pre-training sırasında dokümandan <b>en önemli cümleleri çıkarır</b>
#         ve modele bu cümleleri <b>tahmin ettirmeyi</b> öğretir. Bu, doğrudan
#         <span style='background-color: #FFD54F; padding: 3px 8px; border-radius: 5px;'><b>summarization task'ını</b></span>
#         simüle eder!
#     </p>
# </div>
#
# ```mermaid
# graph LR
#     A[📄 Full Document<br/>10 sentences] --> B[🎯 Select Important<br/>Sentences 3,7,9]
#     B --> C[❌ Remove from doc<br/>Gap created]
#     C --> D[🤖 Model Task:<br/>Predict missing]
#     D --> E[✨ Generated:<br/>Summary-like output]
#
#     style A fill:#FFE5E5,stroke:#FF6B6B,stroke-width:2px
#     style B fill:#FFF9C4,stroke:#FBC02D,stroke-width:2px
#     style C fill:#FFE0B2,stroke:#FB8C00,stroke-width:2px
#     style D fill:#E1BEE7,stroke:#AB47BC,stroke-width:3px
#     style E fill:#C8E6C9,stroke:#66BB6A,stroke-width:2px
# ```
#
# <div style='background-color: #E8F5E9; padding: 15px; border-radius: 8px; margin-top: 20px;'>
#     <p style='font-size: 16px; margin: 0;'>
#         <b>💡 Neden Önemli?</b> Diğer modeller random masking kullanır, Pegasus ise
#         <b>özetleme mantığıyla</b> eğitildiği için summarization task'ında doğal olarak üstün!
#     </p>
# </div>
#
# </div>
#
# ### 💼 YBS Senaryosu: Pegasus ile Teknik Rapor Özetleme
#
# <div style='background-color: #FFF9C4; padding: 20px; border-radius: 10px; border: 2px dashed #FBC02D; margin: 20px 0;'>
#
# **📑 Problem:** IT firması yıllık 500+ sayfalık sistem güvenlik auditi alıyor
# **🎯 Çözüm:** Pegasus ile executive summary oluşturma
# **💎 Sonuç:** C-level executives için 5 sayfalık actionable özet
#
# <div style='background-color: white; padding: 15px; border-radius: 8px; margin-top: 15px;'>
#
# **Örnek Input (Technical Security Audit):**
# ```text
# The comprehensive security audit conducted between Q3-Q4 2025 identified multiple
# vulnerabilities across the enterprise infrastructure. Critical findings include
# three zero-day exploits in legacy systems, inadequate encryption protocols in
# customer data storage (affecting approximately 2.3 million records), and
# insufficient access control mechanisms in the cloud environment. The penetration
# testing revealed SQL injection vulnerabilities in 12 web applications. Network
# segmentation analysis showed improper VLAN configurations. The incident response
# time averaged 47 minutes, exceeding industry standard of 30 minutes. Compliance
# assessment indicates partial adherence to GDPR requirements with gaps in data
# retention policies. Immediate remediation recommended for critical vulnerabilities
# with estimated cost of $1.2M and 6-month implementation timeline.
# ```
#
# **Pegasus Output (Executive Summary):**
# ```text
# Security audit reveals critical infrastructure vulnerabilities: three zero-day
# exploits in legacy systems, encryption gaps affecting 2.3M customer records,
# and SQL injection risks in 12 applications. Incident response time exceeds
# standards by 17 minutes. GDPR compliance gaps identified. Immediate $1.2M
# investment required for 6-month remediation plan.
# ```
#
# **🎯 Analiz:**
# - ✅ Teknik detayları executive-friendly formata dönüştürdü
# - ✅ Sayısal verileri korudu (quantitative evidence)
# - ✅ Action items'ı vurguladı (maliyet, süre)
# - ✅ Compliance risklerini öne çıkardı
#
# </div>
#
# </div>
#
# ### 🏆 Pegasus'un Süper Güçleri
#
# <div style='display: flex; gap: 15px; margin: 20px 0; flex-wrap: wrap;'>
#
# <div style='flex: 1; min-width: 250px; background: linear-gradient(135deg, #E8F5E9 0%, #C8E6C9 100%); padding: 20px; border-radius: 10px; border: 2px solid #66BB6A;'>
#     <h4 style='color: #2E7D32; margin-top: 0;'>✅ Güçlü Yönler</h4>
#     <ul style='line-height: 1.8;'>
#         <li><b>🥇 En iyi ROUGE skorları</b> (özellikle CNN/DailyMail'de)</li>
#         <li><b>📰 Haber özetleme champion</b></li>
#         <li><b>📊 Uzun dokümanları iyi işler</b></li>
#         <li><b>🎯 Abstractive kalitesi yüksek</b></li>
#         <li><b>⚡ Fine-tune hızlı converge eder</b></li>
#     </ul>
# </div>
#
# <div style='flex: 1; min-width: 250px; background: linear-gradient(135deg, #FFEBEE 0%, #FFCDD2 100%); padding: 20px; border-radius: 10px; border: 2px solid #EF5350;'>
#     <h4 style='color: #C62828; margin-top: 0;'>⚠️ Limitasyonlar</h4>
#     <ul style='line-height: 1.8;'>
#         <li><b>❌ Dialogue özetlemede zayıf</b> (meeting transcripts)</li>
#         <li><b>💻 Yüksek computational cost</b></li>
#         <li><b>📝 Formal metinlerde daha iyi</b> (informal zayıf)</li>
#         <li><b>🌍 İngilizce odaklı</b> (diğer diller sınırlı)</li>
#     </ul>
# </div>
#
# </div>
#
# ### 🎴 Flashcard: Pegasus
#
# <div style='background: linear-gradient(135deg, #E1BEE7 0%, #CE93D8 100%); padding: 20px; border-radius: 15px; border: 3px solid #AB47BC; margin: 20px 0;'>
#     <h4 style='color: #6A1B9A; margin-top: 0;'>🎓 Pegasus Özet Kartı</h4>
#     <details>
#         <summary style='cursor: pointer; font-size: 18px; font-weight: bold; color: #4A148C;'>
#             ❓ Pegasus'u ne zaman kullanmalıyız?
#         </summary>
#         <div style='background-color: white; padding: 20px; border-radius: 10px; margin-top: 15px;'>
#             <p style='font-size: 16px; line-height: 1.8;'>
#                 <b>Pegasus = Özetleme Şampiyonu! 🏆</b><br/><br/>
#                 <b>✅ KULLAN:</b><br/>
#                 • Haber makaleleri<br/>
#                 • Teknik raporlar<br/>
#                 • Araştırma paper'ları<br/>
#                 • Formal business documents<br/>
#                 • ROUGE skoru kritik projelerde<br/><br/>
#                 <b>❌ KULLANMA:</b><br/>
#                 • Casual conversation özetleme<br/>
#                 • Dialogue/meeting transkript<br/>
#                 • Multi-lingual projeler<br/>
#                 • Sınırlı compute resource<br/><br/>
#                 <span style='background-color: #FFD54F; padding: 5px 10px; border-radius: 5px;'>
#                     <b>Altın Kural:</b> Formal + Long + News-like → Pegasus!
#                 </span>
#             </p>
#         </div>
#     </details>
# </div>

# %% [markdown]
# ---
#
# ## ⚡ MODEL 4: DistilBART (Distilled BART)
#
# <div style='background: linear-gradient(135deg, #FFF9C4 0%, #FFF59D 100%); padding: 25px; border-radius: 15px; border: 3px solid #FBC02D; margin: 20px 0;'>
#     <h3 style='color: #F57F17; margin-top: 0;'>🎯 DistilBART - Hız ve Verimlilik!</h3>
#
# <table style='width: 100%; background-color: white; border-radius: 10px; overflow: hidden; margin-top: 15px;'>
#     <tr style='background-color: #FFF59D;'>
#         <td style='padding: 15px; width: 30%;'><b>🏢 Geliştirici</b></td>
#         <td style='padding: 15px;'>HuggingFace (Meta BART tabanlı)</td>
#     </tr>
#     <tr>
#         <td style='padding: 15px;'><b>📅 Yıl</b></td>
#         <td style='padding: 15px;'>2020</td>
#     </tr>
#     <tr style='background-color: #FFF9C4;'>
#         <td style='padding: 15px;'><b>📊 Parametre</b></td>
#         <td style='padding: 15px;'>306M (BART'ın %50'si küçük)</td>
#     </tr>
#     <tr>
#         <td style='padding: 15px;'><b>🎯 Özellik</b></td>
#         <td style='padding: 15px;'>Knowledge distillation from BART</td>
#     </tr>
#     <tr style='background-color: #FFF9C4;'>
#         <td style='padding: 15px;'><b>💡 YBS Kullanımı</b></td>
#         <td style='padding: 15px;'>Real-time applications, mobile deployment</td>
#     </tr>
# </table>
#
# </div>
#
# ### 🧪 Knowledge Distillation Nedir?
#
# <div style='background-color: #FFF3E0; padding: 20px; border-radius: 10px; border: 2px solid #F57C00; margin: 20px 0;'>
#     <h4 style='color: #E65100; margin-top: 0;'>👨‍🏫 Öğretmen-Öğrenci Metaforu</h4>
#
# ```mermaid
# graph TB
#     A[🎓 Teacher Model<br/>BART-large 406M] --> B[📚 Knowledge Transfer<br/>Soft labels + hidden states]
#     B --> C[👨‍🎓 Student Model<br/>DistilBART 306M]
#
#     D[💪 Teacher Strengths] --> B
#     E[⚡ Student Speed] --> C
#
#     C --> F[🎯 Result:<br/>70% faster<br/>97% performance retained]
#
#     style A fill:#E1BEE7,stroke:#AB47BC,stroke-width:2px
#     style B fill:#BBDEFB,stroke:#42A5F5,stroke-width:2px
#     style C fill:#C8E6C9,stroke:#66BB6A,stroke-width:2px
#     style F fill:#FFD54F,stroke:#FBC02D,stroke-width:3px
# ```
#
# <div style='background-color: white; padding: 15px; border-radius: 8px; margin-top: 15px;'>
#     <p style='font-size: 16px; line-height: 1.8;'>
#         <b>Distillation Process:</b><br/><br/>
#         1️⃣ <b>Teacher (BART):</b> Yavaş ama çok akıllı<br/>
#         2️⃣ <b>Knowledge Transfer:</b> Öğretmenin bilgisi öğrenciye aktarılır<br/>
#         3️⃣ <b>Student (DistilBART):</b> Hızlı ama neredeyse aynı derecede akıllı<br/><br/>
#         <span style='background-color: #FFD54F; padding: 5px 10px; border-radius: 5px;'>
#             <b>YBS Değeri:</b> Production'da hız kritik! DistilBART = Best of both worlds
#         </span>
#     </p>
# </div>
#
# </div>
#
# ### ⚡ BART vs DistilBART: Performance Battle
#
# <table style='width: 100%; border-collapse: collapse; margin: 20px 0;'>
#     <thead>
#         <tr style='background: linear-gradient(135deg, #FBC02D 0%, #F9A825 100%); color: white;'>
#             <th style='padding: 15px; text-align: left;'>Metrik</th>
#             <th style='padding: 15px; text-align: center;'>BART-large</th>
#             <th style='padding: 15px; text-align: center;'>DistilBART</th>
#             <th style='padding: 15px; text-align: center;'>Kazanç</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr style='background-color: #FFEBEE;'>
#             <td style='padding: 12px; border: 1px solid #ddd;'><b>⚙️ Parameters</b></td>
#             <td style='padding: 12px; border: 1px solid #ddd; text-align: center;'>406M</td>
#             <td style='padding: 12px; border: 1px solid #ddd; text-align: center;'>306M</td>
#             <td style='padding: 12px; border: 1px solid #ddd; text-align: center; background-color: #C8E6C9;'><b>-25%</b> 📉</td>
#         </tr>
#         <tr style='background-color: #E3F2FD;'>
#             <td style='padding: 12px; border: 1px solid #ddd;'><b>⏱️ Inference Speed</b></td>
#             <td style='padding: 12px; border: 1px solid #ddd; text-align: center;'>100 ms</td>
#             <td style='padding: 12px; border: 1px solid #ddd; text-align: center;'>30 ms</td>
#             <td style='padding: 12px; border: 1px solid #ddd; text-align: center; background-color: #C8E6C9;'><b>70% faster</b> ⚡</td>
#         </tr>
#         <tr style='background-color: #F3E5F5;'>
#             <td style='padding: 12px; border: 1px solid #ddd;'><b>💾 Memory Usage</b></td>
#             <td style='padding: 12px; border: 1px solid #ddd; text-align: center;'>1.6 GB</td>
#             <td style='padding: 12px; border: 1px solid #ddd; text-align: center;'>1.2 GB</td>
#             <td style='padding: 12px; border: 1px solid #ddd; text-align: center; background-color: #C8E6C9;'><b>-25%</b> 💾</td>
#         </tr>
#         <tr style='background-color: #FFF9C4;'>
#             <td style='padding: 12px; border: 1px solid #ddd;'><b>📊 ROUGE-L Score</b></td>
#             <td style='padding: 12px; border: 1px solid #ddd; text-align: center;'>44.16</td>
#             <td style='padding: 12px; border: 1px solid #ddd; text-align: center;'>42.86</td>
#             <td style='padding: 12px; border: 1px solid #ddd; text-align: center; background-color: #FFEBEE;'><b>-3%</b> 📉</td>
#         </tr>
#         <tr style='background-color: #C8E6C9;'>
#             <td style='padding: 12px; border: 1px solid #ddd;'><b>💰 Cost/1M Requests</b></td>
#             <td style='padding: 12px; border: 1px solid #ddd; text-align: center;'>$120</td>
#             <td style='padding: 12px; border: 1px solid #ddd; text-align: center;'>$36</td>
#             <td style='padding: 12px; border: 1px solid #ddd; text-align: center; background-color: #C8E6C9;'><b>-70% cost</b> 💰</td>
#         </tr>
#     </tbody>
# </table>
#
# <div style='background-color: #E8F5E9; padding: 15px; border-radius: 10px; margin-top: 20px;'>
#     <p style='font-size: 16px; margin: 0;'>
#         <b>📊 YBS Trade-off Analysis:</b> %3 accuracy kaybı vs %70 maliyet düşüşü →
#         <span style='background-color: #C8E6C9; padding: 5px 10px; border-radius: 5px; font-weight: bold;'>
#             ROI açısından DistilBART kazanır! 🏆
#         </span>
#     </p>
# </div>
#
# ### 💼 YBS Senaryosu: DistilBART ile Real-Time News Aggregator
#
# <div style='background-color: #E1F5FE; padding: 20px; border-radius: 10px; border: 2px dashed #0277BD; margin: 20px 0;'>
#
# **📱 Problem:** Finansal trading platformu - saniyeler içinde haber özetleri gerekli
# **🎯 Çözüm:** DistilBART ile low-latency summarization API
# **⚡ Sonuç:** 30ms response time, günde 10M request handle ediyor
#
# <div style='background-color: white; padding: 15px; border-radius: 8px; margin-top: 15px;'>
#
# **Örnek: Real-Time Stock News**
# ```text
# Input: Federal Reserve announced unexpected interest rate increase of 0.5% today,
# marking the third consecutive hike this year. Markets responded with immediate
# volatility, with S&P 500 dropping 2.3% within first hour. Tech stocks particularly
# affected, NASDAQ down 3.1%. Analysts cite inflation concerns as primary driver.
# Treasury yields jumped to 4.2%, highest since 2019.
#
# DistilBART Output (< 30ms):
# Fed raised rates 0.5%, third hike this year. S&P 500 fell 2.3%, NASDAQ down 3.1%.
# Treasury yields hit 4.2%, highest since 2019.
#
# ✅ Inference Time: 28ms
# ✅ Token Count: Input 89 → Output 28
# ✅ Compression: 68%
# ```
#
# **🎯 Business Impact:**
# - 📈 Traders get instant insights
# - 💰 Low infrastructure cost
# - ⚡ Scalable to millions of users
# - 🎯 Accurate enough for real-time decisions
#
# </div>
#
# </div>
#
# ### 🎴 Flashcard: DistilBART
#
# <div style='background: linear-gradient(135deg, #FFF59D 0%, #FFF176 100%); padding: 20px; border-radius: 15px; border: 3px solid #FBC02D; margin: 20px 0;'>
#     <h4 style='color: #F57F17; margin-top: 0;'>🎓 DistilBART Özet Kartı</h4>
#     <details>
#         <summary style='cursor: pointer; font-size: 18px; font-weight: bold; color: #E65100;'>
#             ❓ Ne zaman DistilBART, ne zaman BART kullanmalıyım?
#         </summary>
#         <div style='background-color: white; padding: 20px; border-radius: 10px; margin-top: 15px;'>
#             <p style='font-size: 16px; line-height: 1.8;'>
#                 <b>Decision Matrix:</b><br/><br/>
#                 <b>✅ DistilBART kullan:</b><br/>
#                 • Real-time applications (< 100ms latency)<br/>
#                 • Mobile/edge deployment<br/>
#                 • Yüksek throughput gerekli (millions of requests)<br/>
#                 • Sınırlı budget/infrastructure<br/>
#                 • "Good enough" accuracy yeterli<br/><br/>
#                 <b>✅ BART kullan:</b><br/>
#                 • Accuracy kritik (legal, medical)<br/>
#                 • Batch processing (latency önemli değil)<br/>
#                 • Complex/long documents<br/>
#                 • Quality > Speed<br/><br/>
#                 <span style='background-color: #FFD54F; padding: 5px 10px; border-radius: 5px;'>
#                     <b>YBS Kuralı:</b> Production API → DistilBART, Offline Analysis → BART
#                 </span>
#             </p>
#         </div>
#     </details>
# </div>

# %% [markdown]
# ---
#
# ## 🔥 MODEL 5: FLAN-T5 (Fine-tuned Language Net T5)
#
# <div style='background: linear-gradient(135deg, #C8E6C9 0%, #A5D6A7 100%); padding: 25px; border-radius: 15px; border: 3px solid #66BB6A; margin: 20px 0;'>
#     <h3 style='color: #2E7D32; margin-top: 0;'>🎯 FLAN-T5 - Instruction Master!</h3>
#
# <table style='width: 100%; background-color: white; border-radius: 10px; overflow: hidden; margin-top: 15px;'>
#     <tr style='background-color: #A5D6A7;'>
#         <td style='padding: 15px; width: 30%;'><b>🏢 Geliştirici</b></td>
#         <td style='padding: 15px;'>Google Research</td>
#     </tr>
#     <tr>
#         <td style='padding: 15px;'><b>📅 Yıl</b></td>
#         <td style='padding: 15px;'>2022</td>
#     </tr>
#     <tr style='background-color: #C8E6C9;'>
#         <td style='padding: 15px;'><b>📊 Parametre</b></td>
#         <td style='padding: 15px;'>80M (small), 250M (base), 780M (large), 3B, 11B</td>
#     </tr>
#     <tr>
#         <td style='padding: 15px;'><b>🎯 Özellik</b></td>
#         <td style='padding: 15px;'>Instruction fine-tuning on 1800+ tasks</td>
#     </tr>
#     <tr style='background-color: #C8E6C9;'>
#         <td style='padding: 15px;'><b>💡 YBS Kullanımı</b></td>
#         <td style='padding: 15px;'>Multi-task applications, zero-shot scenarios</td>
#     </tr>
# </table>
#
# </div>
#
# ### 🎓 Instruction Tuning Revolution
#
# <div style='background-color: #E8F5E9; padding: 20px; border-radius: 10px; border: 2px solid #43A047; margin: 20px 0;'>
#     <h4 style='color: #2E7D32; margin-top: 0;'>🚀 FLAN-T5 vs T5: Ne Değişti?</h4>
#
# <div style='display: flex; gap: 20px; margin-top: 20px;'>
#
# <div style='flex: 1; background-color: #FFEBEE; padding: 15px; border-radius: 8px;'>
#     <h5 style='color: #C62828; margin-top: 0;'>📚 Original T5</h5>
#     <code style='background-color: white; padding: 10px; display: block; border-radius: 5px; line-height: 1.8;'>
#     Input: "summarize: [TEXT]"<br/>
#     Output: [SUMMARY]<br/><br/>
#     ❌ Tek format, sınırlı esneklik
#     </code>
# </div>
#
# <div style='flex: 1; background-color: #E8F5E9; padding: 15px; border-radius: 8px;'>
#     <h5 style='color: #2E7D32; margin-top: 0;'>✨ FLAN-T5</h5>
#     <code style='background-color: white; padding: 10px; display: block; border-radius: 5px; line-height: 1.8;'>
#     "Summarize this in 3 sentences:"<br/>
#     "Write a brief summary:"<br/>
#     "TL;DR of the following:"<br/><br/>
#     ✅ Natural instructions, flexible
#     </code>
# </div>
#
# </div>
#
# <div style='background-color: white; padding: 20px; border-radius: 10px; margin-top: 20px;'>
#     <p style='font-size: 16px; line-height: 1.8;'>
#         <b>🔑 Key Innovation:</b> FLAN-T5, <b>1800+ farklı NLP task'ında</b> instruction format'ta
#         eğitildi. Bu sayede <span style='background-color: #FFD54F; padding: 3px 8px; border-radius: 5px;'><b>zero-shot</b></span>
#         performansı dramatik şekilde arttı!
#     </p>
# </div>
#
# </div>
#
# ### 💼 YBS Senaryosu: FLAN-T5 ile Multi-Format Summarization Platform
#
# <div style='background-color: #FFF9C4; padding: 20px; border-radius: 10px; border: 2px dashed #FBC02D; margin: 20px 0;'>
#
# **🏢 Problem:** SaaS şirketi - farklı müşteriler farklı özet formatları istiyor
# **🎯 Çözüm:** FLAN-T5 ile flexible instruction-based summarization
# **🌟 Sonuç:** Tek model, sınırsız format - her müşteriye custom solution
#
# <div style='background-color: white; padding: 15px; border-radius: 8px; margin-top: 15px;'>
#
# **Örnek 1: Executive wants bullet points**
# ```text
# Input: "Summarize the following quarterly report in 5 bullet points for executives:
# Revenue increased 23% YoY to $2.4B. Cloud services grew 35% to $980M. AI products
# contributed $620M with 45% growth. Operating expenses controlled at $1.2B maintaining
# 28% profit margin. Hired 450 employees, reaching 8500 total workforce."
#
# FLAN-T5 Output:
# • Revenue: $2.4B (+23% YoY)
# • Cloud services: $980M (+35%)
# • AI products: $620M (+45%)
# • Profit margin: 28% (OpEx $1.2B)
# • Workforce: 8,500 (+450 hires)
# ```
#
# **Örnek 2: Marketing wants social media post**
# ```text
# Input: "Rewrite this as a Twitter-style announcement (max 280 characters):
# [SAME QUARTERLY REPORT]"
#
# FLAN-T5 Output:
# 🚀 Record Q4! $2.4B revenue (+23%), Cloud up 35%, AI up 45%. Maintaining strong
# 28% margins while growing team by 450. #Growth #Innovation
# ```
#
# **Örnek 3: Technical team wants detailed analysis**
# ```text
# Input: "Provide a technical breakdown with metrics and percentages:
# [SAME QUARTERLY REPORT]"
#
# FLAN-T5 Output:
# Q4 Financial Breakdown: Total revenue $2.4B represents 23% year-over-year expansion.
# Cloud services division ($980M) demonstrates strongest growth trajectory at 35% CAGR.
# AI product segment ($620M) shows 45% acceleration. OPEX efficiency maintained at
# $1.2B, yielding 28% EBITDA margin. Human capital investment: 450 net additions
# (5.3% workforce growth) to 8,500 FTE.
# ```
#
# **🎯 Business Value:**
# - 📊 One model, infinite formats
# - ⚡ No retraining for new styles
# - 💰 Cost-effective personalization
# - 🎯 Better user satisfaction
#
# </div>
#
# </div>
#
# ### 🎴 Flashcard: FLAN-T5
#
# <div style='background: linear-gradient(135deg, #A5D6A7 0%, #81C784 100%); padding: 20px; border-radius: 15px; border: 3px solid #66BB6A; margin: 20px 0;'>
#     <h4 style='color: #1B5E20; margin-top: 0;'>🎓 FLAN-T5 Özet Kartı</h4>
#     <details>
#         <summary style='cursor: pointer; font-size: 18px; font-weight: bold; color: #2E7D32;'>
#             ❓ FLAN-T5'in süper gücü nedir ve ne zaman kullanmalıyız?
#         </summary>
#         <div style='background-color: white; padding: 20px; border-radius: 10px; margin-top: 15px;'>
#             <p style='font-size: 16px; line-height: 1.8;'>
#                 <b>🌟 Süper Güç: Natural Language Instructions!</b><br/><br/>
#                 FLAN-T5, <b>herhangi bir instruction'ı anlayabilir</b>. "summarize:", "translate:",
#                 "explain like I'm 5:" gibi doğal komutları işleyebilir.<br/><br/>
#                 <b>✅ Kullanım Senaryoları:</b><br/>
#                 • Multi-format output gerektiren uygulamalar<br/>
#                 • Zero-shot/few-shot learning<br/>
#                 • User'a custom instruction verdirtmek<br/>
#                 • Tek model ile çoklu task<br/>
#                 • Düşük data'da bile yüksek performans<br/><br/>
#                 <b>❌ Kullanma:</b><br/>
#                 • Çok uzun dokümanlar (> 512 tokens)<br/>
#                 • Ultra-low latency gerekli (DistilBART daha hızlı)<br/><br/>
#                 <span style='background-color: #FFD54F; padding: 5px 10px; border-radius: 5px;'>
#                     <b>YBS Tip:</b> Flexibility > Performance → FLAN-T5 kazanır!
#                 </span>
#             </p>
#         </div>
#     </details>
# </div>

# %% [markdown]
# ---
#
# ## 📜 MODEL 6: LED (Longformer Encoder-Decoder)
#
# <div style='background: linear-gradient(135deg, #BBDEFB 0%, #90CAF9 100%); padding: 25px; border-radius: 15px; border: 3px solid #42A5F5; margin: 20px 0;'>
#     <h3 style='color: #0D47A1; margin-top: 0;'>🎯 LED - Long Document Champion!</h3>
#
# <table style='width: 100%; background-color: white; border-radius: 10px; overflow: hidden; margin-top: 15px;'>
#     <tr style='background-color: #90CAF9;'>
#         <td style='padding: 15px; width: 30%;'><b>🏢 Geliştirici</b></td>
#         <td style='padding: 15px;'>Allen Institute for AI</td>
#     </tr>
#     <tr>
#         <td style='padding: 15px;'><b>📅 Yıl</b></td>
#         <td style='padding: 15px;'>2020</td>
#     </tr>
#     <tr style='background-color: #BBDEFB;'>
#         <td style='padding: 15px;'><b>📊 Parametre</b></td>
#         <td style='padding: 15px;'>406M (base), 1.6B (large)</td>
#     </tr>
#     <tr>
#         <td style='padding: 15px;'><b>🎯 Özellik</b></td>
#         <td style='padding: 15px;'>Efficient attention up to 16,384 tokens!</td>
#     </tr>
#     <tr style='background-color: #BBDEFB;'>
#         <td style='padding: 15px;'><b>💡 YBS Kullanımı</b></td>
#         <td style='padding: 15px;'>Legal documents, research papers, books</td>
#     </tr>
# </table>
#
# </div>
#
# ### 🔬 Efficient Attention Mechanism
#
# <div style='background-color: #E3F2FD; padding: 20px; border-radius: 10px; border: 2px solid #1976D2; margin: 20px 0;'>
#     <h4 style='color: #0D47A1; margin-top: 0;'>⚡ Neden Diğer Modeller Uzun Metinde Başarısız?</h4>
#
# <table style='width: 100%; margin-top: 20px; border-collapse: collapse;'>
#     <thead>
#         <tr style='background-color: #0D47A1; color: white;'>
#             <th style='padding: 12px; text-align: left;'>Model</th>
#             <th style='padding: 12px; text-align: center;'>Max Tokens</th>
#             <th style='padding: 12px; text-align: center;'>Complexity</th>
#             <th style='padding: 12px; text-align: center;'>Memory</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr style='background-color: #FFEBEE;'>
#             <td style='padding: 10px;'>BART</td>
#             <td style='padding: 10px; text-align: center;'>1,024</td>
#             <td style='padding: 10px; text-align: center;'>O(n²)</td>
#             <td style='padding: 10px; text-align: center;'>High 📈</td>
#         </tr>
#         <tr style='background-color: #FFF9C4;'>
#             <td style='padding: 10px;'>T5</td>
#             <td style='padding: 10px; text-align: center;'>512</td>
#             <td style='padding: 10px; text-align: center;'>O(n²)</td>
#             <td style='padding: 10px; text-align: center;'>High 📈</td>
#         </tr>
#         <tr style='background-color: #C8E6C9;'>
#             <td style='padding: 10px;'><b>LED</b></td>
#             <td style='padding: 10px; text-align: center;'><b>16,384</b> ✨</td>
#             <td style='padding: 10px; text-align: center;'><b>O(n)</b> ⚡</td>
#             <td style='padding: 10px; text-align: center;'><b>Low</b> 📉</td>
#         </tr>
#     </tbody>
# </table>
#
# <div style='background-color: white; padding: 20px; border-radius: 10px; margin-top: 20px;'>
#     <h5 style='color: #1565C0; margin-top: 0;'>🧠 Sliding Window + Global Attention</h5>
#
# ```mermaid
# graph LR
#     A[📄 Long Document<br/>16K tokens] --> B[🪟 Local Windows<br/>Sliding attention]
#     A --> C[🌍 Global Tokens<br/>Full attention]
#     B --> D[⚡ Efficient<br/>Linear complexity]
#     C --> D
#     D --> E[✨ Summary<br/>Full context preserved]
#
#     style A fill:#FFE5E5,stroke:#FF6B6B,stroke-width:2px
#     style B fill:#E1F5FE,stroke:#0277BD,stroke-width:2px
#     style C fill:#E8F5E9,stroke:#66BB6A,stroke-width:2px
#     style D fill:#FFF9C4,stroke:#FBC02D,stroke-width:3px
#     style E fill:#C8E6C9,stroke:#66BB6A,stroke-width:2px
# ```
#
# <p style='font-size: 16px; line-height: 1.8; margin-top: 20px;'>
#     <b>💡 Nasıl Çalışır?</b><br/>
#     • <b>Local Attention:</b> Her token sadece yakınındaki tokenlara bakar (sliding window)<br/>
#     • <b>Global Attention:</b> Özel tokenler (CLS, summary tokens) tüm dokümana bakar<br/>
#     • <b>Sonuç:</b> O(n²) yerine O(n) complexity → 32x daha uzun dokümanlar!
# </p>
#
# </div>
#
# </div>
#
# ### 💼 YBS Senaryosu: LED ile Legal Contract Analysis
#
# <div style='background-color: #E8F5E9; padding: 20px; border-radius: 10px; border: 2px dashed #66BB6A; margin: 20px 0;'>
#
# **⚖️ Problem:** Law firm - 200+ sayfalık contract'ları analiz etmek gerekiyor
# **🎯 Çözüm:** LED ile comprehensive legal summarization
# **📊 Sonuç:** Lawyer time %60 azaldı, risk detection %40 arttı
#
# <div style='background-color: white; padding: 15px; border-radius: 8px; margin-top: 15px;'>
#
# **Örnek: M&A Contract (187 pages, ~12K tokens)**
#
# ```text
# Input: [MASSIVE LEGAL DOCUMENT - 12,000 tokens]
# MERGER AND ACQUISITION AGREEMENT between TechCorp International and DataSystems Inc.
# ... (187 pages of legal text including clauses, warranties, indemnifications,
# schedules, exhibits, financial statements, due diligence reports, compliance
# requirements, intellectual property transfers, employee agreements, termination
# conditions, dispute resolution procedures, governing law, confidentiality
# provisions, representations and warranties, closing conditions, etc.) ...
#
# LED Output:
# EXECUTIVE SUMMARY - M&A Agreement
#
# PARTIES & TRANSACTION:
# - Acquirer: TechCorp International ($2.4B purchase price)
# - Target: DataSystems Inc. (cloud infrastructure business)
# - Structure: Stock purchase agreement, 70% cash, 30% stock
# - Closing: Q2 2026 (estimated 120 days post-signing)
#
# KEY TERMS:
# - Purchase Price: $2.4B ($1.68B cash, $720M TechCorp shares)
# - Earnout: Additional $300M contingent on 2026-2027 revenue targets
# - Working Capital: $50M adjustment mechanism
# - Escrow: $120M held for 18 months (indemnification claims)
#
# CRITICAL CLAUSES:
# - Material Adverse Effect (MAE): Standard definition, 15% threshold
# - Indemnification Cap: $240M (10% of purchase price)
# - Survival Period: 18 months (general), 5 years (tax/IP)
# - Non-Compete: Key executives, 3 years, North America
# - Employee Retention: 90% for 12 months, $50M retention pool
#
# CLOSING CONDITIONS:
# ✅ Regulatory approvals (FTC, EU Commission)
# ✅ Shareholder approval (75% threshold)
# ✅ No material litigation
# ✅ Key customer consents (top 10 customers)
#
# RISK FACTORS IDENTIFIED:
# ⚠️ Pending patent litigation ($25M exposure)
# ⚠️ GDPR compliance gaps (estimated $5M remediation)
# ⚠️ Customer concentration (Top 3 = 45% revenue)
#
# RECOMMENDATIONS:
# 1. Accelerate regulatory filings (potential 6-month delay risk)
# 2. Negotiate improved MAE threshold (industry standard 20%)
# 3. Request additional disclosure on IP litigation
# ```
#
# **🎯 Business Impact:**
# - ⏱️ Analysis time: 40 hours → 2 hours
# - 📊 Risk detection: Comprehensive coverage
# - 💰 Legal fees: $80K → $20K per contract
# - ✅ Key clause extraction: 100% accuracy
#
# </div>
#
# </div>
#
# ### 📊 Token Length Comparison
#
# <div style='background-color: #FFF3E0; padding: 20px; border-radius: 10px; margin: 20px 0;'>
#     <h4 style='color: #E65100; margin-top: 0;'>📏 Kaç Sayfa İşleyebilir?</h4>
#
# <table style='width: 100%; border-collapse: collapse; margin-top: 15px;'>
#     <tr style='background-color: #FB8C00; color: white;'>
#         <th style='padding: 12px;'>Model</th>
#         <th style='padding: 12px; text-align: center;'>Max Tokens</th>
#         <th style='padding: 12px; text-align: center;'>~Pages (single-spaced)</th>
#         <th style='padding: 12px; text-align: center;'>Use Case</th>
#     </tr>
#     <tr style='background-color: #FFEBEE;'>
#         <td style='padding: 10px;'>T5</td>
#         <td style='padding: 10px; text-align: center;'>512</td>
#         <td style='padding: 10px; text-align: center;'>~1 page</td>
#         <td style='padding: 10px;'>Short emails</td>
#     </tr>
#     <tr style='background-color: #E3F2FD;'>
#         <td style='padding: 10px;'>BART</td>
#         <td style='padding: 10px; text-align: center;'>1,024</td>
#         <td style='padding: 10px; text-align: center;'>~2 pages</td>
#         <td style='padding: 10px;'>Articles, reports</td>
#     </tr>
#     <tr style='background-color: #F3E5F5;'>
#         <td style='padding: 10px;'>Pegasus</td>
#         <td style='padding: 10px; text-align: center;'>1,024</td>
#         <td style='padding: 10px; text-align: center;'>~2 pages</td>
#         <td style='padding: 10px;'>News, blogs</td>
#     </tr>
#     <tr style='background-color: #C8E6C9;'>
#         <td style='padding: 10px;'><b>LED</b></td>
#         <td style='padding: 10px; text-align: center;'><b>16,384</b></td>
#         <td style='padding: 10px; text-align: center;'><b>~32 pages</b> 🚀</td>
#         <td style='padding: 10px;'><b>Books, contracts, theses</b></td>
#     </tr>
# </table>
#
# <p style='background-color: #FFD54F; padding: 15px; border-radius: 8px; margin-top: 20px; font-size: 16px;'>
#     <b>💡 YBS Insight:</b> Eğer dokümanlarınız 2+ sayfa ise ve chunking yapmak istemiyorsanız,
#     <b>LED tek seçeneğiniz!</b>
# </p>
#
# </div>
#
# ### 🎴 Flashcard: LED
#
# <div style='background: linear-gradient(135deg, #90CAF9 0%, #64B5F6 100%); padding: 20px; border-radius: 15px; border: 3px solid #42A5F5; margin: 20px 0;'>
#     <h4 style='color: #0D47A1; margin-top: 0;'>🎓 LED Özet Kartı</h4>
#     <details>
#         <summary style='cursor: pointer; font-size: 18px; font-weight: bold; color: #01579B;'>
#             ❓ LED'i hangi kritik senaryolarda tercih etmeliyiz?
#         </summary>
#         <div style='background-color: white; padding: 20px; border-radius: 10px; margin-top: 15px;'>
#             <p style='font-size: 16px; line-height: 1.8;'>
#                 <b>📜 LED = Long Document Expert!</b><br/><br/>
#                 <b>✅ Mutlaka LED Kullan:</b><br/>
#                 • Legal contracts (50-300 pages)<br/>
#                 • Academic papers/theses<br/>
#                 • Book summarization<br/>
#                 • Medical records/case studies<br/>
#                 • Comprehensive annual reports<br/>
#                 • Any document > 2 pages<br/><br/>
#                 <b>❌ LED Gereksiz:</b><br/>
#                 • Short emails (< 512 tokens)<br/>
#                 • Social media posts<br/>
#                 • News articles (< 1000 words)<br/><br/>
#                 <b>⚠️ Trade-off:</b><br/>
#                 LED, uzun doküman işlerken muhteşem ama kısa metinlerde
#                 BART/Pegasus'tan daha yavaş. Token length'e göre karar verin!<br/><br/>
#                 <span style='background-color: #FFD54F; padding: 5px 10px; border-radius: 5px;'>
#                     <b>Karar Kuralı:</b> > 1024 tokens → LED, < 1024 → BART/Pegasus
#                 </span>
#             </p>
#         </div>
#     </details>
# </div>

# %% [markdown]
# ---
#
# ## 🦅 MODEL 7: BigBird-Pegasus
#
# <div style='background: linear-gradient(135deg, #FFE0B2 0%, #FFCC80 100%); padding: 25px; border-radius: 15px; border: 3px solid #FF9800; margin: 20px 0;'>
#     <h3 style='color: #E65100; margin-top: 0;'>🎯 BigBird-Pegasus - Sparse Attention Master!</h3>
#
# <table style='width: 100%; background-color: white; border-radius: 10px; overflow: hidden; margin-top: 15px;'>
#     <tr style='background-color: #FFCC80;'>
#         <td style='padding: 15px; width: 30%;'><b>🏢 Geliştirici</b></td>
#         <td style='padding: 15px;'>Google Research</td>
#     </tr>
#     <tr>
#         <td style='padding: 15px;'><b>📅 Yıl</b></td>
#         <td style='padding: 15px;'>2021</td>
#     </tr>
#     <tr style='background-color: #FFE0B2;'>
#         <td style='padding: 15px;'><b>📊 Parametre</b></td>
#         <td style='padding: 15px;'>340M (large)</td>
#     </tr>
#     <tr>
#         <td style='padding: 15px;'><b>🎯 Özellik</b></td>
#         <td style='padding: 15px;'>Sparse attention (local + global + random)</td>
#     </tr>
#     <tr style='background-color: #FFE0B2;'>
#         <td style='padding: 15px;'><b>💡 YBS Kullanımı</b></td>
#         <td style='padding: 15px;'>Scientific papers, technical documentation</td>
#     </tr>
# </table>
#
# </div>
#
# ### 🔬 BigBird's Revolutionary Sparse Attention
#
# <div style='background-color: #FFF3E0; padding: 20px; border-radius: 10px; border: 2px solid #F57C00; margin: 20px 0;'>
#     <h4 style='color: #E65100; margin-top: 0;'>🧠 3-Pronged Attention Strategy</h4>
#
# ```mermaid
# graph TD
#     A[📄 Input Sequence<br/>4096 tokens] --> B[🪟 Local Attention<br/>Neighboring tokens]
#     A --> C[🌍 Global Attention<br/>Special tokens]
#     A --> D[🎲 Random Attention<br/>Long-range deps]
#
#     B --> E[⚡ Sparse Patterns<br/>O(n) complexity]
#     C --> E
#     D --> E
#
#     E --> F[✨ Output<br/>Full context + Efficiency]
#
#     style A fill:#FFE5E5,stroke:#FF6B6B,stroke-width:2px
#     style B fill:#E3F2FD,stroke:#42A5F5,stroke-width:2px
#     style C fill:#C8E6C9,stroke:#66BB6A,stroke-width:2px
#     style D fill:#FFF9C4,stroke:#FBC02D,stroke-width:2px
#     style E fill:#E1BEE7,stroke:#AB47BC,stroke-width:3px
#     style F fill:#FFE0B2,stroke:#FB8C00,stroke-width:2px
# ```
#
# <div style='display: flex; gap: 15px; margin-top: 20px;'>
#
# <div style='flex: 1; background-color: #E3F2FD; padding: 15px; border-radius: 8px; border-left: 4px solid #2196F3;'>
#     <h5 style='color: #1565C0; margin-top: 0;'>🪟 Local Attention</h5>
#     <p style='line-height: 1.6; font-size: 14px;'>
#         Her token sadece <b>w=256</b> komşusuna bakar. Cümle içi ilişkiler için.
#     </p>
# </div>
#
# <div style='flex: 1; background-color: #E8F5E9; padding: 15px; border-radius: 8px; border-left: 4px solid #66BB6A;'>
#     <h5 style='color: #2E7D32; margin-top: 0;'>🌍 Global Attention</h5>
#     <p style='line-height: 1.6; font-size: 14px;'>
#         <b>g=64</b> özel token tüm sequenceı görür. High-level understanding için.
#     </p>
# </div>
#
# <div style='flex: 1; background-color: #FFF9C4; padding: 15px; border-radius: 8px; border-left: 4px solid #FBC02D;'>
#     <h5 style='color: #F57F17; margin-top: 0;'>🎲 Random Attention</h5>
#     <p style='line-height: 1.6; font-size: 14px;'>
#         <b>r=64</b> random token. Long-range dependencies için.
#     </p>
# </div>
#
# </div>
#
# <div style='background-color: white; padding: 20px; border-radius: 10px; margin-top: 20px;'>
#     <p style='font-size: 16px; line-height: 1.8;'>
#         <b>💡 Neden Bu Önemli?</b><br/>
#         Standard attention: Her token, her tokena bakar = O(n²) → 4096 token için <b>16M</b> operations!<br/>
#         BigBird attention: Sparse pattern = O(n) → 4096 token için sadece <b>1.3M</b> operations!<br/><br/>
#         <span style='background-color: #C8E6C9; padding: 5px 10px; border-radius: 5px;'>
#             <b>Sonuç:</b> 12x daha hızlı, aynı performance! 🚀
#         </span>
#     </p>
# </div>
#
# </div>
#
# ### 💼 YBS Senaryosu: BigBird ile Scientific Literature Review
#
# <div style='background-color: #E8F5E9; padding: 20px; border-radius: 10px; border: 2px dashed #66BB6A; margin: 20px 0;'>
#
# **🔬 Problem:** R&D department - 50+ sayfa teknik paper'ları hızlıca review etmek
# **🎯 Çözüm:** BigBird-Pegasus ile scientific paper summarization
# **📊 Sonuç:** Literature review süresi %75 azaldı
#
# <div style='background-color: white; padding: 15px; border-radius: 8px; margin-top: 15px;'>
#
# **Örnek: AI Research Paper (48 pages, 3,800 tokens)**
#
# ```text
# Input: [TECHNICAL RESEARCH PAPER]
# "Efficient Transformers: A Survey of Sparse Attention Mechanisms"
#
# Abstract: Recent advances in transformer architectures have led to unprecedented
# performance in NLP tasks, however, the quadratic complexity of self-attention
# limits scalability...
#
# [48 pages including: Introduction, Related Work, Methodology (mathematical proofs,
# algorithm descriptions), Experiments (multiple datasets, ablation studies,
# comparison tables), Results (performance metrics, computational analysis),
# Discussion, Limitations, Future Work, References (150+ citations)]
#
# BigBird-Pegasus Output:
#
# COMPREHENSIVE SUMMARY:
#
# RESEARCH FOCUS:
# Survey of sparse attention mechanisms designed to reduce transformer complexity
# from O(n²) to linear or near-linear. Analyzes 23 different efficient transformer
# architectures proposed 2019-2025.
#
# MAIN CONTRIBUTIONS:
# 1. Taxonomy of sparse attention patterns (local, strided, fixed, learned)
# 2. Theoretical analysis proving sparse patterns can approximate full attention
# 3. Empirical comparison across 12 NLP benchmarks
# 4. Computational efficiency analysis (FLOPs, memory, latency)
#
# KEY FINDINGS:
# • Local + Global attention (BigBird, Longformer) achieves 97% of full
#   attention performance with 10x speedup
# • Learned patterns (Reformer, Routing Transformer) show promise but
#   inconsistent across tasks
# • Hybrid approaches (LED, BigBird-Pegasus) offer best accuracy-efficiency trade-off
# • Sparse attention enables 8x longer sequences on same hardware
#
# EXPERIMENTAL RESULTS:
# Benchmark Performance (average ROUGE-L):
# - Full Attention: 44.2 (baseline)
# - BigBird: 43.8 (-0.9%, 10x faster)
# - Linformer: 41.5 (-6.1%, 15x faster)
# - Performer: 42.3 (-4.3%, 12x faster)
#
# LIMITATIONS:
# • Implementation complexity higher than standard transformers
# • Not all frameworks support sparse operations natively
# • Optimal sparse pattern varies by task/domain
#
# FUTURE DIRECTIONS:
# 1. Adaptive sparse patterns learned per-instance
# 2. Hardware-specific optimizations for sparse operations
# 3. Theoretical guarantees for approximation quality
#
# RELEVANCE TO INDUSTRY:
# Critical for scaling transformers to book-length documents, video understanding,
# and genomic sequences. Production deployments show 40-60% cost reduction.
# ```
#
# **🎯 Research Team Impact:**
# - ⏱️ Reading time: 8 hours → 15 minutes
# - 📊 Key insights: All major contributions captured
# - 🔬 Decision-making: Quick assessment of paper relevance
# - 💰 Researcher productivity: 20x increase in papers reviewed
#
# </div>
#
# </div>
#
# ### 📊 BigBird vs LED: Long Document Showdown
#
# <table style='width: 100%; border-collapse: collapse; margin: 20px 0;'>
#     <thead>
#         <tr style='background: linear-gradient(135deg, #FF9800 0%, #F57C00 100%); color: white;'>
#             <th style='padding: 15px; text-align: left;'>Feature</th>
#             <th style='padding: 15px; text-align: center;'>BigBird-Pegasus</th>
#             <th style='padding: 15px; text-align: center;'>LED</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr style='background-color: #FFEBEE;'>
#             <td style='padding: 12px; border: 1px solid #ddd;'><b>🎯 Attention Type</b></td>
#             <td style='padding: 12px; border: 1px solid #ddd; text-align: center;'>Local + Global + Random</td>
#             <td style='padding: 12px; border: 1px solid #ddd; text-align: center;'>Sliding window + Global</td>
#         </tr>
#         <tr style='background-color: #E3F2FD;'>
#             <td style='padding: 12px; border: 1px solid #ddd;'><b>📏 Max Length</b></td>
#             <td style='padding: 12px; border: 1px solid #ddd; text-align: center;'>4,096 tokens</td>
#             <td style='padding: 12px; border: 1px solid #ddd; text-align: center;'>16,384 tokens ✅</td>
#         </tr>
#         <tr style='background-color: #F3E5F5;'>
#             <td style='padding: 12px; border: 1px solid #ddd;'><b>⚡ Speed</b></td>
#             <td style='padding: 12px; border: 1px solid #ddd; text-align: center;'>Faster (sparse ops) ✅</td>
#             <td style='padding: 12px; border: 1px solid #ddd; text-align: center;'>Moderate</td>
#         </tr>
#         <tr style='background-color: #FFF9C4;'>
#             <td style='padding: 12px; border: 1px solid #ddd;'><b>📊 Accuracy</b></td>
#             <td style='padding: 12px; border: 1px solid #ddd; text-align: center;'>High (Pegasus heritage) ✅</td>
#             <td style='padding: 12px; border: 1px solid #ddd; text-align: center;'>High</td>
#         </tr>
#         <tr style='background-color: #C8E6C9;'>
#             <td style='padding: 12px; border: 1px solid #ddd;'><b>💼 Best For</b></td>
#             <td style='padding: 12px; border: 1px solid #ddd; text-align: center;'>Scientific papers, tech docs</td>
#             <td style='padding: 12px; border: 1px solid #ddd; text-align: center;'>Legal, books, ultra-long</td>
#         </tr>
#     </tbody>
# </table>
#
# <div style='background-color: #FFD54F; padding: 15px; border-radius: 10px; margin-top: 20px;'>
#     <p style='font-size: 16px; margin: 0;'>
#         <b>🎯 YBS Decision Rule:</b><br/>
#         • <b>2-8 pages:</b> BigBird-Pegasus (faster + accurate)<br/>
#         • <b>8+ pages:</b> LED (longer context support)<br/>
#         • <b>Scientific content:</b> BigBird-Pegasus (better at technical text)<br/>
#         • <b>Legal/narrative:</b> LED (better at sequential understanding)
#     </p>
# </div>
#
# ### 🎴 Flashcard: BigBird-Pegasus
#
# <div style='background: linear-gradient(135deg, #FFCC80 0%, #FFB74D 100%); padding: 20px; border-radius: 15px; border: 3px solid #FF9800; margin: 20px 0;'>
#     <h4 style='color: #E65100; margin-top: 0;'>🎓 BigBird-Pegasus Özet Kartı</h4>
#     <details>
#         <summary style='cursor: pointer; font-size: 18px; font-weight: bold; color: #E65100;'>
#             ❓ BigBird'ün sparse attention'ı nasıl çalışır ve neden önemli?
#         </summary>
#         <div style='background-color: white; padding: 20px; border-radius: 10px; margin-top: 15px;'>
#             <p style='font-size: 16px; line-height: 1.8;'>
#                 <b>🦅 BigBird's Secret Sauce: Üçlü Attention!</b><br/><br/>
#
#                 <b>1️⃣ Local Attention (🪟):</b> Her token komşularına bakar → Cümle yapısı<br/>
#                 <b>2️⃣ Global Attention (🌍):</b> Özel tokenler her yere bakar → Genel anlam<br/>
#                 <b>3️⃣ Random Attention (🎲):</b> Random bağlantılar → Uzun mesafe ilişkiler<br/><br/>
#
#                 <b>🎯 Matematik:</b><br/>
#                 • Standard: n × n = 4096² = 16M operations<br/>
#                 • BigBird: n × (w + g + r) = 4096 × 384 = 1.6M operations<br/>
#                 • Kazanç: <b>10x faster!</b> ⚡<br/><br/>
#
#                 <b>✅ Kullan:</b> 2-8 sayfa, technical/scientific content<br/>
#                 <b>❌ Kullanma:</b> 8+ sayfa (LED daha iyi), çok kısa metinler<br/><br/>
#
#                 <span style='background-color: #FFD54F; padding: 5px 10px; border-radius: 5px;'>
#                     <b>Sweet Spot:</b> Medium-long documents with complex structure
#                 </span>
#             </p>
#         </div>
#     </details>
# </div>

# %% [markdown]
# ---
#
# ## 🌍 MODEL 8: mT5 (Multilingual T5)
#
# <div style='background: linear-gradient(135deg, #C5E1A5 0%, #AED581 100%); padding: 25px; border-radius: 15px; border: 3px solid #8BC34A; margin: 20px 0;'>
#     <h3 style='color: #33691E; margin-top: 0;'>🎯 mT5 - Global Language Champion!</h3>
#
# <table style='width: 100%; background-color: white; border-radius: 10px; overflow: hidden; margin-top: 15px;'>
#     <tr style='background-color: #AED581;'>
#         <td style='padding: 15px; width: 30%;'><b>🏢 Geliştirici</b></td>
#         <td style='padding: 15px;'>Google Research</td>
#     </tr>
#     <tr>
#         <td style='padding: 15px;'><b>📅 Yıl</b></td>
#         <td style='padding: 15px;'>2020</td>
#     </tr>
#     <tr style='background-color: #C5E1A5;'>
#         <td style='padding: 15px;'><b>📊 Parametre</b></td>
#         <td style='padding: 15px;'>300M (small), 580M (base), 1.2B (large), 3.7B (xl), 13B (xxl)</td>
#     </tr>
#     <tr>
#         <td style='padding: 15px;'><b>🎯 Özellik</b></td>
#         <td style='padding: 15px;'>Pre-trained on 101 languages!</td>
#     </tr>
#     <tr style='background-color: #C5E1A5;'>
#         <td style='padding: 15px;'><b>💡 YBS Kullanımı</b></td>
#         <td style='padding: 15px;'>Global companies, multilingual content, localization</td>
#     </tr>
# </table>
#
# </div>
#
# ### 🌏 101 Dil Desteği: Küresel Erişim
#
# <div style='background-color: #E8F5E9; padding: 20px; border-radius: 10px; border: 2px solid #66BB6A; margin: 20px 0;'>
#     <h4 style='color: #2E7D32; margin-top: 0;'>🗺️ Desteklenen Dil Aileleri</h4>
#
# <div style='display: grid; grid-template-columns: 1fr 1fr 1fr; gap: 15px; margin-top: 20px;'>
#
# <div style='background: linear-gradient(135deg, #FFE5E5 0%, #FFCDD2 100%); padding: 15px; border-radius: 10px;'>
#     <h5 style='color: #C62828; margin-top: 0;'>🌐 European</h5>
#     <ul style='font-size: 14px; line-height: 1.6;'>
#         <li>English, Spanish, French</li>
#         <li>German, Italian, Portuguese</li>
#         <li>Russian, Polish, Turkish</li>
#         <li>Dutch, Swedish, Czech</li>
#         <li>+ 30 more</li>
#     </ul>
# </div>
#
# <div style='background: linear-gradient(135deg, #E3F2FD 0%, #BBDEFB 100%); padding: 15px; border-radius: 10px;'>
#     <h5 style='color: #1565C0; margin-top: 0;'>🏯 Asian</h5>
#     <ul style='font-size: 14px; line-height: 1.6;'>
#         <li>Chinese, Japanese, Korean</li>
#         <li>Hindi, Bengali, Tamil</li>
#         <li>Thai, Vietnamese, Malay</li>
#         <li>Indonesian, Filipino</li>
#         <li>+ 25 more</li>
#     </ul>
# </div>
#
# <div style='background: linear-gradient(135deg, #FFF9C4 0%, #FFF59D 100%); padding: 15px; border-radius: 10px;'>
#     <h5 style='color: #F57F17; margin-top: 0;'>🌍 Others</h5>
#     <ul style='font-size: 14px; line-height: 1.6;'>
#         <li>Arabic, Hebrew, Persian</li>
#         <li>Swahili, Yoruba, Zulu</li>
#         <li>Afrikaans, Amharic</li>
#         <li>Low-resource languages</li>
#         <li>+ 46 more</li>
#     </ul>
# </div>
#
# </div>
#
# <div style='background-color: white; padding: 20px; border-radius: 10px; margin-top: 20px;'>
#     <p style='font-size: 16px; line-height: 1.8;'>
#         <b>🎯 Pre-training Strategy:</b><br/>
#         mT5, <b>mC4 corpus</b> (multilingual Common Crawl) üzerinde eğitildi -
#         <span style='background-color: #FFD54F; padding: 3px 8px; border-radius: 5px;'><b>6.3 trillion tokens</b></span>
#         across 101 languages!<br/><br/>
#         <b>💡 Transfer Learning Magic:</b> Yüksek kaynaklı dillerden (English) düşük kaynaklı dillere
#         (Swahili) bilgi transfer edilir → Her dil için optimal performans!
#     </p>
# </div>
#
# </div>
#
# ### 💼 YBS Senaryosu: mT5 ile Global Customer Support
#
# <div style='background-color: #E1F5FE; padding: 20px; border-radius: 10px; border: 2px dashed #0277BD; margin: 20px 0;'>
#
# **🌏 Problem:** E-commerce platform - 15+ ülkede müşteri desteği, her biri farklı dilde
# **🎯 Çözüm:** mT5 ile unified multilingual ticket summarization
# **💰 Sonuç:** $2M/yıl localization maliyeti tasarrufu
#
# <div style='background-color: white; padding: 15px; border-radius: 8px; margin-top: 15px;'>
#
# **Örnek 1: Turkish Support Ticket**
# ```text
# Input (Turkish):
# Merhaba, geçen hafta sipariş ettiğim ürün hâlâ elime ulaşmadı. Kargo takip
# numarası çalışmıyor ve müşteri hizmetlerinden bir yanıt alamadım. Ürün acil
# bir hediye için gerekiyordu ve artık geç kaldı. İade talep ediyorum ve tüm
# süreç boyunca yaşadığım zorluklar için tazminat bekliyorum. Sipariş no:
# TR-2026-45872. Lütfen acil dönüş yapın.
#
# mT5 Output (Turkish Summary):
# Sipariş TR-2026-45872 gecikmeli. Kargo takip çalışmıyor, müşteri hizmetleri
# yanıtsız. Müşteri iade + tazminat talep ediyor. Acil çözüm gerekli.
# ```
#
# **Örnek 2: Japanese Support Ticket**
# ```text
# Input (Japanese):
# 先週注文した商品がまだ届いていません。配送追跡番号が機能しておらず、
# カスタマーサービスから返信がありません。商品は緊急のギフトとして必要
# でしたが、もう遅れています。返金を希望し、このプロセス全体で経験した
# 困難に対する補償を期待しています。注文番号：JP-2026-45872。
# 至急ご連絡ください。
#
# mT5 Output (Japanese Summary):
# 注文JP-2026-45872が遅延。追跡不可、カスタマーサービス無応答。
# 顧客が返金と補償を要求。緊急対応必要。
# ```
#
# **Örnek 3: Spanish Support Ticket**
# ```text
# Input (Spanish):
# Hola, el producto que pedí la semana pasada aún no ha llegado. El número de
# seguimiento no funciona y no he recibido respuesta del servicio al cliente.
# El producto era para un regalo urgente y ahora llegó tarde. Solicito un reembolso
# y espero compensación por las dificultades que experimenté durante todo este
# proceso. Número de pedido: ES-2026-45872. Por favor responda urgentemente.
#
# mT5 Output (Spanish Summary):
# Pedido ES-2026-45872 retrasado. Seguimiento no funciona, servicio al cliente
# sin respuesta. Cliente solicita reembolso + compensación. Requiere atención urgente.
# ```
#
# **🎯 Cross-lingual Insight:**
# mT5, farklı dillerdeki **aynı problemi** tutarlı formatta özetliyor!
# - ✅ Unified ticket categorization
# - ✅ Priority level detection (urgent)
# - ✅ Action items clear (refund + compensation)
# - ✅ Single model for all markets
#
# **💰 Business Impact:**
# - **Before mT5:** 15 separate models, 15x maintenance cost
# - **After mT5:** 1 model, 1x cost, consistent quality
# - **Savings:** $2M/year in localization + infrastructure
# - **Response time:** 60 min → 5 min (automated routing)
#
# </div>
#
# </div>
#
# ### 🌐 Zero-Shot Cross-Lingual Transfer
#
# <div style='background-color: #F3E5F5; padding: 20px; border-radius: 10px; border: 2px solid #AB47BC; margin: 20px 0;'>
#     <h4 style='color: #6A1B9A; margin-top: 0;'>🎓 Magic of Multilingual Models</h4>
#
# <div style='background-color: white; padding: 20px; border-radius: 10px; margin-top: 15px;'>
#
# <p style='font-size: 16px; line-height: 1.8;'>
#     <b>🔮 Zero-Shot Scenario:</b> İngilizce'de fine-tune edilen mT5,
#     <b>hiç görmediği dillerde</b> de çalışabilir!
# </p>
#
# ```mermaid
# graph LR
#     A[🏋️ Fine-tune<br/>English data only] --> B[🤖 mT5 Model<br/>Multilingual pre-training]
#     B --> C[🇹🇷 Turkish<br/>No training]
#     B --> D[🇯🇵 Japanese<br/>No training]
#     B --> E[🇪🇸 Spanish<br/>No training]
#     B --> F[🇩🇪 German<br/>No training]
#
#     style A fill:#E3F2FD,stroke:#42A5F5,stroke-width:2px
#     style B fill:#FFD54F,stroke:#FBC02D,stroke-width:3px
#     style C fill:#C8E6C9,stroke:#66BB6A,stroke-width:2px
#     style D fill:#C8E6C9,stroke:#66BB6A,stroke-width:2px
#     style E fill:#C8E6C9,stroke:#66BB6A,stroke-width:2px
#     style F fill:#C8E6C9,stroke:#66BB6A,stroke-width:2px
# ```
#
# <table style='width: 100%; border-collapse: collapse; margin-top: 20px;'>
#     <tr style='background-color: #667eea; color: white;'>
#         <th style='padding: 12px;'>Training Data</th>
#         <th style='padding: 12px; text-align: center;'>English</th>
#         <th style='padding: 12px; text-align: center;'>Spanish</th>
#         <th style='padding: 12px; text-align: center;'>Turkish</th>
#         <th style='padding: 12px; text-align: center;'>Hindi</th>
#     </tr>
#     <tr style='background-color: #FFEBEE;'>
#         <td style='padding: 10px;'><b>English-only T5</b></td>
#         <td style='padding: 10px; text-align: center; background-color: #C8E6C9;'>✅ 92%</td>
#         <td style='padding: 10px; text-align: center;'>❌ 12%</td>
#         <td style='padding: 10px; text-align: center;'>❌ 8%</td>
#         <td style='padding: 10px; text-align: center;'>❌ 5%</td>
#     </tr>
#     <tr style='background-color: #C8E6C9;'>
#         <td style='padding: 10px;'><b>mT5 (English fine-tune)</b></td>
#         <td style='padding: 10px; text-align: center; background-color: #C8E6C9;'>✅ 90%</td>
#         <td style='padding: 10px; text-align: center; background-color: #FFE082;'>🎯 78%</td>
#         <td style='padding: 10px; text-align: center; background-color: #FFE082;'>🎯 72%</td>
#         <td style='padding: 10px; text-align: center; background-color: #FFE082;'>🎯 65%</td>
#     </tr>
# </table>
#
# <p style='background-color: #FFD54F; padding: 15px; border-radius: 8px; margin-top: 20px; font-size: 16px;'>
#     <b>💡 YBS Insight:</b> Sadece İngilizce data ile fine-tune yap, 100+ dilde çalışan
#     sistem elde et! Data collection maliyeti %95 azalır! 🚀
# </p>
#
# </div>
#
# </div>
#
# ### ⚖️ mT5 vs T5: Trade-offs
#
# <table style='width: 100%; border-collapse: collapse; margin: 20px 0;'>
#     <thead>
#         <tr style='background: linear-gradient(135deg, #8BC34A 0%, #689F38 100%); color: white;'>
#             <th style='padding: 15px; text-align: left;'>Aspect</th>
#             <th style='padding: 15px; text-align: center;'>T5 (English)</th>
#             <th style='padding: 15px; text-align: center;'>mT5 (Multilingual)</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr style='background-color: #FFEBEE;'>
#             <td style='padding: 12px; border: 1px solid #ddd;'><b>🌍 Languages</b></td>
#             <td style='padding: 12px; border: 1px solid #ddd; text-align: center;'>1 (English)</td>
#             <td style='padding: 12px; border: 1px solid #ddd; text-align: center; background-color: #C8E6C9;'><b>101 languages</b> ✅</td>
#         </tr>
#         <tr style='background-color: #E3F2FD;'>
#             <td style='padding: 12px; border: 1px solid #ddd;'><b>📊 English Performance</b></td>
#             <td style='padding: 12px; border: 1px solid #ddd; text-align: center; background-color: #C8E6C9;'><b>Best (92%)</b> ✅</td>
#             <td style='padding: 12px; border: 1px solid #ddd; text-align: center;'>Good (90%)</td>
#         </tr>
#         <tr style='background-color: #F3E5F5;'>
#             <td style='padding: 12px; border: 1px solid #ddd;'><b>⚡ Inference Speed</b></td>
#             <td style='padding: 12px; border: 1px solid #ddd; text-align: center; background-color: #C8E6C9;'><b>Faster</b> ✅</td>
#             <td style='padding: 12px; border: 1px solid #ddd; text-align: center;'>10-15% slower</td>
#         </tr>
#         <tr style='background-color: #FFF9C4;'>
#             <td style='padding: 12px; border: 1px solid #ddd;'><b>💾 Model Size</b></td>
#             <td style='padding: 12px; border: 1px solid #ddd; text-align: center; background-color: #C8E6C9;'><b>Smaller</b> ✅</td>
#             <td style='padding: 12px; border: 1px solid #ddd; text-align: center;'>Larger (more vocab)</td>
#         </tr>
#         <tr style='background-color: #C8E6C9;'>
#             <td style='padding: 12px; border: 1px solid #ddd;'><b>💼 Use Case</b></td>
#             <td style='padding: 12px; border: 1px solid #ddd; text-align: center;'>English-only markets</td>
#             <td style='padding: 12px; border: 1px solid #ddd; text-align: center; background-color: #C8E6C9;'><b>Global products</b> ✅</td>
#         </tr>
#     </tbody>
# </table>
#
# ### 🎴 Flashcard: mT5
#
# <div style='background: linear-gradient(135deg, #AED581 0%, #9CCC65 100%); padding: 20px; border-radius: 15px; border: 3px solid #8BC34A; margin: 20px 0;'>
#     <h4 style='color: #33691E; margin-top: 0;'>🎓 mT5 Özet Kartı</h4>
#     <details>
#         <summary style='cursor: pointer; font-size: 18px; font-weight: bold; color: #1B5E20;'>
#             ❓ mT5'i hangi durumlarda T5'e tercih etmeliyiz?
#         </summary>
#         <div style='background-color: white; padding: 20px; border-radius: 10px; margin-top: 15px;'>
#             <p style='font-size: 16px; line-height: 1.8;'>
#                 <b>🌍 mT5 = Global Expansion Key!</b><br/><br/>
#
#                 <b>✅ mT5 KULLAN:</b><br/>
#                 • Ürününüz 2+ ülkede active<br/>
#                 • Her dil için ayrı model maintain etmek maliyetli<br/>
#                 • Zero-shot cross-lingual transfer istiyorsanız<br/>
#                 • Low-resource diller desteklemeniz gerekiyorsa<br/>
#                 • Global customer base (multilingual support)<br/><br/>
#
#                 <b>✅ T5 KULLAN:</b><br/>
#                 • Sadece English market<br/>
#                 • Maximum English performance kritik<br/>
#                 • Sınırlı compute resource (mT5 daha büyük)<br/>
#                 • Latency çok önemli (T5 %10-15 hızlı)<br/><br/>
#
#                 <b>📊 ROI Calculation:</b><br/>
#                 • 5+ dil → mT5 (tek model = 5x cost savings)<br/>
#                 • 1-2 dil → Language-specific models daha iyi<br/><br/>
#
#                 <span style='background-color: #FFD54F; padding: 5px 10px; border-radius: 5px;'>
#                     <b>Decision Rule:</b> Global ambition → mT5, Local focus → T5
#                 </span>
#             </p>
#         </div>
#     </details>
# </div>

# %% [markdown]
# ---
#
# # 🏆 COMPREHENSIVE MODEL COMPARISON: Final Decision Matrix
#
# <div style='background: linear-gradient(135deg, #667eea 0%, #764ba2 100%); padding: 30px; border-radius: 15px; color: white; text-align: center; margin: 30px 0;'>
#     <h2 style='margin-top: 0;'>🎯 Hangi Model, Hangi Senaryo İçin?</h2>
#     <p style='font-size: 18px;'>
#         8 model öğrendik - şimdi <b>akıllıca seçim</b> zamanı!
#     </p>
# </div>

# %%
# 📊 ADIM 2.4: Model Karşılaştırma Tablosu - Görselleştirme
# 8 modelin güçlü/zayıf yönlerini görsel olarak karşılaştıralım

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Model özellikleri data frame'i oluşturalım
models_data = {
    'Model': ['T5', 'BART', 'Pegasus', 'DistilBART', 'FLAN-T5', 'LED', 'BigBird-Pegasus', 'mT5'],
    'Accuracy': [8.5, 8.7, 9.0, 8.2, 8.8, 8.4, 8.6, 8.3],  # 10 üzerinden
    'Speed': [8.0, 7.5, 7.0, 9.5, 7.8, 6.5, 7.2, 7.3],
    'Max_Length': [512, 1024, 1024, 1024, 512, 16384, 4096, 512],
    'Versatility': [9.0, 7.5, 7.0, 7.5, 9.5, 6.0, 6.5, 9.0],
    'Memory_Efficiency': [8.0, 7.0, 6.5, 9.0, 7.5, 5.0, 6.0, 7.0],
    'Languages': [1, 1, 1, 1, 1, 1, 1, 101]  # Desteklenen dil sayısı
}

df_models = pd.DataFrame(models_data)

# Pastel renkler tanımlayalım
pastel_colors = ['#FFCDD2', '#BBDEFB', '#E1BEE7', '#FFF59D', '#C8E6C9', '#90CAF9', '#FFCC80', '#AED581']

# Görselleştirme: Radar Chart (Spider Plot)
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(18, 7))
fig.patch.set_facecolor('#F5F5F5')

# Sol taraf: İlk 4 model radar chart
categories = ['Accuracy', 'Speed', 'Versatility', 'Memory\nEfficiency']
models_subset1 = df_models.iloc[:4]

angles = np.linspace(0, 2 * np.pi, len(categories), endpoint=False).tolist()
angles += angles[:1]

ax1.set_facecolor('#FFFFFF')
for idx, model in enumerate(models_subset1['Model']):
    values = models_subset1.iloc[idx][['Accuracy', 'Speed', 'Versatility', 'Memory_Efficiency']].tolist()
    values += values[:1]
    ax1.plot(angles, values, 'o-', linewidth=2, label=model, color=pastel_colors[idx])
    ax1.fill(angles, values, alpha=0.15, color=pastel_colors[idx])

ax1.set_xticks(angles[:-1])
ax1.set_xticklabels(categories, size=11, weight='bold')
ax1.set_ylim(0, 10)
ax1.set_title('🎯 Models 1-4: Performance Comparison', size=14, weight='bold', pad=20)
ax1.legend(loc='upper right', bbox_to_anchor=(1.15, 1.15), fontsize=10)
ax1.grid(True, linestyle='--', alpha=0.3)

# Sağ taraf: Son 4 model radar chart
models_subset2 = df_models.iloc[4:]

ax2.set_facecolor('#FFFFFF')
for idx, model in enumerate(models_subset2['Model']):
    values = models_subset2.iloc[idx][['Accuracy', 'Speed', 'Versatility', 'Memory_Efficiency']].tolist()
    values += values[:1]
    ax2.plot(angles, values, 'o-', linewidth=2, label=model, color=pastel_colors[idx + 4])
    ax2.fill(angles, values, alpha=0.15, color=pastel_colors[idx + 4])

ax2.set_xticks(angles[:-1])
ax2.set_xticklabels(categories, size=11, weight='bold')
ax2.set_ylim(0, 10)
ax2.set_title('🚀 Models 5-8: Performance Comparison', size=14, weight='bold', pad=20)
ax2.legend(loc='upper right', bbox_to_anchor=(1.15, 1.15), fontsize=10)
ax2.grid(True, linestyle='--', alpha=0.3)

plt.tight_layout()
plt.savefig('model_comparison_radar.png', dpi=150, bbox_inches='tight', facecolor='#F5F5F5')
plt.show()

print("✅ Model karşılaştırma görselleştirmesi tamamlandı!")
print(f"\n📊 Model Özet İstatistikleri:")
print(df_models[['Model', 'Accuracy', 'Speed', 'Max_Length']].to_string(index=False))
# Out:
# ✅ Model karşılaştırma görselleştirmesi tamamlandı!
#
# 📊 Model Özet İstatistikleri:
#           Model  Accuracy  Speed  Max_Length
#              T5       8.5    8.0         512
#            BART       8.7    7.5        1024
#         Pegasus       9.0    7.0        1024
#      DistilBART       8.2    9.5        1024
#         FLAN-T5       8.8    7.8         512
#             LED       8.4    6.5       16384
# BigBird-Pegasus       8.6    7.2        4096
#             mT5       8.3    7.3         512

# %% [markdown]
# ---
#
# ## 🎯 YBS Decision Flowchart: Doğru Model Seçimi
#
# ```mermaid
# graph TD
#     START[🚀 Summarization Project Start] --> Q1{Doküman<br/>kaç sayfa?}
#
#     Q1 -->|< 1 page| Q2{Hız<br/>kritik mi?}
#     Q1 -->|1-2 pages| Q3{Gürültülü<br/>metin mi?}
#     Q1 -->|2-8 pages| Q4{Teknik/<br/>Scientific?}
#     Q1 -->|8+ pages| LED[📜 LED<br/>Long documents]
#
#     Q2 -->|Evet| DISTILBART[⚡ DistilBART<br/>Fast API]
#     Q2 -->|Hayır| Q5{Çoklu<br/>format?}
#
#     Q5 -->|Evet| FLANT5[🔥 FLAN-T5<br/>Flexible instructions]
#     Q5 -->|Hayır| T5[🥇 T5<br/>General purpose]
#
#     Q3 -->|Evet| BART[🥈 BART<br/>Noisy text expert]
#     Q3 -->|Hayır| PEGASUS[🥉 Pegasus<br/>High quality]
#
#     Q4 -->|Evet| BIGBIRD[🦅 BigBird-Pegasus<br/>Scientific papers]
#     Q4 -->|Hayır| LED
#
#     START --> Q6{Çoklu<br/>dil?}
#     Q6 -->|Evet| MT5[🌍 mT5<br/>101 languages]
#     Q6 -->|Hayır| Q1
#
#     style START fill:#FFE5E5,stroke:#FF6B6B,stroke-width:3px
#     style T5 fill:#FFCDD2,stroke:#EF5350,stroke-width:2px
#     style BART fill:#BBDEFB,stroke:#42A5F5,stroke-width:2px
#     style PEGASUS fill:#E1BEE7,stroke:#AB47BC,stroke-width:2px
#     style DISTILBART fill:#FFF59D,stroke:#FBC02D,stroke-width:2px
#     style FLANT5 fill:#C8E6C9,stroke:#66BB6A,stroke-width:2px
#     style LED fill:#90CAF9,stroke:#42A5F5,stroke-width:2px
#     style BIGBIRD fill:#FFCC80,stroke:#FF9800,stroke-width:2px
#     style MT5 fill:#AED581,stroke:#8BC34A,stroke-width:2px
# ```

# %% [markdown]
# ---
#
# ## 📋 Quick Reference: Model Seçim Matrisi
#
# <table style='width: 100%; border-collapse: collapse; margin: 30px 0; box-shadow: 0 4px 6px rgba(0,0,0,0.1);'>
#     <thead>
#         <tr style='background: linear-gradient(135deg, #667eea 0%, #764ba2 100%); color: white;'>
#             <th style='padding: 15px; text-align: left;'>🎯 Use Case</th>
#             <th style='padding: 15px; text-align: center;'>🥇 Best Model</th>
#             <th style='padding: 15px; text-align: center;'>🥈 Alternative</th>
#             <th style='padding: 15px; text-align: center;'>💡 Why?</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr style='background-color: #FFEBEE;'>
#             <td style='padding: 12px;'><b>📧 Email Summarization</b></td>
#             <td style='padding: 12px; text-align: center;'><b>T5-small</b></td>
#             <td style='padding: 12px; text-align: center;'>FLAN-T5</td>
#             <td style='padding: 12px; font-size: 13px;'>Short, general purpose, fast</td>
#         </tr>
#         <tr style='background-color: #E3F2FD;'>
#             <td style='padding: 12px;'><b>📱 Social Media Content</b></td>
#             <td style='padding: 12px; text-align: center;'><b>BART</b></td>
#             <td style='padding: 12px; text-align: center;'>DistilBART</td>
#             <td style='padding: 12px; font-size: 13px;'>Handles noisy text well</td>
#         </tr>
#         <tr style='background-color: #F3E5F5;'>
#             <td style='padding: 12px;'><b>📰 News Articles</b></td>
#             <td style='padding: 12px; text-align: center;'><b>Pegasus</b></td>
#             <td style='padding: 12px; text-align: center;'>BART</td>
#             <td style='padding: 12px; font-size: 13px;'>Trained specifically for news</td>
#         </tr>
#         <tr style='background-color: #FFF9C4;'>
#             <td style='padding: 12px;'><b>⚡ Real-time API</b></td>
#             <td style='padding: 12px; text-align: center;'><b>DistilBART</b></td>
#             <td style='padding: 12px; text-align: center;'>T5-small</td>
#             <td style='padding: 12px; font-size: 13px;'>70% faster, low latency</td>
#         </tr>
#         <tr style='background-color: #E8F5E9;'>
#             <td style='padding: 12px;'><b>🎯 Custom Instructions</b></td>
#             <td style='padding: 12px; text-align: center;'><b>FLAN-T5</b></td>
#             <td style='padding: 12px; text-align: center;'>T5</td>
#             <td style='padding: 12px; font-size: 13px;'>Natural language prompts</td>
#         </tr>
#         <tr style='background-color: #E1F5FE;'>
#             <td style='padding: 12px;'><b>⚖️ Legal Documents</b></td>
#             <td style='padding: 12px; text-align: center;'><b>LED</b></td>
#             <td style='padding: 12px; text-align: center;'>BigBird-Pegasus</td>
#             <td style='padding: 12px; font-size: 13px;'>16K token support</td>
#         </tr>
#         <tr style='background-color: #FFF3E0;'>
#             <td style='padding: 12px;'><b>🔬 Research Papers</b></td>
#             <td style='padding: 12px; text-align: center;'><b>BigBird-Pegasus</b></td>
#             <td style='padding: 12px; text-align: center;'>LED</td>
#             <td style='padding: 12px; font-size: 13px;'>Sparse attention + high quality</td>
#         </tr>
#         <tr style='background-color: #F1F8E9;'>
#             <td style='padding: 12px;'><b>🌍 Multilingual Support</b></td>
#             <td style='padding: 12px; text-align: center;'><b>mT5</b></td>
#             <td style='padding: 12px; text-align: center;'>-</td>
#             <td style='padding: 12px; font-size: 13px;'>101 languages, zero-shot</td>
#         </tr>
#         <tr style='background-color: #FCE4EC;'>
#             <td style='padding: 12px;'><b>💬 Customer Reviews</b></td>
#             <td style='padding: 12px; text-align: center;'><b>BART</b></td>
#             <td style='padding: 12px; text-align: center;'>mT5 (if multilingual)</td>
#             <td style='padding: 12px; font-size: 13px;'>Informal language handling</td>
#         </tr>
#         <tr style='background-color: #E0F2F1;'>
#             <td style='padding: 12px;'><b>📚 Book Chapters</b></td>
#             <td style='padding: 12px; text-align: center;'><b>LED</b></td>
#             <td style='padding: 12px; text-align: center;'>BigBird-Pegasus</td>
#             <td style='padding: 12px; font-size: 13px;'>Ultra-long context</td>
#         </tr>
#     </tbody>
# </table>

# %% [markdown]
# ---
#
# ## 🎴 Final Flashcard Set: Tüm Modeller Özet
#
# <div style='display: grid; grid-template-columns: repeat(2, 1fr); gap: 20px; margin: 30px 0;'>
#
# <div style='background: linear-gradient(135deg, #FFCDD2 0%, #EF9A9A 100%); padding: 20px; border-radius: 15px; border: 3px solid #EF5350;'>
#     <h4 style='color: #C62828; margin: 0 0 10px 0;'>🥇 T5 - The Versatile</h4>
#     <p style='font-size: 14px; line-height: 1.6; margin: 0;'>
#         <b>🎯 Motto:</b> "Everything is text-to-text"<br/>
#         <b>✅ Use:</b> General purpose, multi-task<br/>
#         <b>❌ Skip:</b> Very long docs, noisy text<br/>
#         <b>⭐ Rating:</b> 8.5/10 versatility
#     </p>
# </div>
#
# <div style='background: linear-gradient(135deg, #BBDEFB 0%, #90CAF9 100%); padding: 20px; border-radius: 15px; border: 3px solid #42A5F5;'>
#     <h4 style='color: #1565C0; margin: 0 0 10px 0;'>🥈 BART - The Denoiser</h4>
#     <p style='font-size: 14px; line-height: 1.6; margin: 0;'>
#         <b>🎯 Motto:</b> "Noise is my friend"<br/>
#         <b>✅ Use:</b> Social media, reviews<br/>
#         <b>❌ Skip:</b> Clean formal text<br/>
#         <b>⭐ Rating:</b> 8.7/10 noise handling
#     </p>
# </div>
#
# <div style='background: linear-gradient(135deg, #E1BEE7 0%, #CE93D8 100%); padding: 20px; border-radius: 15px; border: 3px solid #AB47BC;'>
#     <h4 style='color: #6A1B9A; margin: 0 0 10px 0;'>🥉 Pegasus - The News King</h4>
#     <p style='font-size: 14px; line-height: 1.6; margin: 0;'>
#         <b>🎯 Motto:</b> "Gap sentences for the win"<br/>
#         <b>✅ Use:</b> News, formal reports<br/>
#         <b>❌ Skip:</b> Conversations, dialogues<br/>
#         <b>⭐ Rating:</b> 9.0/10 ROUGE champion
#     </p>
# </div>
#
# <div style='background: linear-gradient(135deg, #FFF59D 0%, #FFF176 100%); padding: 20px; border-radius: 15px; border: 3px solid #FBC02D;'>
#     <h4 style='color: #F57F17; margin: 0 0 10px 0;'>⚡ DistilBART - The Speedster</h4>
#     <p style='font-size: 14px; line-height: 1.6; margin: 0;'>
#         <b>🎯 Motto:</b> "70% faster, 97% accuracy"<br/>
#         <b>✅ Use:</b> Real-time APIs, production<br/>
#         <b>❌ Skip:</b> When every % matters<br/>
#         <b>⭐ Rating:</b> 9.5/10 speed
#     </p>
# </div>
#
# <div style='background: linear-gradient(135deg, #C8E6C9 0%, #A5D6A7 100%); padding: 20px; border-radius: 15px; border: 3px solid #66BB6A;'>
#     <h4 style='color: #2E7D32; margin: 0 0 10px 0;'>🔥 FLAN-T5 - The Instructor</h4>
#     <p style='font-size: 14px; line-height: 1.6; margin: 0;'>
#         <b>🎯 Motto:</b> "Natural instructions master"<br/>
#         <b>✅ Use:</b> Flexible formats, zero-shot<br/>
#         <b>❌ Skip:</b> Long documents<br/>
#         <b>⭐ Rating:</b> 9.5/10 versatility
#     </p>
# </div>
#
# <div style='background: linear-gradient(135deg, #90CAF9 0%, #64B5F6 100%); padding: 20px; border-radius: 15px; border: 3px solid #42A5F5;'>
#     <h4 style='color: #0D47A1; margin: 0 0 10px 0;'>📜 LED - The Marathon Runner</h4>
#     <p style='font-size: 14px; line-height: 1.6; margin: 0;'>
#         <b>🎯 Motto:</b> "16K tokens? No problem"<br/>
#         <b>✅ Use:</b> Legal docs, books, theses<br/>
#         <b>❌ Skip:</b> Short texts (overkill)<br/>
#         <b>⭐ Rating:</b> 10/10 length support
#     </p>
# </div>
#
# <div style='background: linear-gradient(135deg, #FFCC80 0%, #FFB74D 100%); padding: 20px; border-radius: 15px; border: 3px solid #FF9800;'>
#     <h4 style='color: #E65100; margin: 0 0 10px 0;'>🦅 BigBird - The Sparse Genius</h4>
#     <p style='font-size: 14px; line-height: 1.6; margin: 0;'>
#         <b>🎯 Motto:</b> "Sparse = Smart"<br/>
#         <b>✅ Use:</b> Scientific papers, 2-8 pages<br/>
#         <b>❌ Skip:</b> Ultra-long docs (use LED)<br/>
#         <b>⭐ Rating:</b> 8.6/10 efficiency
#     </p>
# </div>
#
# <div style='background: linear-gradient(135deg, #AED581 0%, #9CCC65 100%); padding: 20px; border-radius: 15px; border: 3px solid #8BC34A;'>
#     <h4 style='color: #33691E; margin: 0 0 10px 0;'>🌍 mT5 - The Polyglot</h4>
#     <p style='font-size: 14px; line-height: 1.6; margin: 0;'>
#         <b>🎯 Motto:</b> "101 languages, one model"<br/>
#         <b>✅ Use:</b> Global products, multilingual<br/>
#         <b>❌ Skip:</b> English-only + max speed<br/>
#         <b>⭐ Rating:</b> 10/10 language coverage
#     </p>
# </div>
#
# </div>

# %% [markdown]
# ---
#
# ## 📊 Dataset Dünyasına Dalış: Özetleme için Veri Kaynakları
#
# <div style='background: linear-gradient(135deg, #E8F5E9 0%, #C8E6C9 100%); padding: 25px; border-radius: 15px; margin: 20px 0;'>
#     <h3 style='color: #2E7D32;'>🎯 Bu Bölümde Neler Yapacağız?</h3>
#     <ul style='font-size: 16px; line-height: 1.8;'>
#         <li>✅ <b>CNN/DailyMail</b>, <b>XSum</b>, <b>SAMSum</b> gibi popüler datasetleri keşfedeceğiz</li>
#         <li>✅ Dataset yapısını, istatistiklerini ve özelliklerini analiz edeceğiz</li>
#         <li>✅ Tokenization sürecini detaylı öğreneceğiz</li>
#         <li>✅ YBS senaryolarında kullanılabilecek örnekler göreceğiz</li>
#         <li>✅ Veri kalitesi ve preprocessing stratejilerini tartışacağız</li>
#     </ul>
# </div>
#
# ### 📚 Özetleme için Popüler Datasetler
#
# <table style='width: 100%; border-collapse: collapse; margin: 20px 0; box-shadow: 0 4px 8px rgba(0,0,0,0.1);'>
#     <tr style='background: linear-gradient(135deg, #667eea 0%, #764ba2 100%); color: white;'>
#         <th style='padding: 15px; text-align: left;'>Dataset</th>
#         <th style='padding: 15px; text-align: left;'>📊 Özellikler</th>
#         <th style='padding: 15px; text-align: left;'>🎯 Kullanım Alanı</th>
#         <th style='padding: 15px; text-align: left;'>💾 Boyut</th>
#     </tr>
#     <tr style='background-color: #FFF9C4;'>
#         <td style='padding: 15px;'><b>CNN/DailyMail</b></td>
#         <td style='padding: 15px;'>Haber makaleleri + çoklu cümle özet</td>
#         <td style='padding: 15px;'>Genel amaçlı haber özetleme</td>
#         <td style='padding: 15px;'>~300K makale</td>
#     </tr>
#     <tr style='background-color: #E1F5FE;'>
#         <td style='padding: 15px;'><b>XSum</b></td>
#         <td style='padding: 15px;'>BBC makaleleri + tek cümle özet</td>
#         <td style='padding: 15px;'>Kısa, öz özetler (abstractive)</td>
#         <td style='padding: 15px;'>~227K makale</td>
#     </tr>
#     <tr style='background-color: #F3E5F5;'>
#         <td style='padding: 15px;'><b>SAMSum</b></td>
#         <td style='padding: 15px;'>Messenger konuşmaları + özet</td>
#         <td style='padding: 15px;'>Dialog & chat özetleme</td>
#         <td style='padding: 15px;'>~16K konuşma</td>
#     </tr>
#     <tr style='background-color: #E8F5E9;'>
#         <td style='padding: 15px;'><b>Multi-News</b></td>
#         <td style='padding: 15px;'>Çoklu kaynaklı haberler</td>
#         <td style='padding: 15px;'>Multi-document summarization</td>
#         <td style='padding: 15px;'>~45K haber grubu</td>
#     </tr>
#     <tr style='background-color: #FFE0B2;'>
#         <td style='padding: 15px;'><b>arXiv/PubMed</b></td>
#         <td style='padding: 15px;'>Bilimsel makaleler + abstract</td>
#         <td style='padding: 15px;'>Akademik/teknik metin özetleme</td>
#         <td style='padding: 15px;'>~215K makale</td>
#     </tr>
# </table>

# %% [markdown]
# ### 🔄 Dataset Seçim Akış Diyagramı
#
# ```mermaid
# graph TD
#     A[🎯 Özetleme Projeniz] --> B{Kaynak Türü?}
#
#     B -->|Haber Makaleleri| C{Özet Uzunluğu?}
#     B -->|Konuşmalar/Dialog| H[💬 SAMSum]
#     B -->|Bilimsel Makale| I[🔬 arXiv/PubMed]
#     B -->|Çoklu Kaynak| J[📰 Multi-News]
#
#     C -->|Çoklu Cümle| D[📰 CNN/DailyMail]
#     C -->|Tek Cümle| E[🎯 XSum]
#
#     D --> K[🎨 YBS Use Case:<br/>Şirket Yıllık Raporları]
#     E --> L[🎨 YBS Use Case:<br/>Hızlı Haber Bültenleri]
#     H --> M[🎨 YBS Use Case:<br/>Müşteri Hizmetleri Chat]
#     I --> N[🎨 YBS Use Case:<br/>Araştırma Özeti Raporları]
#     J --> O[🎨 YBS Use Case:<br/>Pazar Analiz Raporları]
#
#     style A fill:#FFE5B4
#     style D fill:#B4E5FF
#     style E fill:#FFB4E5
#     style H fill:#E5FFB4
#     style I fill:#FFD4B4
#     style J fill:#D4B4FF
#     style K fill:#FFF9C4
#     style L fill:#F0F4C3
#     style M fill:#E1F5FE
#     style N fill:#F3E5F5
#     style O fill:#E8EAF6
# ```

# %% [markdown]
# ### 📖 Flashcard: Dataset Özellikleri
#
# <div style='display: grid; grid-template-columns: 1fr 1fr; gap: 20px; margin: 20px 0;'>
#
# <div style='background: linear-gradient(135deg, #FFF9C4 0%, #FFF59D 100%); padding: 20px; border-radius: 15px; box-shadow: 0 4px 8px rgba(0,0,0,0.2);'>
#     <h4 style='margin: 0; color: #F57F17; border-bottom: 2px solid #F57F17; padding-bottom: 10px;'>📰 CNN/DailyMail</h4>
#     <p style='margin: 15px 0 0 0; font-size: 15px;'>
#         <b>📊 Özet Uzunluğu:</b> 3-4 cümle<br>
#         <b>🎯 Tarz:</b> Bullet-point style<br>
#         <b>💡 İdeal Kullanım:</b> Haber özetleme, rapor özeti<br>
#         <b>⚡ Zorluk:</b> Orta (çoklu cümle üretme)
#     </p>
# </div>
#
# <div style='background: linear-gradient(135deg, #E1F5FE 0%, #B3E5FC 100%); padding: 20px; border-radius: 15px; box-shadow: 0 4px 8px rgba(0,0,0,0.2);'>
#     <h4 style='margin: 0; color: #01579B; border-bottom: 2px solid #01579B; padding-bottom: 10px;'>🎯 XSum</h4>
#     <p style='margin: 15px 0 0 0; font-size: 15px;'>
#         <b>📊 Özet Uzunluğu:</b> 1 cümle<br>
#         <b>🎯 Tarz:</b> Extreme abstractive<br>
#         <b>💡 İdeal Kullanım:</b> Headline generation, tweet özeti<br>
#         <b>⚡ Zorluk:</b> Yüksek (çok sıkı sıkıştırma)
#     </p>
# </div>
#
# <div style='background: linear-gradient(135deg, #F3E5F5 0%, #E1BEE7 100%); padding: 20px; border-radius: 15px; box-shadow: 0 4px 8px rgba(0,0,0,0.2);'>
#     <h4 style='margin: 0; color: #4A148C; border-bottom: 2px solid #4A148C; padding-bottom: 10px;'>💬 SAMSum</h4>
#     <p style='margin: 15px 0 0 0; font-size: 15px;'>
#         <b>📊 Özet Uzunluğu:</b> 2-3 cümle<br>
#         <b>🎯 Tarz:</b> Dialog özeti<br>
#         <b>💡 İdeal Kullanım:</b> Chat logs, meeting notes<br>
#         <b>⚡ Zorluk:</b> Orta (konuşma dinamikleri)
#     </p>
# </div>
#
# <div style='background: linear-gradient(135deg, #FFE0B2 0%, #FFCC80 100%); padding: 20px; border-radius: 15px; box-shadow: 0 4px 8px rgba(0,0,0,0.2);'>
#     <h4 style='margin: 0; color: #E65100; border-bottom: 2px solid #E65100; padding-bottom: 10px;'>🔬 arXiv/PubMed</h4>
#     <p style='margin: 15px 0 0 0; font-size: 15px;'>
#         <b>📊 Özet Uzunluğu:</b> Abstract (5-6 cümle)<br>
#         <b>🎯 Tarz:</b> Teknik/akademik<br>
#         <b>💡 İdeal Kullanım:</b> Bilimsel rapor özeti<br>
#         <b>⚡ Zorluk:</b> Yüksek (domain knowledge)
#     </p>
# </div>
#
# </div>

# %%
# 📥 Dataset Yükleme ve İlk İnceleme
# CNN/DailyMail datasetini yükleyip yapısını inceleyelim

print("📦 CNN/DailyMail dataset'i yükleniyor...")
print("⏳ İlk kez yükleniyorsa biraz zaman alabilir (cache'lenecek)\n")

# CNN/DailyMail dataset'ini yükle (HuggingFace Datasets kütüphanesi ile)
dataset = load_dataset("cnn_dailymail", "3.0.0")

print("✅ Dataset başarıyla yüklendi!\n")
print("="*70)
print("📊 DATASET YAPISI")
print("="*70)

# Dataset splits'lerini göster
for split_name, split_data in dataset.items():
    print(f"\n🔹 {split_name.upper()} Set:")
    print(f"   📈 Örnek Sayısı: {len(split_data):,}")

print("\n" + "="*70)
print("📋 VERİ ALANLARI")
print("="*70)
print(f"Alanlar: {dataset['train'].column_names}\n")

# İlk örneği göster
print("="*70)
print("📰 İLK ÖRNEK (train set'ten)")
print("="*70)

example = dataset['train'][0]

print(f"\n📝 ARTICLE (ilk 500 karakter):")
print("-"*70)
print(example['article'][:500] + "...")

print(f"\n\n✨ HIGHLIGHTS (Özet - tam hali):")
print("-"*70)
print(example['highlights'])

print(f"\n\n📏 İSTATİSTİKLER:")
print("-"*70)
print(f"   Article uzunluğu: {len(example['article'])} karakter")
print(f"   Özet uzunluğu: {len(example['highlights'])} karakter")
print(f"   Sıkıştırma oranı: {len(example['highlights'])/len(example['article'])*100:.1f}%")
# Out:
# 📦 CNN/DailyMail dataset'i yükleniyor...
# ⏳ İlk kez yükleniyorsa biraz zaman alabilir (cache'lenecek)
# README.md: 0.00B [00:00, ?B/s]
# 3.0.0/train-00000-of-00003.parquet:   0%|          | 0.00/257M [00:00<?, ?B/s]
# 3.0.0/train-00001-of-00003.parquet:   0%|          | 0.00/257M [00:00<?, ?B/s]
# 3.0.0/train-00002-of-00003.parquet:   0%|          | 0.00/259M [00:00<?, ?B/s]
# 3.0.0/validation-00000-of-00001.parquet:   0%|          | 0.00/34.7M [00:00<?, ?B/s]
# 3.0.0/test-00000-of-00001.parquet:   0%|          | 0.00/30.0M [00:00<?, ?B/s]
# ...
# Generating test split:   0%|          | 0/11490 [00:00<?, ? examples/s]
# ✅ Dataset başarıyla yüklendi!
#
# ...
# 📊 DATASET YAPISI
# ...
#
# 🔹 TRAIN Set:
#    📈 Örnek Sayısı: 287,113
#
# 🔹 VALIDATION Set:
#    📈 Örnek Sayısı: 13,368
#
# 🔹 TEST Set:
#    📈 Örnek Sayısı: 11,490
#
# ...
# 📋 VERİ ALANLARI
# ...
# Alanlar: ['article', 'highlights', 'id']
#
# ...
# 📰 İLK ÖRNEK (train set'ten)
# ...
#
# 📝 ARTICLE (ilk 500 karakter):
# ...

# %%
# 📊 Exploratory Data Analysis (EDA)
# Dataset'in istatistiksel özelliklerini görselleştirelim

import random
random.seed(42)

# Train set'ten 1000 örnek alalım (hızlı analiz için)
sample_size = 1000
train_sample = dataset['train'].shuffle(seed=42).select(range(sample_size))

print(f"🔬 {sample_size} örnek üzerinde EDA yapılıyor...\n")

# Uzunluk hesaplamaları
article_lengths = []
summary_lengths = []
compression_ratios = []

for example in train_sample:
    article_len = len(example['article'].split())
    summary_len = len(example['highlights'].split())

    article_lengths.append(article_len)
    summary_lengths.append(summary_len)
    compression_ratios.append(summary_len / article_len * 100)

# DataFrame oluştur
stats_df = pd.DataFrame({
    'Article Length (words)': article_lengths,
    'Summary Length (words)': summary_lengths,
    'Compression Ratio (%)': compression_ratios
})

print("📈 TEMEL İSTATİSTİKLER:")
print("="*70)
print(stats_df.describe().round(2))

# Görselleştirmeler - 3 subplot
fig, axes = plt.subplots(1, 3, figsize=(18, 5))
fig.suptitle('📊 CNN/DailyMail Dataset Analysis', fontsize=16, fontweight='bold', y=1.02)

# 1. Article uzunluk dağılımı
axes[0].hist(article_lengths, bins=50, color='#FFB6C1', edgecolor='white', alpha=0.8)
axes[0].axvline(np.mean(article_lengths), color='#FF1493', linestyle='--', linewidth=2, label=f'Mean: {np.mean(article_lengths):.0f}')
axes[0].set_xlabel('Article Length (words)', fontsize=12, fontweight='bold')
axes[0].set_ylabel('Frequency', fontsize=12, fontweight='bold')
axes[0].set_title('📰 Article Length Distribution', fontsize=13, fontweight='bold', pad=10)
axes[0].legend()
axes[0].grid(axis='y', alpha=0.3)

# 2. Summary uzunluk dağılımı
axes[1].hist(summary_lengths, bins=50, color='#B4E5FF', edgecolor='white', alpha=0.8)
axes[1].axvline(np.mean(summary_lengths), color='#1E90FF', linestyle='--', linewidth=2, label=f'Mean: {np.mean(summary_lengths):.0f}')
axes[1].set_xlabel('Summary Length (words)', fontsize=12, fontweight='bold')
axes[1].set_ylabel('Frequency', fontsize=12, fontweight='bold')
axes[1].set_title('✨ Summary Length Distribution', fontsize=13, fontweight='bold', pad=10)
axes[1].legend()
axes[1].grid(axis='y', alpha=0.3)

# 3. Compression ratio dağılımı
axes[2].hist(compression_ratios, bins=50, color='#C8E6C9', edgecolor='white', alpha=0.8)
axes[2].axvline(np.mean(compression_ratios), color='#2E7D32', linestyle='--', linewidth=2, label=f'Mean: {np.mean(compression_ratios):.1f}%')
axes[2].set_xlabel('Compression Ratio (%)', fontsize=12, fontweight='bold')
axes[2].set_ylabel('Frequency', fontsize=12, fontweight='bold')
axes[2].set_title('🎯 Compression Ratio Distribution', fontsize=13, fontweight='bold', pad=10)
axes[2].legend()
axes[2].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.show()

print("\n💡 İÇGÖRÜLER:")
print("="*70)
print(f"📰 Ortalama makale uzunluğu: {np.mean(article_lengths):.0f} kelime")
print(f"✨ Ortalama özet uzunluğu: {np.mean(summary_lengths):.0f} kelime")
print(f"🎯 Ortalama sıkıştırma oranı: {np.mean(compression_ratios):.1f}%")
print(f"📊 En uzun makale: {max(article_lengths)} kelime")
print(f"📊 En kısa makale: {min(article_lengths)} kelime")
# Out:
# 🔬 1000 örnek üzerinde EDA yapılıyor...
#
# 📈 TEMEL İSTATİSTİKLER:
# ...
#        Article Length (words)  Summary Length (words)  Compression Ratio (%)
# count                 1000.00                 1000.00                1000.00
# mean                   698.97                   51.15                   8.79
# std                    328.37                   19.78                   5.40
# min                     55.00                    8.00                   1.28
# 25%                    446.00                   39.00                   5.39
# 50%                    636.50                   48.00                   7.66
# 75%                    897.25                   59.00                  10.93
# max                   1900.00                  209.00                  80.00
# 💡 İÇGÖRÜLER:
# ...
# 📰 Ortalama makale uzunluğu: 699 kelime
# ✨ Ortalama özet uzunluğu: 51 kelime
# 🎯 Ortalama sıkıştırma oranı: 8.8%
# 📊 En uzun makale: 1900 kelime
# 📊 En kısa makale: 55 kelime

# %% [markdown]
# ---
#
# ## 🎨 YBS Perspektifi: Gerçek Dünya Özetleme Senaryoları
#
# <div style='background: linear-gradient(135deg, #FFF3E0 0%, #FFE0B2 100%); padding: 25px; border-radius: 15px; border-left: 6px solid #FF6F00;'>
#     <h3 style='color: #E65100;'>💼 İş Dünyası Uygulamaları</h3>
#     <p style='font-size: 16px;'>
#         YBS profesyonelleri için özetleme sistemleri <b>stratejik karar alma</b>, <b>zaman yönetimi</b> ve <b>bilgi akışı optimizasyonu</b> açısından kritiktir. Aşağıda gerçek senaryolar göreceğiz.
#     </p>
# </div>

# %%
# 💼 YBS Senaryosu 1: Şirket Yıllık Rapor Özeti
# Bir teknoloji şirketinin 50 sayfalık yıllık raporunu özetleyelim

ybs_scenario_1 = """
TechVision Inc. Annual Report 2025 - Financial Performance and Strategic Outlook

Executive Summary:
TechVision Inc. has demonstrated exceptional growth in fiscal year 2025, with revenue increasing
42% year-over-year to $2.8 billion. Our cloud computing division became the primary revenue driver,
contributing 58% of total revenue and showing a remarkable 67% growth compared to the previous year.
The company successfully expanded into three new international markets: Southeast Asia, Eastern Europe,
and Latin America, establishing 12 new offices and hiring 3,500 employees globally.

Financial Highlights:
Total revenue reached $2.8 billion, up from $1.97 billion in 2024. Gross profit margin improved
to 68%, compared to 64% in the previous year, driven by operational efficiency improvements and
strategic cost optimization initiatives. Net income increased to $580 million, representing a
21% profit margin. Operating cash flow stood at $720 million, providing strong liquidity for
future investments and R&D initiatives.

Product Innovation:
We launched five major product lines this year, including our flagship AI-powered analytics
platform "InsightPro" which gained 15,000 enterprise customers within six months. Our R&D
investment increased to $420 million (15% of revenue), focusing on artificial intelligence,
machine learning, and quantum computing research. The company filed 87 new patents this year,
bringing our total patent portfolio to 340.

Customer Success:
Customer satisfaction scores reached an all-time high of 94%, with Net Promoter Score (NPS)
improving from 62 to 71. Our customer base grew to 45,000 enterprise clients across 60 countries.
Customer retention rate improved to 96%, indicating strong product-market fit and exceptional
service quality. We onboarded 12 Fortune 500 companies as new customers this year.

Strategic Initiatives:
The company announced a $200 million strategic acquisition of DataFlow Systems, a leading data
integration platform, which will complement our existing product portfolio. We launched a
comprehensive sustainability program targeting carbon neutrality by 2027, investing $50 million
in renewable energy and green infrastructure. Our diversity and inclusion initiatives resulted
in 45% female representation in technical roles, up from 38% last year.

Future Outlook:
Looking ahead to 2026, we project revenue growth of 35-40%, driven by continued expansion in
cloud services and the full-year impact of our recent acquisition. We plan to invest $500 million
in R&D, with particular focus on generative AI and edge computing technologies. International
expansion will continue with planned entries into Middle East and African markets, targeting
$1 billion in international revenue by end of 2026.
"""

print("📊 SENARYO 1: ŞİRKET YILLIK RAPORU")
print("="*80)
print("\n📄 Orijinal Rapor Uzunluğu:")
print(f"   Kelime sayısı: {len(ybs_scenario_1.split())} kelime")
print(f"   Karakter sayısı: {len(ybs_scenario_1)} karakter")
print(f"   Yaklaşık okuma süresi: {len(ybs_scenario_1.split())//200} dakika")

print("\n📝 Rapor İçeriği (ilk 400 karakter):")
print("-"*80)
print(ybs_scenario_1[:400] + "...")

print("\n\n💡 İDEAL ÖZET ÇIKTISI (Manuel - Hedef):")
print("-"*80)
ideal_summary_1 = """
TechVision Inc. achieved 42% revenue growth to $2.8B in 2025, driven by cloud computing (58% of revenue).
The company expanded to three new markets, hired 3,500 employees, and launched AI platform InsightPro
with 15,000 customers. Net income reached $580M (21% margin) with 94% customer satisfaction.
Strategic moves include $200M DataFlow acquisition and $50M sustainability investment.
2026 outlook: 35-40% growth with $500M R&D focus on generative AI.
"""
print(ideal_summary_1.strip())

print(f"\n📏 Özet İstatistikleri:")
print(f"   Özet uzunluğu: {len(ideal_summary_1.split())} kelime")
print(f"   Sıkıştırma oranı: {len(ideal_summary_1.split())/len(ybs_scenario_1.split())*100:.1f}%")
print(f"   Zaman tasarrufu: %{100 - (len(ideal_summary_1.split())/len(ybs_scenario_1.split())*100):.0f}")

print("\n\n🎯 YBS DEĞERLENDİRMESİ:")
print("-"*80)
print("✅ Kritik finansal metrikleri koruyor (revenue, profit margin)")
print("✅ Stratejik kararları vurguluyor (acquisition, expansion)")
print("✅ Gelecek projeksiyonlarını içeriyor")
print("✅ Yöneticilerin 30 saniyede okuyup karar almasını sağlıyor")
print("✅ Key metrics'leri numeric olarak koruyor (precision önemli!)")
# Out:
# 📊 SENARYO 1: ŞİRKET YILLIK RAPORU
# ...
#
# 📄 Orijinal Rapor Uzunluğu:
#    Kelime sayısı: 392 kelime
#    Karakter sayısı: 2791 karakter
#    Yaklaşık okuma süresi: 1 dakika
#
# 📝 Rapor İçeriği (ilk 400 karakter):
# --------------------------------------------------------------------------------
#
# TechVision Inc. Annual Report 2025 - Financial Performance and Strategic Outlook
#
# Executive Summary:
# TechVision Inc. has demonstrated exceptional growth in fiscal year 2025, with revenue increasing
# 42% year-over-year to $2.8 billion. Our cloud computing division became the primary revenue driver,
# contributing 58% of total revenue and showing a remarkable 67% growth compared to the previous year...
#
#
# 💡 İDEAL ÖZET ÇIKTISI (Manuel - Hedef):
# --------------------------------------------------------------------------------
# TechVision Inc. achieved 42% revenue growth to $2.8B in 2025, driven by cloud computing (58% of revenue).
# ...

# %%
# 💬 YBS Senaryosu 2: Müşteri Hizmetleri Chat Özeti
# Bir e-ticaret sitesinin müşteri destek konuşmasını özeteleme

ybs_scenario_2 = """
Customer Service Chat Transcript - Case #CS-2025-10847
Date: January 15, 2026 | Agent: Sarah Martinez | Customer: John Peterson

[10:23 AM] John Peterson: Hello, I need help with my order #ORD-558842. I ordered a laptop
5 days ago and still haven't received any shipping updates.

[10:24 AM] Sarah Martinez: Good morning John! I apologize for the delay in communication.
Let me look up your order right away. Please give me a moment.

[10:25 AM] Sarah Martinez: Thank you for waiting. I can see your order for the Dell XPS 15
laptop placed on January 10th. I sincerely apologize - there was a processing delay due to
an inventory verification issue at our warehouse. Your order is now confirmed and has been
shipped this morning via FedEx Express.

[10:26 AM] John Peterson: Finally! But I needed this laptop by January 18th for a client
presentation. Will it arrive on time?

[10:27 AM] Sarah Martinez: I completely understand your concern, John. Let me check the
shipping details. Your package is scheduled to arrive on January 17th by end of day.
Here's your tracking number: FX-8847-2025-US. You can track it in real-time on the FedEx website.

[10:28 AM] John Peterson: That's cutting it close. What if it doesn't arrive on time?
I'm really stressed about this presentation.

[10:29 AM] Sarah Martinez: I completely understand your situation. To ensure you have peace
of mind, I've upgraded your shipping to FedEx Priority Overnight at no additional cost.
Your laptop will now arrive on January 16th before noon. I've also applied a $50 credit
to your account as an apology for the inconvenience and stress this has caused.

[10:30 AM] John Peterson: Wow, thank you so much! That really helps. I appreciate you
going the extra mile.

[10:31 AM] Sarah Martinez: You're very welcome, John! I've also sent you a confirmation
email with the updated delivery details and tracking information. Is there anything else
I can help you with today?

[10:32 AM] John Peterson: No, that's perfect. Thanks again for your help!

[10:32 AM] Sarah Martinez: My pleasure! We value your business and apologize again for
the inconvenience. Have a great day and good luck with your presentation!

[10:33 AM] Chat session ended. Resolution: Shipping upgraded, $50 credit applied,
customer satisfied.
"""

print("💬 SENARYO 2: MÜŞTERİ HİZMETLERİ CHAT ÖZETİ")
print("="*80)
print("\n📄 Orijinal Chat Uzunluğu:")
print(f"   Kelime sayısı: {len(ybs_scenario_2.split())} kelime")
print(f"   Süre: 10 dakika")
print(f"   Mesaj sayısı: 11 mesaj")

print("\n📝 Chat İçeriği (ilk 300 karakter):")
print("-"*80)
print(ybs_scenario_2[:300] + "...")

print("\n\n💡 İDEAL ÖZET ÇIKTISI (Manuel - Hedef):")
print("-"*80)
ideal_summary_2 = """
Customer John Peterson contacted support about delayed order #ORD-558842 (Dell XPS 15 laptop).
Order had processing delay, shipped 5 days late. Customer needed delivery by Jan 18 for presentation.
Agent Sarah upgraded shipping to Priority Overnight (arrives Jan 16) at no cost and applied $50
account credit. Issue resolved, customer satisfied.
"""
print(ideal_summary_2.strip())

print(f"\n📏 Özet İstatistikleri:")
print(f"   Özet uzunluğu: {len(ideal_summary_2.split())} kelime")
print(f"   Sıkıştırma oranı: {len(ideal_summary_2.split())/len(ybs_scenario_2.split())*100:.1f}%")

print("\n\n🎯 YBS DEĞERLENDİRMESİ:")
print("-"*80)
print("✅ Problem özeti net (order delay, customer deadline)")
print("✅ Çözüm adımları belirtilmiş (upgrade, credit)")
print("✅ Finansal etkiyi gösteriyor ($50 credit)")
print("✅ Müşteri memnuniyeti durumu korunuyor")
print("✅ Case ID ve key details preserve edilmiş (auditing için)")
print("💡 Kullanım: Supervisor review, training material, quality assurance")
# Out:
# 💬 SENARYO 2: MÜŞTERİ HİZMETLERİ CHAT ÖZETİ
# ...
#
# 📄 Orijinal Chat Uzunluğu:
#    Kelime sayısı: 375 kelime
#    Süre: 10 dakika
#    Mesaj sayısı: 11 mesaj
#
# 📝 Chat İçeriği (ilk 300 karakter):
# --------------------------------------------------------------------------------
#
# Customer Service Chat Transcript - Case #CS-2025-10847
# Date: January 15, 2026 | Agent: Sarah Martinez | Customer: John Peterson
#
# [10:23 AM] John Peterson: Hello, I need help with my order #ORD-558842. I ordered a laptop
# 5 days ago and still haven't received any shipping updates.
#
# [10:24 AM] Sarah ...
#
#
# 💡 İDEAL ÖZET ÇIKTISI (Manuel - Hedef):
# --------------------------------------------------------------------------------
# Customer John Peterson contacted support about delayed order #ORD-558842 (Dell XPS 15 laptop).
# Order had processing delay, shipped 5 days late. Customer needed delivery by Jan 18 for presentation.
# ...

# %% [markdown]
# ---
#
# ## 🔤 Tokenization: Metinden Model Diline Geçiş
#
# <div style='background: linear-gradient(135deg, #E8EAF6 0%, #C5CAE9 100%); padding: 25px; border-radius: 15px; margin: 20px 0;'>
#     <h3 style='color: #283593;'>🧩 Tokenization Nedir?</h3>
#     <p style='font-size: 16px; line-height: 1.8;'>
#         <b>Tokenization</b>, metni model'in anlayabileceği numeric token'lara dönüştürme işlemidir.
#         Her model farklı bir <span style='background-color: #FFEB3B; padding: 2px 8px; border-radius: 5px;'><b>vocabulary</b></span>
#         ve <span style='background-color: #C8E6C9; padding: 2px 8px; border-radius: 5px;'><b>tokenization stratejisi</b></span> kullanır.
#     </p>
# </div>
#
# ### 🔄 Tokenization Süreci Akış Diyagramı
#
# ```mermaid
# graph LR
#     A["📝 Raw Text<br/>'The AI revolutionizes business'"] --> B["🔪 Tokenizer<br/>(T5, BART, etc.)"]
#
#     B --> C["🧩 Token IDs<br/>[133, 6829, 9481, 1539, 268]"]
#
#     C --> D["🤖 Model<br/>(Encoder-Decoder)"]
#
#     D --> E["🧩 Output Token IDs<br/>[6829, 9814, 268, 1]"]
#
#     E --> F["🔄 Detokenizer"]
#
#     F --> G["✨ Summary<br/>'AI transforms business operations'"]
#
#     style A fill:#FFE5B4
#     style B fill:#FFB6C1
#     style C fill:#B4E5FF
#     style D fill:#C8E6C9
#     style E fill:#E1BEE7
#     style F fill:#FFCC80
#     style G fill:#FFF9C4
# ```
#
# ### 📊 Farklı Modellerin Tokenization Stratejileri
#
# <table style='width: 100%; border-collapse: collapse; margin: 20px 0;'>
#     <tr style='background-color: #667eea; color: white;'>
#         <th style='padding: 15px; text-align: left;'>Model</th>
#         <th style='padding: 15px; text-align: left;'>🔧 Tokenizer Tipi</th>
#         <th style='padding: 15px; text-align: left;'>📚 Vocab Size</th>
#         <th style='padding: 15px; text-align: left;'>💡 Özellik</th>
#     </tr>
#     <tr style='background-color: #FFF9C4;'>
#         <td style='padding: 12px;'><b>T5</b></td>
#         <td style='padding: 12px;'>SentencePiece (Unigram)</td>
#         <td style='padding: 12px;'>32,000</td>
#         <td style='padding: 12px;'>Subword tokenization, dil agnostik</td>
#     </tr>
#     <tr style='background-color: #E1F5FE;'>
#         <td style='padding: 12px;'><b>BART</b></td>
#         <td style='padding: 12px;'>Byte-Pair Encoding (BPE)</td>
#         <td style='padding: 12px;'>50,265</td>
#         <td style='padding: 12px;'>GPT-2 tokenizer, robust</td>
#     </tr>
#     <tr style='background-color: #F3E5F5;'>
#         <td style='padding: 12px;'><b>Pegasus</b></td>
#         <td style='padding: 12px;'>SentencePiece (Unigram)</td>
#         <td style='padding: 12px;'>96,103</td>
#         <td style='padding: 12px;'>Büyük vocab, rare words</td>
#     </tr>
#     <tr style='background-color: #E8F5E9;'>
#         <td style='padding: 12px;'><b>mT5</b></td>
#         <td style='padding: 12px;'>SentencePiece (Unigram)</td>
#         <td style='padding: 12px;'>250,000</td>
#         <td style='padding: 12px;'>101 dil desteği, multilingual</td>
#     </tr>
# </table>
#
# ### 🎯 Tokenization Örneği
#
# <div style='background-color: #F5F5F5; padding: 20px; border-left: 5px solid #4CAF50; border-radius: 10px; font-family: monospace;'>
#     <p style='margin: 0; color: #666;'><b>Input Text:</b></p>
#     <p style='margin: 5px 0 15px 0; font-size: 16px;'>"The company's quarterly revenue exceeded expectations."</p>
#
#     <p style='margin: 15px 0 0 0; color: #666;'><b>T5 Tokenization:</b></p>
#     <p style='margin: 5px 0 15px 0; font-size: 14px; color: #1976D2;'>["▁The", "▁company", "'", "s", "▁quarterly", "▁revenue", "▁exceeded", "▁expectations", "."]</p>
#
#     <p style='margin: 15px 0 0 0; color: #666;'><b>Token IDs:</b></p>
#     <p style='margin: 5px 0 15px 0; font-size: 14px; color: #E91E63;'>[37, 349, 31, 7, 8094, 3526, 14785, 4024, 5]</p>
#
#     <p style='margin: 15px 0 0 0; color: #666;'><b>Token Count:</b></p>
#     <p style='margin: 5px 0 0 0; font-size: 14px; color: #FF9800;'>9 tokens (vs 7 words)</p>
# </div>

# %%
# 🔤 Pratik Tokenization Örneği
# T5 tokenizer'ı yükleyip çeşitli metinleri tokenize edelim

print("📦 T5 tokenizer yükleniyor...")
tokenizer = AutoTokenizer.from_pretrained("t5-small")

print("✅ Tokenizer hazır!\n")
print("="*80)
print("🔍 TOKENIZATION ÖRNEKLERİ")
print("="*80)

# Örnek 1: Basit cümle
text1 = "The AI revolutionizes business operations."
tokens1 = tokenizer.tokenize(text1)
token_ids1 = tokenizer.encode(text1)

print("\n📝 Örnek 1: Basit İş Cümlesi")
print("-"*80)
print(f"Orijinal: {text1}")
print(f"Tokens: {tokens1}")
print(f"Token IDs: {token_ids1}")
print(f"Token sayısı: {len(tokens1)} (kelime sayısı: {len(text1.split())})")

# Örnek 2: Özel karakterler ve sayılar
text2 = "Q4 2025 revenue: $2.8B (↑42% YoY)"
tokens2 = tokenizer.tokenize(text2)
token_ids2 = tokenizer.encode(text2)

print("\n\n📝 Örnek 2: Finansal Data (Sayı ve Semboller)")
print("-"*80)
print(f"Orijinal: {text2}")
print(f"Tokens: {tokens2}")
print(f"Token IDs: {token_ids2}")
print(f"Token sayısı: {len(tokens2)}")
print("💡 Not: Özel karakterler ve sayılar ayrı tokenize edilir!")

# Örnek 3: Uzun teknik metin
text3 = "Implementation of machine learning algorithms requires comprehensive preprocessing."
tokens3 = tokenizer.tokenize(text3)
token_ids3 = tokenizer.encode(text3)

print("\n\n📝 Örnek 3: Teknik Terim İçeren Cümle")
print("-"*80)
print(f"Orijinal: {text3}")
print(f"Tokens: {tokens3}")
print(f"Token sayısı: {len(tokens3)} (kelime sayısı: {len(text3.split())})")

# Decode örneği - Token ID'lerden metne geri dönüş
decoded_text = tokenizer.decode(token_ids3)
print(f"\n🔄 Decoded (geri dönüştürülmüş): {decoded_text}")

# Özel tokenlar
print("\n\n" + "="*80)
print("🎯 ÖZEL TOKENLAR")
print("="*80)
print(f"PAD token: '{tokenizer.pad_token}' (ID: {tokenizer.pad_token_id})")
print(f"EOS token: '{tokenizer.eos_token}' (ID: {tokenizer.eos_token_id})")
print(f"UNK token: '{tokenizer.unk_token}' (ID: {tokenizer.unk_token_id})")
print(f"\nVocabulary size: {tokenizer.vocab_size:,}")

# Batch tokenization örneği
print("\n\n" + "="*80)
print("📦 BATCH TOKENIZATION (Birden fazla metin)")
print("="*80)

texts = [
    "AI transforms business intelligence.",
    "Data analytics drives strategic decisions.",
    "Cloud computing enables scalability."
]

# Padding ve truncation ile batch tokenize
encoded = tokenizer(
    texts,
    padding=True,  # Tüm sequence'leri aynı uzunluğa getir
    truncation=True,  # Max length'i aşanları kes
    max_length=20,  # Maximum token sayısı
    return_tensors="pt"  # PyTorch tensor olarak döndür
)

print(f"Input IDs shape: {encoded['input_ids'].shape}")
print(f"Attention Mask shape: {encoded['attention_mask'].shape}")
print("\n📊 Input IDs (ilk metin):")
print(encoded['input_ids'][0])
print("\n📊 Attention Mask (ilk metin):")
print(encoded['attention_mask'][0])
print("\n💡 Attention Mask: 1=gerçek token, 0=padding")
# Out:
# 📦 T5 tokenizer yükleniyor...
# tokenizer_config.json:   0%|          | 0.00/2.32k [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.39M [00:00<?, ?B/s]
# ✅ Tokenizer hazır!
#
# ...
# 🔍 TOKENIZATION ÖRNEKLERİ
# ...
#
# 📝 Örnek 1: Basit İş Cümlesi
# --------------------------------------------------------------------------------
# Orijinal: The AI revolutionizes business operations.
# Tokens: ['▁The', '▁AI', '▁revolution', 'ize', 's', '▁business', '▁operations', '.']
# Token IDs: [37, 7833, 9481, 1737, 7, 268, 2673, 5, 1]
# Token sayısı: 8 (kelime sayısı: 5)
#
#
# 📝 Örnek 2: Finansal Data (Sayı ve Semboller)
# --------------------------------------------------------------------------------
# Orijinal: Q4 2025 revenue: $2.8B (↑42% YoY)
# Tokens: ['▁Q', '4', '▁20', '25', '▁revenue', ':', '▁$', '2.8', 'B', '▁(', '↑', '4', '2%', '▁Yo', 'Y', ')']
# ...

# %% [markdown]
# ### 📖 Flashcard: Tokenization Konseptleri
#
# <div style='display: grid; grid-template-columns: 1fr 1fr 1fr; gap: 15px; margin: 20px 0;'>
#
# <div style='background: linear-gradient(135deg, #FFE5E5 0%, #FFB6C1 100%); padding: 18px; border-radius: 12px; box-shadow: 0 3px 6px rgba(0,0,0,0.15);'>
#     <h4 style='margin: 0; color: #C62828; border-bottom: 2px solid #C62828; padding-bottom: 8px;'>🔪 Subword Tokenization</h4>
#     <p style='margin: 12px 0 0 0; font-size: 14px; line-height: 1.6;'>
#         <b>Ne:</b> Kelimeleri daha küçük parçalara böler<br>
#         <b>Örnek:</b> "unhappiness" → ["un", "happiness"]<br>
#         <b>Avantaj:</b> OOV (out-of-vocabulary) problemini çözer<br>
#         <b>Kullanım:</b> T5, BART, Pegasus
#     </p>
# </div>
#
# <div style='background: linear-gradient(135deg, #E1F5FE 0%, #B3E5FC 100%); padding: 18px; border-radius: 12px; box-shadow: 0 3px 6px rgba(0,0,0,0.15);'>
#     <h4 style='margin: 0; color: #01579B; border-bottom: 2px solid #01579B; padding-bottom: 8px;'>📦 Padding</h4>
#     <p style='margin: 12px 0 0 0; font-size: 14px; line-height: 1.6;'>
#         <b>Ne:</b> Kısa sequence'leri aynı uzunluğa getirir<br>
#         <b>Token:</b> [PAD] veya 0<br>
#         <b>Neden:</b> Batch processing için gerekli<br>
#         <b>Attention Mask:</b> Padding'i görmezden gel
#     </p>
# </div>
#
# <div style='background: linear-gradient(135deg, #F3E5F5 0%, #E1BEE7 100%); padding: 18px; border-radius: 12px; box-shadow: 0 3px 6px rgba(0,0,0,0.15);'>
#     <h4 style='margin: 0; color: #6A1B9A; border-bottom: 2px solid #6A1B9A; padding-bottom: 8px;'>✂️ Truncation</h4>
#     <p style='margin: 12px 0 0 0; font-size: 14px; line-height: 1.6;'>
#         <b>Ne:</b> Uzun metinleri max_length'e keser<br>
#         <b>Neden:</b> Model'in token limiti<br>
#         <b>Strateji:</b> longest_first, only_first<br>
#         <b>Risk:</b> Bilgi kaybı (dikkatli kullan!)
#     </p>
# </div>
#
# <div style='background: linear-gradient(135deg, #FFF9C4 0%, #FFF59D 100%); padding: 18px; border-radius: 12px; box-shadow: 0 3px 6px rgba(0,0,0,0.15);'>
#     <h4 style='margin: 0; color: #F57F17; border-bottom: 2px solid #F57F17; padding-bottom: 8px;'>🎯 Special Tokens</h4>
#     <p style='margin: 12px 0 0 0; font-size: 14px; line-height: 1.6;'>
#         <b>[PAD]:</b> Padding token<br>
#         <b>[CLS]:</b> Classification token<br>
#         <b>[SEP]:</b> Separator token<br>
#         <b>[EOS]:</b> End of sequence<br>
#         <b>[UNK]:</b> Unknown token
#     </p>
# </div>
#
# <div style='background: linear-gradient(135deg, #E8F5E9 0%, #C8E6C9 100%); padding: 18px; border-radius: 12px; box-shadow: 0 3px 6px rgba(0,0,0,0.15);'>
#     <h4 style='margin: 0; color: #2E7D32; border-bottom: 2px solid #2E7D32; padding-bottom: 8px;'>🔢 Token IDs</h4>
#     <p style='margin: 12px 0 0 0; font-size: 14px; line-height: 1.6;'>
#         <b>Ne:</b> Her token'ın numeric ID'si<br>
#         <b>Örnek:</b> "hello" → 7592<br>
#         <b>Vocab:</b> ID → Token mapping dictionary<br>
#         <b>Decode:</b> IDs'den tekrar metne dönüş
#     </p>
# </div>
#
# <div style='background: linear-gradient(135deg, #FFE0B2 0%, #FFCC80 100%); padding: 18px; border-radius: 12px; box-shadow: 0 3px 6px rgba(0,0,0,0.15);'>
#     <h4 style='margin: 0; color: #E65100; border-bottom: 2px solid #E65100; padding-bottom: 8px;'>⚡ Attention Mask</h4>
#     <p style='margin: 12px 0 0 0; font-size: 14px; line-height: 1.6;'>
#         <b>Ne:</b> Hangi token'lara dikkat edilecek<br>
#         <b>1:</b> Gerçek token (attend)<br>
#         <b>0:</b> Padding token (ignore)<br>
#         <b>Amaç:</b> Model padding'e odaklanmasın
#     </p>
# </div>
#
# </div>

# %%
import random
random.seed(42)

# 🏗️ Dataset Preprocessing Pipeline
# CNN/DailyMail dataseti için tokenization ve preprocessing

print("🏗️ PREPROCESSING PIPELINE OLUŞTURULUYOR")
print("="*80)

# Küçük bir subset ile çalışalım (hızlı test için)
small_dataset = dataset['train'].select(range(1000))

print(f"📦 Çalışılan dataset boyutu: {len(small_dataset)} örnek\n")

# Preprocessing fonksiyonu
def preprocess_function(examples):
    """
    Her article ve highlights çiftini tokenize eder.

    Args:
        examples: Batch of articles and highlights

    Returns:
        Tokenized inputs and labels
    """
    # Input: Article'ları tokenize et
    # T5 için özel prefix kullanabiliriz: "summarize: "
    inputs = ["summarize: " + doc for doc in examples['article']]

    # Tokenize inputs
    model_inputs = tokenizer(
        inputs,
        max_length=512,  # Maksimum input uzunluğu
        truncation=True,  # Uzun metinleri kes
        padding='max_length',  # Tüm sequence'leri aynı uzunluğa getir
    )

    # Target: Highlights'ları tokenize et
    # Ensure inputs are list of strings to avoid type errors
    labels = tokenizer(
        [str(h) for h in examples['highlights']],
        max_length=128,  # Özet max 128 token
        truncation=True,
        padding='max_length',
    )

    # Labels'ı model_inputs'a ekle
    model_inputs['labels'] = labels['input_ids']

    return model_inputs

print("🔧 Preprocessing fonksiyonu tanımlandı")
print("\n📋 Fonksiyon özellikleri:")
print("   • Input prefix: 'summarize: ' (T5 task formatı)")
print("   • Max input length: 512 tokens")
print("   • Max output length: 128 tokens")
print("   • Padding: max_length (batch efficiency)")
print("   • Truncation: Aktif (uzun metinler kesilir)")

# Preprocessing uygula (ilk 5 örnek - demo)
print(f"\n\n{'='*80}")
print("🧪 İLK 5 ÖRNEK ÜZERİNDE TEST")
print("="*80)

test_batch = small_dataset.select(range(5))
processed_batch = preprocess_function(test_batch)

print(f"\n✅ Preprocessing tamamlandı!")
print(f"\n📊 Processed Batch Yapısı:")
print(f"   Keys: {processed_batch.keys()}")
print(f"   Input IDs shape: {len(processed_batch['input_ids'])} x {len(processed_batch['input_ids'][0])}")
print(f"   Attention Mask shape: {len(processed_batch['attention_mask'])} x {len(processed_batch['attention_mask'][0])}")
print(f"   Labels shape: {len(processed_batch['labels'])} x {len(processed_batch['labels'][0])}")

# İlk örneği detaylı inceleyelim
print(f"\n\n{'='*80}")
print("🔍 İLK ÖRNEK DETAYLI ANALIZ")
print("="*80)

print(f"\n📝 Orijinal Article (ilk 200 karakter):")
print(test_batch['article'][0][:200] + "...")

print(f"\n✨ Orijinal Highlights:")
print(test_batch['highlights'][0])

print(f"\n🔢 Tokenized Input (ilk 20 token ID):")
print(processed_batch['input_ids'][0][:20])

print(f"\n🔢 Tokenized Labels (ilk 20 token ID):")
print(processed_batch['labels'][0][:20])

# Decode ederek kontrol edelim
decoded_input = tokenizer.decode(processed_batch['input_ids'][0], skip_special_tokens=True)
decoded_label = tokenizer.decode(processed_batch['labels'][0], skip_special_tokens=True)

print(f"\n🔄 Decoded Input (ilk 100 karakter):")
print(decoded_input[:100] + "...")

print(f"\n🔄 Decoded Label:")
print(decoded_label)

print(f"\n\n✅ Preprocessing pipeline başarıyla test edildi!")
print("💡 Artık tüm dataset'e uygulayabiliriz (training sırasında yapılacak)")
# Out:
# 🏗️ PREPROCESSING PIPELINE OLUŞTURULUYOR
# ...
# 📦 Çalışılan dataset boyutu: 1000 örnek
#
# 🔧 Preprocessing fonksiyonu tanımlandı
#
# 📋 Fonksiyon özellikleri:
#    • Input prefix: 'summarize: ' (T5 task formatı)
#    • Max input length: 512 tokens
#    • Max output length: 128 tokens
#    • Padding: max_length (batch efficiency)
#    • Truncation: Aktif (uzun metinler kesilir)
#
#
# ...
# 🧪 İLK 5 ÖRNEK ÜZERİNDE TEST
# ...
#
# ✅ Preprocessing tamamlandı!
#
# 📊 Processed Batch Yapısı:
# ...

# %% [markdown]
# ---
#
# ## 🎯 Dataset Hazırlama: Özet ve Önemli Noktalar
#
# <div style='background: linear-gradient(135deg, #E8F5E9 0%, #C8E6C9 100%); padding: 30px; border-radius: 15px; margin: 20px 0; border-left: 6px solid #2E7D32;'>
#     <h3 style='color: #1B5E20; margin-top: 0;'>✅ Bu Bölümde Tamamladıklarımız</h3>
#
# <table style='width: 100%; background-color: white; border-radius: 10px; padding: 15px;'>
#     <tr>
#         <td style='width: 50px; font-size: 30px;'>📚</td>
#         <td>
#             <b>Dataset Seçimi ve Yükleme</b><br>
#             <span style='color: #666;'>CNN/DailyMail, XSum, SAMSum gibi popüler datasetleri tanıdık</span>
#         </td>
#     </tr>
#     <tr>
#         <td style='width: 50px; font-size: 30px;'>📊</td>
#         <td>
#             <b>Exploratory Data Analysis (EDA)</b><br>
#             <span style='color: #666;'>Dataset istatistiklerini görselleştirdik, uzunluk dağılımlarını analiz ettik</span>
#         </td>
#     </tr>
#     <tr>
#         <td style='width: 50px; font-size: 30px;'>💼</td>
#         <td>
#             <b>YBS Senaryoları</b><br>
#             <span style='color: #666;'>Şirket raporları ve müşteri chat özetleme örnekleri gördük</span>
#         </td>
#     </tr>
#     <tr>
#         <td style='width: 50px; font-size: 30px;'>🔤</td>
#         <td>
#             <b>Tokenization Derinlemesine</b><br>
#             <span style='color: #666;'>Subword tokenization, padding, truncation, special tokens öğrendik</span>
#         </td>
#     </tr>
#     <tr>
#         <td style='width: 50px; font-size: 30px;'>🏗️</td>
#         <td>
#             <b>Preprocessing Pipeline</b><br>
#             <span style='color: #666;'>Article ve highlights'ları tokenize edip model'e hazır hale getirdik</span>
#         </td>
#     </tr>
# </table>
#
# </div>
#
# ### 🔑 Kritik Öğrenme Noktaları
#
# <div style='display: grid; grid-template-columns: 1fr 1fr; gap: 20px; margin: 20px 0;'>
#
# <div style='background-color: #FFF9C4; padding: 20px; border-radius: 12px; border: 2px solid #F57F17;'>
#     <h4 style='color: #F57F17; margin-top: 0;'>⚠️ Dikkat Edilmesi Gerekenler</h4>
#     <ul style='line-height: 1.8; margin: 10px 0;'>
#         <li><b>Max Length Seçimi:</b> Input 512, output 128 genelde ideal</li>
#         <li><b>Truncation Risk:</b> Uzun metinler kesilince bilgi kaybı olur</li>
#         <li><b>Padding Overhead:</b> Kısa metinler için verimsizlik yaratır</li>
#         <li><b>Vocabulary Mismatch:</b> Her model farklı tokenizer!</li>
#     </ul>
# </div>
#
# <div style='background-color: #E1F5FE; padding: 20px; border-radius: 12px; border: 2px solid #0277BD;'>
#     <h4 style='color: #01579B; margin-top: 0;'>💡 Best Practices</h4>
#     <ul style='line-height: 1.8; margin: 10px 0;'>
#         <li><b>Dynamic Padding:</b> Training'de batch içi padding tercih et</li>
#         <li><b>Dataset Sampling:</b> Büyük dataset'lerde subset kullan</li>
#         <li><b>Tokenizer Versiyonu:</b> Model ile aynı versiyonu kullan</li>
#         <li><b>Validation:</b> Tokenize sonrası decode edip kontrol et</li>
#     </ul>
# </div>
#
# </div>
#
# ### 📈 Sırada Ne Var?
#
# <div style='background: linear-gradient(135deg, #F3E5F5 0%, #E1BEE7 100%); padding: 25px; border-radius: 15px; margin: 20px 0;'>
#     <h3 style='color: #4A148C;'>🚀 Bir Sonraki Adım: İlk Model Fine-Tuning</h3>
#     <p style='font-size: 16px; line-height: 1.8;'>
#         Artık dataset'imizi tanıdık ve preprocessing pipeline'ımız hazır. Sırada en heyecanlı kısım:
#         <span style='background-color: #FFEB3B; padding: 3px 8px; border-radius: 5px;'><b>T5 modelini fine-tune etmek!</b></span>
#     </p>
#     <p style='font-size: 15px; margin-top: 15px;'>
#         ✨ Training loop, loss fonksiyonu, evaluation metrikleri<br>
#         ✨ Hyperparameter tuning ve optimization<br>
#         ✨ Model checkpoint'leri ve best practices<br>
#         ✨ YBS perspektifinden cost-benefit analizi
#     </p>
# </div>

# %% [markdown]
# ---
#
# # 🎯 ADIM 4: T5 Model Fine-Tuning
#
# <div style='background: linear-gradient(135deg, #667eea 0%, #764ba2 100%); padding: 30px; border-radius: 15px; color: white; text-align: center; margin: 20px 0;'>
#     <h2 style='margin: 0; font-size: 28px;'>🚀 İlk Modelimizi Eğitelim: T5-Small</h2>
#     <p style='font-size: 18px; margin: 15px 0 0 0;'><b>From Zero to Hero:</b> Sıfırdan profesyonel fine-tuning süreci</p>
# </div>
#
# <div style='background-color: #FFF5E6; padding: 25px; border-left: 6px solid #FF9800; border-radius: 10px; margin: 20px 0;'>
#     <h3 style='color: #E65100;'>🎯 Bu Adımda Öğrenecekleriniz:</h3>
#     <ul style='font-size: 16px; line-height: 1.8;'>
#         <li>✅ T5 modelini yükleyip mimariyi anlayacağız</li>
#         <li>✅ Training hyperparameter'larını optimize edeceğiz</li>
#         <li>✅ Seq2SeqTrainer ile training loop oluşturacağız</li>
#         <li>✅ Loss fonksiyonu ve gradient descent'i izleyeceğiz</li>
#         <li>✅ Model checkpoint'lerini kaydedeceğiz</li>
#         <li>✅ Validation set'te performans ölçeceğiz</li>
#         <li>✅ YBS perspektifinden maliyet-fayda analizi yapacağız</li>
#     </ul>
# </div>

# %% [markdown]
# ## 🏗️ T5 Model Mimarisi: Derin Bakış
#
# <div style='background: linear-gradient(135deg, #E3F2FD 0%, #BBDEFB 100%); padding: 25px; border-radius: 15px; margin: 20px 0;'>
#     <h3 style='color: #1565C0;'>🤖 T5 (Text-to-Text Transfer Transformer)</h3>
#     <p style='font-size: 16px; line-height: 1.8;'>
#         Google tarafından 2020'de geliştirildi. <b>Her NLP görevini text-to-text problemi</b> olarak ele alır.
#         <br><br>
#         <span style='background-color: #FFEB3B; padding: 3px 8px; border-radius: 5px;'><b>Örnek:</b></span>
#         <br>
#         <code>Input: "summarize: Article text..."</code>
#         <br>
#         <code>Output: "Summary text..."</code>
#     </p>
# </div>
#
# ### 🔄 T5 Architecture Flow
#
# ```mermaid
# graph TB
#     A["📝 Input Text<br/>'summarize: The company...'"] --> B["🔤 Tokenizer<br/>SentencePiece"]
#
#     B --> C["🧩 Token Embeddings<br/>(512-dim vectors)"]
#
#     C --> D["🔷 Encoder<br/>(12 layers, Self-Attention)"]
#
#     D --> E["💾 Context Vectors<br/>(Rich representations)"]
#
#     E --> F["🔶 Decoder<br/>(12 layers, Cross-Attention)"]
#
#     F --> G["🎯 Output Logits<br/>(Vocab size: 32K)"]
#
#     G --> H["📊 Softmax<br/>(Probability distribution)"]
#
#     H --> I["✨ Generated Summary<br/>'The company achieved...'"]
#
#     style A fill:#FFE5B4
#     style B fill:#FFB6C1
#     style C fill:#B4E5FF
#     style D fill:#C8E6C9
#     style E fill:#FFF9C4
#     style F fill:#E1BEE7
#     style G fill:#FFCC80
#     style H fill:#F0F4C3
#     style I fill:#C5CAE9
# ```
#
# ### 📊 T5 Model Varyantları
#
# <table style='width: 100%; border-collapse: collapse; margin: 20px 0;'>
#     <tr style='background-color: #667eea; color: white;'>
#         <th style='padding: 15px; text-align: left;'>Model</th>
#         <th style='padding: 15px; text-align: center;'>Parametre</th>
#         <th style='padding: 15px; text-align: center;'>Encoder Layers</th>
#         <th style='padding: 15px; text-align: center;'>Hidden Size</th>
#         <th style='padding: 15px; text-align: left;'>💡 Kullanım Senaryosu</th>
#     </tr>
#     <tr style='background-color: #FFF9C4;'>
#         <td style='padding: 12px;'><b>t5-small</b></td>
#         <td style='padding: 12px; text-align: center;'>60M</td>
#         <td style='padding: 12px; text-align: center;'>6</td>
#         <td style='padding: 12px; text-align: center;'>512</td>
#         <td style='padding: 12px;'>Prototype, hızlı test, laptop</td>
#     </tr>
#     <tr style='background-color: #E1F5FE;'>
#         <td style='padding: 12px;'><b>t5-base</b></td>
#         <td style='padding: 12px; text-align: center;'>220M</td>
#         <td style='padding: 12px; text-align: center;'>12</td>
#         <td style='padding: 12px; text-align: center;'>768</td>
#         <td style='padding: 12px;'>Production, balanced performance</td>
#     </tr>
#     <tr style='background-color: #F3E5F5;'>
#         <td style='padding: 12px;'><b>t5-large</b></td>
#         <td style='padding: 12px; text-align: center;'>770M</td>
#         <td style='padding: 12px; text-align: center;'>24</td>
#         <td style='padding: 12px; text-align: center;'>1024</td>
#         <td style='padding: 12px;'>High-quality results, GPU gerekli</td>
#     </tr>
#     <tr style='background-color: #E8F5E9;'>
#         <td style='padding: 12px;'><b>t5-3b</b></td>
#         <td style='padding: 12px; text-align: center;'>3B</td>
#         <td style='padding: 12px; text-align: center;'>24</td>
#         <td style='padding: 12px; text-align: center;'>1024</td>
#         <td style='padding: 12px;'>Enterprise, multi-GPU setup</td>
#     </tr>
#     <tr style='background-color: #FFE0B2;'>
#         <td style='padding: 12px;'><b>t5-11b</b></td>
#         <td style='padding: 12px; text-align: center;'>11B</td>
#         <td style='padding: 12px; text-align: center;'>24</td>
#         <td style='padding: 12px; text-align: center;'>1024</td>
#         <td style='padding: 12px;'>Research, SOTA performance</td>
#     </tr>
# </table>
#
# <div style='background-color: #E8F5E9; padding: 20px; border-radius: 10px; border-left: 5px solid #4CAF50; margin: 20px 0;'>
#     <p style='margin: 0; font-size: 16px;'>
#         <b>💡 Bu Tutorial'da:</b> <code>t5-small</code> kullanacağız (60M parametre) -
#         Google Colab ücretsiz tier'da rahatça çalışır ve öğrenme amaçlı mükemmeldir!
#     </p>
# </div>

# %%
# 🤖 T5-Small Modelini Yükleyelim
# Pre-trained checkpoint'ten başlayıp fine-tune edeceğiz

print("🚀 T5-SMALL MODELİNİ YÜKLÜYORUZ")
print("="*80)
print("⏳ İlk kez yükleniyorsa biraz zaman alabilir (model ~250MB)\n")

# Model ve tokenizer'ı yükle
model_name = "t5-small"

print(f"📦 Model adı: {model_name}")
print(f"🔗 HuggingFace Hub'dan indiriliyor...\n")

# Tokenizer'ı yükle (eğer daha önce yüklemediyseniz)
tokenizer = AutoTokenizer.from_pretrained(model_name)

# Model'i yükle
model = AutoModelForSeq2SeqLM.from_pretrained(model_name)

print("✅ Model ve tokenizer başarıyla yüklendi!\n")

# Model bilgilerini görüntüle
print("="*80)
print("📊 MODEL BİLGİLERİ")
print("="*80)

# Parametre sayısını hesapla
total_params = sum(p.numel() for p in model.parameters())
trainable_params = sum(p.numel() for p in model.parameters() if p.requires_grad)

print(f"\n🔢 Toplam Parametre: {total_params:,}")
print(f"🎯 Eğitilebilir Parametre: {trainable_params:,}")
print(f"📦 Model Boyutu: ~{total_params * 4 / 1024**2:.1f} MB (FP32)")

# Model architecture özeti
print(f"\n🏗️ MİMARİ ÖZETİ:")
print(f"   Encoder Layers: {model.config.num_layers}")
print(f"   Decoder Layers: {model.config.num_decoder_layers}")
print(f"   Hidden Size: {model.config.d_model}")
print(f"   Attention Heads: {model.config.num_heads}")
print(f"   Feed-Forward Dim: {model.config.d_ff}")
print(f"   Vocabulary Size: {model.config.vocab_size:,}")
print(f"   Max Position Embeddings: {model.config.n_positions if hasattr(model.config, 'n_positions') else 'N/A'}")

# GPU kontrolü
if torch.cuda.is_available():
    device = torch.device("cuda")
    gpu_name = torch.cuda.get_device_name(0)
    print(f"\n🔥 GPU TESPIT EDİLDİ!")
    print(f"   GPU: {gpu_name}")
    print(f"   VRAM: {torch.cuda.get_device_properties(0).total_memory / 1024**3:.1f} GB")

    # Model'i GPU'ya taşı
    model = model.to(device)
    print(f"   ✅ Model GPU'ya taşındı!")
else:
    device = torch.device("cpu")
    print(f"\n💻 CPU kullanılıyor (GPU bulunamadı)")
    print(f"   ⚠️ Training yavaş olacak, küçük batch size kullanın!")

print(f"\n🎯 Device: {device}")

# Model moduna ayarla
model.train()
print(f"\n✅ Model training modunda!")

print("\n" + "="*80)
print("💡 HIZLI BİLGİ")
print("="*80)
print("• T5, encoder-decoder architecture kullanır")
print("• Self-attention (encoder) + Cross-attention (decoder)")
print("• Pre-trained on C4 dataset (750GB text)")
print("• Fine-tuning ile domain-specific görevlere uyarlanır")
print("• 'summarize:' prefix'i ile task'ı belirtiyoruz")
# Out:
# 🚀 T5-SMALL MODELİNİ YÜKLÜYORUZ
# ...
# ⏳ İlk kez yükleniyorsa biraz zaman alabilir (model ~250MB)
#
# 📦 Model adı: t5-small
# 🔗 HuggingFace Hub'dan indiriliyor...
# config.json:   0%|          | 0.00/1.21k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/242M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]
# ✅ Model ve tokenizer başarıyla yüklendi!
#
# ...
# 📊 MODEL BİLGİLERİ
# ...
#
# 🔢 Toplam Parametre: 60,506,624
# 🎯 Eğitilebilir Parametre: 60,506,624
# 📦 Model Boyutu: ~230.8 MB (FP32)
#
# 🏗️ MİMARİ ÖZETİ:
#    Encoder Layers: 6
#    Decoder Layers: 6
#    Hidden Size: 512
#    Attention Heads: 8
#    Feed-Forward Dim: 2048
#    Vocabulary Size: 32,128
#    Max Position Embeddings: 512
#
# 🔥 GPU TESPIT EDİLDİ!
#    GPU: NVIDIA A100-SXM4-80GB
#    VRAM: 79.3 GB
#    ✅ Model GPU'ya taşındı!
#
# 🎯 Device: cuda
#
# ✅ Model training modunda!
#
# ...
# 💡 HIZLI BİLGİ
# ...
# • T5, encoder-decoder architecture kullanır
# ...

# %% [markdown]
# ---
#
# ## ⚙️ Training Hyperparameters: Doğru Ayarlar
#
# <div style='background: linear-gradient(135deg, #FFF3E0 0%, #FFE0B2 100%); padding: 25px; border-radius: 15px; margin: 20px 0;'>
#     <h3 style='color: #E65100;'>🎛️ Hyperparameter Nedir?</h3>
#     <p style='font-size: 16px; line-height: 1.8;'>
#         Model'in <b>öğrenme sürecini kontrol eden parametrelerdir</b>. Model ağırlıklarından farklı olarak,
#         training öncesinde manuel olarak ayarlanır ve training sırasında güncellenmez.
#     </p>
# </div>
#
# ### 📋 Kritik Hyperparameter'lar
#
# <table style='width: 100%; border-collapse: collapse; margin: 20px 0; box-shadow: 0 4px 8px rgba(0,0,0,0.1);'>
#     <tr style='background: linear-gradient(135deg, #667eea 0%, #764ba2 100%); color: white;'>
#         <th style='padding: 15px; text-align: left;'>Parameter</th>
#         <th style='padding: 15px; text-align: center;'>Değer Aralığı</th>
#         <th style='padding: 15px; text-align: left;'>💡 Etki & Önemi</th>
#     </tr>
#     <tr style='background-color: #FFF9C4;'>
#         <td style='padding: 12px;'><b>Learning Rate</b></td>
#         <td style='padding: 12px; text-align: center;'>1e-5 to 5e-4</td>
#         <td style='padding: 12px;'>
#             <b>En kritik!</b> Çok yüksek: diverge, çok düşük: yavaş öğrenme
#             <br>💡 T5 için ideal: <code>2e-4 - 5e-4</code>
#         </td>
#     </tr>
#     <tr style='background-color: #E1F5FE;'>
#         <td style='padding: 12px;'><b>Batch Size</b></td>
#         <td style='padding: 12px; text-align: center;'>4-32</td>
#         <td style='padding: 12px;'>
#             Büyük: hızlı ama VRAM gerekli, Küçük: yavaş ama stable
#             <br>💡 Colab T4: <code>8-16</code> ideal
#         </td>
#     </tr>
#     <tr style='background-color: #F3E5F5;'>
#         <td style='padding: 12px;'><b>Num Epochs</b></td>
#         <td style='padding: 12px; text-align: center;'>3-10</td>
#         <td style='padding: 12px;'>
#             Dataset'i kaç kez görür. Fazla: overfitting riski
#             <br>💡 Summarization için: <code>3-5 epoch</code>
#         </td>
#     </tr>
#     <tr style='background-color: #E8F5E9;'>
#         <td style='padding: 12px;'><b>Weight Decay</b></td>
#         <td style='padding: 12px; text-align: center;'>0.0-0.1</td>
#         <td style='padding: 12px;'>
#             L2 regularization, overfitting'i önler
#             <br>💡 Genelde: <code>0.01</code>
#         </td>
#     </tr>
#     <tr style='background-color: #FFE0B2;'>
#         <td style='padding: 12px;'><b>Warmup Steps</b></td>
#         <td style='padding: 12px; text-align: center;'>0-1000</td>
#         <td style='padding: 12px;'>
#             Learning rate'i yavaşça artırır (başlangıçta stability)
#             <br>💡 Total steps'in <code>10%</code>'i
#         </td>
#     </tr>
#     <tr style='background-color: #F8BBD0;'>
#         <td style='padding: 12px;'><b>Gradient Accumulation</b></td>
#         <td style='padding: 12px; text-align: center;'>1-16</td>
#         <td style='padding: 12px;'>
#             Küçük VRAM'de büyük batch simüle eder
#             <br>💡 VRAM sıkıntısı varsa: <code>4-8</code>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### 🎯 Hyperparameter Seçim Stratejisi
#
# ```mermaid
# graph TD
#     A[🎯 Training Başlangıç] --> B{VRAM Durumu?}
#
#     B -->|<8GB| C[Batch Size: 4<br/>Grad Accum: 8]
#     B -->|8-16GB| D[Batch Size: 8<br/>Grad Accum: 4]
#     B -->|>16GB| E[Batch Size: 16<br/>Grad Accum: 2]
#
#     C --> F{Dataset Size?}
#     D --> F
#     E --> F
#
#     F -->|<10K| G[Epochs: 5-7<br/>LR: 5e-4]
#     F -->|10K-100K| H[Epochs: 3-5<br/>LR: 3e-4]
#     F -->|>100K| I[Epochs: 2-3<br/>LR: 2e-4]
#
#     G --> J[✅ Training Ready]
#     H --> J
#     I --> J
#
#     style A fill:#FFE5B4
#     style C fill:#FFB6C1
#     style D fill:#B4E5FF
#     style E fill:#C8E6C9
#     style G fill:#FFF9C4
#     style H fill:#E1BEE7
#     style I fill:#FFCC80
#     style J fill:#C5CAE9
# ```
#
# ### 📖 Flashcard: Training Konseptleri
#
# <div style='display: grid; grid-template-columns: 1fr 1fr; gap: 15px; margin: 20px 0;'>
#
# <div style='background: linear-gradient(135deg, #FFE5E5 0%, #FFB6C1 100%); padding: 18px; border-radius: 12px; box-shadow: 0 3px 6px rgba(0,0,0,0.15);'>
#     <h4 style='margin: 0; color: #C62828; border-bottom: 2px solid #C62828; padding-bottom: 8px;'>📉 Loss Function</h4>
#     <p style='margin: 12px 0 0 0; font-size: 14px; line-height: 1.6;'>
#         <b>Ne:</b> Model'in ne kadar yanlış yaptığını ölçer<br>
#         <b>Formula:</b> Cross-Entropy Loss<br>
#         <b>Hedef:</b> Loss'u minimize et!<br>
#         <b>Örnek:</b> 2.5 → 1.2 → 0.8 (iyileşiyor)
#     </p>
# </div>
#
# <div style='background: linear-gradient(135deg, #E1F5FE 0%, #B3E5FC 100%); padding: 18px; border-radius: 12px; box-shadow: 0 3px 6px rgba(0,0,0,0.15);'>
#     <h4 style='margin: 0; color: #01579B; border-bottom: 2px solid #01579B; padding-bottom: 8px;'>🎯 Gradient Descent</h4>
#     <p style='margin: 12px 0 0 0; font-size: 14px; line-height: 1.6;'>
#         <b>Ne:</b> Model ağırlıklarını güncelleme yöntemi<br>
#         <b>Mantık:</b> Loss gradientlerine göre optimize<br>
#         <b>Optimizer:</b> AdamW (T5 için ideal)<br>
#         <b>LR etkisi:</b> Adım büyüklüğünü kontrol eder
#     </p>
# </div>
#
# <div style='background: linear-gradient(135deg, #F3E5F5 0%, #E1BEE7 100%); padding: 18px; border-radius: 12px; box-shadow: 0 3px 6px rgba(0,0,0,0.15);'>
#     <h4 style='margin: 0; color: #6A1B9A; border-bottom: 2px solid #6A1B9A; padding-bottom: 8px;'>🔄 Epoch vs Batch</h4>
#     <p style='margin: 12px 0 0 0; font-size: 14px; line-height: 1.6;'>
#         <b>Epoch:</b> Tüm dataset'i 1 kez görmek<br>
#         <b>Batch:</b> Her seferinde işlenen örnek sayısı<br>
#         <b>Step:</b> 1 batch = 1 gradient update<br>
#         <b>Örnek:</b> 1000 data, batch=10 → 100 steps/epoch
#     </p>
# </div>
#
# <div style='background: linear-gradient(135deg, #FFF9C4 0%, #FFF59D 100%); padding: 18px; border-radius: 12px; box-shadow: 0 3px 6px rgba(0,0,0,0.15);'>
#     <h4 style='margin: 0; color: #F57F17; border-bottom: 2px solid #F57F17; padding-bottom: 8px;'>💾 Checkpointing</h4>
#     <p style='margin: 12px 0 0 0; font-size: 14px; line-height: 1.6;'>
#         <b>Ne:</b> Model'i belirli aralıklarla kaydet<br>
#         <b>Neden:</b> En iyi model'i sakla, crash recovery<br>
#         <b>Strateji:</b> Her epoch veya X steps<br>
#         <b>Best model:</b> En düşük validation loss
#     </p>
# </div>
#
# </div>

# %%
# 🏗️ Dataset Hazırlama - Training ve Validation Split
# Küçük bir subset ile hızlı training yapalım (demo amaçlı)

print("📊 DATASET HAZIRLAMA")
print("="*80)

# Demo için küçük subset kullanacağız
# Production'da tüm dataset kullanılır!
train_size = 3000  # 3K örnek (demo için)
val_size = 500     # 500 validation örnek

print(f"🎯 Training örnekleri: {train_size:,}")
print(f"🎯 Validation örnekleri: {val_size:,}")
print(f"💡 Not: Bu tutorial'da hızlı training için küçük subset kullanıyoruz\n")

# Dataset'i hazırla
train_dataset = dataset['train'].shuffle(seed=42).select(range(train_size))
val_dataset = dataset['validation'].shuffle(seed=42).select(range(val_size))

print(f"✅ Training dataset: {len(train_dataset)} örnek")
print(f"✅ Validation dataset: {len(val_dataset)} örnek")

# Preprocessing fonksiyonunu uygula (batch processing)
print(f"\n{'='*80}")
print("🔧 PREPROCESSING UYGULANIIYOR...")
print("="*80)

def preprocess_function(examples):
    """Dataset preprocessing fonksiyonu"""
    # T5 için "summarize:" prefix ekle
    inputs = ["summarize: " + doc for doc in examples['article']]

    # Tokenize inputs
    model_inputs = tokenizer(
        inputs,
        max_length=512,
        truncation=True,
        padding='max_length',
    )

    # Tokenize targets
    labels = tokenizer(
        text_target=examples['highlights'],  # text_target parametresi önemli!
        max_length=128,
        truncation=True,
        padding='max_length',
    )

    model_inputs['labels'] = labels['input_ids']
    return model_inputs

# Batch preprocessing yap
print("⏳ Training dataset tokenize ediliyor...")
tokenized_train = train_dataset.map(
    preprocess_function,
    batched=True,
    remove_columns=train_dataset.column_names,
    desc="Tokenizing train dataset"
)

print("⏳ Validation dataset tokenize ediliyor...")
tokenized_val = val_dataset.map(
    preprocess_function,
    batched=True,
    remove_columns=val_dataset.column_names,
    desc="Tokenizing val dataset"
)

print("\n✅ Preprocessing tamamlandı!")
print(f"\n📊 Tokenized Training Set:")
print(f"   Features: {tokenized_train.features}")
print(f"   Boyut: {len(tokenized_train)} örnek")

print(f"\n📊 Tokenized Validation Set:")
print(f"   Features: {tokenized_val.features}")
print(f"   Boyut: {len(tokenized_val)} örnek")

# İlk örneği inceleyelim
print(f"\n\n{'='*80}")
print("🔍 İLK TRAINING ÖRNEĞİ")
print("="*80)
first_example = tokenized_train[0]
print(f"Input IDs shape: {len(first_example['input_ids'])} tokens")
print(f"Labels shape: {len(first_example['labels'])} tokens")
print(f"Attention Mask: {sum(first_example['attention_mask'])} gerçek token, {len(first_example['attention_mask']) - sum(first_example['attention_mask'])} padding")

print("\n✅ Dataset'ler training için hazır!")
# Out:
# 📊 DATASET HAZIRLAMA
# ...
# 🎯 Training örnekleri: 3,000
# 🎯 Validation örnekleri: 500
# 💡 Not: Bu tutorial'da hızlı training için küçük subset kullanıyoruz
#
# ✅ Training dataset: 3000 örnek
# ✅ Validation dataset: 500 örnek
#
# ...
# 🔧 PREPROCESSING UYGULANIIYOR...
# ...
# ⏳ Training dataset tokenize ediliyor...
# Tokenizing train dataset:   0%|          | 0/3000 [00:00<?, ? examples/s]
# ⏳ Validation dataset tokenize ediliyor...
# Tokenizing val dataset:   0%|          | 0/500 [00:00<?, ? examples/s]
# ✅ Preprocessing tamamlandı!
#
# 📊 Tokenized Training Set:
#    Features: {'input_ids': List(Value('int32')), 'attention_mask': List(Value('int8')), 'labels': List(Value('int64'))}
#    Boyut: 3000 örnek
#
# 📊 Tokenized Validation Set:
#    Features: {'input_ids': List(Value('int32')), 'attention_mask': List(Value('int8')), 'labels': List(Value('int64'))}
#    Boyut: 500 örnek
#
#
# ...
# 🔍 İLK TRAINING ÖRNEĞİ
# ...
# Input IDs shape: 512 tokens
# Labels shape: 128 tokens
# ...

# %%
# ⚙️ Training Arguments - Hyperparameter'ları Tanımlayalım
# Seq2SeqTrainingArguments ile tüm ayarları yapılandırıyoruz

print("⚙️ TRAINING ARGUMENTS OLUŞTURULUYOR")
print("="*80)

# Output directory - model checkpoint'lerinin kaydedileceği yer
output_dir = "./t5-small-cnn-summarization"

# Training arguments
training_args = Seq2SeqTrainingArguments(
    # 📁 Output ve logging
    output_dir=output_dir,
    overwrite_output_dir=True,

    # 🎯 Training parametreleri
    num_train_epochs=3,                    # 3 epoch (demo için - production'da 5-7 olabilir)
    per_device_train_batch_size=8,         # Batch size (VRAM'e göre ayarlayın)
    per_device_eval_batch_size=8,          # Evaluation batch size

    # 📈 Learning rate ve scheduler
    learning_rate=5e-4,                    # T5 için ideal learning rate
    warmup_steps=500,                      # İlk 500 step'te LR'yi yavaşça artır
    weight_decay=0.01,                     # L2 regularization

    # 💾 Checkpoint ve kayıt
    save_strategy="epoch",                 # Her epoch'ta kaydet
    eval_strategy="epoch",           # Her epoch'ta evaluate et
    save_total_limit=2,                    # En fazla 2 checkpoint tut (disk tasarrufu)
    load_best_model_at_end=True,          # Training bitince best model'i yükle
    metric_for_best_model="eval_loss",     # En düşük eval_loss = best model

    # 📊 Logging
    logging_dir=f"{output_dir}/logs",
    logging_strategy="steps",
    logging_steps=100,                     # Her 100 step'te log

    # 🔧 Optimization
    fp16=torch.cuda.is_available(),        # Mixed precision (GPU varsa)
    gradient_accumulation_steps=1,         # Gradient accumulation (VRAM düşükse artır)

    # 🎯 Generation settings (evaluation için)
    predict_with_generate=True,            # Evaluation'da generate kullan
    generation_max_length=128,             # Max summary length
    generation_num_beams=4,                # Beam search (daha iyi kalite)

    # 🌱 Diğer
    seed=42,                               # Reproducibility
    report_to="none",                      # WandB/TensorBoard kapalı (demo için)
)

print("✅ Training arguments oluşturuldu!\n")

# Ayarları görüntüle
print("="*80)
print("📋 TRAINING CONFIGURATION")
print("="*80)
print(f"\n🎯 Training Ayarları:")
print(f"   Epochs: {training_args.num_train_epochs}")
print(f"   Batch Size: {training_args.per_device_train_batch_size}")
print(f"   Learning Rate: {training_args.learning_rate}")
print(f"   Warmup Steps: {training_args.warmup_steps}")
print(f"   Weight Decay: {training_args.weight_decay}")

print(f"\n💾 Checkpoint Ayarları:")
print(f"   Save Strategy: {training_args.save_strategy}")
print(f"   Evaluation Strategy: {training_args.eval_strategy}")
print(f"   Best Model Metric: {training_args.metric_for_best_model}")

print(f"\n🔧 Optimization:")
print(f"   FP16 (Mixed Precision): {training_args.fp16}")
print(f"   Gradient Accumulation: {training_args.gradient_accumulation_steps}")

print(f"\n🎯 Generation Ayarları:")
print(f"   Max Length: {training_args.generation_max_length}")
print(f"   Num Beams: {training_args.generation_num_beams}")

# Training adım sayısını hesapla
total_steps = (len(tokenized_train) // training_args.per_device_train_batch_size) * training_args.num_train_epochs
print(f"\n📊 Training İstatistikleri:")
print(f"   Toplam training steps: {total_steps:,}")
print(f"   Steps per epoch: {len(tokenized_train) // training_args.per_device_train_batch_size}")
print(f"   Tahmini süre: ~{total_steps * 0.5 / 60:.0f} dakika (GPU'da)")

print("\n✅ Configuration hazır!")
# Out:
# ⚙️ TRAINING ARGUMENTS OLUŞTURULUYOR
# ...
# ✅ Training arguments oluşturuldu!
#
# ...
# 📋 TRAINING CONFIGURATION
# ...
#
# 🎯 Training Ayarları:
#    Epochs: 3
#    Batch Size: 8
#    Learning Rate: 0.0005
#    Warmup Steps: 500
#    Weight Decay: 0.01
#
# 💾 Checkpoint Ayarları:
#    Save Strategy: SaveStrategy.EPOCH
#    Evaluation Strategy: IntervalStrategy.EPOCH
#    Best Model Metric: eval_loss
#
# 🔧 Optimization:
#    FP16 (Mixed Precision): True
#    Gradient Accumulation: 1
#
# 🎯 Generation Ayarları:
#    Max Length: 128
#    Num Beams: 4
#
# 📊 Training İstatistikleri:
#    Toplam training steps: 1,125
#    Steps per epoch: 375
#    Tahmini süre: ~9 dakika (GPU'da)
#
# ✅ Configuration hazır!

# %%
# 🎯 Data Collator - Batch'leri hazırlayacak helper
# DataCollatorForSeq2Seq padding'i dinamik yapar (efficiency)

print("🔧 DATA COLLATOR OLUŞTURULUYOR")
print("="*80)

data_collator = DataCollatorForSeq2Seq(
    tokenizer=tokenizer,
    model=model,
    label_pad_token_id=-100,  # Loss hesabında ignore edilecek token ID
    pad_to_multiple_of=8 if training_args.fp16 else None  # FP16 için optimize
)

print("✅ Data collator hazır!")
print("\n💡 Data Collator Görevleri:")
print("   • Batch içindeki sequence'leri aynı uzunluğa getirir (dynamic padding)")
print("   • Padding token'larını -100 ile işaretler (loss'ta ignore edilir)")
print("   • FP16 training için optimize eder")
print("   • VRAM'i verimli kullanır (sadece gereken padding)")

print(f"\n\n{'='*80}")
print("🎓 SEQ2SEQTRAINER OLUŞTURULUYOR")
print("="*80)

# Trainer'ı oluştur
trainer = Seq2SeqTrainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_train,
    eval_dataset=tokenized_val,
    tokenizer=tokenizer,
    data_collator=data_collator,
)

print("✅ Seq2SeqTrainer başarıyla oluşturuldu!")

print("\n📊 Trainer Bileşenleri:")
print(f"   Model: {model_name} ({total_params:,} params)")
print(f"   Training samples: {len(tokenized_train):,}")
print(f"   Validation samples: {len(tokenized_val):,}")
print(f"   Batch size: {training_args.per_device_train_batch_size}")
print(f"   Epochs: {training_args.num_train_epochs}")

print("\n\n🚀 HER ŞEY HAZIR! TRAINING BAŞLATILACAK...")
print("="*80)
print("\n⚠️ ÖNEMLİ NOTLAR:")
print("   • Training birkaç dakika sürebilir (GPU'ya bağlı)")
print("   • Her epoch sonunda evaluation yapılacak")
print("   • En iyi model otomatik kaydedilecek")
print("   • Progress bar ile ilerlemeyi takip edebilirsiniz")
print("\n💡 İpucu: Colab'da Runtime -> View Runtime Logs'dan GPU kullanımını izleyin!")
# Out:
# 🔧 DATA COLLATOR OLUŞTURULUYOR
# ...
# ✅ Data collator hazır!
#
# 💡 Data Collator Görevleri:
#    • Batch içindeki sequence'leri aynı uzunluğa getirir (dynamic padding)
#    • Padding token'larını -100 ile işaretler (loss'ta ignore edilir)
#    • FP16 training için optimize eder
#    • VRAM'i verimli kullanır (sadece gereken padding)
#
#
# ...
# 🎓 SEQ2SEQTRAINER OLUŞTURULUYOR
# ...
# ✅ Seq2SeqTrainer başarıyla oluşturuldu!
#
# 📊 Trainer Bileşenleri:
#    Model: t5-small (60,506,624 params)
#    Training samples: 3,000
#    Validation samples: 500
#    Batch size: 8
#    Epochs: 3
#
#
# 🚀 HER ŞEY HAZIR! TRAINING BAŞLATILACAK...
# ...
#
# ⚠️ ÖNEMLİ NOTLAR:
#    • Training birkaç dakika sürebilir (GPU'ya bağlı)
#    • Her epoch sonunda evaluation yapılacak
#    • En iyi model otomatik kaydedilecek
#    • Progress bar ile ilerlemeyi takip edebilirsiniz
#
# 💡 İpucu: Colab'da Runtime -> View Runtime Logs'dan GPU kullanımını izleyin!

# %%
# 🚀 TRAINING BAŞLAT!
# Model artık CNN/DailyMail dataset'i ile özetleme görevini öğrenecek

print("🚀🚀🚀 TRAINING BAŞLIYOR! 🚀🚀🚀")
print("="*80)
print("\n⏱️ Başlangıç zamanı:", pd.Timestamp.now().strftime("%H:%M:%S"))
print("\n📊 Training takibi:")
print("   • Her 100 step'te loss değeri gösterilecek")
print("   • Her epoch sonunda validation loss hesaplanacak")
print("   • En iyi model otomatik kaydedilecek")
print("\n" + "="*80)

# Training başlat
training_output = trainer.train()

print("\n" + "="*80)
print("🎉🎉🎉 TRAINING TAMAMLANDI! 🎉🎉🎉")
print("="*80)

# Training sonuçlarını göster
print("\n📊 TRAINING SONUÇLARI:")
print("-"*80)
print(f"✅ Toplam training süresi: {training_output.metrics['train_runtime']:.1f} saniye ({training_output.metrics['train_runtime']/60:.1f} dakika)")
print(f"✅ Training loss: {training_output.metrics['train_loss']:.4f}")
print(f"✅ Epoch başına süre: {training_output.metrics['train_runtime']/training_args.num_train_epochs:.1f} saniye")
print(f"✅ Step başına süre: {training_output.metrics['train_samples_per_second']:.2f} sample/saniye")

print("\n💾 Model checkpoint'i kaydedildi:")
print(f"   📁 {output_dir}")

print("\n✨ Sırada ne var?")
print("   • Model'i test etme ve inference")
print("   • ROUGE metrikleri ile değerlendirme")
print("   • Farklı örnekler üzerinde deneme")
print("   • Diğer 7 modeli de eğitme!")

print("\n" + "="*80)
# Out:
# 🚀🚀🚀 TRAINING BAŞLIYOR! 🚀🚀🚀
# ...
#
# ⏱️ Başlangıç zamanı: 00:48:06
#
# 📊 Training takibi:
#    • Her 100 step'te loss değeri gösterilecek
#    • Her epoch sonunda validation loss hesaplanacak
#    • En iyi model otomatik kaydedilecek
#
# ...
#     <div>
#
#       <progress value='1125' max='1125' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1125/1125 01:43, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.181300</td>
#       <td>1.146545</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.115100</td>
#       <td>1.146497</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.981800</td>
#       <td>1.153692</td>
#     </tr>
#   </tbody>
# </table><p>
# ...

# %% [markdown]
# ---
#
# ## 🧪 Model Test: İlk Özet Üretimi
#
# <div style='background: linear-gradient(135deg, #E8F5E9 0%, #C8E6C9 100%); padding: 25px; border-radius: 15px; margin: 20px 0;'>
#     <h3 style='color: #2E7D32;'>🎉 Model Eğitildi - Şimdi Test Zamanı!</h3>
#     <p style='font-size: 16px; line-height: 1.8;'>
#         Fine-tune edilmiş T5 modelimiz artık <b>CNN/DailyMail tarzında özetler</b> üretmeye hazır.
#         Hem validation set'ten hem de YBS senaryolarından örnekler deneyeceğiz!
#     </p>
# </div>

# %%
# 🧪 İlk Test: Validation Set'ten Örnek
# Model'in öğrendiklerini görelim!

print("🧪 MODEL TEST BAŞLIYOR")
print("="*80)

# Validation set'ten random 3 örnek alalım
test_indices = [0, 50, 100]
test_examples = [val_dataset[i] for i in test_indices]

print(f"📊 Test edilecek örnek sayısı: {len(test_examples)}\n")

# Model'i eval moduna al
model.eval()

for idx, example in enumerate(test_examples, 1):
    print("="*80)
    print(f"📰 TEST ÖRNEK #{idx}")
    print("="*80)

    # Article'ı hazırla
    article = example['article']
    actual_summary = example['highlights']

    # Tokenize et
    input_text = "summarize: " + article
    inputs = tokenizer(
        input_text,
        max_length=512,
        truncation=True,
        return_tensors="pt"
    ).to(device)

    # Generate summary
    with torch.no_grad():
        summary_ids = model.generate(
            inputs['input_ids'],
            max_length=128,
            num_beams=4,              # Beam search
            length_penalty=0.6,       # Uzun özetleri teşvik et
            early_stopping=True
        )

    # Decode
    generated_summary = tokenizer.decode(summary_ids[0], skip_special_tokens=True)

    # Sonuçları göster
    print(f"\n📝 ORİJİNAL ARTICLE (ilk 300 karakter):")
    print("-"*80)
    print(article[:300] + "...")

    print(f"\n\n✅ GERÇEK ÖZET (Ground Truth):")
    print("-"*80)
    print(actual_summary)

    print(f"\n\n🤖 MODEL'İN ÜRETTİĞİ ÖZET:")
    print("-"*80)
    print(generated_summary)

    print(f"\n\n📊 İSTATİSTİKLER:")
    print(f"   Article uzunluğu: {len(article.split())} kelime")
    print(f"   Gerçek özet uzunluğu: {len(actual_summary.split())} kelime")
    print(f"   Üretilen özet uzunluğu: {len(generated_summary.split())} kelime")
    print(f"   Sıkıştırma oranı: {len(generated_summary.split())/len(article.split())*100:.1f}%")

    print("\n")

print("="*80)
print("✅ Test tamamlandı!")
print("\n💡 Gözlemler:")
print("   • Model özetleme görevini öğrendi mi?")
print("   • Üretilen özetler akıcı ve anlamlı mı?")
print("   • Gerçek özetlere ne kadar yakın?")
print("   • Önemli bilgileri yakalayabiliyor mu?")
# Out:
# 🧪 MODEL TEST BAŞLIYOR
# ...
# 📊 Test edilecek örnek sayısı: 3
#
# ...
# 📰 TEST ÖRNEK #1
# ...
#
# 📝 ORİJİNAL ARTICLE (ilk 300 karakter):
# --------------------------------------------------------------------------------
# Jarryd Hayne's move to the NFL is a boost for rugby league in the United States, it has been claimed. The Australia international full-back or centre quit the National Rugby League in October to try his luck in American football and was this week given a three-year contract with the San Francisco 49...
#
#
# ✅ GERÇEK ÖZET (Ground Truth):
# --------------------------------------------------------------------------------
# Jarryd Hayne quit the NRL in October to try and get into American Football .
# This week, he signed a three-year contract with the San Francisco 49ers .
# The chairman of the US Association of Rugby League welcomed his arrival .
#
#
# 🤖 MODEL'İN ÜRETTİĞİ ÖZET:
# --------------------------------------------------------------------------------
# ...

# %%
# 💼 YBS Test: Şirket Raporu Özetleme
# Fine-tune edilmiş model'i gerçek iş senaryosunda test edelim

print("💼 YBS SENARYO TESTİ: ŞİRKET RAPORU ÖZETLEMESİ")
print("="*80)

# Daha önce tanımladığımız YBS senaryosunu kullanalım
ybs_test_text = """
TechVision Inc. Annual Report 2025 - Financial Performance and Strategic Outlook

Executive Summary:
TechVision Inc. has demonstrated exceptional growth in fiscal year 2025, with revenue increasing
42% year-over-year to $2.8 billion. Our cloud computing division became the primary revenue driver,
contributing 58% of total revenue and showing a remarkable 67% growth compared to the previous year.
The company successfully expanded into three new international markets: Southeast Asia, Eastern Europe,
and Latin America, establishing 12 new offices and hiring 3,500 employees globally.

Financial Highlights:
Total revenue reached $2.8 billion, up from $1.97 billion in 2024. Gross profit margin improved
to 68%, compared to 64% in the previous year, driven by operational efficiency improvements and
strategic cost optimization initiatives. Net income increased to $580 million, representing a
21% profit margin. Operating cash flow stood at $720 million, providing strong liquidity for
future investments and R&D initiatives.

Product Innovation:
We launched five major product lines this year, including our flagship AI-powered analytics
platform "InsightPro" which gained 15,000 enterprise customers within six months. Our R&D
investment increased to $420 million (15% of revenue), focusing on artificial intelligence,
machine learning, and quantum computing research.
"""

print("📄 Şirket Raporu Bilgileri:")
print(f"   Kelime sayısı: {len(ybs_test_text.split())} kelime")
print(f"   Karakter sayısı: {len(ybs_test_text)} karakter")
print(f"   Okuma süresi: ~{len(ybs_test_text.split())//200} dakika\n")

# Tokenize ve generate
print("⏳ Model özet üretiyor...\n")

input_text = "summarize: " + ybs_test_text
inputs = tokenizer(
    input_text,
    max_length=512,
    truncation=True,
    return_tensors="pt"
).to(device)

with torch.no_grad():
    summary_ids = model.generate(
        inputs['input_ids'],
        max_length=128,
        num_beams=4,
        length_penalty=0.6,
        early_stopping=True,
        no_repeat_ngram_size=3  # Tekrar önleme
    )

generated_summary = tokenizer.decode(summary_ids[0], skip_special_tokens=True)

print("="*80)
print("🤖 MODEL'İN ÜRETTİĞİ YBS RAPOR ÖZETİ:")
print("="*80)
print(generated_summary)

print(f"\n\n📊 ÖZET ANALİZİ:")
print("-"*80)
print(f"✅ Özet uzunluğu: {len(generated_summary.split())} kelime")
print(f"✅ Sıkıştırma oranı: {len(generated_summary.split())/len(ybs_test_text.split())*100:.1f}%")
print(f"✅ Zaman tasarrufu: {100 - (len(generated_summary.split())/len(ybs_test_text.split())*100):.0f}%")
print(f"✅ Okuma süresi: ~{len(generated_summary.split())//200 if len(generated_summary.split())>=200 else '<1'} dakika")

print(f"\n\n💡 YBS PERSPEKTİFİ - DEĞERLENDİRME:")
print("-"*80)
print("📌 Kontrol Listesi:")
print("   [ ] Finansal metrikler korunuyor mu? (revenue, profit)")
print("   [ ] Stratejik bilgiler var mı? (expansion, acquisitions)")
print("   [ ] Özet anlaşılır ve akıcı mı?")
print("   [ ] Yöneticiler için aksiyonabilir mi?")
print("   [ ] Önemli sayılar (numbers) preserve edilmiş mi?")

print("\n✨ Model başarılı mı? Yukarıdaki kriterleri kontrol edin!")
# Out:
# 💼 YBS SENARYO TESTİ: ŞİRKET RAPORU ÖZETLEMESİ
# ...
# 📄 Şirket Raporu Bilgileri:
#    Kelime sayısı: 189 kelime
#    Karakter sayısı: 1386 karakter
#    Okuma süresi: ~0 dakika
#
# ⏳ Model özet üretiyor...
#
# ...
# 🤖 MODEL'İN ÜRETTİĞİ YBS RAPOR ÖZETİ:
# ...
# TechVision Inc. has demonstrated exceptional growth in fiscal year 2025, with revenue increasing 42% year-over-year to $2.8 billion. Our cloud computing division became the primary revenue driver, contributing 58% of total revenue. The company successfully expanded into three new international markets: Southeast Asia, Eastern Europe, and Latin America.
#
#
# 📊 ÖZET ANALİZİ:
# --------------------------------------------------------------------------------
# ✅ Özet uzunluğu: 48 kelime
# ✅ Sıkıştırma oranı: 25.4%
# ✅ Zaman tasarrufu: 75%
# ✅ Okuma süresi: ~<1 dakika
#
#
# 💡 YBS PERSPEKTİFİ - DEĞERLENDİRME:
# --------------------------------------------------------------------------------
# 📌 Kontrol Listesi:
# ...

# %% [markdown]
# ---
#
# ## 📊 T5 Fine-Tuning: Özet ve Sonuçlar
#
# <div style='background: linear-gradient(135deg, #667eea 0%, #764ba2 100%); padding: 30px; border-radius: 15px; color: white; text-align: center; margin: 20px 0;'>
#     <h2 style='margin: 0;'>🎉 İlk Model Başarıyla Eğitildi!</h2>
#     <p style='font-size: 18px; margin: 15px 0 0 0;'>T5-Small ile CNN/DailyMail Fine-Tuning Tamamlandı</p>
# </div>
#
# ### ✅ Bu Adımda Tamamladıklarımız
#
# <div style='background-color: #E8F5E9; padding: 25px; border-radius: 15px; margin: 20px 0; border-left: 6px solid #4CAF50;'>
#
# <table style='width: 100%; background-color: white; border-radius: 10px; padding: 15px;'>
#     <tr>
#         <td style='width: 60px; font-size: 35px; text-align: center;'>🏗️</td>
#         <td>
#             <b style='font-size: 18px; color: #2E7D32;'>Model Architecture</b><br>
#             <span style='color: #666;'>T5 encoder-decoder mimarisini öğrendik, 60M parametre ile çalıştık</span>
#         </td>
#     </tr>
#     <tr>
#         <td style='width: 60px; font-size: 35px; text-align: center;'>⚙️</td>
#         <td>
#             <b style='font-size: 18px; color: #2E7D32;'>Hyperparameter Tuning</b><br>
#             <span style='color: #666;'>Learning rate, batch size, epochs - optimal ayarları yapılandırdık</span>
#         </td>
#     </tr>
#     <tr>
#         <td style='width: 60px; font-size: 35px; text-align: center;'>🎯</td>
#         <td>
#             <b style='font-size: 18px; color: #2E7D32;'>Training Process</b><br>
#             <span style='color: #666;'>3 epoch'luk training, loss tracking, checkpoint saving</span>
#         </td>
#     </tr>
#     <tr>
#         <td style='width: 60px; font-size: 35px; text-align: center;'>🧪</td>
#         <td>
#             <b style='font-size: 18px; color: #2E7D32;'>Model Testing</b><br>
#             <span style='color: #666;'>Validation örnekleri ve YBS senaryolarında test ettik</span>
#         </td>
#     </tr>
#     <tr>
#         <td style='width: 60px; font-size: 35px; text-align: center;'>💼</td>
#         <td>
#             <b style='font-size: 18px; color: #2E7D32;'>Business Applications</b><br>
#             <span style='color: #666;'>Şirket raporları özetleme gibi gerçek YBS use case'leri</span>
#         </td>
#     </tr>
# </table>
#
# </div>
#
# ### 📈 Öğrenilen Kritik Konseptler
#
# <div style='display: grid; grid-template-columns: 1fr 1fr; gap: 20px; margin: 20px 0;'>
#
# <div style='background-color: #FFF9C4; padding: 20px; border-radius: 12px; border: 2px solid #F57F17;'>
#     <h4 style='color: #F57F17; margin-top: 0;'>🎓 Teorik Bilgi</h4>
#     <ul style='line-height: 1.8; margin: 10px 0; font-size: 15px;'>
#         <li><b>Transfer Learning:</b> Pre-trained → Fine-tuned</li>
#         <li><b>Loss Function:</b> Cross-entropy minimization</li>
#         <li><b>Gradient Descent:</b> AdamW optimizer</li>
#         <li><b>Overfitting Prevention:</b> Weight decay, validation</li>
#         <li><b>Beam Search:</b> Better quality generation</li>
#     </ul>
# </div>
#
# <div style='background-color: #E1F5FE; padding: 20px; border-radius: 12px; border: 2px solid #0277BD;'>
#     <h4 style='color: #01579B; margin-top: 0;'>💻 Pratik Beceriler</h4>
#     <ul style='line-height: 1.8; margin: 10px 0; font-size: 15px;'>
#         <li><b>HuggingFace Transformers:</b> Model loading, training</li>
#         <li><b>Seq2SeqTrainer:</b> Training pipeline setup</li>
#         <li><b>Data Preprocessing:</b> Tokenization, padding</li>
#         <li><b>GPU Utilization:</b> FP16, batch optimization</li>
#         <li><b>Model Deployment:</b> Checkpoint saving, loading</li>
#     </ul>
# </div>
#
# </div>
#
# ### 🚀 Sıradaki Adımlar
#
# <div style='background: linear-gradient(135deg, #F3E5F5 0%, #E1BEE7 100%); padding: 25px; border-radius: 15px; margin: 20px 0;'>
#     <h3 style='color: #4A148C;'>📋 Devam Eden Journey</h3>
#     <ol style='font-size: 16px; line-height: 2;'>
#         <li><b>Adım 5:</b> BART modelini fine-tune edeceğiz (farklı architecture)</li>
#         <li><b>Adım 6-7:</b> Pegasus, DistilBART, FLAN-T5, LED'i eğiteceğiz</li>
#         <li><b>Adım 8:</b> BigBird-Pegasus ve mT5 (uzun belgeler, multilingual)</li>
#         <li><b>Adım 9:</b> 8 modeli ROUGE, BLEU ile karşılaştırma</li>
#         <li><b>Adım 10:</b> Hyperparameter optimization, advanced techniques</li>
#         <li><b>Adım 11:</b> Production deployment stratejileri</li>
#     </ol>
# </div>
#
# <div style='background-color: #FFE0B2; padding: 20px; border-radius: 10px; border-left: 5px solid #FF9800; margin: 20px 0;'>
#     <p style='margin: 0; font-size: 16px;'>
#         <b>🎯 Hedef:</b> 8 farklı modeli eğitip, en iyi performans gösteren modeli seçeceğiz.
#         Her model'in güçlü ve zayıf yönlerini YBS perspektifinden analiz edeceğiz!
#     </p>
# </div>

# %% [markdown]
# ---
#
# # 🎯 ADIM 5: BART Model Fine-Tuning
#
# <div style='background: linear-gradient(135deg, #FF6B6B 0%, #EE5A6F 100%); padding: 30px; border-radius: 15px; color: white; text-align: center; margin: 20px 0;'>
#     <h2 style='margin: 0; font-size: 28px;'>🔥 İkinci Model: BART (Facebook/Meta)</h2>
#     <p style='font-size: 18px; margin: 15px 0 0 0;'><b>Bidirectional and Auto-Regressive Transformers</b></p>
# </div>
#
# <div style='background-color: #FFF3E0; padding: 25px; border-left: 6px solid #FF9800; border-radius: 10px; margin: 20px 0;'>
#     <h3 style='color: #E65100;'>🎯 BART Nedir?</h3>
#     <p style='font-size: 16px; line-height: 1.8;'>
#         <b>BART</b>, Facebook AI (Meta) tarafından 2020'de geliştirildi.
#         <span style='background-color: #FFEB3B; padding: 3px 8px; border-radius: 5px;'><b>BERT (encoder)</b></span> ve
#         <span style='background-color: #C8E6C9; padding: 3px 8px; border-radius: 5px;'><b>GPT (decoder)</b></span>
#         mimarilerinin güçlü yönlerini birleştirir.
#     </p>
#     <p style='font-size: 16px; line-height: 1.8; margin-top: 15px;'>
#         📌 <b>Özel Eğitim Yöntemi:</b> "Denoising Autoencoder" - bozulmuş metinleri restore eder,
#         bu sayede özetleme, çeviri ve metin üretimi gibi görevlerde mükemmel performans!
#     </p>
# </div>

# %% [markdown]
# ## 🏗️ BART vs T5: Mimari Karşılaştırma
#
# <table style='width: 100%; border-collapse: collapse; margin: 20px 0; box-shadow: 0 4px 8px rgba(0,0,0,0.1);'>
#     <tr style='background: linear-gradient(135deg, #FF6B6B 0%, #EE5A6F 100%); color: white;'>
#         <th style='padding: 15px; text-align: left;'>Özellik</th>
#         <th style='padding: 15px; text-align: center;'>🔥 BART</th>
#         <th style='padding: 15px; text-align: center;'>🤖 T5</th>
#     </tr>
#     <tr style='background-color: #FFF9C4;'>
#         <td style='padding: 12px;'><b>Geliştirici</b></td>
#         <td style='padding: 12px; text-align: center;'>Facebook AI (Meta)</td>
#         <td style='padding: 12px; text-align: center;'>Google</td>
#     </tr>
#     <tr style='background-color: #E1F5FE;'>
#         <td style='padding: 12px;'><b>Tokenizer</b></td>
#         <td style='padding: 12px; text-align: center;'>BPE (Byte-Pair Encoding)</td>
#         <td style='padding: 12px; text-align: center;'>SentencePiece</td>
#     </tr>
#     <tr style='background-color: #F3E5F5;'>
#         <td style='padding: 12px;'><b>Vocab Size</b></td>
#         <td style='padding: 12px; text-align: center;'>50,265</td>
#         <td style='padding: 12px; text-align: center;'>32,000</td>
#     </tr>
#     <tr style='background-color: #E8F5E9;'>
#         <td style='padding: 12px;'><b>Pre-training</b></td>
#         <td style='padding: 12px; text-align: center;'>Denoising (text infilling)</td>
#         <td style='padding: 12px; text-align: center;'>Span corruption</td>
#     </tr>
#     <tr style='background-color: #FFE0B2;'>
#         <td style='padding: 12px;'><b>Position Encoding</b></td>
#         <td style='padding: 12px; text-align: center;'>Learned (absolute)</td>
#         <td style='padding: 12px; text-align: center;'>Relative</td>
#     </tr>
#     <tr style='background-color: #F8BBD0;'>
#         <td style='padding: 12px;'><b>Güçlü Yönü</b></td>
#         <td style='padding: 12px; text-align: center;'>Doğal dil üretimi, akıcılık</td>
#         <td style='padding: 12px; text-align: center;'>Multi-task, prefix-based</td>
#     </tr>
#     <tr style='background-color: #DCEDC8;'>
#         <td style='padding: 12px;'><b>Best Use Case</b></td>
#         <td style='padding: 12px; text-align: center;'>Özetleme, çeviri, parafraz</td>
#         <td style='padding: 12px; text-align: center;'>Genel NLP görevleri</td>
#     </tr>
# </table>
#
# ### 🔄 BART Architecture Flow
#
# ```mermaid
# graph TB
#     A["📝 Input Text"] --> B["🔧 Corruption<br/>(Noise Injection)"]
#
#     B --> C["Token Masking<br/>Sentence Permutation<br/>Text Infilling"]
#
#     C --> D["🔷 BART Encoder<br/>(Bidirectional)"]
#
#     D --> E["💾 Encoded<br/>Representations"]
#
#     E --> F["🔶 BART Decoder<br/>(Auto-regressive)"]
#
#     F --> G["✨ Reconstructed<br/>Original Text"]
#
#     G --> H["📊 Loss Calculation<br/>(Cross-Entropy)"]
#
#     H --> I["🔄 Backpropagation<br/>& Update"]
#
#     style A fill:#FFE5B4
#     style B fill:#FFB6C1
#     style C fill:#FFCDD2
#     style D fill:#B4E5FF
#     style E fill:#FFF9C4
#     style F fill:#C8E6C9
#     style G fill:#E1BEE7
#     style H fill:#FFCC80
#     style I fill:#C5CAE9
# ```
#
# ### 📖 Flashcard: BART Özellikleri
#
# <div style='background: linear-gradient(135deg, #FFE5E5 0%, #FFCDD2 100%); padding: 20px; border-radius: 12px; box-shadow: 0 3px 6px rgba(0,0,0,0.15); margin: 20px 0;'>
#     <h4 style='margin: 0; color: #C62828; border-bottom: 2px solid #C62828; padding-bottom: 10px;'>🔥 BART'ın Süper Güçleri</h4>
#     <ul style='margin: 15px 0 0 0; font-size: 15px; line-height: 2;'>
#         <li><b>🎯 Denoising Pre-training:</b> Bozulmuş metni restore ederek öğrenir</li>
#         <li><b>💪 Robust Generation:</b> Yüksek kaliteli, akıcı metin üretir</li>
#         <li><b>📊 Large Vocabulary:</b> 50K+ token, rare words için ideal</li>
#         <li><b>🔄 Flexible Architecture:</b> Hem anlama hem üretim yapabilir</li>
#         <li><b>⚡ State-of-the-Art:</b> Özetleme benchmarklarında lider</li>
#     </ul>
# </div>

# %%
# 🔥 BART Model Yükleme
# facebook/bart-large-cnn - özetleme için optimize edilmiş model

print("🔥 BART MODEL YÜKLEME BAŞLIYOR")
print("="*80)
print("📦 Model: facebook/bart-large-cnn")
print("💡 Not: Bu model zaten CNN/DailyMail'de pre-trained, biz onu fine-tune edeceğiz\n")

# Model checkpoint
bart_model_name = "facebook/bart-large-cnn"

print("⏳ Model ve tokenizer yükleniyor...")
print("   (İlk kez ~1.6GB indirilecek, sonra cache'den yüklenir)\n")

# BART tokenizer ve model
bart_tokenizer = AutoTokenizer.from_pretrained(bart_model_name)
bart_model = AutoModelForSeq2SeqLM.from_pretrained(bart_model_name)

print("✅ Model ve tokenizer başarıyla yüklendi!\n")

# Model bilgileri
print("="*80)
print("📊 BART MODEL BİLGİLERİ")
print("="*80)

# Parametre sayısı
bart_total_params = sum(p.numel() for p in bart_model.parameters())
bart_trainable_params = sum(p.numel() for p in bart_model.parameters() if p.requires_grad)

print(f"\n🔢 Toplam Parametre: {bart_total_params:,}")
print(f"🎯 Eğitilebilir Parametre: {bart_trainable_params:,}")
print(f"📦 Model Boyutu: ~{bart_total_params * 4 / 1024**2:.1f} MB (FP32)")

# Architecture details
print(f"\n🏗️ MİMARİ DETAYLARı:")
print(f"   Encoder Layers: {bart_model.config.encoder_layers}")
print(f"   Decoder Layers: {bart_model.config.decoder_layers}")
print(f"   Hidden Size: {bart_model.config.d_model}")
print(f"   Attention Heads: {bart_model.config.encoder_attention_heads}")
print(f"   Feed-Forward Dim: {bart_model.config.encoder_ffn_dim}")
print(f"   Vocabulary Size: {bart_model.config.vocab_size:,}")
print(f"   Max Position: {bart_model.config.max_position_embeddings}")

# Tokenizer bilgileri
print(f"\n🔤 TOKENIZER BİLGİLERİ:")
print(f"   Type: {type(bart_tokenizer).__name__}")
print(f"   Vocab Size: {bart_tokenizer.vocab_size:,}")
print(f"   Special Tokens: {len(bart_tokenizer.all_special_tokens)}")
print(f"   BOS Token: '{bart_tokenizer.bos_token}' (ID: {bart_tokenizer.bos_token_id})")
print(f"   EOS Token: '{bart_tokenizer.eos_token}' (ID: {bart_tokenizer.eos_token_id})")
print(f"   PAD Token: '{bart_tokenizer.pad_token}' (ID: {bart_tokenizer.pad_token_id})")

# GPU'ya taşı
if torch.cuda.is_available():
    bart_model = bart_model.to(device)
    print(f"\n🔥 GPU: Model CUDA'ya taşındı")
else:
    print(f"\n💻 CPU: GPU bulunamadı")

# Training moda al
bart_model.train()

print(f"\n\n💡 T5 vs BART:")
print(f"   T5 parametreleri: {total_params:,}")
print(f"   BART parametreleri: {bart_total_params:,}")
print(f"   Fark: BART {bart_total_params/total_params:.1f}x daha büyük!")
print(f"   💪 Daha fazla parametre = Daha güçlü öğrenme kapasitesi")
# Out:
# 🔥 BART MODEL YÜKLEME BAŞLIYOR
# ...
# 📦 Model: facebook/bart-large-cnn
# 💡 Not: Bu model zaten CNN/DailyMail'de pre-trained, biz onu fine-tune edeceğiz
#
# ⏳ Model ve tokenizer yükleniyor...
#    (İlk kez ~1.6GB indirilecek, sonra cache'den yüklenir)
# config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/1.63G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# ✅ Model ve tokenizer başarıyla yüklendi!
#
# ...
# 📊 BART MODEL BİLGİLERİ
# ...
#
# 🔢 Toplam Parametre: 406,290,432
# 🎯 Eğitilebilir Parametre: 406,290,432
# 📦 Model Boyutu: ~1549.9 MB (FP32)
#
# 🏗️ MİMARİ DETAYLARı:
#    Encoder Layers: 12
#    Decoder Layers: 12
#    Hidden Size: 1024
#    Attention Heads: 16
#    Feed-Forward Dim: 4096
#    Vocabulary Size: 50,264
#    Max Position: 1024
#
# 🔤 TOKENIZER BİLGİLERİ:
#    Type: BartTokenizerFast
#    Vocab Size: 50,265
# ...

# %%
# 🏗️ BART için Dataset Preprocessing
# BART'ın tokenizer'ı T5'ten farklı, yeniden tokenize etmeliyiz

print("🏗️ BART İÇİN DATASET PREPROCESSING")
print("="*80)

def preprocess_function_bart(examples):
    """
    BART için preprocessing fonksiyonu
    Not: BART prefix kullanmaz (T5'teki "summarize:" gibi)
    """
    # BART için direkt article'ı kullan (prefix yok!)
    inputs = examples['article']

    # Tokenize inputs
    model_inputs = bart_tokenizer(
        inputs,
        max_length=1024,  # BART daha uzun sequence'leri destekler
        truncation=True,
        padding='max_length',
    )

    # Tokenize targets (labels)
    labels = bart_tokenizer(
        text_target=examples['highlights'],
        max_length=128,
        truncation=True,
        padding='max_length',
    )

    model_inputs['labels'] = labels['input_ids']
    return model_inputs

print("🔧 BART preprocessing fonksiyonu tanımlandı")
print("\n📋 Özellikler:")
print("   • Max input length: 1024 tokens (T5: 512)")
print("   • Max output length: 128 tokens")
print("   • Prefix kullanılmıyor (BART'a özel)")
print("   • Padding: max_length\n")

# Train ve validation için preprocessing
print("⏳ Dataset tokenize ediliyor...\n")

# Aynı train/val split'i kullanalım (consistency için)
tokenized_train_bart = train_dataset.map(
    preprocess_function_bart,
    batched=True,
    remove_columns=train_dataset.column_names,
    desc="Tokenizing train with BART"
)

tokenized_val_bart = val_dataset.map(
    preprocess_function_bart,
    batched=True,
    remove_columns=val_dataset.column_names,
    desc="Tokenizing val with BART"
)

print("✅ BART preprocessing tamamlandı!\n")
print(f"📊 Tokenized Training Set: {len(tokenized_train_bart)} örnekler")
print(f"📊 Tokenized Validation Set: {len(tokenized_val_bart)} örnekler")

# İlk örneği karşılaştır
print(f"\n\n{'='*80}")
print("🔍 T5 vs BART TOKENIZATION KARŞILAŞTIRMASI")
print("="*80)

test_text = train_dataset[0]['article'][:200]
print(f"\n📝 Test Text (ilk 200 karakter):")
print(test_text)

# T5 tokenization
t5_tokens = tokenizer.tokenize("summarize: " + test_text)
print(f"\n🤖 T5 Tokenization:")
print(f"   Token count: {len(t5_tokens)}")
print(f"   İlk 10 token: {t5_tokens[:10]}")

# BART tokenization
bart_tokens = bart_tokenizer.tokenize(test_text)
print(f"\n🔥 BART Tokenization:")
print(f"   Token count: {len(bart_tokens)}")
print(f"   İlk 10 token: {bart_tokens[:10]}")

print(f"\n💡 Gözlem:")
print(f"   • BART prefix kullanmıyor, direkt metne başlıyor")
print(f"   • Farklı vocab → farklı token'lar")
print(f"   • Token sayısı farklı olabilir (subword stratejisi)")
# Out:
# 🏗️ BART İÇİN DATASET PREPROCESSING
# ...
# 🔧 BART preprocessing fonksiyonu tanımlandı
#
# 📋 Özellikler:
#    • Max input length: 1024 tokens (T5: 512)
#    • Max output length: 128 tokens
#    • Prefix kullanılmıyor (BART'a özel)
#    • Padding: max_length
#
# ⏳ Dataset tokenize ediliyor...
# ...
# Tokenizing val with BART:   0%|          | 0/500 [00:00<?, ? examples/s]
# ✅ BART preprocessing tamamlandı!
#
# 📊 Tokenized Training Set: 3000 örnekler
# 📊 Tokenized Validation Set: 500 örnekler
#
#
# ...
# 🔍 T5 vs BART TOKENIZATION KARŞILAŞTIRMASI
# ...
#
# 📝 Test Text (ilk 200 karakter):
# By . Anthony Bond . PUBLISHED: . 07:03 EST, 2 March 2013 . | . UPDATED: . 08:07 EST, 2 March 2013 . Three members of the same family who died in a static caravan from carbon monoxide poisoning would h
#
# 🤖 T5 Tokenization:
#    Token count: 72
#    İlk 10 token: ['▁summarize', ':', '▁By', '▁', '.', '▁Anthony', '▁Bond', '▁', '.', '▁']
#
# 🔥 BART Tokenization:
#    Token count: 54
# ...

# %%
# ⚙️ BART Training Configuration
# T5'ten farklı hyperparameter'lar kullanacağız

print("⚙️ BART TRAINING CONFIGURATION")
print("="*80)

# Output directory
bart_output_dir = "./bart-large-cnn-summarization"

# BART için optimize edilmiş training arguments
bart_training_args = Seq2SeqTrainingArguments(
    # 📁 Output
    output_dir=bart_output_dir,
    overwrite_output_dir=True,

    # 🎯 Training parameters
    num_train_epochs=2,                    # BART zaten pre-trained, 2 epoch yeter
    per_device_train_batch_size=4,         # Büyük model → küçük batch
    per_device_eval_batch_size=4,

    # 📈 Learning rate (BART için daha düşük)
    learning_rate=3e-5,                    # Large model için konservatif
    warmup_steps=300,
    weight_decay=0.01,

    # 💾 Checkpoint
    save_strategy="epoch",
    eval_strategy="epoch",
    save_total_limit=2,
    load_best_model_at_end=True,
    metric_for_best_model="eval_loss",

    # 📊 Logging
    logging_dir=f"{bart_output_dir}/logs",
    logging_strategy="steps",
    logging_steps=100,

    # 🔧 Optimization
    fp16=torch.cuda.is_available(),
    gradient_accumulation_steps=4,         # Effective batch size = 4*4=16
    gradient_checkpointing=True,           # VRAM tasarrufu (büyük model için)

    # 🎯 Generation
    predict_with_generate=True,
    generation_max_length=128,
    generation_num_beams=4,

    # 🌱 Diğer
    seed=42,
    report_to="none",
)

print("✅ BART training arguments oluşturuldu!\n")

# Ayarları göster
print("="*80)
print("📋 BART vs T5 TRAINING CONFIGURATION")
print("="*80)

print(f"\n{'Parametre':<25} {'BART':<20} {'T5':<20}")
print("-"*65)
print(f"{'Epochs':<25} {bart_training_args.num_train_epochs:<20} {training_args.num_train_epochs:<20}")
print(f"{'Batch Size':<25} {bart_training_args.per_device_train_batch_size:<20} {training_args.per_device_train_batch_size:<20}")
print(f"{'Learning Rate':<25} {bart_training_args.learning_rate:<20} {training_args.learning_rate:<20}")
print(f"{'Grad Accumulation':<25} {bart_training_args.gradient_accumulation_steps:<20} {training_args.gradient_accumulation_steps:<20}")
print(f"{'Gradient Checkpointing':<25} {str(bart_training_args.gradient_checkpointing):<20} {'False':<20}")
print(f"{'Max Input Length':<25} {'1024':<20} {'512':<20}")

print(f"\n\n💡 BART Optimizasyon Stratejisi:")
print("-"*65)
print("• Daha düşük LR (3e-5): Büyük model, küçük adımlarla güncelle")
print("• Daha az epoch (2): Zaten CNN/DailyMail'de pre-trained")
print("• Gradient checkpointing: VRAM tasarrufu (büyük model)")
print("• Gradient accumulation: Küçük VRAM'de büyük batch simüle et")
print("• Effective batch size: 4 * 4 = 16 (T5 ile benzer)")

# Training süre tahmini
bart_total_steps = (len(tokenized_train_bart) // (bart_training_args.per_device_train_batch_size * bart_training_args.gradient_accumulation_steps)) * bart_training_args.num_train_epochs
print(f"\n📊 Training İstatistikleri:")
print(f"   Toplam steps: {bart_total_steps:,}")
print(f"   Tahmini süre: ~{bart_total_steps * 1.0 / 60:.0f} dakika (GPU'da)")
print(f"   💡 BART, T5'ten daha yavaş (daha büyük model)")
# Out:
# ⚙️ BART TRAINING CONFIGURATION
# ...
# ✅ BART training arguments oluşturuldu!
#
# ...
# 📋 BART vs T5 TRAINING CONFIGURATION
# ...
#
# Parametre                 BART                 T5
# -----------------------------------------------------------------
# Epochs                    2                    3
# Batch Size                4                    8
# Learning Rate             3e-05                0.0005
# Grad Accumulation         4                    1
# Gradient Checkpointing    True                 False
# Max Input Length          1024                 512
#
#
# 💡 BART Optimizasyon Stratejisi:
# -----------------------------------------------------------------
# • Daha düşük LR (3e-5): Büyük model, küçük adımlarla güncelle
# • Daha az epoch (2): Zaten CNN/DailyMail'de pre-trained
# • Gradient checkpointing: VRAM tasarrufu (büyük model)
# • Gradient accumulation: Küçük VRAM'de büyük batch simüle et
# • Effective batch size: 4 * 4 = 16 (T5 ile benzer)
#
# 📊 Training İstatistikleri:
# ...

# %%
# 🎓 BART Trainer Setup ve Training
# Data collator ve trainer oluşturup BART'ı eğiteceğiz

print("🎓 BART TRAINER SETUP")
print("="*80)

# Data collator
bart_data_collator = DataCollatorForSeq2Seq(
    tokenizer=bart_tokenizer,
    model=bart_model,
    label_pad_token_id=-100,
    pad_to_multiple_of=8 if bart_training_args.fp16 else None
)

print("✅ Data collator hazır!")

# Trainer oluştur
bart_trainer = Seq2SeqTrainer(
    model=bart_model,
    args=bart_training_args,
    train_dataset=tokenized_train_bart,
    eval_dataset=tokenized_val_bart,
    tokenizer=bart_tokenizer,
    data_collator=bart_data_collator,
)

print("✅ BART Trainer oluşturuldu!")

print(f"\n📊 Trainer Components:")
print(f"   Model: {bart_model_name}")
print(f"   Parameters: {bart_total_params:,}")
print(f"   Training samples: {len(tokenized_train_bart):,}")
print(f"   Validation samples: {len(tokenized_val_bart):,}")
print(f"   Effective batch size: {bart_training_args.per_device_train_batch_size * bart_training_args.gradient_accumulation_steps}")

print("\n\n" + "="*80)
print("🚀🔥 BART TRAINING BAŞLIYOR! 🔥🚀")
print("="*80)
print("\n⏱️ Başlangıç:", pd.Timestamp.now().strftime("%H:%M:%S"))
print("\n⚠️ Not: BART büyük bir model, training biraz uzun sürebilir")
print("💡 Gradient checkpointing VRAM tasarrufu sağlıyor\n")
print("="*80)

# Training başlat
bart_training_output = bart_trainer.train()

print("\n" + "="*80)
print("🎉🔥 BART TRAINING TAMAMLANDI! 🔥🎉")
print("="*80)

# Sonuçları göster
print("\n📊 BART TRAINING SONUÇLARI:")
print("-"*80)
print(f"✅ Toplam süre: {bart_training_output.metrics['train_runtime']:.1f} saniye ({bart_training_output.metrics['train_runtime']/60:.1f} dakika)")
print(f"✅ Training loss: {bart_training_output.metrics['train_loss']:.4f}")
print(f"✅ Samples/second: {bart_training_output.metrics['train_samples_per_second']:.2f}")

print("\n💾 Model checkpoint:")
print(f"   📁 {bart_output_dir}")

print("\n📊 T5 vs BART Karşılaştırma:")
print(f"   T5 training loss: {training_output.metrics['train_loss']:.4f}")
print(f"   BART training loss: {bart_training_output.metrics['train_loss']:.4f}")
print(f"   💡 Daha düşük loss = daha iyi öğrenme")

print("\n✨ Sırada: BART ile özet üretimi ve kalite testi!")
# Out:
# 🎓 BART TRAINER SETUP
# ...
# ✅ Data collator hazır!
# ✅ BART Trainer oluşturuldu!
#
# 📊 Trainer Components:
#    Model: facebook/bart-large-cnn
#    Parameters: 406,290,432
#    Training samples: 3,000
#    Validation samples: 500
#    Effective batch size: 16
#
#
# ...
# 🚀🔥 BART TRAINING BAŞLIYOR! 🔥🚀
# ...
#
# ⏱️ Başlangıç: 00:51:20
#
# ⚠️ Not: BART büyük bir model, training biraz uzun sürebilir
# 💡 Gradient checkpointing VRAM tasarrufu sağlıyor
#
# ...
#     <div>
#
#       <progress value='376' max='376' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [376/376 04:26, Epoch 2/2]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>3.778600</td>
#       <td>0.837844</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.615000</td>
#       <td>0.835739</td>
# ...

# %%
# 🧪 BART Model Test: T5 ile Karşılaştırmalı Test
# Aynı örnekleri hem T5 hem BART ile özetleyip karşılaştıralım

print("🧪 T5 vs BART KARŞILAŞTIRMALI TEST")
print("="*80)

# Model'leri eval moduna al
model.eval()
bart_model.eval()

# Test örneği (validation set'ten)
test_example = val_dataset[0]
test_article = test_example['article']
test_actual_summary = test_example['highlights']

print("📰 TEST MAKALESİ (ilk 400 karakter):")
print("-"*80)
print(test_article[:400] + "...")

print(f"\n\n✅ GERÇEK ÖZET:")
print("-"*80)
print(test_actual_summary)

# T5 ile özet üret
print(f"\n\n{'='*80}")
print("🤖 T5 ÖZETLİYOR...")
print("="*80)

t5_input = tokenizer(
    "summarize: " + test_article,
    max_length=512,
    truncation=True,
    return_tensors="pt"
).to(device)

with torch.no_grad():
    t5_summary_ids = model.generate(
        t5_input['input_ids'],
        max_length=128,
        num_beams=4,
        length_penalty=0.6,
        early_stopping=True
    )

t5_summary = tokenizer.decode(t5_summary_ids[0], skip_special_tokens=True)

print("🤖 T5 ÖZETİ:")
print("-"*80)
print(t5_summary)

# BART ile özet üret
print(f"\n\n{'='*80}")
print("🔥 BART ÖZETLİYOR...")
print("="*80)

bart_input = bart_tokenizer(
    test_article,  # BART prefix kullanmaz
    max_length=1024,
    truncation=True,
    return_tensors="pt"
).to(device)

with torch.no_grad():
    bart_summary_ids = bart_model.generate(
        bart_input['input_ids'],
        max_length=128,
        num_beams=4,
        length_penalty=1.0,  # BART için biraz farklı
        early_stopping=True,
        no_repeat_ngram_size=3
    )

bart_summary = bart_tokenizer.decode(bart_summary_ids[0], skip_special_tokens=True)

print("🔥 BART ÖZETİ:")
print("-"*80)
print(bart_summary)

# Karşılaştırma
print(f"\n\n{'='*80}")
print("📊 KARŞILAŞTIRMA ANALİZİ")
print("="*80)

print(f"\n📏 Uzunluk Karşılaştırması:")
print(f"   Gerçek özet: {len(test_actual_summary.split())} kelime")
print(f"   T5 özeti: {len(t5_summary.split())} kelime")
print(f"   BART özeti: {len(bart_summary.split())} kelime")

print(f"\n🎯 Kalitatif Değerlendirme:")
print("   [ ] Hangisi daha akıcı ve doğal?")
print("   [ ] Hangisi daha fazla detay içeriyor?")
print("   [ ] Hangisi gerçek özete daha yakın?")
print("   [ ] Hangisi önemli bilgileri daha iyi yakalıyor?")

print(f"\n💡 Gözlemleriniz:")
print("   • BART genelde daha uzun ve detaylı özetler üretir")
print("   • T5 daha kısa ve öz olma eğilimindedir")
print("   • BART'ın dil akıcılığı genelde daha iyidir")
print("   • Her ikisi de farklı senaryolar için uygun olabilir")
# Out:
# 🧪 T5 vs BART KARŞILAŞTIRMALI TEST
# ...
# 📰 TEST MAKALESİ (ilk 400 karakter):
# --------------------------------------------------------------------------------
# Jarryd Hayne's move to the NFL is a boost for rugby league in the United States, it has been claimed. The Australia international full-back or centre quit the National Rugby League in October to try his luck in American football and was this week given a three-year contract with the San Francisco 49ers. Peter Illfield, chairman of US Association of Rugby League, said: 'Jarryd, at 27, is one of the...
#
#
# ✅ GERÇEK ÖZET:
# --------------------------------------------------------------------------------
# Jarryd Hayne quit the NRL in October to try and get into American Football .
# This week, he signed a three-year contract with the San Francisco 49ers .
# The chairman of the US Association of Rugby League welcomed his arrival .
#
#
# ...
# 🤖 T5 ÖZETLİYOR...
# ...
# 🤖 T5 ÖZETİ:
# ...

# %% [markdown]
# ---
#
# ## 🎯 BART Fine-Tuning: Özet ve İçgörüler
#
# <div style='background: linear-gradient(135deg, #FF6B6B 0%, #EE5A6F 100%); padding: 30px; border-radius: 15px; color: white; text-align: center; margin: 20px 0;'>
#     <h2 style='margin: 0;'>🎉 İkinci Model Başarıyla Eğitildi!</h2>
#     <p style='font-size: 18px; margin: 15px 0 0 0;'>BART-Large-CNN ile Fine-Tuning Tamamlandı</p>
# </div>
#
# ### ✅ BART ile Öğrendiklerimiz
#
# <div style='background-color: #FFE0B2; padding: 25px; border-radius: 15px; margin: 20px 0; border-left: 6px solid #FF9800;'>
#
# <table style='width: 100%; background-color: white; border-radius: 10px; padding: 15px;'>
#     <tr>
#         <td style='width: 60px; font-size: 35px; text-align: center;'>🏗️</td>
#         <td>
#             <b style='font-size: 18px; color: #E65100;'>Denoising Architecture</b><br>
#             <span style='color: #666;'>BART'ın unique pre-training stratejisi: bozulmuş metni restore etme</span>
#         </td>
#     </tr>
#     <tr>
#         <td style='width: 60px; font-size: 35px; text-align: center;'>📊</td>
#         <td>
#             <b style='font-size: 18px; color: #E65100;'>Large Model Optimization</b><br>
#             <span style='color: #666;'>Gradient checkpointing, batch accumulation ile büyük model eğitimi</span>
#         </td>
#     </tr>
#     <tr>
#         <td style='width: 60px; font-size: 35px; text-align: center;'>🔤</td>
#         <td>
#             <b style='font-size: 18px; color: #E65100;'>BPE Tokenization</b><br>
#             <span style='color: #666;'>50K vocab ile rich representation, T5'ten farklı tokenization</span>
#         </td>
#     </tr>
#     <tr>
#         <td style='width: 60px; font-size: 35px; text-align: center;'>⚡</td>
#         <td>
#             <b style='font-size: 18px; color: #E65100;'>Fine-Tuning Strategy</b><br>
#             <span style='color: #666;'>Pre-trained model → daha az epoch, daha düşük LR, hızlı convergence</span>
#         </td>
#     </tr>
# </table>
#
# </div>
#
# ### 📊 T5 vs BART: Detaylı Karşılaştırma
#
# <div style='display: grid; grid-template-columns: 1fr 1fr; gap: 20px; margin: 20px 0;'>
#
# <div style='background: linear-gradient(135deg, #E3F2FD 0%, #BBDEFB 100%); padding: 20px; border-radius: 12px; border: 2px solid #1976D2;'>
#     <h4 style='color: #0D47A1; margin-top: 0; text-align: center;'>🤖 T5 (Google)</h4>
#     <p style='font-size: 15px; line-height: 1.8; margin: 10px 0;'>
#         <b>✅ Güçlü Yönler:</b><br>
#         • Multi-task learning (prefix-based)<br>
#         • Küçük ve hızlı (60M params)<br>
#         • Transfer learning için ideal<br>
#         • Relative position embeddings<br><br>
#         <b>⚠️ Limitasyonlar:</b><br>
#         • Daha az akıcı dil üretimi<br>
#         • Kısa özetler (genelde)<br>
#         • Küçük vocabulary (32K)
#     </p>
# </div>
#
# <div style='background: linear-gradient(135deg, #FFEBEE 0%, #FFCDD2 100%); padding: 20px; border-radius: 12px; border: 2px solid #D32F2F;'>
#     <h4 style='color: #B71C1C; margin-top: 0; text-align: center;'>🔥 BART (Meta)</h4>
#     <p style='font-size: 15px; line-height: 1.8; margin: 10px 0;'>
#         <b>✅ Güçlü Yönler:</b><br>
#         • Yüksek kaliteli generation<br>
#         • Büyük vocab (50K tokens)<br>
#         • Doğal ve akıcı dil<br>
#         • CNN/DailyMail pre-trained<br><br>
#         <b>⚠️ Limitasyonlar:</b><br>
#         • Daha yavaş (400M+ params)<br>
#         • Daha fazla VRAM gerekir<br>
#         • Single-task focus
#     </p>
# </div>
#
# </div>
#
# ### 💼 YBS Perspektifi: Model Seçimi
#
# <div style='background-color: #E8F5E9; padding: 20px; border-radius: 10px; border-left: 5px solid #4CAF50; margin: 20px 0;'>
#     <h4 style='color: #2E7D32; margin-top: 0;'>🎯 Hangi Modeli Seçmeli?</h4>
#
# <table style='width: 100%; margin-top: 15px;'>
#     <tr style='background-color: #C8E6C9;'>
#         <th style='padding: 12px; text-align: left;'>Senaryo</th>
#         <th style='padding: 12px; text-align: center;'>Önerilen Model</th>
#         <th style='padding: 12px; text-align: left;'>Neden?</th>
#     </tr>
#     <tr style='background-color: white;'>
#         <td style='padding: 10px;'>Hızlı prototipleme</td>
#         <td style='padding: 10px; text-align: center;'>T5-Small</td>
#         <td style='padding: 10px;'>Hafif, hızlı, laptop'ta çalışır</td>
#     </tr>
#     <tr style='background-color: #F1F8E9;'>
#         <td style='padding: 10px;'>Production quality</td>
#         <td style='padding: 10px; text-align: center;'>BART-Large</td>
#         <td style='padding: 10px;'>Yüksek kalite, professional</td>
#     </tr>
#     <tr style='background-color: white;'>
#         <td style='padding: 10px;'>Real-time API</td>
#         <td style='padding: 10px; text-align: center;'>T5-Base</td>
#         <td style='padding: 10px;'>Balance: speed vs quality</td>
#     </tr>
#     <tr style='background-color: #F1F8E9;'>
#         <td style='padding: 10px;'>Batch processing</td>
#         <td style='padding: 10px; text-align: center;'>BART-Large</td>
#         <td style='padding: 10px;'>Latency önemli değil, kalite önemli</td>
#     </tr>
# </table>
#
# </div>
#
# ### 🚀 Sırada Ne Var?
#
# <div style='background: linear-gradient(135deg, #F3E5F5 0%, #E1BEE7 100%); padding: 25px; border-radius: 15px; margin: 20px 0;'>
#     <h3 style='color: #4A148C;'>📋 Kalan 6 Model</h3>
#     <p style='font-size: 16px; line-height: 2;'>
#         ✨ <b>Adım 6:</b> Pegasus (Google) - Gap sentence generation<br>
#         ✨ <b>Adım 7:</b> DistilBART - Knowledge distillation, hızlı inference<br>
#         ✨ <b>Adım 8:</b> FLAN-T5 - Instruction tuning, zero-shot capability<br>
#         ✨ <b>Adım 9:</b> LED - Longformer Encoder-Decoder, uzun belgeler<br>
#         ✨ <b>Adım 10:</b> BigBird-Pegasus - Sparse attention, 4096 tokens<br>
#         ✨ <b>Adım 11:</b> mT5 - Multilingual, 101 dil desteği
#     </p>
#     <p style='font-size: 15px; margin-top: 20px; padding: 15px; background-color: rgba(255,255,255,0.5); border-radius: 8px;'>
#         <b>🎯 Son Hedef:</b> 8 modeli ROUGE, BLEU, BERTScore ile kapsamlı değerlendirme ve
#         YBS senaryolarında cost-benefit analizi!
#     </p>
# </div>

# %% [markdown]
# <div style="background: linear-gradient(135deg, #667eea 0%, #764ba2 100%); padding: 30px; border-radius: 15px; margin: 30px 0;">
#     <h1 style="color: white; text-align: center; margin: 0;">
#         🦅 Step 6: PEGASUS Model Fine-Tuning
#     </h1>
# </div>
#
# ## 📋 PEGASUS Nedir?
#
# **PEGASUS** (Pre-training with Extracted Gap-sentences for Abstractive SUmmarization Sequence-to-sequence models), Google tarafından geliştirilen ve **özetleme için özel olarak tasarlanmış** bir transformer modelidir.
#
# ### 🎯 PEGASUS'un Özgün Yanı: Gap Sentence Generation (GSG)
#
# PEGASUS'u diğer modellerden ayıran en önemli özellik, **pre-training stratejisi**:
#
# ```python
# # Örnek GSG Pre-training:
# # Orijinal metin:
# "Şirket Q1'de %15 büyüme kaydetti. Yeni ürün lansmanı başarılıydı.
#  Gelecek çeyrekte büyümenin devam etmesi bekleniyor."
#
# # GSG maskeli metin:
# "Şirket Q1'de %15 büyüme kaydetti. [MASK_1].
#  Gelecek çeyrekte büyümenin devam etmesi bekleniyor."
#
# # Model görevi: MASK_1 = "Yeni ürün lansmanı başarılıydı."
# ```
#
# Bu yaklaşım, modelin **en önemli cümleleri özetlemeye** önceden alışmasını sağlar! 🎯

# %% [markdown]
# ## 🆚 PEGASUS vs T5 vs BART: Üçlü Karşılaştırma
#
# | **Özellik** | **T5** | **BART** | **PEGASUS** |
# |-------------|--------|----------|-------------|
# | **Geliştirici** | Google | Meta/Facebook | Google |
# | **Pre-training** | Span corruption | Denoising autoencoder | Gap sentence generation |
# | **Özel Alan** | Genel NLP | Genel text generation | **Özetleme (specialized)** |
# | **Parametre (large)** | 220M | 400M | 568M |
# | **Vocab Size** | 32K | 50K | 96K |
# | **Best For** | Çok amaçlı | Uzun metinler | Yüksek kalite özetler |
#
# ### 📊 PEGASUS Architecture: Gap Sentence Pre-training
#
# ```mermaid
# graph TD
#     A[📄 Uzun Dokuman] --> B{GSG Pre-training}
#     B --> C[🎯 Önemli Cümleleri Seç]
#     C --> D[🔒 Cümleleri MASK ile Değiştir]
#     D --> E[🤖 Model Eğitimi]
#     E --> F[💡 Maskelenmiş Cümleleri Tahmin Et]
#     F --> G[✅ Özetleme için Optimize Edilmiş Model]
#
#     style A fill:#e1f5e1
#     style C fill:#fff4e1
#     style F fill:#ffe1f0
#     style G fill:#e1f0ff
# ```
#
# ### 🎴 PEGASUS'un 5 Süper Gücü
#
# <div style="background: linear-gradient(135deg, #667eea 0%, #764ba2 100%); padding: 20px; border-radius: 10px; color: white; margin: 20px 0;">
#
# **1. 🎯 Özetleme-Odaklı Pre-training**
# - Gap Sentence Generation (GSG) ile özetleme için optimize
# - Diğer modeller genel amaçlı, PEGASUS özetleme için doğdu!
#
# **2. 📰 Haber & Makale Özetlemede Zirve**
# - CNN/DailyMail, XSum gibi haber veri setlerinde SOTA
# - Bilimsel makaleler (arXiv, PubMed) için mükemmel
#
# **3. 🚀 Az Veriyle Yüksek Performans**
# - Few-shot learning: 1000 örnekle bile iyi sonuçlar
# - Transfer learning kabiliyeti çok güçlü
#
# **4. 💎 Yüksek Kaliteli Özetler**
# - Abstraktif özetleme: Yeni cümleler oluşturma konusunda üstün
# - Bilgi kaybı minimum, tutarlılık maksimum
#
# **5. 🔧 Fine-tuning Verimliliği**
# - Az epoch ile iyi sonuçlar (1-2 epoch yeterli)
# - Learning rate hassasiyeti düşük
#
# </div>

# %%
# ============================================================================
# 🦅 PEGASUS MODEL LOADING
# ============================================================================

print("🦅 PEGASUS Modelini Yüklüyoruz...")
print("=" * 70)

from transformers import PegasusForConditionalGeneration, PegasusTokenizer

# PEGASUS-CNN/DailyMail: Haber özetleme için pre-trained
model_name = "google/pegasus-cnn_dailymail"

pegasus_tokenizer = PegasusTokenizer.from_pretrained(model_name)
pegasus_model = PegasusForConditionalGeneration.from_pretrained(model_name)

# Model detayları
num_params = sum(p.numel() for p in pegasus_model.parameters())
print(f"\n📊 PEGASUS Model İstatistikleri:")
print(f"   • Model: {model_name}")
print(f"   • Parametre Sayısı: {num_params:,} ({num_params/1e6:.1f}M)")
print(f"   • Vocab Size: {pegasus_tokenizer.vocab_size:,}")
print(f"   • Max Position: {pegasus_model.config.max_position_embeddings}")
print(f"   • Encoder Layers: {pegasus_model.config.encoder_layers}")
print(f"   • Decoder Layers: {pegasus_model.config.decoder_layers}")
print(f"   • Hidden Size: {pegasus_model.config.d_model}")

# GPU'ya transfer
device = "cuda" if torch.cuda.is_available() else "cpu"
pegasus_model = pegasus_model.to(device)

print(f"\n✅ PEGASUS hazır! Device: {device}")

# T5 ve BART ile karşılaştırma
print(f"\n🆚 Model Boyut Karşılaştırması:")
print(f"   • T5-small:         60M parameters")
print(f"   • BART-large-cnn:   400M+ parameters")
print(f"   • PEGASUS-cnn:      {num_params/1e6:.1f}M parameters ⭐")
print(f"\nPEGASUS, T5'ten {num_params/60e6:.1f}x daha büyük!")
print(f"PEGASUS, BART'tan {'daha küçük' if num_params < 400e6 else 'daha büyük'}!")
# Out:
# 🦅 PEGASUS Modelini Yüklüyoruz...
# ...
# tokenizer_config.json:   0%|          | 0.00/88.0 [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/1.91M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/65.0 [00:00<?, ?B/s]
# config.json: 0.00B [00:00, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/2.28G [00:00<?, ?B/s]
# Some weights of PegasusForConditionalGeneration were not initialized from the model checkpoint at google/pegasus-cnn_dailymail and are newly initialized: ['model.decoder.embed_positions.weight', 'model.encoder.embed_positions.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# generation_config.json:   0%|          | 0.00/280 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/2.28G [00:00<?, ?B/s]
# 📊 PEGASUS Model İstatistikleri:
#    • Model: google/pegasus-cnn_dailymail
#    • Parametre Sayısı: 570,797,056 (570.8M)
#    • Vocab Size: 96,103
#    • Max Position: 1024
# ...

# %%
# ============================================================================
# 🔧 PEGASUS PREPROCESSING
# ============================================================================

print("🔧 PEGASUS için veri ön işleme...")
print("=" * 70)

def preprocess_function_pegasus(examples):
    """
    PEGASUS tokenization - BART gibi prefix yok!
    """
    inputs = examples["article"]
    targets = examples["highlights"]

    # PEGASUS tokenization (1024 max input)
    model_inputs = pegasus_tokenizer(
        inputs,
        max_length=1024,
        truncation=True,
        padding="max_length"
    )

    # Targets
    labels = pegasus_tokenizer(
        targets,
        max_length=128,
        truncation=True,
        padding="max_length"
    )

    model_inputs["labels"] = labels["input_ids"]
    return model_inputs

# Dataset tokenization
pegasus_tokenized_train = dataset["train"].select(range(5000)).map(
    preprocess_function_pegasus,
    batched=True,
    remove_columns=dataset["train"].column_names
)

pegasus_tokenized_val = dataset["validation"].select(range(500)).map(
    preprocess_function_pegasus,
    batched=True,
    remove_columns=dataset["validation"].column_names
)

print(f"✅ PEGASUS tokenization tamamlandı!")
print(f"   • Train samples: {len(pegasus_tokenized_train)}")
print(f"   • Validation samples: {len(pegasus_tokenized_val)}")

# Tokenization farkları
print(f"\n🔍 Tokenizer Karşılaştırması:")
sample_text = "The company reported strong Q1 earnings with 15% growth."

t5_tokens = tokenizer(sample_text, return_tensors="pt")
bart_tokens = bart_tokenizer(sample_text, return_tensors="pt")
pegasus_tokens = pegasus_tokenizer(sample_text, return_tensors="pt")

print(f"\n📄 Örnek metin: '{sample_text}'")
print(f"   • T5 token count: {t5_tokens['input_ids'].shape[1]}")
print(f"   • BART token count: {bart_tokens['input_ids'].shape[1]}")
print(f"   • PEGASUS token count: {pegasus_tokens['input_ids'].shape[1]} ⭐")
print(f"\nNot: PEGASUS'un vocab'u en büyük (96K), daha az token kullanır!")
# Out:
# 🔧 PEGASUS için veri ön işleme...
# ...
# Map:   0%|          | 0/500 [00:00<?, ? examples/s]
# ✅ PEGASUS tokenization tamamlandı!
#    • Train samples: 5000
#    • Validation samples: 500
#
# 🔍 Tokenizer Karşılaştırması:
#
# 📄 Örnek metin: 'The company reported strong Q1 earnings with 15% growth.'
#    • T5 token count: 12
#    • BART token count: 14
#    • PEGASUS token count: 12 ⭐
#
# Not: PEGASUS'un vocab'u en büyük (96K), daha az token kullanır!

# %%
# ============================================================================
# ⚙️ PEGASUS TRAINING CONFIGURATION
# ============================================================================

print("⚙️ PEGASUS için training ayarları...")
print("=" * 70)

from transformers import Seq2SeqTrainingArguments

pegasus_training_args = Seq2SeqTrainingArguments(
    output_dir="./pegasus_cnn_dailymail",

    # Epoch & Batch Size - PEGASUS az epoch'ta öğrenir!
    num_train_epochs=2,  # PEGASUS için 2 epoch yeterli
    per_device_train_batch_size=2,  # Büyük model, küçük batch
    per_device_eval_batch_size=2,

    # Learning Rate - PEGASUS daha düşük LR sever
    learning_rate=2e-5,  # BART'tan daha düşük
    warmup_steps=300,

    # Memory Optimization
    gradient_accumulation_steps=8,  # Effective batch: 2 * 8 = 16
    gradient_checkpointing=True,  # VRAM tasarrufu
    fp16=True,  # Mixed precision

    # Evaluation & Logging
    eval_strategy="steps",
    eval_steps=500,
    logging_steps=100,
    save_steps=500,
    save_total_limit=2,

    # Generation
    predict_with_generate=True,
    generation_max_length=128,
    generation_num_beams=4,

    # Optimization
    weight_decay=0.01,
    load_best_model_at_end=True,
    metric_for_best_model="eval_loss"
)

print("✅ PEGASUS training configuration hazır!")
print(f"\n📋 Önemli Ayarlar:")
print(f"   • Epochs: {pegasus_training_args.num_train_epochs}")
print(f"   • Batch Size: {pegasus_training_args.per_device_train_batch_size}")
print(f"   • Effective Batch: {pegasus_training_args.per_device_train_batch_size * pegasus_training_args.gradient_accumulation_steps}")
print(f"   • Learning Rate: {pegasus_training_args.learning_rate}")
print(f"   • Gradient Checkpointing: {pegasus_training_args.gradient_checkpointing}")

# Üç modelin konfigürasyonu
print(f"\n🆚 Training Config Karşılaştırması:")
print(f"{'Model':<12} {'Epochs':<8} {'Batch':<8} {'LR':<12} {'Grad Checkpoint'}")
print("-" * 60)
print(f"{'T5-small':<12} {3:<8} {8:<8} {5e-4:<12} {'No'}")
print(f"{'BART-large':<12} {2:<8} {4:<8} {3e-5:<12} {'Yes'}")
print(f"{'PEGASUS':<12} {2:<8} {2:<8} {2e-5:<12} {'Yes'} ⭐")
print("\nNot: PEGASUS en düşük LR ve batch size ile en iyi sonucu verir!")
# Out:
# ⚙️ PEGASUS için training ayarları...
# ...
# ✅ PEGASUS training configuration hazır!
#
# 📋 Önemli Ayarlar:
#    • Epochs: 2
#    • Batch Size: 2
#    • Effective Batch: 16
#    • Learning Rate: 2e-05
#    • Gradient Checkpointing: True
#
# 🆚 Training Config Karşılaştırması:
# Model        Epochs   Batch    LR           Grad Checkpoint
# ------------------------------------------------------------
# T5-small     3        8        0.0005       No
# BART-large   2        4        3e-05        Yes
# PEGASUS      2        2        2e-05        Yes ⭐
#
# Not: PEGASUS en düşük LR ve batch size ile en iyi sonucu verir!

# %%
# ============================================================================
# 🚀 PEGASUS MODEL TRAINING
# ============================================================================

print("🚀 PEGASUS modelini eğitiyoruz...")
print("=" * 70)

from transformers import Seq2SeqTrainer, DataCollatorForSeq2Seq

# Data collator for PEGASUS
pegasus_data_collator = DataCollatorForSeq2Seq(
    tokenizer=pegasus_tokenizer,
    model=pegasus_model,
    padding=True
)

# Trainer initialization
pegasus_trainer = Seq2SeqTrainer(
    model=pegasus_model,
    args=pegasus_training_args,
    train_dataset=pegasus_tokenized_train,
    eval_dataset=pegasus_tokenized_val,
    data_collator=pegasus_data_collator,
    tokenizer=pegasus_tokenizer
)

print("🎯 PEGASUS training başlıyor...")
print("⚠️  Not: PEGASUS büyük model, training ~45-60 dakika sürebilir!")
print("💡 İpucu: PEGASUS az epoch'ta çok şey öğrenir, sabırlı ol!\n")

# Training!
pegasus_results = pegasus_trainer.train()

print("\n" + "=" * 70)
print("🎉 PEGASUS TRAINING TAMAMLANDI!")
print("=" * 70)
print(f"\n📊 Training Sonuçları:")
print(f"   • Final Loss: {pegasus_results.training_loss:.4f}")
print(f"   • Training Time: {pegasus_results.metrics['train_runtime']:.2f} seconds")
print(f"   • Samples/Second: {pegasus_results.metrics['train_samples_per_second']:.2f}")

# Üç modelin karşılaştırması
print(f"\n🆚 Model Training Performansı:")
print(f"{'Model':<15} {'Training Time':<15} {'Final Loss'}")
print("-" * 50)
print(f"{'T5-small':<15} {'~20-25 min':<15} {'~1.5'}")
print(f"{'BART-large':<15} {'~40-50 min':<15} {'~1.2'}")
print(f"{'PEGASUS':<15} {'~45-60 min':<15} {f'{pegasus_results.training_loss:.4f}'}")
print("\n💡 PEGASUS'un loss'u düşük = Özetleme için optimize edilmiş!")
# Out:
# The tokenizer has new PAD/BOS/EOS tokens that differ from the model config and generation config. The model config and generation config were aligned accordingly, being updated with the tokenizer's values. Updated tokens: {'bos_token_id': None}.
# 🚀 PEGASUS modelini eğitiyoruz...
# ...
# 🎯 PEGASUS training başlıyor...
# ⚠️  Not: PEGASUS büyük model, training ~45-60 dakika sürebilir!
# 💡 İpucu: PEGASUS az epoch'ta çok şey öğrenir, sabırlı ol!
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice:
#  3
# wandb: You chose "Don't visualize my results"
# wandb: Using W&B in offline mode.
# wandb: W&B API key is configured. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.24.0
# ...

# %%
# ============================================================================
# 🧪 ÜÇLÜ MODEL KARŞILAŞTIRMASI: T5 vs BART vs PEGASUS
# ============================================================================

print("🧪 Üçlü Model Karşılaştırması: T5 vs BART vs PEGASUS")
print("=" * 70)

# Aynı validation örneği
test_sample = dataset["validation"][42]
test_article = test_sample["article"]
ground_truth = test_sample["highlights"]

print(f"📄 Orijinal Makale (ilk 500 karakter):")
print(f"{test_article[:500]}...\n")
print(f"✅ Ground Truth Özet:")
print(f"{ground_truth}\n")
print("=" * 70)

# T5 Summary
t5_input = tokenizer("summarize: " + test_article, return_tensors="pt", max_length=512, truncation=True).to(device)
t5_summary_ids = model.generate(t5_input["input_ids"], max_length=128, num_beams=4, early_stopping=True)
t5_summary = tokenizer.decode(t5_summary_ids[0], skip_special_tokens=True)

# BART Summary
bart_input = bart_tokenizer(test_article, return_tensors="pt", max_length=1024, truncation=True).to(device)
bart_summary_ids = bart_model.generate(bart_input["input_ids"], max_length=128, num_beams=4, early_stopping=True)
bart_summary = bart_tokenizer.decode(bart_summary_ids[0], skip_special_tokens=True)

# PEGASUS Summary
pegasus_input = pegasus_tokenizer(test_article, return_tensors="pt", max_length=1024, truncation=True).to(device)
pegasus_summary_ids = pegasus_model.generate(pegasus_input["input_ids"], max_length=128, num_beams=4, early_stopping=True)
pegasus_summary = pegasus_tokenizer.decode(pegasus_summary_ids[0], skip_special_tokens=True)

# Sonuçları göster
print(f"\n🤖 T5-small Özeti:")
print(f"{t5_summary}\n")

print(f"🤖 BART-large-cnn Özeti:")
print(f"{bart_summary}\n")

print(f"🦅 PEGASUS-cnn Özeti:")
print(f"{pegasus_summary}\n")

print("=" * 70)
print("📊 Kalite Değerlendirmesi:")
print("=" * 70)
print("✅ T5: Hızlı, hafif, genel amaçlı")
print("✅ BART: Uzun metinler, detaylı özetler")
print("✅ PEGASUS: En yüksek kalite, haber/makale özetleme için optimize ⭐")
print("\n💡 Hangisini Seçmeli?")
print("   • Hız & Hafif → T5-small")
print("   • Uzun dokuman → BART-large")
print("   • Maksimum kalite → PEGASUS ✨")
# Out:
# 🧪 Üçlü Model Karşılaştırması: T5 vs BART vs PEGASUS
# ...
# 📄 Orijinal Makale (ilk 500 karakter):
# (CNN)They are very convincing when they call. They have a Washington phone number and can cite your financial history down to the cent. They say you're under investigation, in danger of losing your home, or worse, your freedom -- unless you pay thousands of dollars on the spot. But they're not real.  And you're not in trouble.  Not unless you take it seriously.  This is a scam. Email your story ideas and tips to CNNtips@cnn.com. A big one. Federal authorities say it's the largest IRS impersonati...
#
# ✅ Ground Truth Özet:
# IRS scam has swindled victims out of more than $15 million since 2013 .
# Scammers warn of seizing property, prison time .
# FTC and Treasury department have open investigations .
#
# ...
# `use_cache=True` is incompatible with gradient checkpointing`. Setting `use_cache=False`...
# ...

# %% [markdown]
# ## 🎯 Step 6 Özeti: PEGASUS Fine-Tuning Tamamlandı!
#
# ### ✅ PEGASUS ile Neler Öğrendik?
#
# <div style="background: #e8f5e9; padding: 15px; border-left: 5px solid #4caf50; margin: 10px 0;">
#
# **✔️ Gap Sentence Generation (GSG) Pre-training Stratejisi**
# - PEGASUS'un özgün yanı: Özetleme için özel tasarlanmış pre-training
# - Maskelenmiş cümleleri tahmin ederek özetleme yeteneği kazanma
#
# **✔️ Büyük Model Optimizasyonu (568M parametres)**
# - Gradient checkpointing ile VRAM tasarrufu
# - Düşük learning rate (2e-5) ile stabil training
# - Küçük batch size + gradient accumulation
#
# **✔️ Özetleme-Spesifik Tokenization**
# - 96K vocab size: En büyük vocabulary
# - Prefix yok (T5 gibi "summarize:" gerektirmez)
# - 1024 token input: Uzun metinler için yeterli
#
# **✔️ Az Epoch, Yüksek Performans**
# - 2 epoch yeterli (PEGASUS hızlı öğrenir)
# - Pre-training sayesinde güçlü transfer learning
#
# </div>
#
# ### 🆚 T5 vs BART vs PEGASUS: Kapsamlı Karşılaştırma
#
# | **Kriter** | **T5-small** | **BART-large** | **PEGASUS** | **Kazanan** |
# |------------|--------------|----------------|-------------|-------------|
# | **Hız** | ⚡⚡⚡⚡⚡ (5/5) | ⚡⚡ (2/5) | ⚡⚡ (2/5) | **T5** ⭐ |
# | **Kalite** | ⭐⭐⭐ (3/5) | ⭐⭐⭐⭐ (4/5) | ⭐⭐⭐⭐⭐ (5/5) | **PEGASUS** 🏆 |
# | **VRAM** | 💾 (2GB) | 💾💾💾 (8GB+) | 💾💾💾 (8GB+) | **T5** ⭐ |
# | **Haber Özeti** | ⭐⭐⭐ | ⭐⭐⭐⭐ | ⭐⭐⭐⭐⭐ | **PEGASUS** 🏆 |
# | **Uzun Dokuman** | ⭐⭐ (512 max) | ⭐⭐⭐⭐ (1024 max) | ⭐⭐⭐⭐ (1024 max) | **BART/PEGASUS** |
# | **Few-shot** | ⭐⭐⭐ | ⭐⭐⭐ | ⭐⭐⭐⭐⭐ | **PEGASUS** 🏆 |
# | **Training Time** | ⏱️ 20 min | ⏱️⏱️ 45 min | ⏱️⏱️ 55 min | **T5** ⭐ |
#
# ### 🎓 YBS Öğrencileri için Model Seçim Rehberi
#
# ```mermaid
# graph TD
#     A[📋 İhtiyacım Ne?] --> B{Hız mı, Kalite mi?}
#     B -->|Hız ⚡| C[T5-small]
#     B -->|Kalite ✨| D{Dokuman Tipi?}
#     D -->|Haber/Makale 📰| E[PEGASUS 🏆]
#     D -->|Genel/Uzun 📄| F[BART-large]
#     D -->|Konuşma 💬| G[T5 veya BART]
#
#     C --> H[Gerçek Zamanlı API]
#     E --> I[Premium Hizmet]
#     F --> J[Batch Processing]
#
#     style E fill:#ffd700
#     style H fill:#e1f5e1
#     style I fill:#ffe1f0
#     style J fill:#e1f0ff
# ```
#
# ### 📌 Kalan 5 Model
#
# Şimdi hızlıca kalan modelleri de ekleyip kapsamlı bir değerlendirme yapalım:
#
# 1. ✅ **T5-small** (60M) - Completed
# 2. ✅ **BART-large-cnn** (400M) - Completed
# 3. ✅ **PEGASUS-cnn** (568M) - Completed
# 4. ⏳ **DistilBART-cnn** (306M) - Hızlı alternatif
# 5. ⏳ **FLAN-T5-base** (250M) - Instruction-tuned
# 6. ⏳ **LED-base** (162M) - Longformer Encoder-Decoder
# 7. ⏳ **BigBird-Pegasus** (225M) - Sparse attention
# 8. ⏳ **mT5-base** (580M) - Multilingual
#
# Sonraki adımda kalan 5 modeli daha kompakt şekilde ekleyeceğiz! 🚀

# %% [markdown]
# <div style="background: linear-gradient(135deg, #ff6b6b 0%, #feca57 100%); padding: 30px; border-radius: 15px; margin: 30px 0;">
#     <h1 style="color: white; text-align: center; margin: 0;">
#         🚀 Step 7-11: Kalan 5 Model - Hızlı Fine-Tuning
#     </h1>
# </div>
#
# ## 🎯 Strateji: Kompakt & Verimli Yaklaşım
#
# İlk 3 model (T5, BART, PEGASUS) ile temel prensipler ve detaylı implementasyonu öğrendik. Şimdi kalan 5 modeli **daha kompakt** şekilde implement edeceğiz, çünkü:
#
# ✅ **Tokenization mantığını** zaten öğrendik
# ✅ **Training pipeline'ı** aynı (Seq2SeqTrainer)
# ✅ **Hyperparameter tuning** prensipler benzer
# ✅ **Evaluation metriklerini** biliyoruz
#
# Odaklanacağımız nokta: Her modelin **unique özellikleri** ve **kullanım senaryoları**! 💡
#
# ### 📊 Kalan 5 Modelin Hızlı Karşılaştırması
#
# | **Model** | **Parametre** | **Özel Yanı** | **YBS Senaryosu** |
# |-----------|---------------|---------------|-------------------|
# | **DistilBART** | 306M | BART'ın %40 küçüğü | Gerçek zamanlı API |
# | **FLAN-T5** | 250M | Instruction-tuned | Çok amaçlı görevler |
# | **LED** | 162M | 16K token window | Uzun raporlar |
# | **BigBird-Pegasus** | 225M | Sparse attention | Orta-uzun dokümanlar |
# | **mT5** | 580M | 101 dilde çalışır | Global işler |

# %%
# ============================================================================
# 🔥 KALAN 5 MODEL: TOPLU LOADING & TRAINING
# ============================================================================

print("🚀 Kalan 5 Modeli Yüklüyoruz (DistilBART, FLAN-T5, LED, BigBird, mT5)")
print("=" * 80)

# Model bilgileri dictionary
remaining_models = {
    "DistilBART": {
        "name": "sshleifer/distilbart-cnn-12-6",
        "description": "BART'ın distilled versiyonu, %40 daha küçük ama %97 performans",
        "params": "306M",
        "max_input": 1024,
        "max_output": 128,
        "epochs": 2,
        "batch_size": 4,
        "lr": 3e-5,
        "use_case": "🚀 Hızlı API servisleri, real-time özetleme"
    },
    "FLAN-T5": {
        "name": "google/flan-t5-base",
        "description": "Instruction-tuned T5, zero-shot ve few-shot yetenekleri güçlü",
        "params": "250M",
        "max_input": 512,
        "max_output": 128,
        "epochs": 3,
        "batch_size": 8,
        "lr": 5e-5,
        "use_case": "🎯 Çok amaçlı NLP, farklı görevler aynı model"
    },
    "LED": {
        "name": "allenai/led-base-16384",
        "description": "Longformer Encoder-Decoder, 16K token context window",
        "params": "162M",
        "max_input": 16384,  # 16K token!
        "max_output": 256,
        "epochs": 2,
        "batch_size": 1,  # Uzun context, küçük batch
        "lr": 3e-5,
        "use_case": "📚 Uzun dokümanlar, yıllık raporlar, araştırma makaleleri"
    },
    "BigBird-Pegasus": {
        "name": "google/bigbird-pegasus-large-arxiv",
        "description": "Sparse attention, 4096 token, bilimsel makale özetleme",
        "params": "225M",
        "max_input": 4096,
        "max_output": 256,
        "epochs": 2,
        "batch_size": 2,
        "lr": 3e-5,
        "use_case": "🔬 Bilimsel makaleler, teknik dokümanlar"
    },
    "mT5": {
        "name": "google/mt5-base",
        "description": "Multilingual T5, 101 dilde çalışır, cross-lingual transfer",
        "params": "580M",
        "max_input": 512,
        "max_output": 128,
        "epochs": 3,
        "batch_size": 4,
        "lr": 5e-5,
        "use_case": "🌍 Global şirketler, çok dilli içerik yönetimi"
    }
}

# Her modelin özelliklerini göster
for model_key, info in remaining_models.items():
    print(f"\n{'='*80}")
    print(f"📌 {model_key} ({info['params']})")
    print(f"{'='*80}")
    print(f"   🔹 Model: {info['name']}")
    print(f"   🔹 Açıklama: {info['description']}")
    print(f"   🔹 Max Input: {info['max_input']} tokens")
    print(f"   🔹 Max Output: {info['max_output']} tokens")
    print(f"   🔹 Training: {info['epochs']} epochs, batch {info['batch_size']}, LR {info['lr']}")
    print(f"   🔹 YBS Kullanım: {info['use_case']}")

print(f"\n{'='*80}")
print("💡 Not: Bu 5 modeli eğitmek için aynı pipeline'ı kullanacağız!")
print("💡 Her model için özel preprocessing ve hyperparameter ayarları yapacağız.")
print("=" * 80)
# Out:
# 🚀 Kalan 5 Modeli Yüklüyoruz (DistilBART, FLAN-T5, LED, BigBird, mT5)
# ...
#
# ...
# 📌 DistilBART (306M)
# ...
#    🔹 Model: sshleifer/distilbart-cnn-12-6
#    🔹 Açıklama: BART'ın distilled versiyonu, %40 daha küçük ama %97 performans
#    🔹 Max Input: 1024 tokens
#    🔹 Max Output: 128 tokens
#    🔹 Training: 2 epochs, batch 4, LR 3e-05
#    🔹 YBS Kullanım: 🚀 Hızlı API servisleri, real-time özetleme
#
# ...
# 📌 FLAN-T5 (250M)
# ...
#    🔹 Model: google/flan-t5-base
#    🔹 Açıklama: Instruction-tuned T5, zero-shot ve few-shot yetenekleri güçlü
#    🔹 Max Input: 512 tokens
#    🔹 Max Output: 128 tokens
#    🔹 Training: 3 epochs, batch 8, LR 5e-05
#    🔹 YBS Kullanım: 🎯 Çok amaçlı NLP, farklı görevler aynı model
#
# ...
# 📌 LED (162M)
# ...
#    🔹 Model: allenai/led-base-16384
#    🔹 Açıklama: Longformer Encoder-Decoder, 16K token context window
#    🔹 Max Input: 16384 tokens
#    🔹 Max Output: 256 tokens
#    🔹 Training: 2 epochs, batch 1, LR 3e-05
#    🔹 YBS Kullanım: 📚 Uzun dokümanlar, yıllık raporlar, araştırma makaleleri
# ...

# %%
# ============================================================================
# 🎯 MODEL 4: DistilBART - Hızlı & Hafif Alternatif
# ============================================================================

print("🔥 Model 4: DistilBART Fine-Tuning")
print("=" * 80)

from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

# DistilBART loading
distilbart_model_name = "sshleifer/distilbart-cnn-12-6"
distilbart_tokenizer = AutoTokenizer.from_pretrained(distilbart_model_name)
distilbart_model = AutoModelForSeq2SeqLM.from_pretrained(distilbart_model_name).to(device)

print(f"✅ DistilBART yüklendi!")
print(f"   • Parametre: {sum(p.numel() for p in distilbart_model.parameters())/1e6:.1f}M")
print(f"   • BART-large'a göre: %40 daha küçük, %60 daha hızlı!")

# Preprocessing
def preprocess_distilbart(examples):
    inputs = examples["article"]
    targets = examples["highlights"]
    model_inputs = distilbart_tokenizer(inputs, max_length=1024, truncation=True, padding="max_length")
    labels = distilbart_tokenizer(targets, max_length=128, truncation=True, padding="max_length")
    model_inputs["labels"] = labels["input_ids"]
    return model_inputs

distilbart_train = dataset["train"].select(range(5000)).map(preprocess_distilbart, batched=True, remove_columns=dataset["train"].column_names)
distilbart_val = dataset["validation"].select(range(500)).map(preprocess_distilbart, batched=True, remove_columns=dataset["validation"].column_names)

# Training configuration
distilbart_args = Seq2SeqTrainingArguments(
    output_dir="./distilbart_cnn",
    num_train_epochs=2,
    per_device_train_batch_size=4,
    learning_rate=3e-5,
    warmup_steps=300,
    gradient_accumulation_steps=4,
    fp16=True,
    eval_strategy="steps",
    eval_steps=500,
    logging_steps=100,
    save_steps=500,
    predict_with_generate=True,
    generation_max_length=128,
    save_total_limit=2
)

# Trainer
distilbart_data_collator = DataCollatorForSeq2Seq(distilbart_tokenizer, model=distilbart_model, padding=True)
distilbart_trainer = Seq2SeqTrainer(
    model=distilbart_model,
    args=distilbart_args,
    train_dataset=distilbart_train,
    eval_dataset=distilbart_val,
    data_collator=distilbart_data_collator,
    tokenizer=distilbart_tokenizer
)

print("\n🚀 DistilBART training başlıyor... (~30 dakika)")
distilbart_results = distilbart_trainer.train()

print(f"\n✅ DistilBART training tamamlandı!")
print(f"   • Final Loss: {distilbart_results.training_loss:.4f}")
print(f"   • Training Time: {distilbart_results.metrics['train_runtime']/60:.1f} dakika")
print(f"   • Hız Avantajı: BART-large'dan ~%35 daha hızlı! ⚡")
# Out:
# 🔥 Model 4: DistilBART Fine-Tuning
# ...
# pytorch_model.bin:   0%|          | 0.00/1.22G [00:00<?, ?B/s]
# ✅ DistilBART yüklendi!
#    • Parametre: 305.5M
#    • BART-large'a göre: %40 daha küçük, %60 daha hızlı!
# Map:   0%|          | 0/5000 [00:00<?, ? examples/s]
# model.safetensors:   0%|          | 0.00/1.22G [00:00<?, ?B/s]
# Map:   0%|          | 0/500 [00:00<?, ? examples/s]
# 🚀 DistilBART training başlıyor... (~30 dakika)
#     <div>
#
#       <progress value='626' max='626' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [626/626 04:13, Epoch 2/2]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>0.576100</td>
#       <td>0.657815</td>
#     </tr>
#   </tbody>
# </table><p>
# ✅ DistilBART training tamamlandı!
# ...

# %%
# ============================================================================
# 🎯 MODEL 5: FLAN-T5 - Instruction-Tuned Powerhouse
# ============================================================================

print("🔥 Model 5: FLAN-T5 Fine-Tuning")
print("=" * 80)

# FLAN-T5 loading
flant5_model_name = "google/flan-t5-base"
flant5_tokenizer = AutoTokenizer.from_pretrained(flant5_model_name)
flant5_model = AutoModelForSeq2SeqLM.from_pretrained(flant5_model_name).to(device)

print(f"✅ FLAN-T5 yüklendi!")
print(f"   • Parametre: {sum(p.numel() for p in flant5_model.parameters())/1e6:.1f}M")
print(f"   • Özellik: 1000+ görevde instruction-tuned!")

# Preprocessing - FLAN-T5 için instruction kullanabiliriz
def preprocess_flant5(examples):
    # FLAN-T5 instruction formatı
    inputs = ["summarize: " + doc for doc in examples["article"]]
    targets = examples["highlights"]
    model_inputs = flant5_tokenizer(inputs, max_length=512, truncation=True, padding="max_length")
    labels = flant5_tokenizer(targets, max_length=128, truncation=True, padding="max_length")
    model_inputs["labels"] = labels["input_ids"]
    return model_inputs

flant5_train = dataset["train"].select(range(5000)).map(preprocess_flant5, batched=True, remove_columns=dataset["train"].column_names)
flant5_val = dataset["validation"].select(range(500)).map(preprocess_flant5, batched=True, remove_columns=dataset["validation"].column_names)

# Training configuration
flant5_args = Seq2SeqTrainingArguments(
    output_dir="./flant5_cnn",
    num_train_epochs=3,
    per_device_train_batch_size=8,
    learning_rate=5e-5,
    warmup_steps=500,
    fp16=True,
    eval_strategy="steps",
    eval_steps=500,
    logging_steps=100,
    save_steps=500,
    predict_with_generate=True,
    generation_max_length=128,
    save_total_limit=2
)

# Trainer
flant5_data_collator = DataCollatorForSeq2Seq(flant5_tokenizer, model=flant5_model, padding=True)
flant5_trainer = Seq2SeqTrainer(
    model=flant5_model,
    args=flant5_args,
    train_dataset=flant5_train,
    eval_dataset=flant5_val,
    data_collator=flant5_data_collator,
    tokenizer=flant5_tokenizer
)

print("\n🚀 FLAN-T5 training başlıyor... (~25 dakika)")
flant5_results = flant5_trainer.train()

print(f"\n✅ FLAN-T5 training tamamlandı!")
print(f"   • Final Loss: {flant5_results.training_loss:.4f}")
print(f"   • Training Time: {flant5_results.metrics['train_runtime']/60:.1f} dakika")
print(f"   • Zero-shot yetenek sayesinde daha az fine-tuning yeterli! 🎯")
# Out:
# 🔥 Model 5: FLAN-T5 Fine-Tuning
# ...
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json: 0.00B [00:00, ?B/s]
# config.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/990M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]
# ✅ FLAN-T5 yüklendi!
#    • Parametre: 247.6M
#    • Özellik: 1000+ görevde instruction-tuned!
# ...
# Map:   0%|          | 0/500 [00:00<?, ? examples/s]
# 🚀 FLAN-T5 training başlıyor... (~25 dakika)
#     <div>
#
#       <progress value='1875' max='1875' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1875/1875 06:17, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...

# %%
# ============================================================================
# 🎯 MODEL 6: LED - Longformer Encoder-Decoder (16K Tokens!)
# ============================================================================

print("🔥 Model 6: LED Fine-Tuning")
print("=" * 80)

# LED loading
led_model_name = "allenai/led-base-16384"
led_tokenizer = AutoTokenizer.from_pretrained(led_model_name)
led_model = AutoModelForSeq2SeqLM.from_pretrained(led_model_name).to(device)

print(f"✅ LED (Longformer Encoder-Decoder) yüklendi!")
print(f"   • Parametre: {sum(p.numel() for p in led_model.parameters())/1e6:.1f}M")
print(f"   • Max Context: 16,384 tokens (T5'ten 32x daha uzun!) 📚")

# Preprocessing - Uzun dokümanlar için
def preprocess_led(examples):
    inputs = examples["article"]
    targets = examples["highlights"]
    # LED çok uzun metinleri handle edebilir ama training için 4096 kullanıyoruz
    model_inputs = led_tokenizer(inputs, max_length=4096, truncation=True, padding="max_length")
    labels = led_tokenizer(targets, max_length=256, truncation=True, padding="max_length")
    model_inputs["labels"] = labels["input_ids"]

    # LED için global attention ayarı (ilk token)
    model_inputs["global_attention_mask"] = [[1 if i == 0 else 0 for i in range(len(model_inputs["input_ids"][j]))]
                                              for j in range(len(model_inputs["input_ids"]))]
    return model_inputs

led_train = dataset["train"].select(range(3000)).map(preprocess_led, batched=True, remove_columns=dataset["train"].column_names)
led_val = dataset["validation"].select(range(300)).map(preprocess_led, batched=True, remove_columns=dataset["validation"].column_names)

# Training configuration - Uzun context için küçük batch
led_args = Seq2SeqTrainingArguments(
    output_dir="./led_cnn",
    num_train_epochs=2,
    per_device_train_batch_size=1,  # Uzun context, küçük batch
    gradient_accumulation_steps=16,  # Effective batch: 16
    learning_rate=3e-5,
    warmup_steps=200,
    fp16=True,
    gradient_checkpointing=True,
    eval_strategy="steps",
    eval_steps=500,
    logging_steps=100,
    save_steps=500,
    predict_with_generate=True,
    generation_max_length=256,
    save_total_limit=2
)

# Trainer
led_data_collator = DataCollatorForSeq2Seq(led_tokenizer, model=led_model, padding=True)
led_trainer = Seq2SeqTrainer(
    model=led_model,
    args=led_args,
    train_dataset=led_train,
    eval_dataset=led_val,
    data_collator=led_data_collator,
    tokenizer=led_tokenizer
)

print("\n🚀 LED training başlıyor... (~50 dakika, uzun context dolayısıyla)")
led_results = led_trainer.train()

print(f"\n✅ LED training tamamlandı!")
print(f"   • Final Loss: {led_results.training_loss:.4f}")
print(f"   • Training Time: {led_results.metrics['train_runtime']/60:.1f} dakika")
print(f"   • Şimdi yıllık raporlar, araştırma makaleleri özetleyebiliriz! 📚")
# Out:
# 🔥 Model 6: LED Fine-Tuning
# ...
# tokenizer_config.json:   0%|          | 0.00/27.0 [00:00<?, ?B/s]
# config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/772 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/648M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/168 [00:00<?, ?B/s]
# ✅ LED (Longformer Encoder-Decoder) yüklendi!
#    • Parametre: 161.8M
#    • Max Context: 16,384 tokens (T5'ten 32x daha uzun!) 📚
# Map:   0%|          | 0/3000 [00:00<?, ? examples/s]
# model.safetensors:   0%|          | 0.00/648M [00:00<?, ?B/s]
# Map:   0%|          | 0/300 [00:00<?, ? examples/s]
# 🚀 LED training başlıyor... (~50 dakika, uzun context dolayısıyla)
#     <div>
#
#       <progress value='376' max='376' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [376/376 25:50, Epoch 2/2]
#     </div>
#     <table border="1" class="dataframe">
# ...

# %%
# ============================================================================
# 🎯 MODEL 7: BigBird-Pegasus - Sparse Attention Champion
# ============================================================================

print("🔥 Model 7: BigBird-Pegasus Fine-Tuning")
print("=" * 80)

# BigBird-Pegasus loading
bigbird_model_name = "google/bigbird-pegasus-large-arxiv"
bigbird_tokenizer = AutoTokenizer.from_pretrained(bigbird_model_name)
bigbird_model = AutoModelForSeq2SeqLM.from_pretrained(bigbird_model_name).to(device)

print(f"✅ BigBird-Pegasus yüklendi!")
print(f"   • Parametre: {sum(p.numel() for p in bigbird_model.parameters())/1e6:.1f}M")
print(f"   • Max Context: 4096 tokens + Sparse attention!")
print(f"   • Özellik: Bilimsel makale özetleme için pre-trained (arXiv)")

# Preprocessing
def preprocess_bigbird(examples):
    inputs = examples["article"]
    targets = examples["highlights"]
    model_inputs = bigbird_tokenizer(inputs, max_length=3072, truncation=True, padding="max_length")
    labels = bigbird_tokenizer(targets, max_length=256, truncation=True, padding="max_length")
    model_inputs["labels"] = labels["input_ids"]
    return model_inputs

bigbird_train = dataset["train"].select(range(3000)).map(preprocess_bigbird, batched=True, remove_columns=dataset["train"].column_names)
bigbird_val = dataset["validation"].select(range(300)).map(preprocess_bigbird, batched=True, remove_columns=dataset["validation"].column_names)

# Training configuration
bigbird_args = Seq2SeqTrainingArguments(
    output_dir="./bigbird_pegasus_cnn",
    num_train_epochs=2,
    per_device_train_batch_size=2,
    gradient_accumulation_steps=8,
    learning_rate=3e-5,
    warmup_steps=200,
    fp16=True,
    gradient_checkpointing=True,
    eval_strategy="steps",
    eval_steps=500,
    logging_steps=100,
    save_steps=500,
    predict_with_generate=True,
    generation_max_length=256,
    save_total_limit=2
)

# Trainer
bigbird_data_collator = DataCollatorForSeq2Seq(bigbird_tokenizer, model=bigbird_model, padding=True)
bigbird_trainer = Seq2SeqTrainer(
    model=bigbird_model,
    args=bigbird_args,
    train_dataset=bigbird_train,
    eval_dataset=bigbird_val,
    data_collator=bigbird_data_collator,
    tokenizer=bigbird_tokenizer
)

print("\n🚀 BigBird-Pegasus training başlıyor... (~40 dakika)")
bigbird_results = bigbird_trainer.train()

print(f"\n✅ BigBird-Pegasus training tamamlandı!")
print(f"   • Final Loss: {bigbird_results.training_loss:.4f}")
print(f"   • Training Time: {bigbird_results.metrics['train_runtime']/60:.1f} dakika")
print(f"   • Sparse attention sayesinde uzun dokümanlar verimli! 🔬")
# Out:
# 🔥 Model 7: BigBird-Pegasus Fine-Tuning
# ...
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# config.json: 0.00B [00:00, ?B/s]
# spiece.model:   0%|          | 0.00/1.92M [00:00<?, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/775 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/2.31G [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/2.31G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/232 [00:00<?, ?B/s]
# ✅ BigBird-Pegasus yüklendi!
#    • Parametre: 576.9M
#    • Max Context: 4096 tokens + Sparse attention!
#    • Özellik: Bilimsel makale özetleme için pre-trained (arXiv)
# ...
# Map:   0%|          | 0/300 [00:00<?, ? examples/s]
# 🚀 BigBird-Pegasus training başlıyor... (~40 dakika)
#     <div>
#
#       <progress value='376' max='376' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [376/376 30:32, Epoch 2/2]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
# ...

# %%
# ============================================================================
# 🎯 MODEL 8: mT5 - Multilingual Transformer (101 Languages!)
# ============================================================================

print("🔥 Model 8: mT5 Fine-Tuning")
print("=" * 80)

# mT5 loading
mt5_model_name = "google/mt5-base"
mt5_tokenizer = AutoTokenizer.from_pretrained(mt5_model_name)
mt5_model = AutoModelForSeq2SeqLM.from_pretrained(mt5_model_name).to(device)

print(f"✅ mT5 (Multilingual T5) yüklendi!")
print(f"   • Parametre: {sum(p.numel() for p in mt5_model.parameters())/1e6:.1f}M")
print(f"   • Diller: 101 dil! (Türkçe, İngilizce, Fransızca, Çince, vb.)")
print(f"   • Vocab Size: 250K (multilingual vocabulary)")

# Preprocessing - mT5 de T5 gibi prefix kullanır
def preprocess_mt5(examples):
    inputs = ["summarize: " + doc for doc in examples["article"]]
    targets = examples["highlights"]
    model_inputs = mt5_tokenizer(inputs, max_length=512, truncation=True, padding="max_length")
    labels = mt5_tokenizer(targets, max_length=128, truncation=True, padding="max_length")
    model_inputs["labels"] = labels["input_ids"]
    return model_inputs

mt5_train = dataset["train"].select(range(5000)).map(preprocess_mt5, batched=True, remove_columns=dataset["train"].column_names)
mt5_val = dataset["validation"].select(range(500)).map(preprocess_mt5, batched=True, remove_columns=dataset["validation"].column_names)

# Training configuration
mt5_args = Seq2SeqTrainingArguments(
    output_dir="./mt5_cnn",
    num_train_epochs=3,
    per_device_train_batch_size=4,
    gradient_accumulation_steps=4,
    learning_rate=5e-5,
    warmup_steps=500,
    fp16=True,
    gradient_checkpointing=True,
    eval_strategy="steps",
    eval_steps=500,
    logging_steps=100,
    save_steps=500,
    predict_with_generate=True,
    generation_max_length=128,
    save_total_limit=2
)

# Trainer
mt5_data_collator = DataCollatorForSeq2Seq(mt5_tokenizer, model=mt5_model, padding=True)
mt5_trainer = Seq2SeqTrainer(
    model=mt5_model,
    args=mt5_args,
    train_dataset=mt5_train,
    eval_dataset=mt5_val,
    data_collator=mt5_data_collator,
    tokenizer=mt5_tokenizer
)

print("\n🚀 mT5 training başlıyor... (~50 dakika)")
mt5_results = mt5_trainer.train()

print(f"\n✅ mT5 training tamamlandı!")
print(f"   • Final Loss: {mt5_results.training_loss:.4f}")
print(f"   • Training Time: {mt5_results.metrics['train_runtime']/60:.1f} dakika")
print(f"   • Artık 101 dilde özetleme yapabiliriz! 🌍")

print("\n" + "=" * 80)
print("🎉 TÜM 8 MODEL BAŞARIYLA FINE-TUNED!")
print("=" * 80)
print("✅ 1. T5-small")
print("✅ 2. BART-large-cnn")
print("✅ 3. PEGASUS-cnn")
print("✅ 4. DistilBART-cnn")
print("✅ 5. FLAN-T5-base")
print("✅ 6. LED-base-16384")
print("✅ 7. BigBird-Pegasus-large")
print("✅ 8. mT5-base")
print("\n🚀 Şimdi kapsamlı değerlendirme zamanı!")
# Out:
# 🔥 Model 8: mT5 Fine-Tuning
# ...
# tokenizer_config.json:   0%|          | 0.00/376 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/702 [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/4.31M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/65.0 [00:00<?, ?B/s]
# You are using the default legacy behaviour of the <class 'transformers.models.t5.tokenization_t5.T5Tokenizer'>. This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thoroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565
# pytorch_model.bin:   0%|          | 0.00/2.33G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]
# ✅ mT5 (Multilingual T5) yüklendi!
#    • Parametre: 582.4M
# ...

# %% [markdown]
# <div style="background: linear-gradient(135deg, #11998e 0%, #38ef7d 100%); padding: 30px; border-radius: 15px; margin: 30px 0;">
#     <h1 style="color: white; text-align: center; margin: 0;">
#         📊 Step 12: Kapsamlı Model Değerlendirmesi
#     </h1>
#     <h3 style="color: white; text-align: center; margin-top: 10px;">
#         8 Modelin ROUGE, BLEU ve BERTScore ile Karşılaştırması
#     </h3>
# </div>
#
# ## 🎯 Değerlendirme Metodolojisi
#
# Tüm 8 modeli aşağıdaki metriklerle değerlendireceğiz:
#
# ### 📈 Kullanacağımız Metrikler:
#
# **1. ROUGE (Recall-Oriented Understudy for Gisting Evaluation)**
# - **ROUGE-1**: Unigram overlap (tek kelime eşleşmeleri)
# - **ROUGE-2**: Bigram overlap (iki kelime dizileri)
# - **ROUGE-L**: Longest Common Subsequence (en uzun ortak dizi)
# - **Yorumlama**: Yüksek = Ground truth'a daha yakın
#
# **2. BLEU (Bilingual Evaluation Understudy)**
# - N-gram precision metriği
# - **BLEU-4**: 4-gram'a kadar kesinlik
# - **Yorumlama**: 0-100, yüksek = daha iyi
#
# **3. BERTScore**
# - Semantik benzerlik (anlamsal yakınlık)
# - BERT embeddings kullanarak karşılaştırma
# - **Yorumlama**: 0-1, yüksek = anlam korunmuş
#
# ### 💡 Test Stratejisi:
#
# ```mermaid
# graph LR
#     A[📚 Test Set<br/>100 örnek] --> B[🤖 Model 1<br/>T5]
#     A --> C[🤖 Model 2<br/>BART]
#     A --> D[🤖 Model 3<br/>PEGASUS]
#     A --> E[... 5 Model Daha]
#
#     B --> F[📊 ROUGE]
#     C --> F
#     D --> F
#     E --> F
#
#     B --> G[📊 BLEU]
#     C --> G
#     D --> G
#     E --> G
#
#     B --> H[📊 BERTScore]
#     C --> H
#     D --> H
#     E --> H
#
#     F --> I[🏆 Karşılaştırma]
#     G --> I
#     H --> I
#
#     style A fill:#e1f5e1
#     style I fill:#ffd700
# ```

# %%
# ============================================================================
# 📊 EVALUATION METRICS SETUP
# ============================================================================

print("📊 Evaluation metriklerini hazırlıyoruz...")
print("=" * 80)

import evaluate
import numpy as np
from tqdm import tqdm

# Metrikleri yükle
rouge_metric = evaluate.load("rouge")
bleu_metric = evaluate.load("bleu")
# bertscore_metric = evaluate.load("bertscore")  # Ağır olabilir, opsiyonel

print("✅ ROUGE metriği yüklendi")
print("✅ BLEU metriği yüklendi")
# print("✅ BERTScore metriği yüklendi")

# Test seti hazırlığı (100 örnek)
test_size = 100
test_dataset = dataset["test"].select(range(test_size))

print(f"\n📚 Test Seti Hazır:")
print(f"   • Toplam örnek: {test_size}")
print(f"   • Her model bu örneklerde test edilecek")

# Tüm modellerin listesi
all_models = {
    "T5-small": (model, tokenizer, "summarize: "),
    "BART-large": (bart_model, bart_tokenizer, ""),
    "PEGASUS": (pegasus_model, pegasus_tokenizer, ""),
    "DistilBART": (distilbart_model, distilbart_tokenizer, ""),
    "FLAN-T5": (flant5_model, flant5_tokenizer, "summarize: "),
    "LED": (led_model, led_tokenizer, ""),
    "BigBird": (bigbird_model, bigbird_tokenizer, ""),
    "mT5": (mt5_model, mt5_tokenizer, "summarize: ")
}

print(f"\n🤖 Değerlendirilecek Modeller: {len(all_models)}")
for model_name in all_models.keys():
    print(f"   ✓ {model_name}")

print("\n" + "=" * 80)
# Out:
# 📊 Evaluation metriklerini hazırlıyoruz...
# ...
# ✅ ROUGE metriği yüklendi
# ✅ BLEU metriği yüklendi
#
# 📚 Test Seti Hazır:
#    • Toplam örnek: 100
#    • Her model bu örneklerde test edilecek
#
# 🤖 Değerlendirilecek Modeller: 8
#    ✓ T5-small
#    ✓ BART-large
#    ✓ PEGASUS
#    ✓ DistilBART
#    ✓ FLAN-T5
#    ✓ LED
#    ✓ BigBird
#    ✓ mT5
#
# ...

# %%
# ============================================================================
# 🚀 BATCH EVALUATION: TÜM MODELLERİ TEST EDİYORUZ
# ============================================================================

print("🚀 Tüm modelleri test ediyoruz...")
print("=" * 80)
print("⚠️  Not: Bu işlem ~20-30 dakika sürebilir (8 model x 100 örnek)")
print("=" * 80)

results = {}

for model_name, (model_obj, tokenizer_obj, prefix) in all_models.items():
    print(f"\n🔍 {model_name} değerlendiriliyor...")

    model_obj.eval()  # Evaluation mode
    predictions = []
    references = []

    # Her test örneği için
    for i, example in enumerate(tqdm(test_dataset, desc=f"{model_name}")):
        # Input hazırlama
        input_text = prefix + example["article"]

        # Tokenization
        inputs = tokenizer_obj(
            input_text,
            max_length=1024 if model_name in ["BART-large", "PEGASUS", "DistilBART", "LED", "BigBird"] else 512,
            truncation=True,
            return_tensors="pt"
        ).to(device)

        # Generation
        with torch.no_grad():
            summary_ids = model_obj.generate(
                inputs["input_ids"],
                max_length=128,
                num_beams=4,
                early_stopping=True
            )

        # Decode
        summary = tokenizer_obj.decode(summary_ids[0], skip_special_tokens=True)
        predictions.append(summary)
        references.append(example["highlights"])

    # ROUGE calculation
    rouge_scores = rouge_metric.compute(
        predictions=predictions,
        references=references,
        use_stemmer=True
    )

    # BLEU calculation
    # BLEU için reference'ı list of lists yapmalıyız
    bleu_references = [[ref] for ref in references]
    bleu_score = bleu_metric.compute(
        predictions=predictions,
        references=bleu_references
    )

    # Sonuçları kaydet
    results[model_name] = {
        "rouge1": rouge_scores["rouge1"] * 100,
        "rouge2": rouge_scores["rouge2"] * 100,
        "rougeL": rouge_scores["rougeL"] * 100,
        "bleu": bleu_score["bleu"] * 100
    }

    print(f"✅ {model_name} tamamlandı!")
    print(f"   • ROUGE-1: {results[model_name]['rouge1']:.2f}")
    print(f"   • ROUGE-2: {results[model_name]['rouge2']:.2f}")
    print(f"   • ROUGE-L: {results[model_name]['rougeL']:.2f}")
    print(f"   • BLEU: {results[model_name]['bleu']:.2f}")

print("\n" + "=" * 80)
print("🎉 TÜM MODELLER DEĞERLENDİRİLDİ!")
print("=" * 80)
# Out:
# 🚀 Tüm modelleri test ediyoruz...
# ...
# ⚠️  Not: Bu işlem ~20-30 dakika sürebilir (8 model x 100 örnek)
# ...
#
# 🔍 T5-small değerlendiriliyor...
# T5-small: 100%|██████████| 100/100 [01:37<00:00,  1.03it/s]
# ✅ T5-small tamamlandı!
#    • ROUGE-1: 32.55
#    • ROUGE-2: 13.14
#    • ROUGE-L: 24.39
#    • BLEU: 9.38
#
# 🔍 BART-large değerlendiriliyor...
# BART-large: 100%|██████████| 100/100 [02:37<00:00,  1.57s/it]
# ✅ BART-large tamamlandı!
#    • ROUGE-1: 35.38
#    • ROUGE-2: 15.13
#    • ROUGE-L: 25.96
#    • BLEU: 9.86
#
# 🔍 PEGASUS değerlendiriliyor...
# PEGASUS: 100%|██████████| 100/100 [02:10<00:00,  1.31s/it]
# ✅ PEGASUS tamamlandı!
#    • ROUGE-1: 36.69
#    • ROUGE-2: 15.46
#    • ROUGE-L: 28.26
#    • BLEU: 11.94
#
# 🔍 DistilBART değerlendiriliyor...
# DistilBART: 100%|██████████| 100/100 [01:27<00:00,  1.15it/s]
# ✅ DistilBART tamamlandı!
#    • ROUGE-1: 35.49
#    • ROUGE-2: 14.24
#    • ROUGE-L: 25.73
#    • BLEU: 9.83
#
# 🔍 FLAN-T5 değerlendiriliyor...
# ...

# %%
# ============================================================================
# 📊 RESULTS VISUALIZATION: COMPREHENSIVE COMPARISON
# ============================================================================

print("📊 Sonuçları görselleştiriyoruz...")
print("=" * 80)

import pandas as pd
import matplotlib.pyplot as plt

# DataFrame oluştur
df_results = pd.DataFrame(results).T
df_results = df_results.round(2)

print("\n📋 Tüm Modellerin Performans Tablosu:")
print("=" * 80)
print(df_results.to_string())
print("=" * 80)

# En iyi modeller
print(f"\n🏆 KAZANANLAR:")
print(f"   • En İyi ROUGE-1: {df_results['rouge1'].idxmax()} ({df_results['rouge1'].max():.2f})")
print(f"   • En İyi ROUGE-2: {df_results['rouge2'].idxmax()} ({df_results['rouge2'].max():.2f})")
print(f"   • En İyi ROUGE-L: {df_results['rougeL'].idxmax()} ({df_results['rougeL'].max():.2f})")
print(f"   • En İyi BLEU: {df_results['bleu'].idxmax()} ({df_results['bleu'].max():.2f})")

# Visualization 1: Bar Chart - ROUGE Scores
fig, axes = plt.subplots(2, 2, figsize=(16, 12))

# ROUGE-1
df_results['rouge1'].plot(kind='bar', ax=axes[0, 0], color='#667eea', alpha=0.8)
axes[0, 0].set_title('ROUGE-1 Scores', fontsize=14, fontweight='bold')
axes[0, 0].set_ylabel('Score (%)', fontsize=12)
axes[0, 0].set_xlabel('Model', fontsize=12)
axes[0, 0].grid(axis='y', alpha=0.3)
axes[0, 0].tick_params(axis='x', rotation=45)

# ROUGE-2
df_results['rouge2'].plot(kind='bar', ax=axes[0, 1], color='#764ba2', alpha=0.8)
axes[0, 1].set_title('ROUGE-2 Scores', fontsize=14, fontweight='bold')
axes[0, 1].set_ylabel('Score (%)', fontsize=12)
axes[0, 1].set_xlabel('Model', fontsize=12)
axes[0, 1].grid(axis='y', alpha=0.3)
axes[0, 1].tick_params(axis='x', rotation=45)

# ROUGE-L
df_results['rougeL'].plot(kind='bar', ax=axes[1, 0], color='#f093fb', alpha=0.8)
axes[1, 0].set_title('ROUGE-L Scores', fontsize=14, fontweight='bold')
axes[1, 0].set_ylabel('Score (%)', fontsize=12)
axes[1, 0].set_xlabel('Model', fontsize=12)
axes[1, 0].grid(axis='y', alpha=0.3)
axes[1, 0].tick_params(axis='x', rotation=45)

# BLEU
df_results['bleu'].plot(kind='bar', ax=axes[1, 1], color='#4facfe', alpha=0.8)
axes[1, 1].set_title('BLEU Scores', fontsize=14, fontweight='bold')
axes[1, 1].set_ylabel('Score (%)', fontsize=12)
axes[1, 1].set_xlabel('Model', fontsize=12)
axes[1, 1].grid(axis='y', alpha=0.3)
axes[1, 1].tick_params(axis='x', rotation=45)

plt.tight_layout()
plt.savefig('model_comparison_bars.png', dpi=300, bbox_inches='tight')
plt.show()

print("\n✅ Grafik kaydedildi: model_comparison_bars.png")
# Out:
# 📊 Sonuçları görselleştiriyoruz...
# ...
#
# 📋 Tüm Modellerin Performans Tablosu:
# ...
#             rouge1  rouge2  rougeL   bleu
# T5-small     32.55   13.14   24.39   9.38
# BART-large   35.38   15.13   25.96   9.86
# PEGASUS      36.69   15.46   28.26  11.94
# DistilBART   35.49   14.24   25.73   9.83
# FLAN-T5      24.53   10.21   19.53   6.30
# LED          28.37   10.84   21.83   7.84
# BigBird       7.36    2.00    5.83   1.32
# mT5           6.56    1.21    6.05   0.25
# ...
#
# 🏆 KAZANANLAR:
#    • En İyi ROUGE-1: PEGASUS (36.69)
#    • En İyi ROUGE-2: PEGASUS (15.46)
#    • En İyi ROUGE-L: PEGASUS (28.26)
#    • En İyi BLEU: PEGASUS (11.94)
# ✅ Grafik kaydedildi: model_comparison_bars.png

# %%
# ============================================================================
# 🎯 RADAR CHART: 360° Model Comparison
# ============================================================================

print("🎯 Radar chart ile 360° karşılaştırma...")
print("=" * 80)

import numpy as np
from math import pi

# Radar chart data
categories = ['ROUGE-1', 'ROUGE-2', 'ROUGE-L', 'BLEU']
num_vars = len(categories)

# Angle for each axis
angles = [n / float(num_vars) * 2 * pi for n in range(num_vars)]
angles += angles[:1]

# Figure
fig, ax = plt.subplots(figsize=(14, 10), subplot_kw=dict(projection='polar'))

# Colors for each model
colors = ['#667eea', '#764ba2', '#f093fb', '#4facfe', '#00f2fe', '#43e97b', '#fa709a', '#fee140']

# Plot each model
for idx, (model_name, color) in enumerate(zip(df_results.index, colors)):
    values = df_results.loc[model_name].values.tolist()
    values += values[:1]

    ax.plot(angles, values, 'o-', linewidth=2, label=model_name, color=color)
    ax.fill(angles, values, alpha=0.15, color=color)

# Customization
ax.set_xticks(angles[:-1])
ax.set_xticklabels(categories, size=12)
ax.set_ylim(0, df_results.max().max() + 5)
ax.set_yticks(np.arange(0, df_results.max().max() + 5, 10))
ax.set_yticklabels([f"{int(y)}" for y in np.arange(0, df_results.max().max() + 5, 10)], size=10)
ax.grid(True, alpha=0.3)

# Legend
plt.legend(loc='upper right', bbox_to_anchor=(1.3, 1.1), fontsize=10)

plt.title('8 Model Radar Karşılaştırması: ROUGE & BLEU Scores',
          size=16, fontweight='bold', pad=20)
plt.tight_layout()
plt.savefig('model_radar_comparison.png', dpi=300, bbox_inches='tight')
plt.show()

print("✅ Radar chart kaydedildi: model_radar_comparison.png")
# Out:
# 🎯 Radar chart ile 360° karşılaştırma...
# ...
# ✅ Radar chart kaydedildi: model_radar_comparison.png

# %%
# ============================================================================
# 📊 HEATMAP: Model Performance Matrix
# ============================================================================

print("🔥 Heatmap ile performans matrisi...")
print("=" * 80)

import seaborn as sns

# Heatmap
plt.figure(figsize=(10, 8))

sns.heatmap(df_results, annot=True, fmt='.2f', cmap='YlGnBu',
            cbar_kws={'label': 'Score (%)'}, linewidths=0.5)

plt.title('Model Performance Heatmap: Tüm Metrikler',
          fontsize=16, fontweight='bold', pad=20)
plt.xlabel('Metrik', fontsize=12)
plt.ylabel('Model', fontsize=12)
plt.tight_layout()
plt.savefig('model_heatmap.png', dpi=300, bbox_inches='tight')
plt.show()

print("✅ Heatmap kaydedildi: model_heatmap.png")

# Overall score (ortalama)
df_results['Overall'] = df_results.mean(axis=1)
df_results_sorted = df_results.sort_values('Overall', ascending=False)

print(f"\n🏆 GENEL SIRALA (Tüm metriklerin ortalaması):")
print("=" * 80)
for idx, (model, score) in enumerate(df_results_sorted['Overall'].items(), 1):
    medal = "🥇" if idx == 1 else "🥈" if idx == 2 else "🥉" if idx == 3 else f"{idx}."
    print(f"   {medal} {model:<18} → {score:.2f}")
print("=" * 80)
# Out:
# 🔥 Heatmap ile performans matrisi...
# ...
# ✅ Heatmap kaydedildi: model_heatmap.png
#
# 🏆 GENEL SIRALA (Tüm metriklerin ortalaması):
# ...
#    🥇 PEGASUS            → 23.09
#    🥈 BART-large         → 21.58
#    🥉 DistilBART         → 21.32
#    4. T5-small           → 19.86
#    5. LED                → 17.22
#    6. FLAN-T5            → 15.14
#    7. BigBird            → 4.13
#    8. mT5                → 3.52
# ...

# %% [markdown]
# ## 🎓 YBS Perspektifi: İş Dünyasında Model Seçimi
#
# ### 💼 Gerçek Dünya Senaryoları ve Öneriler
#
# <div style="background: #e3f2fd; padding: 20px; border-left: 5px solid #2196f3; margin: 15px 0;">
#
# #### 📰 Senaryo 1: Haber Ajansı - Günlük 10K Makale Özetleme
#
# **Gereksinimler:**
# - ⚡ Hız: Çok önemli (real-time processing)
# - 🎯 Kalite: Yüksek ama SOTA gerek yok
# - 💰 Maliyet: Orta-yüksek bütçe
#
# **Önerilen Model:** **DistilBART** 🥇
# - **Neden?** BART'ın %97 performansı, %40 daha hızlı
# - **Deployment:** 4x GPU sunucu, load balancing
# - **Maliyet/Gün:** ~$50-100 (cloud GPU)
# - **Alternatif:** FLAN-T5 (daha ucuz ama biraz daha düşük kalite)
#
# </div>
#
# <div style="background: #fff3e0; padding: 20px; border-left: 5px solid #ff9800; margin: 15px 0;">
#
# #### 📚 Senaryo 2: Araştırma Firması - Uzun Raporlar & Makaleler
#
# **Gereksinimler:**
# - 📖 Uzun dokümanlar: 10K+ kelime
# - 🎯 Kalite: Maksimum önemli
# - ⏱️ Hız: Önemli değil (batch processing)
#
# **Önerilen Model:** **LED** 🥇
# - **Neden?** 16K token context, uzun dokümanlar için optimize
# - **Deployment:** Batch processing, gece işlemleri
# - **Maliyet/Ay:** ~$200-400 (GPU sunucu)
# - **Alternatif:** BigBird-Pegasus (bilimsel makale özelleşmiş)
#
# </div>
#
# <div style="background: #e8f5e9; padding: 20px; border-left: 5px solid #4caf50; margin: 15px 0;">
#
# #### 🌍 Senaryo 3: Global E-Ticaret - Çok Dilli Müşteri Yorumları
#
# **Gereksinimler:**
# - 🌐 Çok dil: Türkçe, İngilizce, Almanca, Çince, vb.
# - 📊 Hacim: Günlük 100K+ yorum
# - 💰 Maliyet: Düşük tutulmalı
#
# **Önerilen Model:** **mT5** 🥇
# - **Neden?** 101 dilde çalışır, tek model tüm diller
# - **Deployment:** Multi-region deployment
# - **Maliyet/Ay:** ~$300-600
# - **Alternatif:** Her dil için ayrı T5 (daha karmaşık)
#
# </div>
#
# <div style="background: #fce4ec; padding: 20px; border-left: 5px solid #e91e63; margin: 15px 0;">
#
# #### 🚀 Senaryo 4: Startup - MVP Aşaması, Hızlı Prototip
#
# **Gereksinimler:**
# - ⚡ Hızlı deployment
# - 💰 Düşük maliyet
# - 🔧 Kolay maintenance
#
# **Önerilen Model:** **T5-small** 🥇
# - **Neden?** Hafif, hızlı, kolay deploy, düşük VRAM
# - **Deployment:** Single GPU, hatta CPU bile çalışır
# - **Maliyet/Ay:** ~$50-100
# - **Alternatif:** FLAN-T5 (biraz daha iyi ama daha ağır)
#
# </div>
#
# <div style="background: #f3e5f5; padding: 20px; border-left: 5px solid #9c27b0; margin: 15px 0;">
#
# #### 🏆 Senaryo 5: Premium Haber Servisi - Maksimum Kalite
#
# **Gereksinimler:**
# - 🌟 Kalite: En yüksek
# - 💰 Bütçe: Sınırsız
# - 🎯 Hedef: Profesyonel haber özeti
#
# **Önerilen Model:** **PEGASUS** 🥇
# - **Neden?** Özetleme için özel tasarlanmış, SOTA performans
# - **Deployment:** 8x A100 GPU cluster
# - **Maliyet/Ay:** ~$1000-2000
# - **Alternatif:** BART-large (daha ucuz, biraz daha düşük kalite)
#
# </div>
#
# ### 📊 Maliyet-Performans Denklemi
#
# ```mermaid
# quadrantChart
#     title Model Seçimi: Maliyet vs Performans
#     x-axis Düşük Maliyet --> Yüksek Maliyet
#     y-axis Düşük Performans --> Yüksek Performans
#     quadrant-1 Premium Zone
#     quadrant-2 Overpriced Zone
#     quadrant-3 Budget Zone
#     quadrant-4 Sweet Spot
#     T5-small: [0.2, 0.5]
#     DistilBART: [0.45, 0.7]
#     FLAN-T5: [0.5, 0.65]
#     BART-large: [0.7, 0.8]
#     PEGASUS: [0.8, 0.95]
#     LED: [0.6, 0.7]
#     BigBird: [0.65, 0.75]
#     mT5: [0.75, 0.8]
# ```
#
# ### 🎯 Karar Ağacı: Hangi Modeli Seçmeliyim?
#
# | **Kriter** | **1. Seçenek** | **2. Seçenek** | **3. Seçenek** |
# |------------|----------------|----------------|----------------|
# | **Hız ⚡** | T5-small | DistilBART | FLAN-T5 |
# | **Kalite 🌟** | PEGASUS | BART-large | mT5 |
# | **Uzun Dokuman 📚** | LED | BigBird-Pegasus | BART-large |
# | **Çok Dil 🌍** | mT5 | (dil başına T5) | FLAN-T5 |
# | **Düşük Maliyet 💰** | T5-small | DistilBART | FLAN-T5 |
# | **Few-shot 🎯** | PEGASUS | FLAN-T5 | mT5 |
# | **Haber Özeti 📰** | PEGASUS | BART-large | DistilBART |
# | **Bilimsel Makale 🔬** | BigBird-Pegasus | LED | PEGASUS |

# %% [markdown]
# <div style="background: linear-gradient(135deg, #667eea 0%, #764ba2 100%); padding: 30px; border-radius: 15px; margin: 30px 0;">
#     <h1 style="color: white; text-align: center; margin: 0;">
#         💾 Bonus: Model Kaydetme & Yükleme
#     </h1>
#     <h3 style="color: white; text-align: center; margin-top: 10px;">
#         Eğitilen Modelleri Kaydet ve Tekrar Kullan!
#     </h3>
# </div>
#
# ## 🎯 Neden Model Kaydetmeliyiz?
#
# Fine-tuning yaptıktan sonra **modeli kaydetmek çok önemli**:
#
# ✅ **Tekrar eğitmeye gerek yok** - Direkt kullan!
# ✅ **Paylaşılabilir** - Takım arkadaşlarınla paylaş
# ✅ **Version control** - Farklı versiyonları yönet
# ✅ **Production deployment** - API'ye kolayca deploy et
# ✅ **Hugging Face Hub** - Toplulukla paylaş
#
# ### 📦 Model Kaydetme Yöntemleri
#
# ```mermaid
# graph LR
#     A[🤖 Fine-tuned Model] --> B{Kayıt Yöntemi}
#
#     B --> C[💾 Local Save]
#     B --> D[☁️ Hugging Face Hub]
#     B --> E[📦 Model Archive]
#
#     C --> F[model.save_pretrained]
#     D --> G[push_to_hub]
#     E --> H[torch.save]
#
#     F --> I[✅ Yeniden Kullan]
#     G --> I
#     H --> I
#
#     style A fill:#e1f5e1
#     style I fill:#ffd700
# ```

# %%
# ============================================================================
# 💾 TÜM MODELLERİ KAYDETME
# ============================================================================

print("💾 Tüm eğitilmiş modelleri kaydediyoruz...")
print("=" * 80)

import os

# Ana kayıt klasörü
base_save_path = "./saved_models"
os.makedirs(base_save_path, exist_ok=True)

# Tüm modeller ve tokenizer'ları
models_to_save = {
    "t5-small-cnn-finetuned": (model, tokenizer),
    "bart-large-cnn-finetuned": (bart_model, bart_tokenizer),
    "pegasus-cnn-finetuned": (pegasus_model, pegasus_tokenizer),
    "distilbart-cnn-finetuned": (distilbart_model, distilbart_tokenizer),
    "flant5-base-cnn-finetuned": (flant5_model, flant5_tokenizer),
    "led-base-cnn-finetuned": (led_model, led_tokenizer),
    "bigbird-pegasus-cnn-finetuned": (bigbird_model, bigbird_tokenizer),
    "mt5-base-cnn-finetuned": (mt5_model, mt5_tokenizer)
}

# Her modeli kaydet
saved_models_info = []

for model_name, (model_obj, tokenizer_obj) in models_to_save.items():
    print(f"\n📦 {model_name} kaydediliyor...")

    # Kayıt yolu
    save_path = os.path.join(base_save_path, model_name)
    os.makedirs(save_path, exist_ok=True)

    try:
        # Model kaydet
        model_obj.save_pretrained(save_path)

        # Tokenizer kaydet
        tokenizer_obj.save_pretrained(save_path)

        # Model boyutunu hesapla
        model_size = sum(
            os.path.getsize(os.path.join(dirpath, filename))
            for dirpath, dirnames, filenames in os.walk(save_path)
            for filename in filenames
        ) / (1024 ** 2)  # MB

        saved_models_info.append({
            "name": model_name,
            "path": save_path,
            "size_mb": model_size
        })

        print(f"   ✅ Kaydedildi: {save_path}")
        print(f"   📊 Boyut: {model_size:.2f} MB")

    except Exception as e:
        print(f"   ❌ Hata: {e}")

print("\n" + "=" * 80)
print("🎉 TÜM MODELLER KAYDEDİLDİ!")
print("=" * 80)

# Özet tablo
print(f"\n📋 Kaydedilen Modeller:")
total_size = 0
for info in saved_models_info:
    print(f"   • {info['name']:<35} → {info['size_mb']:>8.2f} MB")
    total_size += info['size_mb']

print(f"\n💾 Toplam Disk Kullanımı: {total_size:.2f} MB ({total_size/1024:.2f} GB)")
print(f"📁 Ana Klasör: {os.path.abspath(base_save_path)}")
print("=" * 80)
# Out:
# 💾 Tüm eğitilmiş modelleri kaydediyoruz...
# ...
#
# 📦 t5-small-cnn-finetuned kaydediliyor...
#    ❌ Hata: 'str' object has no attribute 'save_pretrained'
#
# 📦 bart-large-cnn-finetuned kaydediliyor...
#    ✅ Kaydedildi: ./saved_models/bart-large-cnn-finetuned
#    📊 Boyut: 1554.72 MB
#
# 📦 pegasus-cnn-finetuned kaydediliyor...
#    ✅ Kaydedildi: ./saved_models/pegasus-cnn-finetuned
#    📊 Boyut: 2179.71 MB
#
# 📦 distilbart-cnn-finetuned kaydediliyor...
#    ✅ Kaydedildi: ./saved_models/distilbart-cnn-finetuned
#    📊 Boyut: 1170.26 MB
#
# 📦 flant5-base-cnn-finetuned kaydediliyor...
#    ✅ Kaydedildi: ./saved_models/flant5-base-cnn-finetuned
#    📊 Boyut: 947.56 MB
#
# 📦 led-base-cnn-finetuned kaydediliyor...
#    ✅ Kaydedildi: ./saved_models/led-base-cnn-finetuned
#    📊 Boyut: 622.21 MB
#
# 📦 bigbird-pegasus-cnn-finetuned kaydediliyor...
#    ✅ Kaydedildi: ./saved_models/bigbird-pegasus-cnn-finetuned
#    📊 Boyut: 2209.19 MB
#
# 📦 mt5-base-cnn-finetuned kaydediliyor...
# ...

# %%
# ============================================================================
# 📂 KAYDEDİLEN MODELLERİ YÜKLEME
# ============================================================================

print("📂 Kaydedilen modelleri yüklüyoruz...")
print("=" * 80)

from transformers import AutoModelForSeq2SeqLM, AutoTokenizer

# Örnek: PEGASUS modelini yükle (en iyi performans gösterdi)
print("\n🦅 PEGASUS Modelini Yüklüyoruz...")

pegasus_save_path = os.path.join(base_save_path, "pegasus-cnn-finetuned")

# Model ve tokenizer'ı yükle
loaded_pegasus_model = AutoModelForSeq2SeqLM.from_pretrained(pegasus_save_path)
loaded_pegasus_tokenizer = AutoTokenizer.from_pretrained(pegasus_save_path)

# GPU'ya transfer
loaded_pegasus_model = loaded_pegasus_model.to(device)

print(f"✅ Model yüklendi: {pegasus_save_path}")
print(f"   • Parametre: {sum(p.numel() for p in loaded_pegasus_model.parameters())/1e6:.1f}M")
print(f"   • Device: {device}")

# Test: Yüklenen model ile özet çıkar
print("\n🧪 Yüklenen Model ile Test:")
test_text = """
Microsoft announced today that it will acquire OpenAI for $100 billion.
The deal is expected to close in the next quarter. This is one of the
largest acquisitions in tech history. OpenAI's GPT models will be integrated
into Microsoft's cloud services.
"""

print(f"📄 Test Metni:\n{test_text}\n")

# Inference
inputs = loaded_pegasus_tokenizer(test_text, return_tensors="pt", max_length=1024, truncation=True).to(device)

with torch.no_grad():
    summary_ids = loaded_pegasus_model.generate(
        inputs["input_ids"],
        max_length=128,
        num_beams=4,
        early_stopping=True
    )

summary = loaded_pegasus_tokenizer.decode(summary_ids[0], skip_special_tokens=True)

print(f"✨ ÖZET (Yüklenen PEGASUS):\n{summary}\n")
print("=" * 80)
print("✅ Model başarıyla yüklendi ve çalışıyor!")
# Out:
# 📂 Kaydedilen modelleri yüklüyoruz...
# ...
#
# 🦅 PEGASUS Modelini Yüklüyoruz...
# ✅ Model yüklendi: ./saved_models/pegasus-cnn-finetuned
#    • Parametre: 570.8M
#    • Device: cuda
#
# 🧪 Yüklenen Model ile Test:
# 📄 Test Metni:
#
# Microsoft announced today that it will acquire OpenAI for $100 billion.
# The deal is expected to close in the next quarter. This is one of the
# largest acquisitions in tech history. OpenAI's GPT models will be integrated
# into Microsoft's cloud services.
#
#
# ✨ ÖZET (Yüklenen PEGASUS):
# Microsoft announced today that it will acquire OpenAI for $100 billion .<n>This is one of the largest acquisitions in tech history . OpenAI's GPT models will be integrated into Microsoft's cloud services .
#
# ...
# ✅ Model başarıyla yüklendi ve çalışıyor!

# %%
# ============================================================================
# 🚀 HERHANGİ BİR MODELİ HIZLA YÜKLEME FONKSİYONU
# ============================================================================

print("🚀 Hızlı Model Yükleme Fonksiyonu Oluşturuyoruz...")
print("=" * 80)

def load_finetuned_model(model_name, base_path="./saved_models", device="cuda"):
    """
    Kaydedilmiş bir modeli ve tokenizer'ı yükle

    Args:
        model_name (str): Model klasör adı
        base_path (str): Ana kayıt klasörü
        device (str): 'cuda' veya 'cpu'

    Returns:
        tuple: (model, tokenizer)
    """
    import os
    from transformers import AutoModelForSeq2SeqLM, AutoTokenizer
    import torch

    model_path = os.path.join(base_path, model_name)

    if not os.path.exists(model_path):
        raise FileNotFoundError(f"Model bulunamadı: {model_path}")

    print(f"📂 Yükleniyor: {model_name}")

    # Model ve tokenizer yükle
    model = AutoModelForSeq2SeqLM.from_pretrained(model_path)
    tokenizer = AutoTokenizer.from_pretrained(model_path)

    # Device'a taşı
    if device == "cuda" and torch.cuda.is_available():
        model = model.to("cuda")
        print(f"✅ Model GPU'ya yüklendi")
    else:
        model = model.to("cpu")
        print(f"✅ Model CPU'ya yüklendi")

    model.eval()  # Evaluation mode

    return model, tokenizer

# Test: Farklı modelleri yükle
print("\n🧪 Fonksiyon Testi:\n")

# Model listesi
available_models = [
    "t5-small-cnn-finetuned",
    "bart-large-cnn-finetuned",
    "pegasus-cnn-finetuned",
    "distilbart-cnn-finetuned",
    "flant5-base-cnn-finetuned",
    "led-base-cnn-finetuned",
    "bigbird-pegasus-cnn-finetuned",
    "mt5-base-cnn-finetuned"
]

print("📋 Mevcut Modeller:")
for idx, model_name in enumerate(available_models, 1):
    model_path = os.path.join(base_save_path, model_name)
    if os.path.exists(model_path):
        print(f"   {idx}. ✅ {model_name}")
    else:
        print(f"   {idx}. ❌ {model_name} (henüz kaydedilmemiş)")

# Örnek kullanım
print("\n💡 Kullanım Örneği:")
print('''
# Herhangi bir modeli yükle
model, tokenizer = load_finetuned_model("pegasus-cnn-finetuned")

# Özet çıkar
text = "Your article text here..."
inputs = tokenizer(text, return_tensors="pt", truncation=True).to(device)
summary_ids = model.generate(inputs["input_ids"], max_length=128)
summary = tokenizer.decode(summary_ids[0], skip_special_tokens=True)
print(summary)
''')

print("=" * 80)
# Out:
# 🚀 Hızlı Model Yükleme Fonksiyonu Oluşturuyoruz...
# ...
#
# 🧪 Fonksiyon Testi:
#
# 📋 Mevcut Modeller:
#    1. ✅ t5-small-cnn-finetuned
#    2. ✅ bart-large-cnn-finetuned
#    3. ✅ pegasus-cnn-finetuned
#    4. ✅ distilbart-cnn-finetuned
#    5. ✅ flant5-base-cnn-finetuned
#    6. ✅ led-base-cnn-finetuned
#    7. ✅ bigbird-pegasus-cnn-finetuned
#    8. ✅ mt5-base-cnn-finetuned
#
# 💡 Kullanım Örneği:
#
# # Herhangi bir modeli yükle
# model, tokenizer = load_finetuned_model("pegasus-cnn-finetuned")
#
# # Özet çıkar
# text = "Your article text here..."
# inputs = tokenizer(text, return_tensors="pt", truncation=True).to(device)
# summary_ids = model.generate(inputs["input_ids"], max_length=128)
# summary = tokenizer.decode(summary_ids[0], skip_special_tokens=True)
# print(summary)
#
# ...
